# %% [markdown]
# # Generate QTL Plot Lead SNP Information
# - **Author(s)** - Frank Grenn
# - **Date Started** - March 2020
# - **Quick Description:** Create a list of all the qtl plots we want to generate (one per gene and feature) and get proxy snps for each plot that doesn't have the risk snp available in the data
# - **Data:**

# %%
library(data.table)
library(dplyr)

# %%
#location of the plot data tsvs created previously
tsv_dir <- "$PATH1/qtl/tsv"

# %% [markdown]
# ## (1) Create a Dataframe Containing Information for all the Plots
#
# we want a plot for each gene, each feature (blood, brain) on each locus

# %%
evidence <- fread("$PATH1/genes_by_locus.csv")
meta5_data <- fread("$PATH1/GWAS_loci_overview.csv")
meta5_data <- meta5_data %>% select("Locus Number", "SNP", "CHR")
prog_data <- fread("$PATH1/ProgressionLoci.csv")
prog_data <- prog_data %>% select("Locus Number", "RSID", "CHR")
colnames(prog_data) <- c("Locus Number", "SNP","CHR")

# %%
#combine all the rsids to one df
variant_data <- rbind(meta5_data, prog_data)

# %%
#merge the evidence df with the variant df
#this is done to account for loci with multiple snps (ex: locus 1 has three risk variants, so we should try to create three plots for each gene on that locus)
plot_df <- merge(x=evidence, y=variant_data, by.x = "Locusnumber", by.y = "Locus Number", all.x = TRUE, allow.cartesian = TRUE)

em_blood <- plot_df
em_blood$'feature' <- 'blood'

em_brain <- plot_df
em_brain$'feature' <- 'brain'

# %%
plot_df <- rbind(em_blood,em_brain)
plot_df <- plot_df[with(plot_df, order(Locusnumber, Gene, SNP)),]

#temp values for the manually assigned lead snp (because some/many likely won't have data for the actual lead snp in the 'SNP' col of this dataframe)
plot_df$'forced_lead_variant' <- "NA"
plot_df$'forced_lead_variant_r2' <- 0
plot_df$'reason' <- "NA"

# %%
dim(plot_df)
head(plot_df)
tail(plot_df)
# Out:
# [1] 5788    8
#   Locusnumber Gene   SNP         CHR feature forced_lead_variant
# 1 1           ADAM15 rs114138760 1   blood   NA
# 2 1           ADAM15 rs114138760 1   brain   NA
# 3 1           ADAM15 rs35749011  1   blood   NA
# 4 1           ADAM15 rs35749011  1   brain   NA
# 5 1           ADAM15 rs76763715  1   blood   NA
# 6 1           ADAM15 rs76763715  1   brain   NA
#   forced_lead_variant_r2 reason
# 1 0                      NA
# 2 0                      NA
# 3 0                      NA
# 4 0                      NA
# 5 0                      NA
# 6 0                      NA
#   Locusnumber Gene    SNP      CHR feature forced_lead_variant
# 1 prog2       SLC44A1 rs382940 9   blood   NA
# 2 prog2       SLC44A1 rs382940 9   brain   NA
# 3 prog2       TAL2    rs382940 9   blood   NA
# 4 prog2       TAL2    rs382940 9   brain   NA
# 5 prog2       TMEM38B rs382940 9   blood   NA
# 6 prog2       TMEM38B rs382940 9   brain   NA
#   forced_lead_variant_r2 reason
# 1 0                      NA
# 2 0                      NA
# 3 0                      NA
# 4 0                      NA
# 5 0                      NA
# 6 0                      NA

# %% [markdown]
# ## (2) Filter the plot_df
#
# `plots_with_risk_snp` will contain the plots that contain the risk snp in the data. So we should have no issue plotting these
# `plots_with_no_data` will contain plots that have no snps in their tsvs to plot. So we won't plot these
# `plots_to_check` will contain plots that don't have the risk snp but do have data. So we will need to find a proxy snp for these to determine if we can plot them or not

# %%
plots_with_risk_snp <- data.frame()
plots_with_no_data <- data.frame()
plots_to_check <- data.frame()

# %% [markdown]
# do the filtering

# %%
for (rownum in 1:nrow(plot_df))
{

  print(rownum)
  

  
  row <- plot_df[rownum,]
  
  chr <- row$CHR
  snp <- row$SNP
  gene <- row$Gene
  feature <- row$feature
  

  print(paste0("checking", snp, " " , gene, " ", feature))
  ###now check the tsvs for data
  #get file path strings
  gwas_fn = paste0(tsv_dir, '/', gene, '_',feature,'_gwas.tsv')
  
  eqtl_fn = paste0(tsv_dir, '/', gene, '_',feature,'_eqtl.tsv')
  
  #check if the files actually exist
  if(file.exists(gwas_fn) && file.exists(eqtl_fn))
  {
    print("files exist")
    #read the tsv files
    g = read.table(gwas_fn, header = T)
    e = read.table(eqtl_fn, header = T)
    
    #if they both aren't empty 
    if(nrow(g)!=0 && nrow(e)!=0)
    {
      
      #merge them by rsid
      df = merge(g, e, by = 'rsid')
      print("df:")
      print(head(df))
      #check if the risk variant is already in the data. If so, then we are fine
      if(row$SNP %in% df$rsid)
      {
        print("we have the risk snp!!!")
        row$'forced_lead_variant' <- row$SNP
        row$'forced_lead_variant_r2' <- 1
        row$'reason' <- "has risk variant"
        plots_with_risk_snp<-rbind(plots_with_risk_snp,row)
        
      }
      #if we don't have the risk variant then put the row in the plot_to_check df to check later
      else
      {
        tmp <- row
        tmp$num_snps <- nrow(df)
        plots_to_check<-rbind(plots_to_check,tmp)
        
      }
      

      

    }
    #if they are empty then put in the no data df
    else
    {
      row$'reason' <- "no data for plot"
      plots_with_no_data<-rbind(plots_with_no_data,row)
    }
  }
  #if the files don't even exist then put in the no data df
  else
  {
      row$'reason' <- "no data for plot"
      plots_with_no_data<-rbind(plots_with_no_data,row)
  }
  plot_df[rownum,] <- row

}
# Out:
# [1] 1
# [1] "checkingrs114138760 ADAM15 blood"
# [1] "files exist"
# [1] "df:"
#         rsid    pval.x      pval.y
# 1  rs1001848 3.518e-07  3.2436e-66
# 2  rs1007170 1.006e-01  9.9655e-40
# 3  rs1010033 7.085e-01  2.5882e-07
# 4  rs1010225 1.703e-01  8.3265e-18
# 5 rs10157801 1.502e-05 3.0782e-163
# 6  rs1018730 7.476e-01  3.1109e-07
# [1] 2
# [1] "checkingrs114138760 ADAM15 brain"
# [1] "files exist"
# [1] "df:"
#         rsid    pval.x      pval.y
# 1  rs1001848 3.518e-07 1.59618e-03
# 2  rs1007170 1.006e-01 1.28004e-05
# 3  rs1046188 9.360e-01 4.89495e-06
# 4 rs10494301 1.956e-01 1.60838e-03
# 5  rs1052176 9.503e-01 7.53418e-06
# 6  rs1052177 9.618e-01 7.56439e-06
# [1] 3
# [1] "checkingrs35749011 ADAM15 blood"
# [1] "files exist"
# [1] "df:"
#         rsid    pval.x      pval.y
# 1  rs1001848 3.518e-07  3.2436e-66
# 2  rs1007170 1.006e-01  9.9655e-40
# 3  rs1010033 7.085e-01  2.5882e-07
# 4  rs1010225 1.703e-01  8.3265e-18
# 5 rs10157801 1.502e-05 3.0782e-163
# 6  rs1018730 7.476e-01  3.1109e-07
# [1] "we have the risk snp!!!"
# [1] 4
# [1] "checkingrs35749011 ADAM15 brain"
# [1] "files exist"
# [1] "df:"
#         rsid    pval.x      pval.y
# 1  rs1001848 3.518e-07 1.59618e-03
# 2  rs1007170 1.006e-01 1.28004e-05
# 3  rs1046188 9.360e-01 4.89495e-06
# 4 rs10494301 1.956e-01 1.60838e-03
# 5  rs1052176 9.503e-01 7.53418e-06
# 6  rs1052177 9.618e-01 7.56439e-06
# [1] 5
# [1] "checkingrs76763715 ADAM15 blood"
# [1] "files exist"
# [1] "df:"
#         rsid    pval.x      pval.y
# 1  rs1001848 3.518e-07  3.2436e-66
# 2  rs1007170 1.006e-01  9.9655e-40
# 3  rs1010033 7.085e-01  2.5882e-07
# 4  rs1010225 1.703e-01  8.3265e-18
# 5 rs10157801 1.502e-05 3.0782e-163
# 6  rs1018730 7.476e-01  3.1109e-07
# [1] 6
# [1] "checkingrs76763715 ADAM15 brain"
# [1] "files exist"
# [1] "df:"
#         rsid    pval.x      pval.y
# 1  rs1001848 3.518e-07 1.59618e-03
# 2  rs1007170 1.006e-01 1.28004e-05
# 3  rs1046188 9.360e-01 4.89495e-06
# 4 rs10494301 1.956e-01 1.60838e-03
# 5  rs1052176 9.503e-01 7.53418e-06
# 6  rs1052177 9.618e-01 7.56439e-06
# [1] 7
# [1] "checkingrs114138760 ADAR blood"
# [1] "files exist"
# [1] "df:"
#         rsid pval.x      pval.y
# 1  rs1027809 0.5281  5.0087e-08
# 2 rs10494301 0.1956  5.4987e-06
# 3 rs10737169 0.4789  2.3832e-08
# 4 rs10796927 0.9895  8.4614e-17
# 5 rs10796931 0.8823  1.2174e-63
# 6 rs10908419 0.4086 7.5911e-100
# [1] 8
# [1] "checkingrs114138760 ADAR brain"
# [1] "files exist"
# [1] "df:"
#         rsid  pval.x      pval.y
# 1 rs10047079 0.05237 2.07890e-02
# 2 rs10752605 0.01629 1.49366e-03
# 3 rs10796927 0.98950 3.08191e-02
# 4 rs10796931 0.88230 3.09645e-02
# 5 rs10908419 0.40860 3.72043e-11
# 6 rs10908421 0.91210 2.57552e-02
# [1] 9
# [1] "checkingrs35749011 ADAR blood"
# [1] "files exist"
# [1] "df:"
#         rsid pval.x      pval.y
# 1  rs1027809 0.5281  5.0087e-08
# 2 rs10494301 0.1956  5.4987e-06
# 3 rs10737169 0.4789  2.3832e-08
# 4 rs10796927 0.9895  8.4614e-17
# 5 rs10796931 0.8823  1.2174e-63
# 6 rs10908419 0.4086 7.5911e-100
# [1] 10
# [1] "checkingrs35749011 ADAR brain"
# [1] "files exist"
# [1] "df:"
#         rsid  pval.x      pval.y
# 1 rs10047079 0.05237 2.07890e-02
# 2 rs10752605 0.01629 1.49366e-03
# 3 rs10796927 0.98950 3.08191e-02
# 4 rs10796931 0.88230 3.09645e-02
# 5 rs10908419 0.40860 3.72043e-11
# 6 rs10908421 0.91210 2.57552e-02
# [1] 11
# [1] "checkingrs76763715 ADAR blood"
# [1] "files exist"
# [1] "df:"
#         rsid pval.x      pval.y
# 1  rs1027809 0.5281  5.0087e-08
# 2 rs10494301 0.1956  5.4987e-06
# 3 rs10737169 0.4789  2.3832e-08
# 4 rs10796927 0.9895  8.4614e-17
# 5 rs10796931 0.8823  1.2174e-63
# 6 rs10908419 0.4086 7.5911e-100
# [1] 12
# [1] "checkingrs76763715 ADAR brain"
# [1] "files exist"
# [1] "df:"
#         rsid  pval.x      pval.y
# 1 rs10047079 0.05237 2.07890e-02
# 2 rs10752605 0.01629 1.49366e-03
# 3 rs10796927 0.98950 3.08191e-02
# 4 rs10796931 0.88230 3.09645e-02
# 5 rs10908419 0.40860 3.72043e-11
# 6 rs10908421 0.91210 2.57552e-02
# [1] 13
# [1] "checkingrs114138760 AQP10 blood"
# [1] "files exist"
# [1] "df:"
#         rsid   pval.x     pval.y
# 1 rs10127484 0.213500 2.1156e-14
# 2 rs10158820 0.027050 1.5523e-13
# 3 rs10159236 0.793900 2.2256e-11
# 4 rs10218433 0.722600 4.8958e-19
# 5  rs1024274 0.767800 7.9496e-07
# 6  rs1044013 0.009971 7.4482e-21
# [1] 14
# [1] "checkingrs114138760 AQP10 brain"
# [1] 15
# [1] "checkingrs35749011 AQP10 blood"
# [1] "files exist"
# [1] "df:"
#         rsid   pval.x     pval.y
# 1 rs10127484 0.213500 2.1156e-14
# 2 rs10158820 0.027050 1.5523e-13
# 3 rs10159236 0.793900 2.2256e-11
# 4 rs10218433 0.722600 4.8958e-19
# 5  rs1024274 0.767800 7.9496e-07
# 6  rs1044013 0.009971 7.4482e-21
# [1] 16
# [1] "checkingrs35749011 AQP10 brain"
# [1] 17
# [1] "checkingrs76763715 AQP10 blood"
# [1] "files exist"
# [1] "df:"
#         rsid   pval.x     pval.y
# 1 rs10127484 0.213500 2.1156e-14
# 2 rs10158820 0.027050 1.5523e-13
# 3 rs10159236 0.793900 2.2256e-11
# 4 rs10218433 0.722600 4.8958e-19
# 5  rs1024274 0.767800 7.9496e-07
# 6  rs1044013 0.009971 7.4482e-21
# [1] 18
# [1] "checkingrs76763715 AQP10 brain"
# [1] 19
# [1] "checkingrs114138760 ARHGEF2 blood"
# [1] "files exist"
# [1] "df:"
#         rsid  pval.x     pval.y
# 1  rs1010033 0.70850 4.1787e-11
# 2  rs1018730 0.74760 3.7407e-11
# 3  rs1055184 0.99410 1.2980e-10
# 4 rs10796955 0.07241 1.3653e-06
# 5 rs10908483 0.02825 2.7697e-06
# 6  rs1094558 0.10820 8.0315e-07
# [1] 20
# [1] "checkingrs114138760 ARHGEF2 brain"
# [1] "files exist"
# [1] "df:"
#          rsid    pval.x    pval.y
# 1  rs10908514 6.412e-01 0.0131459
# 2 rs112064407 5.326e-01 0.0384325
# 3 rs112223391 9.259e-05 0.0295943
# 4  rs11264421 7.992e-01 0.0060240
# 5  rs11264480 6.483e-01 0.0304498
# 6  rs11264514 5.732e-01 0.0180602
# [1] 21
# [1] "checkingrs35749011 ARHGEF2 blood"
# [1] "files exist"
# [1] "df:"
#         rsid  pval.x     pval.y
# 1  rs1010033 0.70850 4.1787e-11
# 2  rs1018730 0.74760 3.7407e-11
# 3  rs1055184 0.99410 1.2980e-10
# 4 rs10796955 0.07241 1.3653e-06
# 5 rs10908483 0.02825 2.7697e-06
# 6  rs1094558 0.10820 8.0315e-07
# [1] 22
# [1] "checkingrs35749011 ARHGEF2 brain"
# [1] "files exist"
# [1] "df:"
#          rsid    pval.x    pval.y
# 1  rs10908514 6.412e-01 0.0131459
# 2 rs112064407 5.326e-01 0.0384325
# 3 rs112223391 9.259e-05 0.0295943
# 4  rs11264421 7.992e-01 0.0060240
# 5  rs11264480 6.483e-01 0.0304498
# 6  rs11264514 5.732e-01 0.0180602
# [1] 23
# [1] "checkingrs76763715 ARHGEF2 blood"
# [1] "files exist"
# [1] "df:"
#         rsid  pval.x     pval.y
# 1  rs1010033 0.70850 4.1787e-11
# 2  rs1018730 0.74760 3.7407e-11
# 3  rs1055184 0.99410 1.2980e-10
# 4 rs10796955 0.07241 1.3653e-06
# 5 rs10908483 0.02825 2.7697e-06
# 6  rs1094558 0.10820 8.0315e-07
# [1] 24
# [1] "checkingrs76763715 ARHGEF2 brain"
# [1] "files exist"
# [1] "df:"
#          rsid    pval.x    pval.y
# 1  rs10908514 6.412e-01 0.0131459
# 2 rs112064407 5.326e-01 0.0384325
# 3 rs112223391 9.259e-05 0.0295943
# 4  rs11264421 7.992e-01 0.0060240
# 5  rs11264480 6.483e-01 0.0304498
# 6  rs11264514 5.732e-01 0.0180602
# [1] 25
# [1] "checkingrs114138760 ASH1L blood"
# [1] "files exist"
# [1] 26
# [1] "checkingrs114138760 ASH1L brain"
# [1] "files exist"
# [1] "df:"
#          rsid pval.x     pval.y
# 1  rs10796932 0.9877 0.03541920
# 2  rs10908424 0.2343 0.01544470
# 3  rs10908468 0.7262 0.01067410
# 4  rs10908840 0.5890 0.00139774
# 5   rs1094559 0.0760 0.04349270
# 6 rs111587150 0.1824 0.02864800
# [1] 27
# [1] "checkingrs35749011 ASH1L blood"
# [1] "files exist"
# [1] 28
# [1] "checkingrs35749011 ASH1L brain"
# [1] "files exist"
# [1] "df:"
#          rsid pval.x     pval.y
# 1  rs10796932 0.9877 0.03541920
# 2  rs10908424 0.2343 0.01544470
# 3  rs10908468 0.7262 0.01067410
# 4  rs10908840 0.5890 0.00139774
# 5   rs1094559 0.0760 0.04349270
# 6 rs111587150 0.1824 0.02864800
# [1] 29
# [1] "checkingrs76763715 ASH1L blood"
# [1] "files exist"
# [1] 30
# [1] "checkingrs76763715 ASH1L brain"
# [1] "files exist"
# [1] "df:"
#          rsid pval.x     pval.y
# 1  rs10796932 0.9877 0.03541920
# 2  rs10908424 0.2343 0.01544470
# 3  rs10908468 0.7262 0.01067410
# 4  rs10908840 0.5890 0.00139774
# 5   rs1094559 0.0760 0.04349270
# 6 rs111587150 0.1824 0.02864800
# [1] 31
# [1] "checkingrs114138760 ASH1L-AS1 blood"
# [1] "files exist"
# [1] 32
# [1] "checkingrs114138760 ASH1L-AS1 brain"
# [1] "files exist"
# [1] "df:"
#         rsid  pval.x      pval.y
# 1  rs1007839 0.88760 0.013858700
# 2 rs10159180 0.05754 0.003210750
# 3 rs10494301 0.19560 0.046794100
# 4 rs10908506 0.07055 0.000806246
# 5 rs10908507 0.13710 0.005658100
# 6  rs1106235 0.96240 0.033339200
# [1] 33
# [1] "checkingrs35749011 ASH1L-AS1 blood"
# [1] "files exist"
# [1] 34
# [1] "checkingrs35749011 ASH1L-AS1 brain"
# [1] "files exist"
# [1] "df:"
#         rsid  pval.x      pval.y
# 1  rs1007839 0.88760 0.013858700
# 2 rs10159180 0.05754 0.003210750
# 3 rs10494301 0.19560 0.046794100
# 4 rs10908506 0.07055 0.000806246
# 5 rs10908507 0.13710 0.005658100
# 6  rs1106235 0.96240 0.033339200
# [1] 35
# [1] "checkingrs76763715 ASH1L-AS1 blood"
# [1] "files exist"
# [1] 36
# [1] "checkingrs76763715 ASH1L-AS1 brain"
# [1] "files exist"
# [1] "df:"
#         rsid  pval.x      pval.y
# 1  rs1007839 0.88760 0.013858700
# 2 rs10159180 0.05754 0.003210750
# 3 rs10494301 0.19560 0.046794100
# 4 rs10908506 0.07055 0.000806246
# 5 rs10908507 0.13710 0.005658100
# 6  rs1106235 0.96240 0.033339200
# [1] 37
# [1] "checkingrs114138760 ATP8B2 blood"
# [1] "files exist"
# [1] "df:"
#         rsid   pval.x     pval.y
# 1 rs10218433 0.722600 2.3416e-21
# 2  rs1043608 0.007233 1.7359e-05
# 3    rs10559 0.007317 1.8225e-05
# 4  rs1073907 0.773500 3.0677e-21
# 5 rs10752605 0.016290 4.7079e-06
# 6 rs10796968 0.007473 1.4209e-05
# [1] 38
# [1] "checkingrs114138760 ATP8B2 brain"
# [1] "files exist"
# [1] "df:"
#         rsid    pval.x    pval.y
# 1 rs10157443 5.397e-03 0.0420627
# 2  rs1046188 9.360e-01 0.0192844
# 3  rs1046379 5.619e-01 0.0324556
# 4  rs1076556 9.012e-01 0.0442044
# 5 rs10796938 3.829e-08 0.0439949
# 6 rs10796939 1.737e-05 0.0173974
# [1] 39
# [1] "checkingrs35749011 ATP8B2 blood"
# [1] "files exist"
# [1] "df:"
#         rsid   pval.x     pval.y
# 1 rs10218433 0.722600 2.3416e-21
# 2  rs1043608 0.007233 1.7359e-05
# 3    rs10559 0.007317 1.8225e-05
# 4  rs1073907 0.773500 3.0677e-21
# 5 rs10752605 0.016290 4.7079e-06
# 6 rs10796968 0.007473 1.4209e-05
# [1] 40
# [1] "checkingrs35749011 ATP8B2 brain"
# [1] "files exist"
# [1] "df:"
#         rsid    pval.x    pval.y
# 1 rs10157443 5.397e-03 0.0420627
# 2  rs1046188 9.360e-01 0.0192844
# 3  rs1046379 5.619e-01 0.0324556
# 4  rs1076556 9.012e-01 0.0442044
# 5 rs10796938 3.829e-08 0.0439949
# 6 rs10796939 1.737e-05 0.0173974
# [1] 41
# [1] "checkingrs76763715 ATP8B2 blood"
# [1] "files exist"
# [1] "df:"
#         rsid   pval.x     pval.y
# 1 rs10218433 0.722600 2.3416e-21
# 2  rs1043608 0.007233 1.7359e-05
# 3    rs10559 0.007317 1.8225e-05
# 4  rs1073907 0.773500 3.0677e-21
# 5 rs10752605 0.016290 4.7079e-06
# 6 rs10796968 0.007473 1.4209e-05
# [1] 42
# [1] "checkingrs76763715 ATP8B2 brain"
# [1] "files exist"
# [1] "df:"
#         rsid    pval.x    pval.y
# 1 rs10157443 5.397e-03 0.0420627
# 2  rs1046188 9.360e-01 0.0192844
# 3  rs1046379 5.619e-01 0.0324556
# 4  rs1076556 9.012e-01 0.0442044
# 5 rs10796938 3.829e-08 0.0439949
# 6 rs10796939 1.737e-05 0.0173974
# [1] 43
# [1] "checkingrs114138760 C1orf189 blood"
# [1] "files exist"
# [1] 44
# [1] "checkingrs114138760 C1orf189 brain"
# [1] "files exist"
# [1] "df:"
#         rsid pval.x     pval.y
# 1 rs10399642 0.3047 0.00340880
# 2  rs1046379 0.5619 0.04132820
# 3 rs10752608 0.6112 0.00957787
# 4 rs10752642 0.8131 0.01444130
# 5 rs10752643 0.7827 0.00296795
# 6 rs10908438 0.9371 0.04066480
# [1] 45
# [1] "checkingrs35749011 C1orf189 blood"
# [1] "files exist"
# [1] 46
# [1] "checkingrs35749011 C1orf189 brain"
# [1] "files exist"
# [1] "df:"
#         rsid pval.x     pval.y
# 1 rs10399642 0.3047 0.00340880
# 2  rs1046379 0.5619 0.04132820
# 3 rs10752608 0.6112 0.00957787
# 4 rs10752642 0.8131 0.01444130
# 5 rs10752643 0.7827 0.00296795
# 6 rs10908438 0.9371 0.04066480
# [1] 47
# [1] "checkingrs76763715 C1orf189 blood"
# [1] "files exist"
# [1] 48
# [1] "checkingrs76763715 C1orf189 brain"
# [1] "files exist"
# [1] "df:"
#         rsid pval.x     pval.y
# 1 rs10399642 0.3047 0.00340880
# 2  rs1046379 0.5619 0.04132820
# 3 rs10752608 0.6112 0.00957787
# 4 rs10752642 0.8131 0.01444130
# 5 rs10752643 0.7827 0.00296795
# 6 rs10908438 0.9371 0.04066480
# [1] 49
# [1] "checkingrs114138760 C1orf43 blood"
# [1] "files exist"
# [1] "df:"
#         rsid   pval.x     pval.y
# 1 rs10127484 0.213500 2.6793e-36
# 2 rs10127983 0.006395 4.8036e-36
# 3 rs10157443 0.005397 5.2627e-08
# 4 rs10158450 0.052460 3.6117e-12
# 5 rs10158820 0.027050 2.0200e-61
# 6  rs1043608 0.007233 2.6861e-36
# [1] 50
# [1] "checkingrs114138760 C1orf43 brain"
# [1] "files exist"
# [1] "df:"
#         rsid   pval.x      pval.y
# 1 rs10047240 0.662300 4.77497e-02
# 2 rs10127983 0.006395 3.32307e-04
# 3 rs10158450 0.052460 3.02558e-02
# 4 rs10158820 0.027050 5.49279e-06
# 5  rs1043608 0.007233 1.72786e-04
# 6  rs1044013 0.009971 2.61973e-05
# [1] 51
# [1] "checkingrs35749011 C1orf43 blood"
# [1] "files exist"
# [1] "df:"
#         rsid   pval.x     pval.y
# 1 rs10127484 0.213500 2.6793e-36
# 2 rs10127983 0.006395 4.8036e-36
# 3 rs10157443 0.005397 5.2627e-08
# 4 rs10158450 0.052460 3.6117e-12
# 5 rs10158820 0.027050 2.0200e-61
# 6  rs1043608 0.007233 2.6861e-36
# [1] 52
# [1] "checkingrs35749011 C1orf43 brain"
# [1] "files exist"
# [1] "df:"
#         rsid   pval.x      pval.y
# 1 rs10047240 0.662300 4.77497e-02
# 2 rs10127983 0.006395 3.32307e-04
# 3 rs10158450 0.052460 3.02558e-02
# 4 rs10158820 0.027050 5.49279e-06
# 5  rs1043608 0.007233 1.72786e-04
# 6  rs1044013 0.009971 2.61973e-05
# [1] 53
# [1] "checkingrs76763715 C1orf43 blood"
# [1] "files exist"
# [1] "df:"
#         rsid   pval.x     pval.y
# 1 rs10127484 0.213500 2.6793e-36
# 2 rs10127983 0.006395 4.8036e-36
# 3 rs10157443 0.005397 5.2627e-08
# 4 rs10158450 0.052460 3.6117e-12
# 5 rs10158820 0.027050 2.0200e-61
# 6  rs1043608 0.007233 2.6861e-36
# [1] 54
# [1] "checkingrs76763715 C1orf43 brain"
# [1] "files exist"
# [1] "df:"
#         rsid   pval.x      pval.y
# 1 rs10047240 0.662300 4.77497e-02
# 2 rs10127983 0.006395 3.32307e-04
# 3 rs10158450 0.052460 3.02558e-02
# 4 rs10158820 0.027050 5.49279e-06
# 5  rs1043608 0.007233 1.72786e-04
# 6  rs1044013 0.009971 2.61973e-05
# [1] 55
# [1] "checkingrs114138760 CHRNB2 blood"
# [1] "files exist"
# [1] "df:"
#         rsid  pval.x     pval.y
# 1 rs10796927 0.98950 3.6771e-23
# 2 rs10796931 0.88230 1.4256e-25
# 3 rs10908419 0.40860 7.7812e-32
# 4 rs10908421 0.91210 2.3103e-21
# 5 rs10908422 0.03648 3.0507e-26
# 6 rs10908423 0.83710 3.6975e-26
# [1] 56
# [1] "checkingrs114138760 CHRNB2 brain"
# [1] "files exist"
# [1] "df:"
#         rsid   pval.x      pval.y
# 1 rs10159236 0.793900 9.22544e-07
# 2  rs1043608 0.007233 2.44966e-02
# 3    rs10559 0.007317 2.69048e-02
# 4 rs10752605 0.016290 9.16767e-10
# 5 rs10752642 0.813100 7.90904e-06
# 6 rs10752643 0.782700 9.92333e-06
# [1] 57
# [1] "checkingrs35749011 CHRNB2 blood"
# [1] "files exist"
# [1] "df:"
#         rsid  pval.x     pval.y
# 1 rs10796927 0.98950 3.6771e-23
# 2 rs10796931 0.88230 1.4256e-25
# 3 rs10908419 0.40860 7.7812e-32
# 4 rs10908421 0.91210 2.3103e-21
# 5 rs10908422 0.03648 3.0507e-26
# 6 rs10908423 0.83710 3.6975e-26
# [1] 58
# [1] "checkingrs35749011 CHRNB2 brain"
# [1] "files exist"
# [1] "df:"
#         rsid   pval.x      pval.y
# 1 rs10159236 0.793900 9.22544e-07
# 2  rs1043608 0.007233 2.44966e-02
# 3    rs10559 0.007317 2.69048e-02
# 4 rs10752605 0.016290 9.16767e-10
# 5 rs10752642 0.813100 7.90904e-06
# 6 rs10752643 0.782700 9.92333e-06
# [1] 59
# [1] "checkingrs76763715 CHRNB2 blood"
# [1] "files exist"
# [1] "df:"
#         rsid  pval.x     pval.y
# 1 rs10796927 0.98950 3.6771e-23
# 2 rs10796931 0.88230 1.4256e-25
# 3 rs10908419 0.40860 7.7812e-32
# 4 rs10908421 0.91210 2.3103e-21
# 5 rs10908422 0.03648 3.0507e-26
# 6 rs10908423 0.83710 3.6975e-26
# [1] 60
# [1] "checkingrs76763715 CHRNB2 brain"
# [1] "files exist"
# [1] "df:"
#         rsid   pval.x      pval.y
# 1 rs10159236 0.793900 9.22544e-07
# 2  rs1043608 0.007233 2.44966e-02
# 3    rs10559 0.007317 2.69048e-02
# 4 rs10752605 0.016290 9.16767e-10
# 5 rs10752642 0.813100 7.90904e-06
# 6 rs10752643 0.782700 9.92333e-06
# [1] 61
# [1] "checkingrs114138760 CKS1B blood"
# [1] "files exist"
# [1] 62
# [1] "checkingrs114138760 CKS1B brain"
# [1] "files exist"
# [1] "df:"
#         rsid pval.x      pval.y
# 1 rs10514914 0.1972 0.000712207
# 2 rs10514924 0.1394 0.000589017
# 3 rs10514926 0.6546 0.029732300
# 4 rs10908429 0.4571 0.033450400
# 5 rs10908468 0.7262 0.039605000
# 6  rs1094462 0.7918 0.000740398
# [1] 63
# [1] "checkingrs35749011 CKS1B blood"
# [1] "files exist"
# [1] 64
# [1] "checkingrs35749011 CKS1B brain"
# [1] "files exist"
# [1] "df:"
#         rsid pval.x      pval.y
# 1 rs10514914 0.1972 0.000712207
# 2 rs10514924 0.1394 0.000589017
# 3 rs10514926 0.6546 0.029732300
# 4 rs10908429 0.4571 0.033450400
# 5 rs10908468 0.7262 0.039605000
# 6  rs1094462 0.7918 0.000740398
# [1] 65
# [1] "checkingrs76763715 CKS1B blood"
# [1] "files exist"
# [1] 66
# [1] "checkingrs76763715 CKS1B brain"
# [1] "files exist"
# [1] "df:"
#         rsid pval.x      pval.y
# 1 rs10514914 0.1972 0.000712207
# 2 rs10514924 0.1394 0.000589017
# 3 rs10514926 0.6546 0.029732300
# 4 rs10908429 0.4571 0.033450400
# 5 rs10908468 0.7262 0.039605000
# 6  rs1094462 0.7918 0.000740398
# [1] 67
# [1] "checkingrs114138760 CLK2 blood"
# [1] "files exist"
# [1] "df:"
#         rsid    pval.x     pval.y
# 1 rs11584621 1.266e-01 9.6621e-06
# 2 rs12725937 8.424e-05 8.3971e-06
# 3 rs35790033 2.017e-05 8.1274e-06
# 4 rs41265007 4.338e-02 5.7688e-07
# 5 rs71628688 4.972e-05 1.6193e-05
# 6 rs76664500 1.666e-02 1.0154e-12
# [1] 68
# [1] "checkingrs114138760 CLK2 brain"
# [1] "files exist"
# [1] "df:"
#         rsid    pval.x      pval.y
# 1  rs1001848 3.518e-07 0.003960220
# 2  rs1007839 8.876e-01 0.049876700
# 3  rs1010033 7.085e-01 0.047890900
# 4 rs10128027 1.459e-02 0.000568676
# 5  rs1051614 9.892e-01 0.008540050
# 6  rs1051614 9.892e-01 0.008540050
# [1] 69
# [1] "checkingrs35749011 CLK2 blood"
# [1] "files exist"
# [1] "df:"
#         rsid    pval.x     pval.y
# 1 rs11584621 1.266e-01 9.6621e-06
# 2 rs12725937 8.424e-05 8.3971e-06
# 3 rs35790033 2.017e-05 8.1274e-06
# 4 rs41265007 4.338e-02 5.7688e-07
# 5 rs71628688 4.972e-05 1.6193e-05
# 6 rs76664500 1.666e-02 1.0154e-12
# [1] 70
# [1] "checkingrs35749011 CLK2 brain"
# [1] "files exist"
# [1] "df:"
#         rsid    pval.x      pval.y
# 1  rs1001848 3.518e-07 0.003960220
# 2  rs1007839 8.876e-01 0.049876700
# 3  rs1010033 7.085e-01 0.047890900
# 4 rs10128027 1.459e-02 0.000568676
# 5  rs1051614 9.892e-01 0.008540050
# 6  rs1051614 9.892e-01 0.008540050
# [1] 71
# [1] "checkingrs76763715 CLK2 blood"
# [1] "files exist"
# [1] "df:"
#         rsid    pval.x     pval.y
# 1 rs11584621 1.266e-01 9.6621e-06
# 2 rs12725937 8.424e-05 8.3971e-06
# 3 rs35790033 2.017e-05 8.1274e-06
# 4 rs41265007 4.338e-02 5.7688e-07
# 5 rs71628688 4.972e-05 1.6193e-05
# 6 rs76664500 1.666e-02 1.0154e-12
# [1] 72
# [1] "checkingrs76763715 CLK2 brain"
# [1] "files exist"
# [1] "df:"
#         rsid    pval.x      pval.y
# 1  rs1001848 3.518e-07 0.003960220
# 2  rs1007839 8.876e-01 0.049876700
# 3  rs1010033 7.085e-01 0.047890900
# 4 rs10128027 1.459e-02 0.000568676
# 5  rs1051614 9.892e-01 0.008540050
# 6  rs1051614 9.892e-01 0.008540050
# [1] 73
# [1] "checkingrs114138760 CREB3L4 blood"
# [1] "files exist"
# [1] "df:"
#         rsid   pval.x     pval.y
# 1 rs10047079 0.052370 8.5471e-06
# 2 rs10127484 0.213500 2.4326e-90
# 3 rs10127983 0.006395 2.2402e-73
# 4 rs10157443 0.005397 4.8961e-10
# 5 rs10158450 0.052460 1.8200e-20
# 6 rs10158820 0.027050 2.1873e-28
# [1] 74
# [1] "checkingrs114138760 CREB3L4 brain"
# [1] "files exist"
# [1] "df:"
#         rsid   pval.x      pval.y
# 1 rs10127484 0.213500 0.000796027
# 2 rs10127983 0.006395 0.022494000
# 3  rs1043608 0.007233 0.026048700
# 4 rs10494300 0.649100 0.000794931
# 5 rs10494303 0.301000 0.000688486
# 6  rs1051370 0.030470 0.029990800
# [1] 75
# [1] "checkingrs35749011 CREB3L4 blood"
# [1] "files exist"
# [1] "df:"
#         rsid   pval.x     pval.y
# 1 rs10047079 0.052370 8.5471e-06
# 2 rs10127484 0.213500 2.4326e-90
# 3 rs10127983 0.006395 2.2402e-73
# 4 rs10157443 0.005397 4.8961e-10
# 5 rs10158450 0.052460 1.8200e-20
# 6 rs10158820 0.027050 2.1873e-28
# [1] 76
# [1] "checkingrs35749011 CREB3L4 brain"
# [1] "files exist"
# [1] "df:"
#         rsid   pval.x      pval.y
# 1 rs10127484 0.213500 0.000796027
# 2 rs10127983 0.006395 0.022494000
# 3  rs1043608 0.007233 0.026048700
# 4 rs10494300 0.649100 0.000794931
# 5 rs10494303 0.301000 0.000688486
# 6  rs1051370 0.030470 0.029990800
# [1] 77
# [1] "checkingrs76763715 CREB3L4 blood"
# [1] "files exist"
# [1] "df:"
#         rsid   pval.x     pval.y
# 1 rs10047079 0.052370 8.5471e-06
# 2 rs10127484 0.213500 2.4326e-90
# 3 rs10127983 0.006395 2.2402e-73
# 4 rs10157443 0.005397 4.8961e-10
# 5 rs10158450 0.052460 1.8200e-20
# 6 rs10158820 0.027050 2.1873e-28
# [1] 78
# [1] "checkingrs76763715 CREB3L4 brain"
# [1] "files exist"
# [1] "df:"
#         rsid   pval.x      pval.y
# 1 rs10127484 0.213500 0.000796027
# 2 rs10127983 0.006395 0.022494000
# 3  rs1043608 0.007233 0.026048700
# 4 rs10494300 0.649100 0.000794931
# 5 rs10494303 0.301000 0.000688486
# 6  rs1051370 0.030470 0.029990800
# [1] 79
# [1] "checkingrs114138760 CRTC2 blood"
# [1] "files exist"
# [1] "df:"
#         rsid   pval.x     pval.y
# 1 rs10127983 0.006395 3.7861e-10
# 2 rs10158820 0.027050 1.8923e-06
# 3  rs1043608 0.007233 1.1447e-09
# 4  rs1051370 0.030470 5.9333e-08
# 5    rs10559 0.007317 4.3256e-10
# 6 rs10752613 0.012210 9.4900e-09
# [1] 80
# [1] "checkingrs114138760 CRTC2 brain"
# [1] "files exist"
# [1] "df:"
#         rsid   pval.x     pval.y
# 1 rs10127484 0.213500 0.02116210
# 2 rs10127983 0.006395 0.04394690
# 3 rs10157443 0.005397 0.02200030
# 4 rs10159119 0.025970 0.00692941
# 5  rs1043608 0.007233 0.02027660
# 6 rs10494291 0.010140 0.00113477
# [1] 81
# [1] "checkingrs35749011 CRTC2 blood"
# [1] "files exist"
# [1] "df:"
#         rsid   pval.x     pval.y
# 1 rs10127983 0.006395 3.7861e-10
# 2 rs10158820 0.027050 1.8923e-06
# 3  rs1043608 0.007233 1.1447e-09
# 4  rs1051370 0.030470 5.9333e-08
# 5    rs10559 0.007317 4.3256e-10
# 6 rs10752613 0.012210 9.4900e-09
# [1] 82
# [1] "checkingrs35749011 CRTC2 brain"
# [1] "files exist"
# [1] "df:"
#         rsid   pval.x     pval.y
# 1 rs10127484 0.213500 0.02116210
# 2 rs10127983 0.006395 0.04394690
# 3 rs10157443 0.005397 0.02200030
# 4 rs10159119 0.025970 0.00692941
# 5  rs1043608 0.007233 0.02027660
# 6 rs10494291 0.010140 0.00113477
# [1] 83
# [1] "checkingrs76763715 CRTC2 blood"
# [1] "files exist"
# [1] "df:"
#         rsid   pval.x     pval.y
# 1 rs10127983 0.006395 3.7861e-10
# 2 rs10158820 0.027050 1.8923e-06
# 3  rs1043608 0.007233 1.1447e-09
# 4  rs1051370 0.030470 5.9333e-08
# 5    rs10559 0.007317 4.3256e-10
# 6 rs10752613 0.012210 9.4900e-09
# [1] 84
# [1] "checkingrs76763715 CRTC2 brain"
# [1] "files exist"
# [1] "df:"
#         rsid   pval.x     pval.y
# 1 rs10127484 0.213500 0.02116210
# 2 rs10127983 0.006395 0.04394690
# 3 rs10157443 0.005397 0.02200030
# 4 rs10159119 0.025970 0.00692941
# 5  rs1043608 0.007233 0.02027660
# 6 rs10494291 0.010140 0.00113477
# [1] 85
# [1] "checkingrs114138760 DAP3 blood"
# [1] "files exist"
# [1] "df:"
#         rsid    pval.x     pval.y
# 1 rs10047112 1.480e-01 8.5723e-09
# 2 rs10157801 1.502e-05 1.7064e-05
# 3  rs1045253 5.136e-01 8.4388e-48
# 4 rs10458626 1.355e-01 2.8890e-14
# 5  rs1046188 9.360e-01 4.7223e-63
# 6  rs1052176 9.503e-01 6.1820e-76
# [1] 86
# [1] "checkingrs114138760 DAP3 brain"
# [1] "files exist"
# [1] "df:"
#         rsid    pval.x     pval.y
# 1  rs1010225 1.703e-01 0.00935063
# 2 rs10494300 6.491e-01 0.02000700
# 3  rs1051614 9.892e-01 0.02687300
# 4  rs1051614 9.892e-01 0.02687300
# 5  rs1052067 8.981e-05 0.04354220
# 6 rs10752609 8.951e-02 0.03151100
# [1] 87
# [1] "checkingrs35749011 DAP3 blood"
# [1] "files exist"
# [1] "df:"
#         rsid    pval.x     pval.y
# 1 rs10047112 1.480e-01 8.5723e-09
# 2 rs10157801 1.502e-05 1.7064e-05
# 3  rs1045253 5.136e-01 8.4388e-48
# 4 rs10458626 1.355e-01 2.8890e-14
# 5  rs1046188 9.360e-01 4.7223e-63
# 6  rs1052176 9.503e-01 6.1820e-76
# [1] 88
# [1] "checkingrs35749011 DAP3 brain"
# [1] "files exist"
# [1] "df:"
#         rsid    pval.x     pval.y
# 1  rs1010225 1.703e-01 0.00935063
# 2 rs10494300 6.491e-01 0.02000700
# 3  rs1051614 9.892e-01 0.02687300
# 4  rs1051614 9.892e-01 0.02687300
# 5  rs1052067 8.981e-05 0.04354220
# 6 rs10752609 8.951e-02 0.03151100
# [1] 89
# [1] "checkingrs76763715 DAP3 blood"
# [1] "files exist"
# [1] "df:"
#         rsid    pval.x     pval.y
# 1 rs10047112 1.480e-01 8.5723e-09
# 2 rs10157801 1.502e-05 1.7064e-05
# 3  rs1045253 5.136e-01 8.4388e-48
# 4 rs10458626 1.355e-01 2.8890e-14
# 5  rs1046188 9.360e-01 4.7223e-63
# 6  rs1052176 9.503e-01 6.1820e-76
# [1] 90
# [1] "checkingrs76763715 DAP3 brain"
# [1] "files exist"
# [1] "df:"
#         rsid    pval.x     pval.y
# 1  rs1010225 1.703e-01 0.00935063
# 2 rs10494300 6.491e-01 0.02000700
# 3  rs1051614 9.892e-01 0.02687300
# 4  rs1051614 9.892e-01 0.02687300
# 5  rs1052067 8.981e-05 0.04354220
# 6 rs10752609 8.951e-02 0.03151100
# [1] 91
# [1] "checkingrs114138760 DCST1 blood"
# [1] "files exist"
# [1] 92
# [1] "checkingrs114138760 DCST1 brain"
# [1] "files exist"
# [1] "df:"
#        rsid    pval.x      pval.y
# 1 rs1001848 3.518e-07 0.009368400
# 2 rs1007170 1.006e-01 0.045881800
# 3 rs1045253 5.136e-01 0.000928419
# 4 rs1046188 9.360e-01 0.002308990
# 5 rs1052176 9.503e-01 0.003870500
# 6 rs1052177 9.618e-01 0.003870500
# [1] 93
# [1] "checkingrs35749011 DCST1 blood"
# [1] "files exist"
# [1] 94
# [1] "checkingrs35749011 DCST1 brain"
# [1] "files exist"
# [1] "df:"
#        rsid    pval.x      pval.y
# 1 rs1001848 3.518e-07 0.009368400
# 2 rs1007170 1.006e-01 0.045881800
# 3 rs1045253 5.136e-01 0.000928419
# 4 rs1046188 9.360e-01 0.002308990
# 5 rs1052176 9.503e-01 0.003870500
# 6 rs1052177 9.618e-01 0.003870500
# [1] 95
# [1] "checkingrs76763715 DCST1 blood"
# [1] "files exist"
# [1] 96
# [1] "checkingrs76763715 DCST1 brain"
# [1] "files exist"
# [1] "df:"
#        rsid    pval.x      pval.y
# 1 rs1001848 3.518e-07 0.009368400
# 2 rs1007170 1.006e-01 0.045881800
# 3 rs1045253 5.136e-01 0.000928419
# 4 rs1046188 9.360e-01 0.002308990
# 5 rs1052176 9.503e-01 0.003870500
# 6 rs1052177 9.618e-01 0.003870500
# [1] 97
# [1] "checkingrs114138760 DCST1-AS1 blood"
# [1] "files exist"
# [1] 98
# [1] "checkingrs114138760 DCST1-AS1 brain"
# [1] 99
# [1] "checkingrs35749011 DCST1-AS1 blood"
# [1] "files exist"
# [1] 100
# [1] "checkingrs35749011 DCST1-AS1 brain"
# [1] 101
# [1] "checkingrs76763715 DCST1-AS1 blood"
# [1] "files exist"
# [1] 102
# [1] "checkingrs76763715 DCST1-AS1 brain"
# [1] 103
# [1] "checkingrs114138760 DCST2 blood"
# [1] "files exist"
# [1] "df:"
#         rsid  pval.x     pval.y
# 1  rs2306125 0.51570 1.2447e-05
# 2  rs3753639 0.05499 8.0444e-06
# 3 rs76798800 0.04513 2.3171e-06
# 4   rs905938 0.04736 9.4000e-07
# [1] 104
# [1] "checkingrs114138760 DCST2 brain"
# [1] "files exist"
# [1] "df:"
#        rsid pval.x      pval.y
# 1 rs1007170 0.1006 1.30873e-06
# 2 rs1010225 0.1703 9.81927e-04
# 3 rs1045253 0.5136 2.99199e-02
# 4 rs1052176 0.9503 2.98108e-02
# 5 rs1052177 0.9618 2.98108e-02
# 6 rs1076556 0.9012 4.61979e-02
# [1] 105
# [1] "checkingrs35749011 DCST2 blood"
# [1] "files exist"
# [1] "df:"
#         rsid  pval.x     pval.y
# 1  rs2306125 0.51570 1.2447e-05
# 2  rs3753639 0.05499 8.0444e-06
# 3 rs76798800 0.04513 2.3171e-06
# 4   rs905938 0.04736 9.4000e-07
# [1] 106
# [1] "checkingrs35749011 DCST2 brain"
# [1] "files exist"
# [1] "df:"
#        rsid pval.x      pval.y
# 1 rs1007170 0.1006 1.30873e-06
# 2 rs1010225 0.1703 9.81927e-04
# 3 rs1045253 0.5136 2.99199e-02
# 4 rs1052176 0.9503 2.98108e-02
# 5 rs1052177 0.9618 2.98108e-02
# 6 rs1076556 0.9012 4.61979e-02
# [1] 107
# [1] "checkingrs76763715 DCST2 blood"
# [1] "files exist"
# [1] "df:"
#         rsid  pval.x     pval.y
# 1  rs2306125 0.51570 1.2447e-05
# 2  rs3753639 0.05499 8.0444e-06
# 3 rs76798800 0.04513 2.3171e-06
# 4   rs905938 0.04736 9.4000e-07
# [1] 108
# [1] "checkingrs76763715 DCST2 brain"
# [1] "files exist"
# [1] "df:"
#        rsid pval.x      pval.y
# 1 rs1007170 0.1006 1.30873e-06
# 2 rs1010225 0.1703 9.81927e-04
# 3 rs1045253 0.5136 2.99199e-02
# 4 rs1052176 0.9503 2.98108e-02
# 5 rs1052177 0.9618 2.98108e-02
# 6 rs1076556 0.9012 4.61979e-02
# [1] 109
# [1] "checkingrs114138760 DENND4B blood"
# [1] "files exist"
# [1] "df:"
#         rsid   pval.x      pval.y
# 1 rs10047079 0.052370  5.8705e-06
# 2 rs10127983 0.006395  1.5599e-10
# 3 rs10157443 0.005397 6.8069e-114
# 4 rs10159236 0.793900  2.9632e-08
# 5  rs1043608 0.007233  3.7971e-09
# 6  rs1046381 0.976200  3.8666e-09
# [1] 110
# [1] "checkingrs114138760 DENND4B brain"
# [1] "files exist"
# [1] "df:"
#         rsid   pval.x      pval.y
# 1  rs1007170 0.100600 9.14083e-03
# 2 rs10157443 0.005397 4.87610e-08
# 3 rs10494291 0.010140 4.55565e-02
# 4 rs10494292 0.010470 4.55705e-02
# 5 rs10494293 0.009973 4.57390e-02
# 6 rs10494294 0.014410 4.57856e-02
# [1] 111
# [1] "checkingrs35749011 DENND4B blood"
# [1] "files exist"
# [1] "df:"
#         rsid   pval.x      pval.y
# 1 rs10047079 0.052370  5.8705e-06
# 2 rs10127983 0.006395  1.5599e-10
# 3 rs10157443 0.005397 6.8069e-114
# 4 rs10159236 0.793900  2.9632e-08
# 5  rs1043608 0.007233  3.7971e-09
# 6  rs1046381 0.976200  3.8666e-09
# [1] 112
# [1] "checkingrs35749011 DENND4B brain"
# [1] "files exist"
# [1] "df:"
#         rsid   pval.x      pval.y
# 1  rs1007170 0.100600 9.14083e-03
# 2 rs10157443 0.005397 4.87610e-08
# 3 rs10494291 0.010140 4.55565e-02
# 4 rs10494292 0.010470 4.55705e-02
# 5 rs10494293 0.009973 4.57390e-02
# 6 rs10494294 0.014410 4.57856e-02
# [1] 113
# [1] "checkingrs76763715 DENND4B blood"
# [1] "files exist"
# [1] "df:"
#         rsid   pval.x      pval.y
# 1 rs10047079 0.052370  5.8705e-06
# 2 rs10127983 0.006395  1.5599e-10
# 3 rs10157443 0.005397 6.8069e-114
# 4 rs10159236 0.793900  2.9632e-08
# 5  rs1043608 0.007233  3.7971e-09
# 6  rs1046381 0.976200  3.8666e-09
# [1] 114
# [1] "checkingrs76763715 DENND4B brain"
# [1] "files exist"
# [1] "df:"
#         rsid   pval.x      pval.y
# 1  rs1007170 0.100600 9.14083e-03
# 2 rs10157443 0.005397 4.87610e-08
# 3 rs10494291 0.010140 4.55565e-02
# 4 rs10494292 0.010470 4.55705e-02
# 5 rs10494293 0.009973 4.57390e-02
# 6 rs10494294 0.014410 4.57856e-02
# [1] 115
# [1] "checkingrs114138760 DPM3 blood"
# [1] "files exist"
# [1] "df:"
#         rsid    pval.x     pval.y
# 1  rs1001848 3.518e-07 4.1171e-11
# 2 rs10157801 1.502e-05 3.2738e-27
# 3  rs1045253 5.136e-01 2.3235e-07
# 4 rs10796938 3.829e-08 4.9090e-20
# 5 rs10796939 1.737e-05 2.2262e-23
# 6 rs10796940 4.679e-01 5.4600e-07
# [1] 116
# [1] "checkingrs114138760 DPM3 brain"
# [1] "files exist"
# [1] "df:"
#         rsid pval.x    pval.y
# 1 rs10047112 0.1480 0.0331550
# 2 rs10752611 0.4470 0.0289085
# 3 rs10796943 0.6761 0.0386816
# 4 rs10796945 0.6229 0.0319621
# 5 rs10796946 0.6048 0.0317773
# 6 rs10908465 0.6263 0.0268178
# [1] 117
# [1] "checkingrs35749011 DPM3 blood"
# [1] "files exist"
# [1] "df:"
#         rsid    pval.x     pval.y
# 1  rs1001848 3.518e-07 4.1171e-11
# 2 rs10157801 1.502e-05 3.2738e-27
# 3  rs1045253 5.136e-01 2.3235e-07
# 4 rs10796938 3.829e-08 4.9090e-20
# 5 rs10796939 1.737e-05 2.2262e-23
# 6 rs10796940 4.679e-01 5.4600e-07
# [1] 118
# [1] "checkingrs35749011 DPM3 brain"
# [1] "files exist"
# [1] "df:"
#         rsid pval.x    pval.y
# 1 rs10047112 0.1480 0.0331550
# 2 rs10752611 0.4470 0.0289085
# 3 rs10796943 0.6761 0.0386816
# 4 rs10796945 0.6229 0.0319621
# 5 rs10796946 0.6048 0.0317773
# 6 rs10908465 0.6263 0.0268178
# [1] 119
# [1] "checkingrs76763715 DPM3 blood"
# [1] "files exist"
# [1] "df:"
#         rsid    pval.x     pval.y
# 1  rs1001848 3.518e-07 4.1171e-11
# 2 rs10157801 1.502e-05 3.2738e-27
# 3  rs1045253 5.136e-01 2.3235e-07
# 4 rs10796938 3.829e-08 4.9090e-20
# 5 rs10796939 1.737e-05 2.2262e-23
# 6 rs10796940 4.679e-01 5.4600e-07
# [1] 120
# [1] "checkingrs76763715 DPM3 brain"
# [1] "files exist"
# [1] "df:"
#         rsid pval.x    pval.y
# 1 rs10047112 0.1480 0.0331550
# 2 rs10752611 0.4470 0.0289085
# 3 rs10796943 0.6761 0.0386816
# 4 rs10796945 0.6229 0.0319621
# 5 rs10796946 0.6048 0.0317773
# 6 rs10908465 0.6263 0.0268178
# [1] 121
# [1] "checkingrs114138760 EFNA1 blood"
# [1] "files exist"
# [1] "df:"
#          rsid    pval.x     pval.y
# 1  rs10796938 3.829e-08 1.4757e-09
# 2  rs10908457 5.082e-02 7.9272e-09
# 3 rs111455542 3.559e-02 9.9631e-10
# 4 rs111993576 5.317e-02 1.9323e-09
# 5 rs112559323 7.356e-02 1.2353e-07
# 6 rs112591935 5.395e-02 2.0474e-09
# [1] 122
# [1] "checkingrs114138760 EFNA1 brain"
# [1] "files exist"
# [1] "df:"
#         rsid    pval.x      pval.y
# 1 rs10047112 1.480e-01 3.43821e-02
# 2  rs1010033 7.085e-01 1.31776e-02
# 3 rs10157801 1.502e-05 5.69649e-11
# 4 rs10158206 5.240e-03 3.46277e-02
# 5  rs1018730 7.476e-01 1.71609e-02
# 6  rs1045253 5.136e-01 8.78253e-03
# [1] 123
# [1] "checkingrs35749011 EFNA1 blood"
# [1] "files exist"
# [1] "df:"
#          rsid    pval.x     pval.y
# 1  rs10796938 3.829e-08 1.4757e-09
# 2  rs10908457 5.082e-02 7.9272e-09
# 3 rs111455542 3.559e-02 9.9631e-10
# 4 rs111993576 5.317e-02 1.9323e-09
# 5 rs112559323 7.356e-02 1.2353e-07
# 6 rs112591935 5.395e-02 2.0474e-09
# [1] 124
# [1] "checkingrs35749011 EFNA1 brain"
# [1] "files exist"
# [1] "df:"
#         rsid    pval.x      pval.y
# 1 rs10047112 1.480e-01 3.43821e-02
# 2  rs1010033 7.085e-01 1.31776e-02
# 3 rs10157801 1.502e-05 5.69649e-11
# 4 rs10158206 5.240e-03 3.46277e-02
# 5  rs1018730 7.476e-01 1.71609e-02
# 6  rs1045253 5.136e-01 8.78253e-03
# [1] 125
# [1] "checkingrs76763715 EFNA1 blood"
# [1] "files exist"
# [1] "df:"
#          rsid    pval.x     pval.y
# 1  rs10796938 3.829e-08 1.4757e-09
# 2  rs10908457 5.082e-02 7.9272e-09
# 3 rs111455542 3.559e-02 9.9631e-10
# 4 rs111993576 5.317e-02 1.9323e-09
# 5 rs112559323 7.356e-02 1.2353e-07
# 6 rs112591935 5.395e-02 2.0474e-09
# [1] 126
# [1] "checkingrs76763715 EFNA1 brain"
# [1] "files exist"
# [1] "df:"
#         rsid    pval.x      pval.y
# 1 rs10047112 1.480e-01 3.43821e-02
# 2  rs1010033 7.085e-01 1.31776e-02
# 3 rs10157801 1.502e-05 5.69649e-11
# 4 rs10158206 5.240e-03 3.46277e-02
# 5  rs1018730 7.476e-01 1.71609e-02
# 6  rs1045253 5.136e-01 8.78253e-03
# [1] 127
# [1] "checkingrs114138760 EFNA3 blood"
# [1] "files exist"
# [1] "df:"
#         rsid    pval.x     pval.y
# 1  rs1001848 3.518e-07 1.9494e-06
# 2 rs10796938 3.829e-08 8.3270e-06
# 3 rs10908454 2.704e-07 1.0045e-05
# 4 rs10908456 3.840e-06 6.1490e-06
# 5 rs11264304 7.921e-13 1.4043e-06
# 6 rs11264305 1.538e-12 6.7022e-07
# [1] 128
# [1] "checkingrs114138760 EFNA3 brain"
# [1] "files exist"
# [1] "df:"
#         rsid    pval.x     pval.y
# 1  rs1001848 3.518e-07 0.00411129
# 2 rs10752606 9.477e-01 0.04158420
# 3 rs10796936 6.179e-01 0.03105970
# 4 rs10796938 3.829e-08 0.04055590
# 5 rs10908424 2.343e-01 0.01934540
# 6 rs10908452 4.494e-01 0.03953760
# [1] 129
# [1] "checkingrs35749011 EFNA3 blood"
# [1] "files exist"
# [1] "df:"
#         rsid    pval.x     pval.y
# 1  rs1001848 3.518e-07 1.9494e-06
# 2 rs10796938 3.829e-08 8.3270e-06
# 3 rs10908454 2.704e-07 1.0045e-05
# 4 rs10908456 3.840e-06 6.1490e-06
# 5 rs11264304 7.921e-13 1.4043e-06
# 6 rs11264305 1.538e-12 6.7022e-07
# [1] 130
# [1] "checkingrs35749011 EFNA3 brain"
# [1] "files exist"
# [1] "df:"
#         rsid    pval.x     pval.y
# 1  rs1001848 3.518e-07 0.00411129
# 2 rs10752606 9.477e-01 0.04158420
# 3 rs10796936 6.179e-01 0.03105970
# 4 rs10796938 3.829e-08 0.04055590
# 5 rs10908424 2.343e-01 0.01934540
# 6 rs10908452 4.494e-01 0.03953760
# [1] 131
# [1] "checkingrs76763715 EFNA3 blood"
# [1] "files exist"
# [1] "df:"
#         rsid    pval.x     pval.y
# 1  rs1001848 3.518e-07 1.9494e-06
# 2 rs10796938 3.829e-08 8.3270e-06
# 3 rs10908454 2.704e-07 1.0045e-05
# 4 rs10908456 3.840e-06 6.1490e-06
# 5 rs11264304 7.921e-13 1.4043e-06
# 6 rs11264305 1.538e-12 6.7022e-07
# [1] 132
# [1] "checkingrs76763715 EFNA3 brain"
# [1] "files exist"
# [1] "df:"
#         rsid    pval.x     pval.y
# 1  rs1001848 3.518e-07 0.00411129
# 2 rs10752606 9.477e-01 0.04158420
# 3 rs10796936 6.179e-01 0.03105970
# 4 rs10796938 3.829e-08 0.04055590
# 5 rs10908424 2.343e-01 0.01934540
# 6 rs10908452 4.494e-01 0.03953760
# [1] 133
# [1] "checkingrs114138760 EFNA4 blood"
# [1] "files exist"
# [1] "df:"
#         rsid pval.x     pval.y
# 1 rs11465206 0.8570 1.6795e-06
# 2 rs72704114 0.8596 3.4606e-06
# [1] 134
# [1] "checkingrs114138760 EFNA4 brain"
# [1] "files exist"
# [1] "df:"
#         rsid  pval.x    pval.y
# 1 rs10047079 0.05237 0.0277826
# 2 rs10218433 0.72260 0.0385183
# 3  rs1027809 0.52810 0.0413949
# 4 rs10737169 0.47890 0.0484450
# 5  rs1073907 0.77350 0.0423480
# 6 rs10908483 0.02825 0.0380091
# [1] 135
# [1] "checkingrs35749011 EFNA4 blood"
# [1] "files exist"
# [1] "df:"
#         rsid pval.x     pval.y
# 1 rs11465206 0.8570 1.6795e-06
# 2 rs72704114 0.8596 3.4606e-06
# [1] 136
# [1] "checkingrs35749011 EFNA4 brain"
# [1] "files exist"
# [1] "df:"
#         rsid  pval.x    pval.y
# 1 rs10047079 0.05237 0.0277826
# 2 rs10218433 0.72260 0.0385183
# 3  rs1027809 0.52810 0.0413949
# 4 rs10737169 0.47890 0.0484450
# 5  rs1073907 0.77350 0.0423480
# 6 rs10908483 0.02825 0.0380091
# [1] 137
# [1] "checkingrs76763715 EFNA4 blood"
# [1] "files exist"
# [1] "df:"
#         rsid pval.x     pval.y
# 1 rs11465206 0.8570 1.6795e-06
# 2 rs72704114 0.8596 3.4606e-06
# [1] 138
# [1] "checkingrs76763715 EFNA4 brain"
# [1] "files exist"
# [1] "df:"
#         rsid  pval.x    pval.y
# 1 rs10047079 0.05237 0.0277826
# 2 rs10218433 0.72260 0.0385183
# 3  rs1027809 0.52810 0.0413949
# 4 rs10737169 0.47890 0.0484450
# 5  rs1073907 0.77350 0.0423480
# 6 rs10908483 0.02825 0.0380091
# [1] 139
# [1] "checkingrs114138760 FAM189B blood"
# [1] "files exist"
# [1] "df:"
#         rsid pval.x     pval.y
# 1  rs1045253 0.5136 7.4042e-10
# 2  rs1046188 0.9360 9.9968e-11
# 3  rs1052176 0.9503 1.8512e-10
# 4  rs1052177 0.9618 2.2533e-10
# 5 rs10752611 0.4470 1.4997e-08
# 6  rs1076556 0.9012 8.6065e-11
# [1] 140
# [1] "checkingrs114138760 FAM189B brain"
# [1] "files exist"
# [1] "df:"
#         rsid   pval.x      pval.y
# 1  rs1010033 0.708500 0.024418400
# 2 rs10159384 0.000343 0.030561800
# 3  rs1018730 0.747600 0.022301800
# 4  rs1045253 0.513600 0.000697097
# 5  rs1046188 0.936000 0.000210789
# 6  rs1052176 0.950300 0.000260252
# [1] 141
# [1] "checkingrs35749011 FAM189B blood"
# [1] "files exist"
# [1] "df:"
#         rsid pval.x     pval.y
# 1  rs1045253 0.5136 7.4042e-10
# 2  rs1046188 0.9360 9.9968e-11
# 3  rs1052176 0.9503 1.8512e-10
# 4  rs1052177 0.9618 2.2533e-10
# 5 rs10752611 0.4470 1.4997e-08
# 6  rs1076556 0.9012 8.6065e-11
# [1] 142
# [1] "checkingrs35749011 FAM189B brain"
# [1] "files exist"
# [1] "df:"
#         rsid   pval.x      pval.y
# 1  rs1010033 0.708500 0.024418400
# 2 rs10159384 0.000343 0.030561800
# 3  rs1018730 0.747600 0.022301800
# 4  rs1045253 0.513600 0.000697097
# 5  rs1046188 0.936000 0.000210789
# 6  rs1052176 0.950300 0.000260252
# [1] 143
# [1] "checkingrs76763715 FAM189B blood"
# [1] "files exist"
# [1] "df:"
#         rsid pval.x     pval.y
# 1  rs1045253 0.5136 7.4042e-10
# 2  rs1046188 0.9360 9.9968e-11
# 3  rs1052176 0.9503 1.8512e-10
# 4  rs1052177 0.9618 2.2533e-10
# 5 rs10752611 0.4470 1.4997e-08
# 6  rs1076556 0.9012 8.6065e-11
# [1] 144
# [1] "checkingrs76763715 FAM189B brain"
# [1] "files exist"
# [1] "df:"
#         rsid   pval.x      pval.y
# 1  rs1010033 0.708500 0.024418400
# 2 rs10159384 0.000343 0.030561800
# 3  rs1018730 0.747600 0.022301800
# 4  rs1045253 0.513600 0.000697097
# 5  rs1046188 0.936000 0.000210789
# 6  rs1052176 0.950300 0.000260252
# [1] 145
# [1] "checkingrs114138760 FDPS blood"
# [1] "files exist"
# [1] "df:"
#         rsid pval.x     pval.y
# 1  rs1045253 0.5136 1.9554e-10
# 2  rs1046188 0.9360 4.5298e-14
# 3  rs1052176 0.9503 5.0370e-16
# 4  rs1052177 0.9618 1.0713e-15
# 5 rs10752611 0.4470 3.2241e-21
# 6  rs1076556 0.9012 1.0721e-14
# [1] 146
# [1] "checkingrs114138760 FDPS brain"
# [1] "files exist"
# [1] "df:"
#         rsid pval.x      pval.y
# 1  rs1010225 0.1703 3.60283e-02
# 2  rs1045253 0.5136 4.15132e-02
# 3  rs1046188 0.9360 5.73307e-05
# 4  rs1052176 0.9503 9.79685e-05
# 5  rs1052177 0.9618 9.81453e-05
# 6 rs10752611 0.4470 1.30900e-03
# [1] 147
# [1] "checkingrs35749011 FDPS blood"
# [1] "files exist"
# [1] "df:"
#         rsid pval.x     pval.y
# 1  rs1045253 0.5136 1.9554e-10
# 2  rs1046188 0.9360 4.5298e-14
# 3  rs1052176 0.9503 5.0370e-16
# 4  rs1052177 0.9618 1.0713e-15
# 5 rs10752611 0.4470 3.2241e-21
# 6  rs1076556 0.9012 1.0721e-14
# [1] 148
# [1] "checkingrs35749011 FDPS brain"
# [1] "files exist"
# [1] "df:"
#         rsid pval.x      pval.y
# 1  rs1010225 0.1703 3.60283e-02
# 2  rs1045253 0.5136 4.15132e-02
# 3  rs1046188 0.9360 5.73307e-05
# 4  rs1052176 0.9503 9.79685e-05
# 5  rs1052177 0.9618 9.81453e-05
# 6 rs10752611 0.4470 1.30900e-03
# [1] 149
# [1] "checkingrs76763715 FDPS blood"
# [1] "files exist"
# [1] "df:"
#         rsid pval.x     pval.y
# 1  rs1045253 0.5136 1.9554e-10
# 2  rs1046188 0.9360 4.5298e-14
# 3  rs1052176 0.9503 5.0370e-16
# 4  rs1052177 0.9618 1.0713e-15
# 5 rs10752611 0.4470 3.2241e-21
# 6  rs1076556 0.9012 1.0721e-14
# [1] 150
# [1] "checkingrs76763715 FDPS brain"
# [1] "files exist"
# [1] "df:"
#         rsid pval.x      pval.y
# 1  rs1010225 0.1703 3.60283e-02
# 2  rs1045253 0.5136 4.15132e-02
# 3  rs1046188 0.9360 5.73307e-05
# 4  rs1052176 0.9503 9.79685e-05
# 5  rs1052177 0.9618 9.81453e-05
# 6 rs10752611 0.4470 1.30900e-03
# [1] 151
# [1] "checkingrs114138760 FLAD1 blood"
# [1] "files exist"
# [1] 152
# [1] "checkingrs114138760 FLAD1 brain"
# [1] "files exist"
# [1] "df:"
#          rsid    pval.x      pval.y
# 1  rs10796927 0.9895000 0.001451070
# 2  rs10908421 0.9121000 0.000472722
# 3  rs10908449 0.0005503 0.049357300
# 4 rs111301013 0.8626000 0.008908010
# 5 rs111885536 0.7114000 0.027051800
# 6  rs11264237 0.9263000 0.000472332
# [1] 153
# [1] "checkingrs35749011 FLAD1 blood"
# [1] "files exist"
# [1] 154
# [1] "checkingrs35749011 FLAD1 brain"
# [1] "files exist"
# [1] "df:"
#          rsid    pval.x      pval.y
# 1  rs10796927 0.9895000 0.001451070
# 2  rs10908421 0.9121000 0.000472722
# 3  rs10908449 0.0005503 0.049357300
# 4 rs111301013 0.8626000 0.008908010
# 5 rs111885536 0.7114000 0.027051800
# 6  rs11264237 0.9263000 0.000472332
# [1] "we have the risk snp!!!"
# [1] 155
# [1] "checkingrs76763715 FLAD1 blood"
# [1] "files exist"
# [1] 156
# [1] "checkingrs76763715 FLAD1 brain"
# [1] "files exist"
# [1] "df:"
#          rsid    pval.x      pval.y
# 1  rs10796927 0.9895000 0.001451070
# 2  rs10908421 0.9121000 0.000472722
# 3  rs10908449 0.0005503 0.049357300
# 4 rs111301013 0.8626000 0.008908010
# 5 rs111885536 0.7114000 0.027051800
# 6  rs11264237 0.9263000 0.000472332
# [1] 157
# [1] "checkingrs114138760 GBA blood"
# [1] "files exist"
# [1] "df:"
#         rsid    pval.x     pval.y
# 1  rs1007170 1.006e-01 2.8632e-06
# 2 rs10157801 1.502e-05 2.7508e-06
# 3  rs1045253 5.136e-01 1.0540e-88
# 4 rs10458626 1.355e-01 7.6554e-06
# 5  rs1046188 9.360e-01 1.4999e-71
# 6  rs1052176 9.503e-01 9.2576e-68
# [1] 158
# [1] "checkingrs114138760 GBA brain"
# [1] "files exist"
# [1] "df:"
#         rsid    pval.x      pval.y
# 1 rs10157801 1.502e-05 0.006644800
# 2  rs1045253 5.136e-01 0.017964800
# 3 rs10737170 1.072e-10 0.014581800
# 4 rs10796938 3.829e-08 0.011763200
# 5 rs10796939 1.737e-05 0.000594428
# 6 rs10796940 4.679e-01 0.019220500
# [1] 159
# [1] "checkingrs35749011 GBA blood"
# [1] "files exist"
# [1] "df:"
#         rsid    pval.x     pval.y
# 1  rs1007170 1.006e-01 2.8632e-06
# 2 rs10157801 1.502e-05 2.7508e-06
# 3  rs1045253 5.136e-01 1.0540e-88
# 4 rs10458626 1.355e-01 7.6554e-06
# 5  rs1046188 9.360e-01 1.4999e-71
# 6  rs1052176 9.503e-01 9.2576e-68
# [1] "we have the risk snp!!!"
# [1] 160
# [1] "checkingrs35749011 GBA brain"
# [1] "files exist"
# [1] "df:"
#         rsid    pval.x      pval.y
# 1 rs10157801 1.502e-05 0.006644800
# 2  rs1045253 5.136e-01 0.017964800
# 3 rs10737170 1.072e-10 0.014581800
# 4 rs10796938 3.829e-08 0.011763200
# 5 rs10796939 1.737e-05 0.000594428
# 6 rs10796940 4.679e-01 0.019220500
# [1] 161
# [1] "checkingrs76763715 GBA blood"
# [1] "files exist"
# [1] "df:"
#         rsid    pval.x     pval.y
# 1  rs1007170 1.006e-01 2.8632e-06
# 2 rs10157801 1.502e-05 2.7508e-06
# 3  rs1045253 5.136e-01 1.0540e-88
# 4 rs10458626 1.355e-01 7.6554e-06
# 5  rs1046188 9.360e-01 1.4999e-71
# 6  rs1052176 9.503e-01 9.2576e-68
# [1] 162
# [1] "checkingrs76763715 GBA brain"
# [1] "files exist"
# [1] "df:"
#         rsid    pval.x      pval.y
# 1 rs10157801 1.502e-05 0.006644800
# 2  rs1045253 5.136e-01 0.017964800
# 3 rs10737170 1.072e-10 0.014581800
# 4 rs10796938 3.829e-08 0.011763200
# 5 rs10796939 1.737e-05 0.000594428
# 6 rs10796940 4.679e-01 0.019220500
# [1] 163
# [1] "checkingrs114138760 GBAP1 blood"
# [1] "files exist"
# [1] "df:"
#         rsid    pval.x        pval.y
# 1  rs1001848 3.518e-07  3.674800e-58
# 2 rs10047112 1.480e-01  1.684500e-49
# 3 rs10157801 1.502e-05 1.010900e-265
# 4  rs1045253 5.136e-01 1.128895e-308
# 5 rs10458626 1.355e-01  4.591100e-23
# 6  rs1046188 9.360e-01 1.128895e-308
# [1] 164
# [1] "checkingrs114138760 GBAP1 brain"
# [1] "files exist"
# [1] "df:"
#         rsid  pval.x      pval.y
# 1  rs1045253 0.51360 3.42679e-03
# 2  rs1046188 0.93600 5.14094e-05
# 3  rs1052176 0.95030 8.50188e-05
# 4  rs1052177 0.96180 8.50502e-05
# 5 rs10752605 0.01629 1.96194e-02
# 6 rs10752606 0.94770 3.73627e-02
# [1] 165
# [1] "checkingrs35749011 GBAP1 blood"
# [1] "files exist"
# [1] "df:"
#         rsid    pval.x        pval.y
# 1  rs1001848 3.518e-07  3.674800e-58
# 2 rs10047112 1.480e-01  1.684500e-49
# 3 rs10157801 1.502e-05 1.010900e-265
# 4  rs1045253 5.136e-01 1.128895e-308
# 5 rs10458626 1.355e-01  4.591100e-23
# 6  rs1046188 9.360e-01 1.128895e-308
# [1] "we have the risk snp!!!"
# [1] 166
# [1] "checkingrs35749011 GBAP1 brain"
# [1] "files exist"
# [1] "df:"
#         rsid  pval.x      pval.y
# 1  rs1045253 0.51360 3.42679e-03
# 2  rs1046188 0.93600 5.14094e-05
# 3  rs1052176 0.95030 8.50188e-05
# 4  rs1052177 0.96180 8.50502e-05
# 5 rs10752605 0.01629 1.96194e-02
# 6 rs10752606 0.94770 3.73627e-02
# [1] 167
# [1] "checkingrs76763715 GBAP1 blood"
# [1] "files exist"
# [1] "df:"
#         rsid    pval.x        pval.y
# 1  rs1001848 3.518e-07  3.674800e-58
# 2 rs10047112 1.480e-01  1.684500e-49
# 3 rs10157801 1.502e-05 1.010900e-265
# 4  rs1045253 5.136e-01 1.128895e-308
# 5 rs10458626 1.355e-01  4.591100e-23
# 6  rs1046188 9.360e-01 1.128895e-308
# [1] 168
# [1] "checkingrs76763715 GBAP1 brain"
# [1] "files exist"
# [1] "df:"
#         rsid  pval.x      pval.y
# 1  rs1045253 0.51360 3.42679e-03
# 2  rs1046188 0.93600 5.14094e-05
# 3  rs1052176 0.95030 8.50188e-05
# 4  rs1052177 0.96180 8.50502e-05
# 5 rs10752605 0.01629 1.96194e-02
# 6 rs10752606 0.94770 3.73627e-02
# [1] 169
# [1] "checkingrs114138760 GON4L blood"
# [1] "files exist"
# [1] 170
# [1] "checkingrs114138760 GON4L brain"
# [1] "files exist"
# [1] "df:"
#         rsid    pval.x    pval.y
# 1  rs1001848 3.518e-07 0.0244532
# 2 rs10082042 8.547e-02 0.0264491
# 3 rs10157555 2.392e-01 0.0482337
# 4 rs10796939 1.737e-05 0.0275278
# 5 rs10796955 7.241e-02 0.0432947
# 6 rs10908454 2.704e-07 0.0248384
# [1] 171
# [1] "checkingrs35749011 GON4L blood"
# [1] "files exist"
# [1] 172
# [1] "checkingrs35749011 GON4L brain"
# [1] "files exist"
# [1] "df:"
#         rsid    pval.x    pval.y
# 1  rs1001848 3.518e-07 0.0244532
# 2 rs10082042 8.547e-02 0.0264491
# 3 rs10157555 2.392e-01 0.0482337
# 4 rs10796939 1.737e-05 0.0275278
# 5 rs10796955 7.241e-02 0.0432947
# 6 rs10908454 2.704e-07 0.0248384
# [1] 173
# [1] "checkingrs76763715 GON4L blood"
# [1] "files exist"
# [1] 174
# [1] "checkingrs76763715 GON4L brain"
# [1] "files exist"
# [1] "df:"
#         rsid    pval.x    pval.y
# 1  rs1001848 3.518e-07 0.0244532
# 2 rs10082042 8.547e-02 0.0264491
# 3 rs10157555 2.392e-01 0.0482337
# 4 rs10796939 1.737e-05 0.0275278
# 5 rs10796955 7.241e-02 0.0432947
# 6 rs10908454 2.704e-07 0.0248384
# [1] 175
# [1] "checkingrs114138760 HAX1 blood"
# [1] "files exist"
# [1] "df:"
#         rsid   pval.x      pval.y
# 1 rs10127983 0.006395  4.0199e-52
# 2 rs10157443 0.005397  3.1372e-08
# 3 rs10158450 0.052460  5.4374e-18
# 4 rs10158820 0.027050 8.3074e-112
# 5  rs1043608 0.007233  8.4074e-55
# 6  rs1044013 0.009971 1.1036e-137
# [1] 176
# [1] "checkingrs114138760 HAX1 brain"
# [1] "files exist"
# [1] "df:"
#         rsid   pval.x      pval.y
# 1 rs10047079 0.052370 0.025887800
# 2 rs10127983 0.006395 0.001172360
# 3 rs10158450 0.052460 0.047524800
# 4 rs10158820 0.027050 0.001160460
# 5  rs1043608 0.007233 0.000973228
# 6  rs1044013 0.009971 0.002012200
# [1] 177
# [1] "checkingrs35749011 HAX1 blood"
# [1] "files exist"
# [1] "df:"
#         rsid   pval.x      pval.y
# 1 rs10127983 0.006395  4.0199e-52
# 2 rs10157443 0.005397  3.1372e-08
# 3 rs10158450 0.052460  5.4374e-18
# 4 rs10158820 0.027050 8.3074e-112
# 5  rs1043608 0.007233  8.4074e-55
# 6  rs1044013 0.009971 1.1036e-137
# [1] 178
# [1] "checkingrs35749011 HAX1 brain"
# [1] "files exist"
# [1] "df:"
#         rsid   pval.x      pval.y
# 1 rs10047079 0.052370 0.025887800
# 2 rs10127983 0.006395 0.001172360
# 3 rs10158450 0.052460 0.047524800
# 4 rs10158820 0.027050 0.001160460
# 5  rs1043608 0.007233 0.000973228
# 6  rs1044013 0.009971 0.002012200
# [1] 179
# [1] "checkingrs76763715 HAX1 blood"
# [1] "files exist"
# [1] "df:"
#         rsid   pval.x      pval.y
# 1 rs10127983 0.006395  4.0199e-52
# 2 rs10157443 0.005397  3.1372e-08
# 3 rs10158450 0.052460  5.4374e-18
# 4 rs10158820 0.027050 8.3074e-112
# 5  rs1043608 0.007233  8.4074e-55
# 6  rs1044013 0.009971 1.1036e-137
# [1] 180
# [1] "checkingrs76763715 HAX1 brain"
# [1] "files exist"
# [1] "df:"
#         rsid   pval.x      pval.y
# 1 rs10047079 0.052370 0.025887800
# 2 rs10127983 0.006395 0.001172360
# 3 rs10158450 0.052460 0.047524800
# 4 rs10158820 0.027050 0.001160460
# 5  rs1043608 0.007233 0.000973228
# 6  rs1044013 0.009971 0.002012200
# [1] 181
# [1] "checkingrs114138760 HCN3 blood"
# [1] "files exist"
# [1] "df:"
#         rsid pval.x     pval.y
# 1  rs1045253 0.5136 3.8225e-11
# 2  rs1046188 0.9360 2.5738e-13
# 3  rs1052176 0.9503 1.3458e-14
# 4  rs1052177 0.9618 1.4372e-14
# 5 rs10752611 0.4470 5.2991e-15
# 6  rs1076556 0.9012 2.5623e-13
# [1] 182
# [1] "checkingrs114138760 HCN3 brain"
# [1] "files exist"
# [1] "df:"
#         rsid  pval.x      pval.y
# 1 rs10047079 0.05237 4.62215e-02
# 2  rs1045253 0.51360 8.40443e-04
# 3  rs1046188 0.93600 1.31032e-08
# 4  rs1052176 0.95030 1.02527e-09
# 5  rs1052177 0.96180 1.02655e-09
# 6 rs10752611 0.44700 4.89254e-05
# [1] 183
# [1] "checkingrs35749011 HCN3 blood"
# [1] "files exist"
# [1] "df:"
#         rsid pval.x     pval.y
# ...
# [1] "files exist"
# [1] "df:"
#         rsid pval.x     pval.y
# 1 rs10084339 0.8289 2.1693e-46
# 2 rs10166900 0.7811 8.6031e-08
# 3 rs10171847 0.2879 1.6020e-27
# 4 rs10173746 0.3561 1.5818e-17
# 5 rs10176756 0.8057 1.5165e-16
# 6 rs10181743 0.7278 2.0520e-20
# [1] 5712
# [1] "checkingrs11683001 RPL31 brain"
# [1] "files exist"
# [1] "df:"
#         rsid  pval.x     pval.y
# 1 rs10166048 0.26720 0.01188690
# 2 rs10171625 0.47610 0.02178830
# 3 rs10172037 0.63790 0.03534660
# 4 rs10172286 0.01862 0.00972024
# 5 rs10181743 0.72780 0.01225150
# 6 rs10182772 0.03996 0.00128000
# [1] 5713
# [1] "checkingrs11683001 SLC9A2 blood"
# [1] "files exist"
# [1] 5714
# [1] "checkingrs11683001 SLC9A2 brain"
# [1] "files exist"
# [1] "df:"
#         rsid  pval.x      pval.y
# 1  rs1008397 0.15000 2.35537e-08
# 2 rs10084206 0.07079 2.02753e-02
# 3 rs10166330 0.21820 1.50819e-02
# 4 rs10166535 0.78640 3.31701e-02
# 5 rs10168222 0.33240 2.99404e-02
# 6 rs10169676 0.20830 1.35244e-02
# [1] 5715
# [1] "checkingrs11683001 SLC9A4 blood"
# [1] "files exist"
# [1] 5716
# [1] "checkingrs11683001 SLC9A4 brain"
# [1] "files exist"
# [1] "df:"
#         rsid  pval.x     pval.y
# 1 rs10084206 0.07079 0.00147195
# 2 rs10460489 0.04280 0.00122330
# 3 rs10460490 0.34990 0.00124906
# 4 rs17026386 0.01906 0.00248970
# 5 rs17026501 0.03138 0.00102005
# 6 rs17026510 0.03216 0.00175369
# [1] 5717
# [1] "checkingrs11683001 SNORD89 blood"
# [1] "files exist"
# [1] "df:"
#         rsid  pval.x      pval.y
# 1 rs10084339 0.82890  1.1218e-08
# 2 rs10166863 0.45660 2.5917e-270
# 3 rs10166900 0.78110  1.3481e-94
# 4 rs10168430 0.01446  3.4032e-10
# 5 rs10170982 0.85350  2.7809e-13
# 6 rs10171484 0.83800  2.9497e-10
# [1] 5718
# [1] "checkingrs11683001 SNORD89 brain"
# [1] "files exist"
# [1] "df:"
#         rsid pval.x      pval.y
# 1 rs10166863 0.4566 1.13999e-03
# 2 rs10166900 0.7811 4.01478e-02
# 3 rs10170109 0.1407 3.27879e-02
# 4 rs10176778 0.2735 2.35400e-03
# 5 rs10177965 0.6650 5.52527e-05
# 6 rs10179426 0.7028 4.52177e-02
# [1] 5719
# [1] "checkingrs11683001 TBC1D8 blood"
# [1] "files exist"
# [1] "df:"
#         rsid  pval.x      pval.y
# 1 rs10164638 0.05733  2.0202e-10
# 2 rs10165970 0.52260  4.5704e-06
# 3 rs10168430 0.01446  1.8042e-06
# 4 rs10171847 0.28790  3.4562e-58
# 5 rs10172545 0.19230  1.0147e-11
# 6 rs10173746 0.35610 2.4766e-153
# [1] 5720
# [1] "checkingrs11683001 TBC1D8 brain"
# [1] "files exist"
# [1] "df:"
#         rsid  pval.x      pval.y
# 1 rs10084339 0.82890 2.47186e-07
# 2 rs10166865 0.02668 3.67565e-02
# 3 rs10174721 0.09427 2.60564e-02
# 4 rs10180350 0.15220 3.59820e-02
# 5 rs10181743 0.72780 1.67064e-02
# 6 rs10182072 0.09682 2.71849e-02
# [1] 5721
# [1] "checkingrs11683001 TBC1D8-AS1 blood"
# [1] "files exist"
# [1] 5722
# [1] "checkingrs11683001 TBC1D8-AS1 brain"
# [1] 5723
# [1] "checkingrs11683001 TMEM182 blood"
# [1] "files exist"
# [1] 5724
# [1] "checkingrs11683001 TMEM182 brain"
# [1] "files exist"
# [1] "df:"
#         rsid  pval.x     pval.y
# 1  rs1007027 0.60350 0.03591450
# 2 rs10171438 0.04528 0.01941430
# 3 rs10172553 0.01975 0.02466110
# 4  rs1019296 0.53830 0.01072260
# 5 rs10193009 0.04379 0.01448970
# 6 rs10194822 0.02651 0.00803174
# [1] 5725
# [1] "checkingrs61863020 ADRA2A blood"
# [1] "files exist"
# [1] "df:"
#         rsid  pval.x     pval.y
# 1 rs10159575 0.14130 6.1723e-06
# 2 rs10160085 0.15420 7.1626e-06
# 3 rs10160191 0.12070 1.9316e-07
# 4 rs10437458 0.14560 3.6110e-07
# 5 rs10466194 0.06355 2.4537e-07
# 6 rs10885089 0.06035 2.6185e-08
# [1] 5726
# [1] "checkingrs61863020 ADRA2A brain"
# [1] "files exist"
# [1] "df:"
#         rsid  pval.x    pval.y
# 1 rs10160191 0.12810 0.0159829
# 2 rs10466194 0.13890 0.0187161
# 3 rs10509950 0.73520 0.0340338
# 4 rs10509951 0.72990 0.0207608
# 5 rs10509955 0.08720 0.0338388
# 6 rs10787271 0.02562 0.0116220
# [1] "we have the risk snp!!!"
# [1] 5727
# [1] "checkingrs61863020 BBIP1 blood"
# [1] "files exist"
# [1] "df:"
#         rsid  pval.x     pval.y
# 1 rs10082499 0.71270 2.7529e-17
# 2 rs10444029 0.28870 1.6655e-23
# 3 rs10509932 0.30290 1.0762e-13
# 4 rs10509933 0.47540 9.5997e-06
# 5 rs10509938 0.35560 8.5631e-06
# 6  rs1052550 0.06231 2.3119e-13
# [1] 5728
# [1] "checkingrs61863020 BBIP1 brain"
# [1] "files exist"
# [1] "df:"
#          rsid  pval.x     pval.y
# 1  rs10884960 0.28280 0.00600816
# 2  rs10884961 0.34500 0.00610612
# 3  rs10885100 0.53040 0.03652490
# 4 rs111865377 0.01163 0.02114770
# 5  rs11195116 0.35810 0.03443750
# 6  rs11195118 0.27300 0.00441202
# [1] 5729
# [1] "checkingrs61863020 DUSP5 blood"
# [1] "files exist"
# [1] "df:"
#         rsid pval.x     pval.y
# 1  rs1000752 0.9290 2.0842e-17
# 2  rs1000753 0.7813 3.2226e-17
# 3  rs1042606 0.7143 8.9037e-67
# 4 rs10444086 0.8670 2.7686e-16
# 5  rs1050755 0.7139 1.8342e-07
# 6 rs10509914 0.7362 1.1169e-05
# [1] 5730
# [1] "checkingrs61863020 DUSP5 brain"
# [1] "files exist"
# [1] "df:"
#         rsid pval.x    pval.y
# 1 rs10509921 0.8804 0.0350399
# 2 rs10509922 0.9136 0.0347932
# 3 rs10509933 0.2292 0.0408496
# 4 rs10787308 0.5459 0.0222161
# 5 rs10884835 0.5996 0.0326746
# 6 rs10884836 0.6560 0.0484430
# [1] 5731
# [1] "checkingrs61863020 GPAM blood"
# [1] "files exist"
# [1] "df:"
#          rsid   pval.x     pval.y
# 1 rs138148681 0.218300 3.2464e-08
# 2 rs144052556 0.075790 5.3149e-09
# 3 rs145271503 0.183900 5.4705e-12
# 4   rs2792742 0.093550 5.5792e-12
# 5   rs2792744 0.044550 1.5831e-05
# 6  rs35116854 0.003629 4.1461e-19
# [1] 5732
# [1] "checkingrs61863020 GPAM brain"
# [1] "files exist"
# [1] "df:"
#         rsid pval.x    pval.y
# 1  rs1028629 0.6761 0.0426669
# 2 rs10509938 0.8195 0.0117405
# 3 rs10509955 0.0872 0.0487819
# 4 rs10509956 0.7715 0.0248180
# 5 rs10749102 0.9500 0.0169570
# 6  rs1078288 0.7818 0.0303212
# [1] 5733
# [1] "checkingrs61863020 HEAT2 blood"
# [1] "files exist"
# [1] 5734
# [1] "checkingrs61863020 HEAT2 brain"
# [1] 5735
# [1] "checkingrs61863020 MIR4680 blood"
# [1] "files exist"
# [1] 5736
# [1] "checkingrs61863020 MIR4680 brain"
# [1] 5737
# [1] "checkingrs61863020 MIR548E blood"
# [1] "files exist"
# [1] 5738
# [1] "checkingrs61863020 MIR548E brain"
# [1] 5739
# [1] "checkingrs61863020 MXI1 blood"
# [1] "files exist"
# [1] "df:"
#         rsid pval.x      pval.y
# 1  rs1000752 0.9290  5.2181e-10
# 2  rs1000753 0.7813  6.4020e-10
# 3  rs1023067 0.6371  4.6364e-30
# 4  rs1023068 0.5538  7.0802e-53
# 5 rs10466193 0.8135  6.8893e-09
# 6  rs1050755 0.7139 7.7810e-148
# [1] 5740
# [1] "checkingrs61863020 MXI1 brain"
# [1] "files exist"
# [1] "df:"
#         rsid pval.x      pval.y
# 1  rs1009532 0.7579 0.000450739
# 2 rs10399964 0.7097 0.000680592
# 3 rs10437458 0.5210 0.035583200
# 4 rs10466193 0.9410 0.000355813
# 5 rs10509907 0.9373 0.000157552
# 6 rs10509912 0.6185 0.003176270
# [1] 5741
# [1] "checkingrs61863020 PDCD4 blood"
# [1] "files exist"
# [1] "df:"
#         rsid pval.x      pval.y
# 1 rs10082499 0.7127  1.7303e-07
# 2 rs10159575 0.1413  8.6351e-06
# 3 rs10160085 0.1542  1.6178e-05
# 4 rs10437458 0.1456  3.2874e-08
# 5 rs10444029 0.2887 3.6068e-109
# 6 rs10509932 0.3029  3.2564e-37
# [1] 5742
# [1] "checkingrs61863020 PDCD4 brain"
# [1] "files exist"
# [1] "df:"
#         rsid pval.x     pval.y
# 1 rs10509925 0.3172 0.01090650
# 2 rs10749097 0.9624 0.04762850
# 3 rs10749099 0.9869 0.03355180
# 4 rs10749100 0.9682 0.03595770
# 5 rs10787279 0.2767 0.04895230
# 6 rs10884962 0.4318 0.00671403
# [1] 5743
# [1] "checkingrs61863020 PDCD4-AS1 blood"
# [1] "files exist"
# [1] 5744
# [1] "checkingrs61863020 PDCD4-AS1 brain"
# [1] "files exist"
# [1] "df:"
#         rsid  pval.x      pval.y
# 1 rs10128296 0.92870 0.035972300
# 2 rs10509932 0.03111 0.001359250
# 3  rs1052550 0.04821 0.000272554
# 4 rs10787307 0.31400 0.020983000
# 5 rs10787377 0.38390 0.047964300
# 6 rs10787378 0.75930 0.029798100
# [1] 5745
# [1] "checkingrs61863020 RBM20 blood"
# [1] "files exist"
# [1] "df:"
#         rsid pval.x     pval.y
# 1 rs10509927 0.4023 2.7403e-10
# 2 rs10509928 0.4260 7.9964e-10
# 3 rs10787254 0.6835 5.7113e-09
# 4 rs10787260 0.9517 1.8368e-06
# 5 rs10787284 0.3144 9.8982e-17
# 6 rs10884991 0.6599 9.7043e-10
# [1] 5746
# [1] "checkingrs61863020 RBM20 brain"
# [1] "files exist"
# [1] "df:"
#         rsid    pval.x     pval.y
# 1 rs10160156 0.4503000 0.01749770
# 2 rs10509924 0.7762000 0.03887110
# 3 rs10509925 0.3172000 0.00365292
# 4 rs10509929 0.0006541 0.01949170
# 5 rs10787259 0.3737000 0.00125109
# 6 rs10787263 0.1131000 0.02567940
# [1] 5747
# [1] "checkingrs61863020 RPL13AP6 blood"
# [1] "files exist"
# [1] 5748
# [1] "checkingrs61863020 RPL13AP6 brain"
# [1] "files exist"
# [1] "df:"
#         rsid pval.x     pval.y
# 1 rs10430679 0.6455 0.03539250
# 2 rs10437458 0.5210 0.02819200
# 3  rs1078289 0.8598 0.03438730
# 4 rs10787230 0.6060 0.03654140
# 5 rs10787307 0.3140 0.00918784
# 6 rs10787308 0.5459 0.03625330
# [1] 5749
# [1] "checkingrs61863020 SHOC2 blood"
# [1] "files exist"
# [1] "df:"
#          rsid  pval.x     pval.y
# 1  rs10509932 0.03111 1.3930e-14
# 2   rs1052550 0.04821 3.0074e-14
# 3  rs10885057 0.38900 1.6135e-05
# 4 rs114425353 0.05886 1.0696e-15
# 5 rs115035566 0.01499 7.2754e-15
# 6 rs115612781 0.03111 8.0494e-15
# [1] 5750
# [1] "checkingrs61863020 SHOC2 brain"
# [1] "files exist"
# [1] "df:"
#         rsid pval.x     pval.y
# 1 rs10082499 0.5167 0.00709193
# 2 rs10509915 0.8445 0.00918325
# 3 rs10509916 0.9978 0.01348700
# 4 rs10749104 0.5962 0.02461690
# 5 rs10787225 0.4562 0.01434900
# 6 rs10787228 0.6981 0.01331120
# [1] 5751
# [1] "checkingrs61863020 SMC3 blood"
# [1] "files exist"
# [1] "df:"
#         rsid pval.x     pval.y
# 1 rs10787254 0.6835 2.6916e-16
# 2 rs10884991 0.6599 1.8709e-14
# 3 rs10884993 0.7053 3.2437e-18
# 4 rs10884994 0.7053 6.1675e-18
# 5 rs10884995 0.5634 1.5016e-14
# 6 rs10884997 0.6817 2.1554e-14
# [1] 5752
# [1] "checkingrs61863020 SMC3 brain"
# [1] "files exist"
# [1] "df:"
#         rsid  pval.x    pval.y
# 1 rs10509899 0.99120 0.0169002
# 2 rs10509901 0.75040 0.0142460
# 3 rs10787157 0.95400 0.0230475
# 4 rs10787186 0.72210 0.0213647
# 5 rs10787260 0.95170 0.0182284
# 6 rs10787271 0.02562 0.0342121
# [1] 5753
# [1] "checkingrs61863020 SMNDC1 blood"
# [1] "files exist"
# [1] "df:"
#         rsid pval.x     pval.y
# 1 rs10509915 0.8445 2.8316e-18
# 2 rs10509916 0.9978 2.0121e-15
# 3 rs10787228 0.6981 1.6700e-18
# 4 rs10787229 0.8232 5.5050e-16
# 5 rs10884939 0.5273 4.7432e-14
# 6 rs10884948 0.6981 1.1466e-18
# [1] 5754
# [1] "checkingrs61863020 SMNDC1 brain"
# [1] "files exist"
# [1] "df:"
#         rsid pval.x    pval.y
# 1 rs10437491 0.3572 0.0397166
# 2 rs10437492 0.3572 0.0397166
# 3 rs10509905 0.7770 0.0481029
# 4 rs10509915 0.8445 0.0214315
# 5 rs10509916 0.9978 0.0333673
# 6 rs10787228 0.6981 0.0335315
# [1] 5755
# [1] "checkingrs382940 ABCA1 blood"
# [1] "files exist"
# [1] "df:"
#         rsid  pval.x     pval.y
# 1  rs1039407 0.14830 1.2691e-19
# 2 rs10512336 0.44940 6.7432e-10
# 3 rs10512337 0.44940 4.9842e-10
# 4 rs10512338 0.45020 1.1621e-10
# 5 rs10521071 0.05781 4.4805e-09
# 6 rs10739907 0.20030 8.4581e-33
# [1] 5756
# [1] "checkingrs382940 ABCA1 brain"
# [1] "files exist"
# [1] "df:"
#         rsid pval.x     pval.y
# 1 rs10115620 0.8543 0.01913830
# 2 rs10117106 0.3953 0.02792530
# 3 rs10118910 0.6995 0.00343073
# 4 rs10123964 0.2855 0.03019790
# 5  rs1018848 0.4336 0.00614662
# 6  rs1018849 0.4422 0.01247430
# [1] 5757
# [1] "checkingrs382940 FKTN blood"
# [1] "files exist"
# [1] "df:"
#         rsid  pval.x     pval.y
# 1 rs10118910 0.69950 4.4070e-06
# 2  rs1018847 0.06662 1.4642e-40
# 3  rs1018848 0.43360 2.0468e-08
# 4  rs1018849 0.44220 2.8991e-13
# 5  rs1024366 0.51140 1.1621e-10
# 6 rs10491808 0.08023 1.5911e-40
# [1] 5758
# [1] "checkingrs382940 FKTN brain"
# [1] "files exist"
# [1] "df:"
#         rsid pval.x      pval.y
# 1  rs1001918 0.5654 3.25643e-02
# 2 rs10116808 0.1580 2.06123e-02
# 3 rs10123964 0.2855 3.50433e-02
# 4  rs1018848 0.4336 3.10453e-07
# 5  rs1018849 0.4422 2.77532e-06
# 6  rs1018850 0.3795 1.72741e-05
# [1] 5759
# [1] "checkingrs382940 FSD1L blood"
# [1] "files exist"
# [1] "df:"
#         rsid  pval.x     pval.y
# 1  rs1018847 0.06662 1.1675e-08
# 2 rs10491808 0.08023 4.8804e-09
# 3 rs10816284 0.99990 4.3127e-14
# 4 rs10991676 0.03916 2.4214e-15
# 5 rs12115847 0.08904 2.7921e-08
# 6 rs17250623 0.09999 4.8261e-08
# [1] 5760
# [1] "checkingrs382940 FSD1L brain"
# [1] "files exist"
# [1] "df:"
#         rsid  pval.x      pval.y
# 1 rs10121901 0.65610 3.23884e-02
# 2  rs1018847 0.06662 4.18713e-08
# 3 rs10491808 0.08023 2.55725e-08
# 4 rs10512343 0.43590 2.74105e-02
# 5 rs10512345 0.91300 2.28871e-03
# 6 rs10816284 0.99990 1.27442e-06
# [1] 5761
# [1] "checkingrs382940 NIPSNAP3A blood"
# [1] "files exist"
# [1] "df:"
#         rsid pval.x      pval.y
# 1 rs10113881 0.8579  1.2482e-05
# 2 rs10113927 0.8542  1.3295e-05
# 3 rs10113957 0.5930  1.6361e-13
# 4 rs10113996 0.5930  1.4995e-13
# 5 rs10114059 0.5704 2.4514e-231
# 6 rs10114519 0.7049  1.6878e-07
# [1] 5762
# [1] "checkingrs382940 NIPSNAP3A brain"
# [1] "files exist"
# [1] "df:"
#         rsid pval.x      pval.y
# 1 rs10116587 0.2493 3.54782e-36
# 2 rs10117535 0.1047 6.46323e-22
# 3 rs10117760 0.6962 2.38364e-12
# 4 rs10118395 0.9335 9.48193e-11
# 5 rs10118764 0.3901 3.47108e-37
# 6 rs10118910 0.6995 3.57909e-02
# [1] 5763
# [1] "checkingrs382940 NIPSNAP3B blood"
# [1] "files exist"
# [1] "df:"
#         rsid pval.x     pval.y
# 1 rs10114059 0.5704 2.0318e-07
# 2 rs10114993 0.5669 4.2279e-07
# 3 rs10115334 0.5590 1.3833e-06
# 4 rs10115731 0.5585 2.2718e-07
# 5 rs10116587 0.2493 4.1988e-29
# 6 rs10117535 0.1047 1.1462e-47
# [1] 5764
# [1] "checkingrs382940 NIPSNAP3B brain"
# [1] "files exist"
# [1] "df:"
#         rsid  pval.x    pval.y
# 1 rs10081753 0.94040 0.0373465
# 2 rs10115620 0.85430 0.0248810
# 3 rs10120087 0.29700 0.0493061
# 4 rs10120853 0.05652 0.0337808
# 5 rs10123330 0.31280 0.0156246
# 6  rs1018847 0.06662 0.0047864
# [1] 5765
# [1] "checkingrs382940 OR13C2 blood"
# [1] "files exist"
# [1] 5766
# [1] "checkingrs382940 OR13C2 brain"
# [1] "files exist"
# [1] "df:"
#         rsid pval.x     pval.y
# 1 rs10124625 0.5924 0.04384200
# 2 rs10512319 0.0281 0.01822610
# 3 rs10761009 0.9088 0.01771400
# 4 rs10820595 0.6047 0.00893457
# 5 rs10990921 0.2825 0.03121690
# 6 rs10990923 0.2602 0.01918050
# [1] 5767
# [1] "checkingrs382940 OR13C3 blood"
# [1] "files exist"
# [1] 5768
# [1] "checkingrs382940 OR13C3 brain"
# [1] 5769
# [1] "checkingrs382940 OR13C4 blood"
# [1] "files exist"
# [1] 5770
# [1] "checkingrs382940 OR13C4 brain"
# [1] 5771
# [1] "checkingrs382940 OR13C5 blood"
# [1] "files exist"
# [1] 5772
# [1] "checkingrs382940 OR13C5 brain"
# [1] "files exist"
# [1] "df:"
#         rsid pval.x     pval.y
# 1 rs10114059 0.5704 0.04787160
# 2 rs10114993 0.5669 0.03328310
# 3 rs10114997 0.8127 0.01452750
# 4 rs10115645 0.8826 0.01132270
# 5 rs10116587 0.2493 0.02100720
# 6 rs10117760 0.6962 0.00590043
# [1] "we have the risk snp!!!"
# [1] 5773
# [1] "checkingrs382940 OR13C8 blood"
# [1] "files exist"
# [1] 5774
# [1] "checkingrs382940 OR13C8 brain"
# [1] 5775
# [1] "checkingrs382940 OR13C9 blood"
# [1] "files exist"
# [1] 5776
# [1] "checkingrs382940 OR13C9 brain"
# [1] 5777
# [1] "checkingrs382940 OR13D1 blood"
# [1] "files exist"
# [1] 5778
# [1] "checkingrs382940 OR13D1 brain"
# [1] 5779
# [1] "checkingrs382940 OR13F1 blood"
# [1] "files exist"
# [1] 5780
# [1] "checkingrs382940 OR13F1 brain"
# [1] 5781
# [1] "checkingrs382940 RALGAPA1P1 blood"
# [1] "files exist"
# [1] 5782
# [1] "checkingrs382940 RALGAPA1P1 brain"
# [1] 5783
# [1] "checkingrs382940 SLC44A1 blood"
# [1] "files exist"
# [1] "df:"
#         rsid pval.x     pval.y
# 1 rs10123152 0.2875 2.0921e-12
# 2 rs10123494 0.2486 1.0903e-07
# 3 rs10124728 0.8991 1.3804e-08
# 4 rs10124755 0.8263 5.6861e-08
# 5 rs10512336 0.4494 3.9184e-09
# 6 rs10512337 0.4494 5.1764e-09
# [1] 5784
# [1] "checkingrs382940 SLC44A1 brain"
# [1] "files exist"
# [1] "df:"
#         rsid  pval.x     pval.y
# 1 rs10115953 0.87730 0.01239410
# 2 rs10116972 0.06281 0.03573330
# 3 rs10124823 0.94970 0.02737310
# 4 rs10156597 0.38920 0.00820823
# 5 rs10217335 0.29560 0.02837000
# 6 rs10217476 0.27010 0.03195430
# [1] 5785
# [1] "checkingrs382940 TAL2 blood"
# [1] "files exist"
# [1] 5786
# [1] "checkingrs382940 TAL2 brain"
# [1] "files exist"
# [1] "df:"
#         rsid pval.x     pval.y
# 1 rs10119948 0.7048 0.02139380
# 2 rs10123964 0.2855 0.01236580
# 3  rs1039407 0.1483 0.00355978
# 4 rs10512336 0.4494 0.00744757
# 5 rs10512337 0.4494 0.00397137
# 6 rs10512343 0.4359 0.01948180
# [1] 5787
# [1] "checkingrs382940 TMEM38B blood"
# [1] "files exist"
# [1] "df:"
#         rsid pval.x     pval.y
# 1 rs10115634 0.3969 1.2259e-22
# 2 rs10118720 0.4118 2.8261e-22
# 3 rs10118910 0.6995 5.5113e-07
# 4 rs10119254 0.4074 9.9967e-23
# 5 rs10119368 0.4522 1.0967e-11
# 6 rs10120372 0.3407 5.0112e-09
# [1] 5788
# [1] "checkingrs382940 TMEM38B brain"
# [1] "files exist"
# [1] "df:"
#         rsid  pval.x     pval.y
# 1 rs10119032 0.28850 0.04839790
# 2 rs10121901 0.65610 0.00392505
# 3 rs10123603 0.91100 0.03800780
# 4 rs10125107 0.05956 0.03331290
# 5  rs1024366 0.51140 0.01769250
# 6 rs10512335 0.31010 0.04974910

# %%
dim(plots_with_risk_snp)
head(plots_with_risk_snp)

write.csv(plots_with_risk_snp,file="$PATH1/qtl/plots_with_risk_snp.csv",row.names=F,col.names=F)
# Out:
#   File "<ipython-input-1-57bf1ef3d918>", line 4
#     write.csv(plots_with_risk_snp,file="$PATH1/qtl/plots_with_risk_snp.csv",row.names=F,col.names=F)
#                                                                            ^
# SyntaxError: keyword can't be an expression

# %%
dim(plots_with_no_data)
head(plots_with_no_data)

write.csv(plots_with_no_data,file="$PATH1/qtl/plots_with_no_data.csv",row.names=F,col.names=F)
# Out:
#   File "<ipython-input-2-e56009d91474>", line 4
#     write.csv(plots_with_no_data,file="$PATH1/qtl/plots_with_no_data.csv",row.names=F,col.names=F)
#                                                                          ^
# SyntaxError: keyword can't be an expression

# %%
dim(plots_to_check)
head(plots_to_check)

write.csv(plots_to_check,file="$PATH1/qtl/plots_to_check.csv",row.names=F,col.names=F)
# Out:
#   File "<ipython-input-3-1a7f5263e812>", line 4
#     write.csv(plots_to_check,file="$PATH1/qtl/plots_to_check.csv",row.names=F,col.names=F)
#                                                                  ^
# SyntaxError: keyword can't be an expression

# %% [markdown]
# ## (3) Obtain Proxy SNPS Per Locus
#
# use LDlinkR to generate a list of snps with a LD R2 > 0.7 for each risk variant
#
# run this in terminal. Queries must be made sequentially for LDlinkR to work (so don't bother changing the script to run in parallel)

# %%
print("Rscript getRiskSNPProxies.R")
# Out:
# [1] "Rscript getRiskSNPProxies.R"

# %% [markdown]
# ## (4) Check Plots for Proxy SNPs
#
# go through all the plots we know need checking and see if they have a proxy.
#
# write plots with a good proxy snp to a file. and then combine that file with the list of plots that already have the risk snp to create a final plot list file

# %%
proxy_dir <- "$PATH1/qtl/proxy_snps"

# %%
plots_to_check <- fread("$PATH1/qtl/plots_to_check.csv")
plots_with_proxy_snp <- data.frame()
plots_with_no_proxy_snp <- data.frame()

# %%
print(dim(plots_to_check))
# Out:
# [1] 3055    9

# %%
for (rownum in 1:nrow(plots_to_check))
{
    row <- plots_to_check[rownum,]

  
    chr <- row$CHR
    snp <- row$SNP
    gene <- row$Gene
    feature <- row$feature
    
    #get file path strings
    gwas_fn = paste0(tsv_dir, '/', gene, '_',feature,'_gwas.tsv')
    eqtl_fn = paste0(tsv_dir, '/', gene, '_',feature,'_eqtl.tsv')
    g = read.table(gwas_fn, header = T)
    e = read.table(eqtl_fn, header = T)

    #merge them by rsid
    df = merge(g, e, by = 'rsid')
    
    #load the proxy snps
    proxies <- fread(paste0(proxy_dir,"/",row$SNP,"_proxies.csv"))
    
    #if we even have any proxy snps for the risk variant
    if(nrow(proxies)>0)
    {
        #merge the proxy snp df with the data df
        merged <- merge(df, proxies, by.x = "rsid", by.y = "RS_Number")

        if(nrow(merged) > 0)
        {
            best_ld_snp <- merged[which.max(merged$R2),]
            row$'forced_lead_variant' <- best_ld_snp$rsid
            row$'forced_lead_variant_r2' <- best_ld_snp$R2
            row$'reason' <- "plot has a good proxy snp"
            plots_with_proxy_snp <- rbind(plots_with_proxy_snp,row)
            
        }
        else
        {
            row$'reason' <- "no good proxy snp exists in the data we want to plot"
            plots_with_no_proxy_snp <- rbind(plots_with_no_proxy_snp, row)
        }
    }
    else
    {
        row$'reason' <- "there was no proxy snp for the risk variant"
        plots_with_no_proxy_snp <- rbind(plots_with_no_proxy_snp, row)
    }
    
    
    
    
}

# %%
dim(plots_with_proxy_snp)
head(plots_with_proxy_snp)

write.csv(plots_with_proxy_snp,file="$PATH1/qtl/plots_with_proxy_snp.csv",row.names=F,col.names=F)
# Out:
#   File "<ipython-input-4-cc62dbcb2f6a>", line 4
#     write.csv(plots_with_proxy_snp,file="$PATH1/qtl/plots_with_proxy_snp.csv",row.names=F,col.names=F)
#                                                                              ^
# SyntaxError: keyword can't be an expression

# %%
dim(plots_with_no_proxy_snp)
head(plots_with_no_proxy_snp)

write.csv(plots_with_no_proxy_snp,file="$PATH1/qtl/plots_with_no_proxy_snp.csv",row.names=F,col.names=F)
# Out:
#   File "<ipython-input-5-9f4ac524fc97>", line 4
#     write.csv(plots_with_no_proxy_snp,file="$PATH1/qtl/plots_with_no_proxy_snp.csv",row.names=F,col.names=F)
#                                                                                    ^
# SyntaxError: keyword can't be an expression

# %% [markdown]
# make the final plot list file

# %%
plots_with_risk_snp <- fread("$PATH1/qtl/plots_with_risk_snp.csv")
plots_with_risk_snp$'num_snps' <- NA

plots_to_plot <- rbind(plots_with_risk_snp, plots_with_proxy_snp)


write.csv(plots_to_plot,file="$PATH1/qtl/plots_to_plot.csv",row.names=F,col.names=F)
# Out:
#   File "<ipython-input-6-ca3f70174a64>", line 2
#     plots_with_risk_snp$'num_snps' <- NA
#                        ^
# SyntaxError: invalid syntax

# %% [markdown]
# finally summary table for all the plots

# %%
plots_to_plot <- plots_to_plot[, -c('num_snps')]
plots_with_no_proxy_snp <- plots_with_no_proxy_snp[, -c('num_snps')]

final_summary <- rbind(plots_to_plot,plots_with_no_proxy_snp, plots_with_no_data)
dim(final_summary)
head(final_summary)
write.csv(final_summary,file="$PATH1/qtl/plots_final_overview.csv",row.names=F,col.names=F)
# Out:
#   File "<ipython-input-7-9e354a901e70>", line 1
#     plots_to_plot <- plots_to_plot[, -c('num_snps')]
#                                    ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## (4) Next Steps
#
# next we want to (finally!) create the plots
#
# so copy the `tsv` folder, and the `plots_to_plot.csv` file locally
#
# we need to run the plot generating code locally because `locuscompareR` uses code to query a sql database for LD values and that doesn't work very well on biowulf
#
# run the script `blood_brain_eQTL_plot.R` locally
