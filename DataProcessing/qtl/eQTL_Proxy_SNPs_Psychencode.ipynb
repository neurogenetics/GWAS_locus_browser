# %% [markdown]
# # Generate QTL Plot Lead SNP Information for Psychencode eQTL Data
# - **Author(s)** - Frank Grenn
# - **Date Started** - March 2020
# - **Quick Description:** Create a list of all the qtl plots we want to generate and get proxy snps for each plot that doesn't have the risk snp available in the data
# - **Data:**

# %%
library(data.table)
library(dplyr)
# Out:
# Attaching package: 'dplyr'
#
#
# The following objects are masked from 'package:data.table':
#
#     between, first, last
#
#
# The following objects are masked from 'package:stats':
#
#     filter, lag
#
#
# The following objects are masked from 'package:base':
#
#     intersect, setdiff, setequal, union

# %%
#location of the plot data tsvs created previously
eqtl_tsv_dir <- "$PATH1/qtl/psychencode/eqtl_tsv"

# %%
gwas_folders <- list.files(eqtl_tsv_dir)
gwas_folders
# Out:
# [1] "meta5" "prog1" "prog2"

# %% [markdown]
# ## (1) Create a Dataframe Containing Information for all the Plots
#
# we want a plot for each gene, each feature on each locus

# %%
evidence <- fread("$PATH1/genes_by_locus.csv")
meta5_data <- fread("$PATH1/GWAS_loci_overview.csv")
meta5_data <- meta5_data %>% select("Locus Number", "SNP", "CHR")
prog_data <- fread("$PATH1/ProgressionLoci.csv")
prog_data <- prog_data %>% select("Locus Number", "RSID", "CHR")
colnames(prog_data) <- c("Locus Number", "SNP","CHR")

# %%
#combine all the rsids to one df
variant_data <- rbind(meta5_data, prog_data)

# %%
#merge the evidence df with the variant df
#this is done to account for loci with multiple snps (ex: locus 1 has three risk variants, so we should try to create three plots for each gene on that locus)
plot_df <- merge(x=evidence, y=variant_data, by.x = "Locusnumber", by.y = "Locus Number", all.x = TRUE, allow.cartesian = TRUE)

plot_df$'feature' <- 'eqtl'

meta5_plots <- plot_df[which(plot_df$Locusnumber!="prog1" & plot_df$Locusnumber!="prog2"),]
meta5_plots$'gwas' <- 'meta5'

prog1_plots <- plot_df[which(plot_df$Locusnumber=="prog1"),]
prog1_plots$'gwas' <- 'prog1'

prog2_plots <- plot_df[which(plot_df$Locusnumber=="prog2"),]
prog2_plots$'gwas' <- 'prog2'

# %%
plot_df <- rbind(meta5_plots,prog1_plots,prog2_plots)
plot_df <- plot_df[with(plot_df, order(Locusnumber, Gene, SNP)),]

#temp values for the manually assigned lead snp (because some/many likely won't have data for the actual lead snp in the 'SNP' col of this dataframe)
plot_df$'forced_lead_variant' <- "NA"
plot_df$'forced_lead_variant_r2' <- 0
plot_df$'reason' <- "NA"

# %%
dim(plot_df)
head(plot_df)
tail(plot_df)
# Out:
# [1] 2894    9
#   Locusnumber Gene   SNP         CHR feature gwas  forced_lead_variant
# 1 1           ADAM15 rs114138760 1   eqtl    meta5 NA
# 2 1           ADAM15 rs35749011  1   eqtl    meta5 NA
# 3 1           ADAM15 rs76763715  1   eqtl    meta5 NA
# 4 1           ADAR   rs114138760 1   eqtl    meta5 NA
# 5 1           ADAR   rs35749011  1   eqtl    meta5 NA
# 6 1           ADAR   rs76763715  1   eqtl    meta5 NA
#   forced_lead_variant_r2 reason
# 1 0                      NA
# 2 0                      NA
# 3 0                      NA
# 4 0                      NA
# 5 0                      NA
# 6 0                      NA
#   Locusnumber Gene       SNP      CHR feature gwas  forced_lead_variant
# 1 prog2       OR13D1     rs382940 9   eqtl    prog2 NA
# 2 prog2       OR13F1     rs382940 9   eqtl    prog2 NA
# 3 prog2       RALGAPA1P1 rs382940 9   eqtl    prog2 NA
# 4 prog2       SLC44A1    rs382940 9   eqtl    prog2 NA
# 5 prog2       TAL2       rs382940 9   eqtl    prog2 NA
# 6 prog2       TMEM38B    rs382940 9   eqtl    prog2 NA
#   forced_lead_variant_r2 reason
# 1 0                      NA
# 2 0                      NA
# 3 0                      NA
# 4 0                      NA
# 5 0                      NA
# 6 0                      NA

# %% [markdown]
# ## (2) Filter the plot_df
#
# `plots_with_risk_snp` will contain the plots that contain the risk snp in the data. So we should have no issue plotting these
# `plots_with_no_data` will contain plots that have no snps in their tsvs to plot. So we won't plot these
# `plots_to_check` will contain plots that don't have the risk snp but do have data. So we will need to find a proxy snp for these to determine if we can plot them or not

# %%
plots_with_risk_snp <- data.frame()
plots_with_no_data <- data.frame()
plots_to_check <- data.frame()

# %% [markdown]
# do the filtering

# %%
for (rownum in 1:nrow(plot_df))
{

  print(rownum)
  

  
  row <- plot_df[rownum,]
  
  chr <- row$CHR
  snp <- row$SNP
  gene <- row$Gene
  feature <- row$feature
  gwas <- row$gwas

  print(paste0("checking", snp, " " , gene, " ", gwas))
    
      
  if(gwas == "meta5")
  {
      tsv_dir <- paste0(eqtl_tsv_dir,"/meta5")
      gwas_fn = paste0(tsv_dir, '/', gene,'_gwas.tsv')
      qtl_fn = paste0(tsv_dir, '/', gene,'_eqtl.tsv')
  }
  if(gwas == "prog1")
  {
      tsv_dir <- paste0(eqtl_tsv_dir,"/prog1")
      gwas_fn = paste0(tsv_dir, '/', gene,'_gwas.tsv')
      qtl_fn = paste0(tsv_dir, '/', gene,'_eqtl.tsv')
  }
  if(gwas == "prog2")
  {
      tsv_dir <- paste0(eqtl_tsv_dir,"/prog2")
      gwas_fn = paste0(tsv_dir, '/', gene,'_gwas.tsv')
      qtl_fn = paste0(tsv_dir, '/', gene,'_eqtl.tsv')
  }

  
  #check if the files actually exist
  if(file.exists(gwas_fn) && file.exists(qtl_fn))
  {
    print("files exist")
    #read the tsv files
    g = read.table(gwas_fn, header = T)
    e = read.table(qtl_fn, header = T)
    
    #if they both aren't empty 
    if(nrow(g)!=0 && nrow(e)!=0)
    {
      
      #merge them by rsid
      df = merge(g, e, by = 'rsid')
      print("df:")
      print(head(df))
      #check if the risk variant is already in the data. If so, then we are fine
      if(row$SNP %in% df$rsid)
      {
        print("we have the risk snp!!!")
        row$'forced_lead_variant' <- row$SNP
        row$'forced_lead_variant_r2' <- 1
        row$'reason' <- "has risk variant"
        plots_with_risk_snp<-rbind(plots_with_risk_snp,row)
        
      }
      #if we don't have the risk variant then put the row in the plot_to_check df to check later
      else
      {
        tmp <- row
        tmp$num_snps <- nrow(df)
        plots_to_check<-rbind(plots_to_check,tmp)
        
      }
      

      

    }
    #if they are empty then put in the no data df
    else
    {
      row$'reason' <- "no data for plot"
      plots_with_no_data<-rbind(plots_with_no_data,row)
    }
  }
  #if the files don't even exist then put in the no data df
  else
  {
      row$'reason' <- "no data for plot"
      plots_with_no_data<-rbind(plots_with_no_data,row)
  }
  plot_df[rownum,] <- row

}
# Out:
# [1] 1
# [1] "checkingrs114138760 ADAM15 meta5"
# [1] "files exist"
# [1] "df:"
#         rsid        var_id.x  pval.x        var_id.y      pval.y
# 1 rs10737174 1:154158882:C:G 0.13770 1:154158882:C:G 1.15465e-04
# 2 rs10796935 1:154891363:G:T 0.04777 1:154891363:G:T 2.04448e-04
# 3 rs10796936 1:154999514:T:A 0.61790 1:154999514:T:A 5.84282e-04
# 4 rs10796944 1:155416328:G:A 0.22990 1:155416328:G:A 4.68168e-04
# 5 rs10796946 1:155429490:A:T 0.60480 1:155429490:A:T 3.44108e-04
# 6 rs10908444 1:154840287:G:A 0.05325 1:154840287:G:A 2.17834e-05
# [1] 2
# [1] "checkingrs35749011 ADAM15 meta5"
# [1] "files exist"
# [1] "df:"
#         rsid        var_id.x  pval.x        var_id.y      pval.y
# 1 rs10737174 1:154158882:C:G 0.13770 1:154158882:C:G 1.15465e-04
# 2 rs10796935 1:154891363:G:T 0.04777 1:154891363:G:T 2.04448e-04
# 3 rs10796936 1:154999514:T:A 0.61790 1:154999514:T:A 5.84282e-04
# 4 rs10796944 1:155416328:G:A 0.22990 1:155416328:G:A 4.68168e-04
# 5 rs10796946 1:155429490:A:T 0.60480 1:155429490:A:T 3.44108e-04
# 6 rs10908444 1:154840287:G:A 0.05325 1:154840287:G:A 2.17834e-05
# [1] 3
# [1] "checkingrs76763715 ADAM15 meta5"
# [1] "files exist"
# [1] "df:"
#         rsid        var_id.x  pval.x        var_id.y      pval.y
# 1 rs10737174 1:154158882:C:G 0.13770 1:154158882:C:G 1.15465e-04
# 2 rs10796935 1:154891363:G:T 0.04777 1:154891363:G:T 2.04448e-04
# 3 rs10796936 1:154999514:T:A 0.61790 1:154999514:T:A 5.84282e-04
# 4 rs10796944 1:155416328:G:A 0.22990 1:155416328:G:A 4.68168e-04
# 5 rs10796946 1:155429490:A:T 0.60480 1:155429490:A:T 3.44108e-04
# 6 rs10908444 1:154840287:G:A 0.05325 1:154840287:G:A 2.17834e-05
# [1] 4
# [1] "checkingrs114138760 ADAR meta5"
# [1] "files exist"
# [1] "df:"
#         rsid        var_id.x  pval.x        var_id.y      pval.y
# 1 rs10796931 1:154652119:G:A 0.88230 1:154652119:G:A 1.17513e-05
# 2 rs10908419 1:154567699:G:A 0.40860 1:154567699:G:A 3.47784e-09
# 3 rs10908422 1:154637388:C:A 0.03648 1:154637388:C:A 3.03255e-04
# 4 rs10908423 1:154644546:G:A 0.83710 1:154644546:G:A 1.82810e-05
# 5 rs11264223 1:154565519:G:A 0.39110 1:154565519:G:A 3.82320e-09
# 6 rs11264228 1:154598437:A:G 0.02882 1:154598437:A:G 1.41302e-14
# [1] 5
# [1] "checkingrs35749011 ADAR meta5"
# [1] "files exist"
# [1] "df:"
#         rsid        var_id.x  pval.x        var_id.y      pval.y
# 1 rs10796931 1:154652119:G:A 0.88230 1:154652119:G:A 1.17513e-05
# 2 rs10908419 1:154567699:G:A 0.40860 1:154567699:G:A 3.47784e-09
# 3 rs10908422 1:154637388:C:A 0.03648 1:154637388:C:A 3.03255e-04
# 4 rs10908423 1:154644546:G:A 0.83710 1:154644546:G:A 1.82810e-05
# 5 rs11264223 1:154565519:G:A 0.39110 1:154565519:G:A 3.82320e-09
# 6 rs11264228 1:154598437:A:G 0.02882 1:154598437:A:G 1.41302e-14
# [1] 6
# [1] "checkingrs76763715 ADAR meta5"
# [1] "files exist"
# [1] "df:"
#         rsid        var_id.x  pval.x        var_id.y      pval.y
# 1 rs10796931 1:154652119:G:A 0.88230 1:154652119:G:A 1.17513e-05
# 2 rs10908419 1:154567699:G:A 0.40860 1:154567699:G:A 3.47784e-09
# 3 rs10908422 1:154637388:C:A 0.03648 1:154637388:C:A 3.03255e-04
# 4 rs10908423 1:154644546:G:A 0.83710 1:154644546:G:A 1.82810e-05
# 5 rs11264223 1:154565519:G:A 0.39110 1:154565519:G:A 3.82320e-09
# 6 rs11264228 1:154598437:A:G 0.02882 1:154598437:A:G 1.41302e-14
# [1] 7
# [1] "checkingrs114138760 AQP10 meta5"
# [1] "files exist"
# [1] "df:"
#          rsid        var_id.x pval.x        var_id.y      pval.y
# 1 rs113622975 1:153525116:C:T 0.8563 1:153525116:C:T 0.000822029
# [1] 8
# [1] "checkingrs35749011 AQP10 meta5"
# [1] "files exist"
# [1] "df:"
#          rsid        var_id.x pval.x        var_id.y      pval.y
# 1 rs113622975 1:153525116:C:T 0.8563 1:153525116:C:T 0.000822029
# [1] 9
# [1] "checkingrs76763715 AQP10 meta5"
# [1] "files exist"
# [1] "df:"
#          rsid        var_id.x pval.x        var_id.y      pval.y
# 1 rs113622975 1:153525116:C:T 0.8563 1:153525116:C:T 0.000822029
# [1] 10
# [1] "checkingrs114138760 ARHGEF2 meta5"
# [1] "files exist"
# [1] "df:"
#          rsid        var_id.x  pval.x        var_id.y      pval.y
# 1  rs10908483 1:155866834:C:T 0.02825 1:155866834:C:T 0.000669585
# 2  rs12026057 1:155889327:C:T 0.04530 1:155889327:C:T 0.000138629
# 3  rs12037177 1:155877029:T:C 0.02556 1:155877029:T:C 0.000672735
# 4  rs12144175 1:155878106:C:T 0.02723 1:155878106:C:T 0.000606051
# 5 rs144492956 1:156056535:A:G 0.05428 1:156056535:A:G 0.000591608
# 6   rs1889533 1:155947930:C:T 0.05047 1:155947930:C:T 0.000191175
# [1] 11
# [1] "checkingrs35749011 ARHGEF2 meta5"
# [1] "files exist"
# [1] "df:"
#          rsid        var_id.x  pval.x        var_id.y      pval.y
# 1  rs10908483 1:155866834:C:T 0.02825 1:155866834:C:T 0.000669585
# 2  rs12026057 1:155889327:C:T 0.04530 1:155889327:C:T 0.000138629
# 3  rs12037177 1:155877029:T:C 0.02556 1:155877029:T:C 0.000672735
# 4  rs12144175 1:155878106:C:T 0.02723 1:155878106:C:T 0.000606051
# 5 rs144492956 1:156056535:A:G 0.05428 1:156056535:A:G 0.000591608
# 6   rs1889533 1:155947930:C:T 0.05047 1:155947930:C:T 0.000191175
# [1] 12
# [1] "checkingrs76763715 ARHGEF2 meta5"
# [1] "files exist"
# [1] "df:"
#          rsid        var_id.x  pval.x        var_id.y      pval.y
# 1  rs10908483 1:155866834:C:T 0.02825 1:155866834:C:T 0.000669585
# 2  rs12026057 1:155889327:C:T 0.04530 1:155889327:C:T 0.000138629
# 3  rs12037177 1:155877029:T:C 0.02556 1:155877029:T:C 0.000672735
# 4  rs12144175 1:155878106:C:T 0.02723 1:155878106:C:T 0.000606051
# 5 rs144492956 1:156056535:A:G 0.05428 1:156056535:A:G 0.000591608
# 6   rs1889533 1:155947930:C:T 0.05047 1:155947930:C:T 0.000191175
# [1] 13
# [1] "checkingrs114138760 ASH1L meta5"
# [1] "files exist"
# [1] 14
# [1] "checkingrs35749011 ASH1L meta5"
# [1] "files exist"
# [1] 15
# [1] "checkingrs76763715 ASH1L meta5"
# [1] "files exist"
# [1] 16
# [1] "checkingrs114138760 ASH1L-AS1 meta5"
# [1] "files exist"
# [1] "df:"
#        rsid        var_id.x pval.x        var_id.y      pval.y
# 1 rs7514174 1:155399292:C:T 0.9016 1:155399292:C:T 0.000227743
# [1] 17
# [1] "checkingrs35749011 ASH1L-AS1 meta5"
# [1] "files exist"
# [1] "df:"
#        rsid        var_id.x pval.x        var_id.y      pval.y
# 1 rs7514174 1:155399292:C:T 0.9016 1:155399292:C:T 0.000227743
# [1] 18
# [1] "checkingrs76763715 ASH1L-AS1 meta5"
# [1] "files exist"
# [1] "df:"
#        rsid        var_id.x pval.x        var_id.y      pval.y
# 1 rs7514174 1:155399292:C:T 0.9016 1:155399292:C:T 0.000227743
# [1] 19
# [1] "checkingrs114138760 ATP8B2 meta5"
# [1] "files exist"
# [1] "df:"
#         rsid        var_id.x  pval.x        var_id.y      pval.y
# 1 rs11585004 1:154367770:T:C 0.09044 1:154367770:T:C 0.000818728
# 2 rs12125018 1:154549491:G:C 0.38700 1:154549491:G:C 0.000416253
# [1] 20
# [1] "checkingrs35749011 ATP8B2 meta5"
# [1] "files exist"
# [1] "df:"
#         rsid        var_id.x  pval.x        var_id.y      pval.y
# 1 rs11585004 1:154367770:T:C 0.09044 1:154367770:T:C 0.000818728
# 2 rs12125018 1:154549491:G:C 0.38700 1:154549491:G:C 0.000416253
# [1] 21
# [1] "checkingrs76763715 ATP8B2 meta5"
# [1] "files exist"
# [1] "df:"
#         rsid        var_id.x  pval.x        var_id.y      pval.y
# 1 rs11585004 1:154367770:T:C 0.09044 1:154367770:T:C 0.000818728
# 2 rs12125018 1:154549491:G:C 0.38700 1:154549491:G:C 0.000416253
# [1] 22
# [1] "checkingrs114138760 C1orf189 meta5"
# [1] "files exist"
# [1] "df:"
#          rsid        var_id.x pval.x        var_id.y      pval.y
# 1 rs183947432 1:154066490:T:C 0.2226 1:154066490:T:C 6.38276e-05
# [1] 23
# [1] "checkingrs35749011 C1orf189 meta5"
# [1] "files exist"
# [1] "df:"
#          rsid        var_id.x pval.x        var_id.y      pval.y
# 1 rs183947432 1:154066490:T:C 0.2226 1:154066490:T:C 6.38276e-05
# [1] 24
# [1] "checkingrs76763715 C1orf189 meta5"
# [1] "files exist"
# [1] "df:"
#          rsid        var_id.x pval.x        var_id.y      pval.y
# 1 rs183947432 1:154066490:T:C 0.2226 1:154066490:T:C 6.38276e-05
# [1] 25
# [1] "checkingrs114138760 C1orf43 meta5"
# [1] "files exist"
# [1] "df:"
#         rsid        var_id.x   pval.x        var_id.y      pval.y
# 1 rs10158820 1:154217763:C:T 0.027050 1:154217763:C:T 2.97149e-11
# 2  rs1051370 1:154129265:A:G 0.030470 1:154129265:A:G 2.90273e-07
# 3 rs10796956 1:153795569:T:C 0.004640 1:153795569:T:C 1.42133e-04
# 4 rs10796968 1:153899330:A:C 0.007473 1:153899330:A:C 3.04435e-04
# 5 rs10796986 1:153987412:G:A 0.017580 1:153987412:G:A 1.25258e-05
# 6 rs10797047 1:154149240:G:A 0.011420 1:154149240:G:A 1.34194e-04
# [1] 26
# [1] "checkingrs35749011 C1orf43 meta5"
# [1] "files exist"
# [1] "df:"
#         rsid        var_id.x   pval.x        var_id.y      pval.y
# 1 rs10158820 1:154217763:C:T 0.027050 1:154217763:C:T 2.97149e-11
# 2  rs1051370 1:154129265:A:G 0.030470 1:154129265:A:G 2.90273e-07
# 3 rs10796956 1:153795569:T:C 0.004640 1:153795569:T:C 1.42133e-04
# 4 rs10796968 1:153899330:A:C 0.007473 1:153899330:A:C 3.04435e-04
# 5 rs10796986 1:153987412:G:A 0.017580 1:153987412:G:A 1.25258e-05
# 6 rs10797047 1:154149240:G:A 0.011420 1:154149240:G:A 1.34194e-04
# [1] 27
# [1] "checkingrs76763715 C1orf43 meta5"
# [1] "files exist"
# [1] "df:"
#         rsid        var_id.x   pval.x        var_id.y      pval.y
# 1 rs10158820 1:154217763:C:T 0.027050 1:154217763:C:T 2.97149e-11
# 2  rs1051370 1:154129265:A:G 0.030470 1:154129265:A:G 2.90273e-07
# 3 rs10796956 1:153795569:T:C 0.004640 1:153795569:T:C 1.42133e-04
# 4 rs10796968 1:153899330:A:C 0.007473 1:153899330:A:C 3.04435e-04
# 5 rs10796986 1:153987412:G:A 0.017580 1:153987412:G:A 1.25258e-05
# 6 rs10797047 1:154149240:G:A 0.011420 1:154149240:G:A 1.34194e-04
# [1] 28
# [1] "checkingrs114138760 CHRNB2 meta5"
# [1] "files exist"
# [1] "df:"
#         rsid        var_id.x pval.x        var_id.y      pval.y
# 1 rs10159236 1:154431405:C:A 0.7939 1:154431405:C:A 1.85804e-09
# 2 rs10752643 1:154503601:G:A 0.7827 1:154503601:G:A 2.36447e-12
# 3 rs10908419 1:154567699:G:A 0.4086 1:154567699:G:A 5.67060e-06
# 4 rs10908840 1:154459477:C:T 0.5890 1:154459477:C:T 1.26588e-06
# 5 rs10908844 1:154500857:G:A 0.8276 1:154500857:G:A 2.23497e-12
# 6 rs10908846 1:154501364:C:A 0.8115 1:154501364:C:A 5.91762e-12
# [1] 29
# [1] "checkingrs35749011 CHRNB2 meta5"
# [1] "files exist"
# [1] "df:"
#         rsid        var_id.x pval.x        var_id.y      pval.y
# 1 rs10159236 1:154431405:C:A 0.7939 1:154431405:C:A 1.85804e-09
# 2 rs10752643 1:154503601:G:A 0.7827 1:154503601:G:A 2.36447e-12
# 3 rs10908419 1:154567699:G:A 0.4086 1:154567699:G:A 5.67060e-06
# 4 rs10908840 1:154459477:C:T 0.5890 1:154459477:C:T 1.26588e-06
# 5 rs10908844 1:154500857:G:A 0.8276 1:154500857:G:A 2.23497e-12
# 6 rs10908846 1:154501364:C:A 0.8115 1:154501364:C:A 5.91762e-12
# [1] 30
# [1] "checkingrs76763715 CHRNB2 meta5"
# [1] "files exist"
# [1] "df:"
#         rsid        var_id.x pval.x        var_id.y      pval.y
# 1 rs10159236 1:154431405:C:A 0.7939 1:154431405:C:A 1.85804e-09
# 2 rs10752643 1:154503601:G:A 0.7827 1:154503601:G:A 2.36447e-12
# 3 rs10908419 1:154567699:G:A 0.4086 1:154567699:G:A 5.67060e-06
# 4 rs10908840 1:154459477:C:T 0.5890 1:154459477:C:T 1.26588e-06
# 5 rs10908844 1:154500857:G:A 0.8276 1:154500857:G:A 2.23497e-12
# 6 rs10908846 1:154501364:C:A 0.8115 1:154501364:C:A 5.91762e-12
# [1] 31
# [1] "checkingrs114138760 CKS1B meta5"
# [1] "files exist"
# [1] 32
# [1] "checkingrs35749011 CKS1B meta5"
# [1] "files exist"
# [1] 33
# [1] "checkingrs76763715 CKS1B meta5"
# [1] "files exist"
# [1] 34
# [1] "checkingrs114138760 CLK2 meta5"
# [1] "files exist"
# [1] 35
# [1] "checkingrs35749011 CLK2 meta5"
# [1] "files exist"
# [1] 36
# [1] "checkingrs76763715 CLK2 meta5"
# [1] "files exist"
# [1] 37
# [1] "checkingrs114138760 CREB3L4 meta5"
# [1] "files exist"
# [1] 38
# [1] "checkingrs35749011 CREB3L4 meta5"
# [1] "files exist"
# [1] 39
# [1] "checkingrs76763715 CREB3L4 meta5"
# [1] "files exist"
# [1] 40
# [1] "checkingrs114138760 CRTC2 meta5"
# [1] "files exist"
# [1] "df:"
#         rsid        var_id.x  pval.x        var_id.y      pval.y
# 1 rs10796935 1:154891363:G:T 0.04777 1:154891363:G:T 0.000749396
# 2 rs10908446 1:154869559:G:A 0.06681 1:154869559:G:A 0.000433350
# 3 rs10908448 1:154882544:C:T 0.04213 1:154882544:C:T 0.000768923
# 4 rs11264281 1:154867221:A:G 0.12040 1:154867221:A:G 0.000598842
# 5 rs11264282 1:154867370:G:A 0.05956 1:154867370:G:A 0.000630595
# 6 rs11264283 1:154869552:A:G 0.06018 1:154869552:A:G 0.000433298
# [1] 41
# [1] "checkingrs35749011 CRTC2 meta5"
# [1] "files exist"
# [1] "df:"
#         rsid        var_id.x  pval.x        var_id.y      pval.y
# 1 rs10796935 1:154891363:G:T 0.04777 1:154891363:G:T 0.000749396
# 2 rs10908446 1:154869559:G:A 0.06681 1:154869559:G:A 0.000433350
# 3 rs10908448 1:154882544:C:T 0.04213 1:154882544:C:T 0.000768923
# 4 rs11264281 1:154867221:A:G 0.12040 1:154867221:A:G 0.000598842
# 5 rs11264282 1:154867370:G:A 0.05956 1:154867370:G:A 0.000630595
# 6 rs11264283 1:154869552:A:G 0.06018 1:154869552:A:G 0.000433298
# [1] 42
# [1] "checkingrs76763715 CRTC2 meta5"
# [1] "files exist"
# [1] "df:"
#         rsid        var_id.x  pval.x        var_id.y      pval.y
# 1 rs10796935 1:154891363:G:T 0.04777 1:154891363:G:T 0.000749396
# 2 rs10908446 1:154869559:G:A 0.06681 1:154869559:G:A 0.000433350
# 3 rs10908448 1:154882544:C:T 0.04213 1:154882544:C:T 0.000768923
# 4 rs11264281 1:154867221:A:G 0.12040 1:154867221:A:G 0.000598842
# 5 rs11264282 1:154867370:G:A 0.05956 1:154867370:G:A 0.000630595
# 6 rs11264283 1:154869552:A:G 0.06018 1:154869552:A:G 0.000433298
# [1] 43
# [1] "checkingrs114138760 DAP3 meta5"
# [1] "files exist"
# [1] "df:"
#         rsid        var_id.x   pval.x        var_id.y      pval.y
# 1 rs11580040 1:155198222:A:G 0.005925 1:155198222:A:G 0.000243571
# 2   rs348196 1:155666961:T:C 0.108700 1:155666961:T:C 0.000514156
# 3  rs6427278 1:155562583:T:C 0.327200 1:155562583:T:C 0.000577917
# 4   rs678157 1:155658341:T:C 0.140800 1:155658341:T:C 0.000569858
# [1] 44
# [1] "checkingrs35749011 DAP3 meta5"
# [1] "files exist"
# [1] "df:"
#         rsid        var_id.x   pval.x        var_id.y      pval.y
# 1 rs11580040 1:155198222:A:G 0.005925 1:155198222:A:G 0.000243571
# 2   rs348196 1:155666961:T:C 0.108700 1:155666961:T:C 0.000514156
# 3  rs6427278 1:155562583:T:C 0.327200 1:155562583:T:C 0.000577917
# 4   rs678157 1:155658341:T:C 0.140800 1:155658341:T:C 0.000569858
# [1] 45
# [1] "checkingrs76763715 DAP3 meta5"
# [1] "files exist"
# [1] "df:"
#         rsid        var_id.x   pval.x        var_id.y      pval.y
# 1 rs11580040 1:155198222:A:G 0.005925 1:155198222:A:G 0.000243571
# 2   rs348196 1:155666961:T:C 0.108700 1:155666961:T:C 0.000514156
# 3  rs6427278 1:155562583:T:C 0.327200 1:155562583:T:C 0.000577917
# 4   rs678157 1:155658341:T:C 0.140800 1:155658341:T:C 0.000569858
# [1] 46
# [1] "checkingrs114138760 DCST1 meta5"
# [1] "files exist"
# [1] "df:"
#         rsid        var_id.x pval.x        var_id.y      pval.y
# 1 rs11265530 1:154285052:G:A 0.6085 1:154285052:G:A 0.000530212
# 2  rs1194611 1:154301246:C:A 0.3275 1:154301246:C:A 0.000687562
# 3  rs6427568 1:154290535:G:A 0.3468 1:154290535:G:A 0.000819264
# [1] 47
# [1] "checkingrs35749011 DCST1 meta5"
# [1] "files exist"
# [1] "df:"
#         rsid        var_id.x pval.x        var_id.y      pval.y
# 1 rs11265530 1:154285052:G:A 0.6085 1:154285052:G:A 0.000530212
# 2  rs1194611 1:154301246:C:A 0.3275 1:154301246:C:A 0.000687562
# 3  rs6427568 1:154290535:G:A 0.3468 1:154290535:G:A 0.000819264
# [1] 48
# [1] "checkingrs76763715 DCST1 meta5"
# [1] "files exist"
# [1] "df:"
#         rsid        var_id.x pval.x        var_id.y      pval.y
# 1 rs11265530 1:154285052:G:A 0.6085 1:154285052:G:A 0.000530212
# 2  rs1194611 1:154301246:C:A 0.3275 1:154301246:C:A 0.000687562
# 3  rs6427568 1:154290535:G:A 0.3468 1:154290535:G:A 0.000819264
# [1] 49
# [1] "checkingrs114138760 DCST1-AS1 meta5"
# [1] "files exist"
# [1] 50
# [1] "checkingrs35749011 DCST1-AS1 meta5"
# [1] "files exist"
# [1] 51
# [1] "checkingrs76763715 DCST1-AS1 meta5"
# [1] "files exist"
# [1] 52
# [1] "checkingrs114138760 DCST2 meta5"
# [1] "files exist"
# [1] "df:"
#         rsid        var_id.x pval.x        var_id.y      pval.y
# 1 rs10796936 1:154999514:T:A 0.6179 1:154999514:T:A 1.63047e-04
# 2 rs12087657 1:154948327:G:T 0.3920 1:154948327:G:T 5.36993e-05
# 3 rs12404174 1:155001004:G:C 0.4779 1:155001004:G:C 1.82416e-04
# 4  rs1870940 1:154984363:G:A 0.0461 1:154984363:G:A 2.69447e-06
# 5  rs2242195 1:154988957:A:G 0.2928 1:154988957:A:G 4.90917e-08
# 6  rs4845701 1:154992955:T:C 0.9750 1:154992955:T:C 7.50072e-08
# [1] 53
# [1] "checkingrs35749011 DCST2 meta5"
# [1] "files exist"
# [1] "df:"
#         rsid        var_id.x pval.x        var_id.y      pval.y
# 1 rs10796936 1:154999514:T:A 0.6179 1:154999514:T:A 1.63047e-04
# 2 rs12087657 1:154948327:G:T 0.3920 1:154948327:G:T 5.36993e-05
# 3 rs12404174 1:155001004:G:C 0.4779 1:155001004:G:C 1.82416e-04
# 4  rs1870940 1:154984363:G:A 0.0461 1:154984363:G:A 2.69447e-06
# 5  rs2242195 1:154988957:A:G 0.2928 1:154988957:A:G 4.90917e-08
# 6  rs4845701 1:154992955:T:C 0.9750 1:154992955:T:C 7.50072e-08
# [1] 54
# [1] "checkingrs76763715 DCST2 meta5"
# [1] "files exist"
# [1] "df:"
#         rsid        var_id.x pval.x        var_id.y      pval.y
# 1 rs10796936 1:154999514:T:A 0.6179 1:154999514:T:A 1.63047e-04
# 2 rs12087657 1:154948327:G:T 0.3920 1:154948327:G:T 5.36993e-05
# 3 rs12404174 1:155001004:G:C 0.4779 1:155001004:G:C 1.82416e-04
# 4  rs1870940 1:154984363:G:A 0.0461 1:154984363:G:A 2.69447e-06
# 5  rs2242195 1:154988957:A:G 0.2928 1:154988957:A:G 4.90917e-08
# 6  rs4845701 1:154992955:T:C 0.9750 1:154992955:T:C 7.50072e-08
# [1] 55
# [1] "checkingrs114138760 DENND4B meta5"
# [1] "files exist"
# [1] "df:"
#          rsid        var_id.x   pval.x        var_id.y      pval.y
# 1  rs10157443 1:153695200:T:C 0.005397 1:153695200:T:C 4.07590e-06
# 2 rs137958065 1:153708984:G:A 0.011180 1:153708984:G:A 4.94571e-08
# 3 rs184894567 1:153719128:T:C 0.055290 1:153719128:T:C 1.87026e-04
# 4  rs74653448 1:153210188:G:A 0.707900 1:153210188:G:A 5.93863e-04
# 5  rs77341498 1:153728750:A:G 0.004049 1:153728750:A:G 2.91161e-07
# 6   rs9426887 1:153711962:A:G 0.013800 1:153711962:A:G 3.46375e-06
# [1] 56
# [1] "checkingrs35749011 DENND4B meta5"
# [1] "files exist"
# [1] "df:"
#          rsid        var_id.x   pval.x        var_id.y      pval.y
# 1  rs10157443 1:153695200:T:C 0.005397 1:153695200:T:C 4.07590e-06
# 2 rs137958065 1:153708984:G:A 0.011180 1:153708984:G:A 4.94571e-08
# 3 rs184894567 1:153719128:T:C 0.055290 1:153719128:T:C 1.87026e-04
# 4  rs74653448 1:153210188:G:A 0.707900 1:153210188:G:A 5.93863e-04
# 5  rs77341498 1:153728750:A:G 0.004049 1:153728750:A:G 2.91161e-07
# 6   rs9426887 1:153711962:A:G 0.013800 1:153711962:A:G 3.46375e-06
# [1] 57
# [1] "checkingrs76763715 DENND4B meta5"
# [1] "files exist"
# [1] "df:"
#          rsid        var_id.x   pval.x        var_id.y      pval.y
# 1  rs10157443 1:153695200:T:C 0.005397 1:153695200:T:C 4.07590e-06
# 2 rs137958065 1:153708984:G:A 0.011180 1:153708984:G:A 4.94571e-08
# 3 rs184894567 1:153719128:T:C 0.055290 1:153719128:T:C 1.87026e-04
# 4  rs74653448 1:153210188:G:A 0.707900 1:153210188:G:A 5.93863e-04
# 5  rs77341498 1:153728750:A:G 0.004049 1:153728750:A:G 2.91161e-07
# 6   rs9426887 1:153711962:A:G 0.013800 1:153711962:A:G 3.46375e-06
# [1] 58
# [1] "checkingrs114138760 DPM3 meta5"
# [1] "files exist"
# [1] "df:"
#          rsid        var_id.x pval.x        var_id.y      pval.y
# 1  rs12745576 1:155113074:A:C 0.1429 1:155113074:A:C 2.60998e-04
# 2 rs150715756 1:154860092:G:A 0.7862 1:154860092:G:A 1.75622e-04
# 3 rs369038429 1:154950727:A:T 0.9816 1:154950727:A:T 2.34432e-05
# 4  rs80352034 1:154870700:C:G 0.9365 1:154870700:C:G 7.70729e-05
# [1] 59
# [1] "checkingrs35749011 DPM3 meta5"
# [1] "files exist"
# [1] "df:"
#          rsid        var_id.x pval.x        var_id.y      pval.y
# 1  rs12745576 1:155113074:A:C 0.1429 1:155113074:A:C 2.60998e-04
# 2 rs150715756 1:154860092:G:A 0.7862 1:154860092:G:A 1.75622e-04
# 3 rs369038429 1:154950727:A:T 0.9816 1:154950727:A:T 2.34432e-05
# 4  rs80352034 1:154870700:C:G 0.9365 1:154870700:C:G 7.70729e-05
# [1] 60
# [1] "checkingrs76763715 DPM3 meta5"
# [1] "files exist"
# [1] "df:"
#          rsid        var_id.x pval.x        var_id.y      pval.y
# 1  rs12745576 1:155113074:A:C 0.1429 1:155113074:A:C 2.60998e-04
# 2 rs150715756 1:154860092:G:A 0.7862 1:154860092:G:A 1.75622e-04
# 3 rs369038429 1:154950727:A:T 0.9816 1:154950727:A:T 2.34432e-05
# 4  rs80352034 1:154870700:C:G 0.9365 1:154870700:C:G 7.70729e-05
# [1] 61
# [1] "checkingrs114138760 EFNA1 meta5"
# [1] "files exist"
# [1] "df:"
#         rsid        var_id.x    pval.x        var_id.y      pval.y
# 1 rs10796938 1:155072055:C:A 3.829e-08 1:155072055:C:A 1.16036e-10
# 2 rs10796939 1:155088795:C:T 1.737e-05 1:155088795:C:T 7.03440e-11
# 3 rs10796940 1:155202689:A:C 4.679e-01 1:155202689:A:C 3.68174e-09
# 4 rs10796941 1:155284261:C:T 7.902e-01 1:155284261:C:T 2.45511e-05
# 5 rs10796944 1:155416328:G:A 2.299e-01 1:155416328:G:A 4.19755e-05
# 6 rs10796946 1:155429490:A:T 6.048e-01 1:155429490:A:T 5.85479e-05
# [1] 62
# [1] "checkingrs35749011 EFNA1 meta5"
# [1] "files exist"
# [1] "df:"
#         rsid        var_id.x    pval.x        var_id.y      pval.y
# 1 rs10796938 1:155072055:C:A 3.829e-08 1:155072055:C:A 1.16036e-10
# 2 rs10796939 1:155088795:C:T 1.737e-05 1:155088795:C:T 7.03440e-11
# 3 rs10796940 1:155202689:A:C 4.679e-01 1:155202689:A:C 3.68174e-09
# 4 rs10796941 1:155284261:C:T 7.902e-01 1:155284261:C:T 2.45511e-05
# 5 rs10796944 1:155416328:G:A 2.299e-01 1:155416328:G:A 4.19755e-05
# 6 rs10796946 1:155429490:A:T 6.048e-01 1:155429490:A:T 5.85479e-05
# [1] 63
# [1] "checkingrs76763715 EFNA1 meta5"
# [1] "files exist"
# [1] "df:"
#         rsid        var_id.x    pval.x        var_id.y      pval.y
# 1 rs10796938 1:155072055:C:A 3.829e-08 1:155072055:C:A 1.16036e-10
# 2 rs10796939 1:155088795:C:T 1.737e-05 1:155088795:C:T 7.03440e-11
# 3 rs10796940 1:155202689:A:C 4.679e-01 1:155202689:A:C 3.68174e-09
# 4 rs10796941 1:155284261:C:T 7.902e-01 1:155284261:C:T 2.45511e-05
# 5 rs10796944 1:155416328:G:A 2.299e-01 1:155416328:G:A 4.19755e-05
# 6 rs10796946 1:155429490:A:T 6.048e-01 1:155429490:A:T 5.85479e-05
# [1] 64
# [1] "checkingrs114138760 EFNA3 meta5"
# [1] "files exist"
# [1] "df:"
#          rsid        var_id.x  pval.x        var_id.y      pval.y
# 1 rs111455542 1:155099947:A:G 0.03559 1:155099947:A:G 5.22067e-04
# 2 rs111993576 1:155089980:C:T 0.05317 1:155089980:C:T 1.82292e-04
# 3 rs112559323 1:155046903:A:G 0.07356 1:155046903:A:G 7.91244e-05
# 4 rs112591935 1:155089652:C:T 0.05395 1:155089652:C:T 1.34315e-04
# 5  rs11264324 1:155090212:C:T 0.05375 1:155090212:C:T 1.23681e-04
# 6  rs11264326 1:155092807:A:G 0.05052 1:155092807:A:G 1.68779e-04
# [1] 65
# [1] "checkingrs35749011 EFNA3 meta5"
# [1] "files exist"
# [1] "df:"
#          rsid        var_id.x  pval.x        var_id.y      pval.y
# 1 rs111455542 1:155099947:A:G 0.03559 1:155099947:A:G 5.22067e-04
# 2 rs111993576 1:155089980:C:T 0.05317 1:155089980:C:T 1.82292e-04
# 3 rs112559323 1:155046903:A:G 0.07356 1:155046903:A:G 7.91244e-05
# 4 rs112591935 1:155089652:C:T 0.05395 1:155089652:C:T 1.34315e-04
# 5  rs11264324 1:155090212:C:T 0.05375 1:155090212:C:T 1.23681e-04
# 6  rs11264326 1:155092807:A:G 0.05052 1:155092807:A:G 1.68779e-04
# [1] 66
# [1] "checkingrs76763715 EFNA3 meta5"
# [1] "files exist"
# [1] "df:"
#          rsid        var_id.x  pval.x        var_id.y      pval.y
# 1 rs111455542 1:155099947:A:G 0.03559 1:155099947:A:G 5.22067e-04
# 2 rs111993576 1:155089980:C:T 0.05317 1:155089980:C:T 1.82292e-04
# 3 rs112559323 1:155046903:A:G 0.07356 1:155046903:A:G 7.91244e-05
# 4 rs112591935 1:155089652:C:T 0.05395 1:155089652:C:T 1.34315e-04
# 5  rs11264324 1:155090212:C:T 0.05375 1:155090212:C:T 1.23681e-04
# 6  rs11264326 1:155092807:A:G 0.05052 1:155092807:A:G 1.68779e-04
# [1] 67
# [1] "checkingrs114138760 EFNA4 meta5"
# [1] "files exist"
# [1] "df:"
#         rsid        var_id.x    pval.x        var_id.y      pval.y
# 1 rs11264307 1:155047719:C:T 3.835e-07 1:155047719:C:T 0.000354415
# 2  rs4845712 1:155043436:G:C 4.604e-09 1:155043436:G:C 0.000116022
# [1] 68
# [1] "checkingrs35749011 EFNA4 meta5"
# [1] "files exist"
# [1] "df:"
#         rsid        var_id.x    pval.x        var_id.y      pval.y
# 1 rs11264307 1:155047719:C:T 3.835e-07 1:155047719:C:T 0.000354415
# 2  rs4845712 1:155043436:G:C 4.604e-09 1:155043436:G:C 0.000116022
# [1] 69
# [1] "checkingrs76763715 EFNA4 meta5"
# [1] "files exist"
# [1] "df:"
#         rsid        var_id.x    pval.x        var_id.y      pval.y
# 1 rs11264307 1:155047719:C:T 3.835e-07 1:155047719:C:T 0.000354415
# 2  rs4845712 1:155043436:G:C 4.604e-09 1:155043436:G:C 0.000116022
# [1] 70
# [1] "checkingrs114138760 FAM189B meta5"
# [1] "files exist"
# [1] "df:"
#         rsid        var_id.x    pval.x        var_id.y      pval.y
# 1 rs10796938 1:155072055:C:A 3.829e-08 1:155072055:C:A 7.07848e-04
# 2 rs10796940 1:155202689:A:C 4.679e-01 1:155202689:A:C 1.13204e-07
# 3 rs10796941 1:155284261:C:T 7.902e-01 1:155284261:C:T 4.15720e-07
# 4 rs10796944 1:155416328:G:A 2.299e-01 1:155416328:G:A 1.48928e-04
# 5 rs10796946 1:155429490:A:T 6.048e-01 1:155429490:A:T 3.02890e-08
# 6 rs10796954 1:155794478:T:C 8.331e-02 1:155794478:T:C 4.35277e-06
# [1] 71
# [1] "checkingrs35749011 FAM189B meta5"
# [1] "files exist"
# [1] "df:"
#         rsid        var_id.x    pval.x        var_id.y      pval.y
# 1 rs10796938 1:155072055:C:A 3.829e-08 1:155072055:C:A 7.07848e-04
# 2 rs10796940 1:155202689:A:C 4.679e-01 1:155202689:A:C 1.13204e-07
# 3 rs10796941 1:155284261:C:T 7.902e-01 1:155284261:C:T 4.15720e-07
# 4 rs10796944 1:155416328:G:A 2.299e-01 1:155416328:G:A 1.48928e-04
# 5 rs10796946 1:155429490:A:T 6.048e-01 1:155429490:A:T 3.02890e-08
# 6 rs10796954 1:155794478:T:C 8.331e-02 1:155794478:T:C 4.35277e-06
# [1] 72
# [1] "checkingrs76763715 FAM189B meta5"
# [1] "files exist"
# [1] "df:"
#         rsid        var_id.x    pval.x        var_id.y      pval.y
# 1 rs10796938 1:155072055:C:A 3.829e-08 1:155072055:C:A 7.07848e-04
# 2 rs10796940 1:155202689:A:C 4.679e-01 1:155202689:A:C 1.13204e-07
# 3 rs10796941 1:155284261:C:T 7.902e-01 1:155284261:C:T 4.15720e-07
# 4 rs10796944 1:155416328:G:A 2.299e-01 1:155416328:G:A 1.48928e-04
# 5 rs10796946 1:155429490:A:T 6.048e-01 1:155429490:A:T 3.02890e-08
# 6 rs10796954 1:155794478:T:C 8.331e-02 1:155794478:T:C 4.35277e-06
# [1] 73
# [1] "checkingrs114138760 FDPS meta5"
# [1] "files exist"
# [1] "df:"
#         rsid        var_id.x  pval.x        var_id.y      pval.y
# 1 rs10796940 1:155202689:A:C 0.46790 1:155202689:A:C 4.39815e-05
# 2 rs10796941 1:155284261:C:T 0.79020 1:155284261:C:T 1.58274e-10
# 3 rs10796944 1:155416328:G:A 0.22990 1:155416328:G:A 4.25193e-06
# 4 rs10796946 1:155429490:A:T 0.60480 1:155429490:A:T 1.99073e-09
# 5 rs10796947 1:155477053:A:G 0.61040 1:155477053:A:G 1.41530e-06
# 6 rs10796954 1:155794478:T:C 0.08331 1:155794478:T:C 5.15972e-08
# [1] 74
# [1] "checkingrs35749011 FDPS meta5"
# [1] "files exist"
# [1] "df:"
#         rsid        var_id.x  pval.x        var_id.y      pval.y
# 1 rs10796940 1:155202689:A:C 0.46790 1:155202689:A:C 4.39815e-05
# 2 rs10796941 1:155284261:C:T 0.79020 1:155284261:C:T 1.58274e-10
# 3 rs10796944 1:155416328:G:A 0.22990 1:155416328:G:A 4.25193e-06
# 4 rs10796946 1:155429490:A:T 0.60480 1:155429490:A:T 1.99073e-09
# 5 rs10796947 1:155477053:A:G 0.61040 1:155477053:A:G 1.41530e-06
# 6 rs10796954 1:155794478:T:C 0.08331 1:155794478:T:C 5.15972e-08
# [1] 75
# [1] "checkingrs76763715 FDPS meta5"
# [1] "files exist"
# [1] "df:"
#         rsid        var_id.x  pval.x        var_id.y      pval.y
# 1 rs10796940 1:155202689:A:C 0.46790 1:155202689:A:C 4.39815e-05
# 2 rs10796941 1:155284261:C:T 0.79020 1:155284261:C:T 1.58274e-10
# 3 rs10796944 1:155416328:G:A 0.22990 1:155416328:G:A 4.25193e-06
# 4 rs10796946 1:155429490:A:T 0.60480 1:155429490:A:T 1.99073e-09
# 5 rs10796947 1:155477053:A:G 0.61040 1:155477053:A:G 1.41530e-06
# 6 rs10796954 1:155794478:T:C 0.08331 1:155794478:T:C 5.15972e-08
# [1] 76
# [1] "checkingrs114138760 FLAD1 meta5"
# [1] "files exist"
# [1] "df:"
#          rsid        var_id.x  pval.x        var_id.y      pval.y
# 1 rs112568185 1:154266460:T:C 0.03491 1:154266460:T:C 0.000537084
# 2  rs11265285 1:154174569:C:T 0.76010 1:154174569:C:T 0.000545001
# 3  rs11810847 1:154264456:C:A 0.03486 1:154264456:C:A 0.000476928
# 4  rs11811448 1:154264212:A:C 0.04056 1:154264212:A:C 0.000559215
# 5  rs12044616 1:154189417:G:A 0.69700 1:154189417:G:A 0.000591158
# 6  rs12739218 1:154218114:C:T 0.65410 1:154218114:C:T 0.000438868
# [1] 77
# [1] "checkingrs35749011 FLAD1 meta5"
# [1] "files exist"
# [1] "df:"
#          rsid        var_id.x  pval.x        var_id.y      pval.y
# 1 rs112568185 1:154266460:T:C 0.03491 1:154266460:T:C 0.000537084
# 2  rs11265285 1:154174569:C:T 0.76010 1:154174569:C:T 0.000545001
# 3  rs11810847 1:154264456:C:A 0.03486 1:154264456:C:A 0.000476928
# 4  rs11811448 1:154264212:A:C 0.04056 1:154264212:A:C 0.000559215
# 5  rs12044616 1:154189417:G:A 0.69700 1:154189417:G:A 0.000591158
# 6  rs12739218 1:154218114:C:T 0.65410 1:154218114:C:T 0.000438868
# [1] 78
# [1] "checkingrs76763715 FLAD1 meta5"
# [1] "files exist"
# [1] "df:"
#          rsid        var_id.x  pval.x        var_id.y      pval.y
# 1 rs112568185 1:154266460:T:C 0.03491 1:154266460:T:C 0.000537084
# 2  rs11265285 1:154174569:C:T 0.76010 1:154174569:C:T 0.000545001
# 3  rs11810847 1:154264456:C:A 0.03486 1:154264456:C:A 0.000476928
# 4  rs11811448 1:154264212:A:C 0.04056 1:154264212:A:C 0.000559215
# 5  rs12044616 1:154189417:G:A 0.69700 1:154189417:G:A 0.000591158
# 6  rs12739218 1:154218114:C:T 0.65410 1:154218114:C:T 0.000438868
# [1] 79
# [1] "checkingrs114138760 GBA meta5"
# [1] "files exist"
# [1] "df:"
#         rsid        var_id.x    pval.x        var_id.y      pval.y
# 1 rs12127609 1:155133491:G:C 2.088e-05 1:155133491:G:C 0.000579011
# 2 rs12129003 1:155129562:G:A 2.376e-05 1:155129562:G:A 0.000438929
# 3  rs2974937 1:155168849:C:T 3.162e-01 1:155168849:C:T 0.000759111
# 4   rs370545 1:155175390:A:G 2.855e-01 1:155175390:A:G 0.000396671
# 5   rs423144 1:155169355:G:T 3.072e-01 1:155169355:G:T 0.000773051
# 6  rs4971077 1:155128717:T:C 2.243e-07 1:155128717:T:C 0.000810780
# [1] 80
# [1] "checkingrs35749011 GBA meta5"
# [1] "files exist"
# [1] "df:"
#         rsid        var_id.x    pval.x        var_id.y      pval.y
# 1 rs12127609 1:155133491:G:C 2.088e-05 1:155133491:G:C 0.000579011
# 2 rs12129003 1:155129562:G:A 2.376e-05 1:155129562:G:A 0.000438929
# 3  rs2974937 1:155168849:C:T 3.162e-01 1:155168849:C:T 0.000759111
# 4   rs370545 1:155175390:A:G 2.855e-01 1:155175390:A:G 0.000396671
# 5   rs423144 1:155169355:G:T 3.072e-01 1:155169355:G:T 0.000773051
# 6  rs4971077 1:155128717:T:C 2.243e-07 1:155128717:T:C 0.000810780
# [1] 81
# [1] "checkingrs76763715 GBA meta5"
# [1] "files exist"
# [1] "df:"
#         rsid        var_id.x    pval.x        var_id.y      pval.y
# 1 rs12127609 1:155133491:G:C 2.088e-05 1:155133491:G:C 0.000579011
# 2 rs12129003 1:155129562:G:A 2.376e-05 1:155129562:G:A 0.000438929
# 3  rs2974937 1:155168849:C:T 3.162e-01 1:155168849:C:T 0.000759111
# 4   rs370545 1:155175390:A:G 2.855e-01 1:155175390:A:G 0.000396671
# 5   rs423144 1:155169355:G:T 3.072e-01 1:155169355:G:T 0.000773051
# 6  rs4971077 1:155128717:T:C 2.243e-07 1:155128717:T:C 0.000810780
# [1] 82
# [1] "checkingrs114138760 GBAP1 meta5"
# [1] "files exist"
# [1] "df:"
#         rsid        var_id.x  pval.x        var_id.y      pval.y
# 1 rs10796941 1:155284261:C:T 0.79020 1:155284261:C:T 6.63360e-05
# 2 rs10796944 1:155416328:G:A 0.22990 1:155416328:G:A 7.31326e-04
# 3 rs10796946 1:155429490:A:T 0.60480 1:155429490:A:T 2.36574e-04
# 4 rs10796947 1:155477053:A:G 0.61040 1:155477053:A:G 4.54749e-05
# 5 rs10796954 1:155794478:T:C 0.08331 1:155794478:T:C 1.58758e-04
# 6 rs10908462 1:155285854:T:C 0.84760 1:155285854:T:C 3.37065e-07
# [1] 83
# [1] "checkingrs35749011 GBAP1 meta5"
# [1] "files exist"
# [1] "df:"
#         rsid        var_id.x  pval.x        var_id.y      pval.y
# 1 rs10796941 1:155284261:C:T 0.79020 1:155284261:C:T 6.63360e-05
# 2 rs10796944 1:155416328:G:A 0.22990 1:155416328:G:A 7.31326e-04
# 3 rs10796946 1:155429490:A:T 0.60480 1:155429490:A:T 2.36574e-04
# 4 rs10796947 1:155477053:A:G 0.61040 1:155477053:A:G 4.54749e-05
# 5 rs10796954 1:155794478:T:C 0.08331 1:155794478:T:C 1.58758e-04
# 6 rs10908462 1:155285854:T:C 0.84760 1:155285854:T:C 3.37065e-07
# [1] 84
# [1] "checkingrs76763715 GBAP1 meta5"
# [1] "files exist"
# [1] "df:"
#         rsid        var_id.x  pval.x        var_id.y      pval.y
# 1 rs10796941 1:155284261:C:T 0.79020 1:155284261:C:T 6.63360e-05
# 2 rs10796944 1:155416328:G:A 0.22990 1:155416328:G:A 7.31326e-04
# 3 rs10796946 1:155429490:A:T 0.60480 1:155429490:A:T 2.36574e-04
# 4 rs10796947 1:155477053:A:G 0.61040 1:155477053:A:G 4.54749e-05
# 5 rs10796954 1:155794478:T:C 0.08331 1:155794478:T:C 1.58758e-04
# 6 rs10908462 1:155285854:T:C 0.84760 1:155285854:T:C 3.37065e-07
# [1] 85
# [1] "checkingrs114138760 GON4L meta5"
# [1] "files exist"
# [1] 86
# [1] "checkingrs35749011 GON4L meta5"
# [1] "files exist"
# [1] 87
# [1] "checkingrs76763715 GON4L meta5"
# [1] "files exist"
# [1] 88
# [1] "checkingrs114138760 HAX1 meta5"
# [1] "files exist"
# [1] "df:"
#         rsid        var_id.x   pval.x        var_id.y      pval.y
# 1 rs10158820 1:154217763:C:T 0.027050 1:154217763:C:T 1.72905e-09
# 2  rs1051370 1:154129265:A:G 0.030470 1:154129265:A:G 6.27385e-06
# 3 rs10796953 1:153768179:A:G 0.009438 1:153768179:A:G 3.93914e-08
# 4 rs10796956 1:153795569:T:C 0.004640 1:153795569:T:C 9.83342e-05
# 5 rs10796958 1:153811367:T:C 0.077420 1:153811367:T:C 8.86413e-05
# 6 rs10796968 1:153899330:A:C 0.007473 1:153899330:A:C 1.02071e-04
# [1] 89
# [1] "checkingrs35749011 HAX1 meta5"
# [1] "files exist"
# [1] "df:"
#         rsid        var_id.x   pval.x        var_id.y      pval.y
# 1 rs10158820 1:154217763:C:T 0.027050 1:154217763:C:T 1.72905e-09
# 2  rs1051370 1:154129265:A:G 0.030470 1:154129265:A:G 6.27385e-06
# 3 rs10796953 1:153768179:A:G 0.009438 1:153768179:A:G 3.93914e-08
# 4 rs10796956 1:153795569:T:C 0.004640 1:153795569:T:C 9.83342e-05
# 5 rs10796958 1:153811367:T:C 0.077420 1:153811367:T:C 8.86413e-05
# 6 rs10796968 1:153899330:A:C 0.007473 1:153899330:A:C 1.02071e-04
# [1] 90
# [1] "checkingrs76763715 HAX1 meta5"
# [1] "files exist"
# [1] "df:"
#         rsid        var_id.x   pval.x        var_id.y      pval.y
# 1 rs10158820 1:154217763:C:T 0.027050 1:154217763:C:T 1.72905e-09
# 2  rs1051370 1:154129265:A:G 0.030470 1:154129265:A:G 6.27385e-06
# 3 rs10796953 1:153768179:A:G 0.009438 1:153768179:A:G 3.93914e-08
# 4 rs10796956 1:153795569:T:C 0.004640 1:153795569:T:C 9.83342e-05
# 5 rs10796958 1:153811367:T:C 0.077420 1:153811367:T:C 8.86413e-05
# 6 rs10796968 1:153899330:A:C 0.007473 1:153899330:A:C 1.02071e-04
# [1] 91
# [1] "checkingrs114138760 HCN3 meta5"
# [1] "files exist"
# [1] "df:"
#         rsid        var_id.x pval.x        var_id.y      pval.y
# 1 rs10796940 1:155202689:A:C 0.4679 1:155202689:A:C 9.55799e-05
# 2 rs10796941 1:155284261:C:T 0.7902 1:155284261:C:T 1.27980e-04
# 3 rs10908459 1:155214066:C:T 0.5239 1:155214066:C:T 3.59999e-05
# 4 rs10908461 1:155275727:C:T 0.8197 1:155275727:C:T 5.74196e-06
# 5 rs11264343 1:155199666:T:C 0.4663 1:155199666:T:C 1.13994e-04
# 6 rs11264345 1:155213124:T:A 0.4237 1:155213124:T:A 4.88919e-05
# [1] 92
# [1] "checkingrs35749011 HCN3 meta5"
# [1] "files exist"
# [1] "df:"
#         rsid        var_id.x pval.x        var_id.y      pval.y
# 1 rs10796940 1:155202689:A:C 0.4679 1:155202689:A:C 9.55799e-05
# 2 rs10796941 1:155284261:C:T 0.7902 1:155284261:C:T 1.27980e-04
# 3 rs10908459 1:155214066:C:T 0.5239 1:155214066:C:T 3.59999e-05
# 4 rs10908461 1:155275727:C:T 0.8197 1:155275727:C:T 5.74196e-06
# 5 rs11264343 1:155199666:T:C 0.4663 1:155199666:T:C 1.13994e-04
# 6 rs11264345 1:155213124:T:A 0.4237 1:155213124:T:A 4.88919e-05
# [1] 93
# [1] "checkingrs76763715 HCN3 meta5"
# [1] "files exist"
# [1] "df:"
#         rsid        var_id.x pval.x        var_id.y      pval.y
# 1 rs10796940 1:155202689:A:C 0.4679 1:155202689:A:C 9.55799e-05
# 2 rs10796941 1:155284261:C:T 0.7902 1:155284261:C:T 1.27980e-04
# 3 rs10908459 1:155214066:C:T 0.5239 1:155214066:C:T 3.59999e-05
# 4 rs10908461 1:155275727:C:T 0.8197 1:155275727:C:T 5.74196e-06
# 5 rs11264343 1:155199666:T:C 0.4663 1:155199666:T:C 1.13994e-04
# 6 rs11264345 1:155213124:T:A 0.4237 1:155213124:T:A 4.88919e-05
# [1] 94
# [1] "checkingrs114138760 IL6R meta5"
# [1] "files exist"
# [1] 95
# [1] "checkingrs35749011 IL6R meta5"
# [1] "files exist"
# [1] 96
# [1] "checkingrs76763715 IL6R meta5"
# [1] "files exist"
# [1] 97
# [1] "checkingrs114138760 IL6R-AS1 meta5"
# [1] "files exist"
# [1] 98
# [1] "checkingrs35749011 IL6R-AS1 meta5"
# [1] "files exist"
# [1] 99
# [1] "checkingrs76763715 IL6R-AS1 meta5"
# [1] "files exist"
# [1] 100
# [1] "checkingrs114138760 JTB meta5"
# [1] "files exist"
# [1] "df:"
#          rsid        var_id.x pval.x        var_id.y      pval.y
# 1 rs111923597 1:154293099:G:C 0.9821 1:154293099:G:C 0.000131798
# 2 rs112559935 1:154336175:G:T 0.7737 1:154336175:G:T 0.000176760
# 3 rs113721028 1:154293096:G:A 0.9817 1:154293096:G:A 0.000122553
# 4 rs139573930 1:154224417:A:T 0.4392 1:154224417:A:T 0.000144687
# [1] 101
# [1] "checkingrs35749011 JTB meta5"
# [1] "files exist"
# [1] "df:"
#          rsid        var_id.x pval.x        var_id.y      pval.y
# 1 rs111923597 1:154293099:G:C 0.9821 1:154293099:G:C 0.000131798
# 2 rs112559935 1:154336175:G:T 0.7737 1:154336175:G:T 0.000176760
# 3 rs113721028 1:154293096:G:A 0.9817 1:154293096:G:A 0.000122553
# 4 rs139573930 1:154224417:A:T 0.4392 1:154224417:A:T 0.000144687
# [1] 102
# [1] "checkingrs76763715 JTB meta5"
# [1] "files exist"
# [1] "df:"
#          rsid        var_id.x pval.x        var_id.y      pval.y
# 1 rs111923597 1:154293099:G:C 0.9821 1:154293099:G:C 0.000131798
# 2 rs112559935 1:154336175:G:T 0.7737 1:154336175:G:T 0.000176760
# 3 rs113721028 1:154293096:G:A 0.9817 1:154293096:G:A 0.000122553
# 4 rs139573930 1:154224417:A:T 0.4392 1:154224417:A:T 0.000144687
# [1] 103
# [1] "checkingrs114138760 KCNN3 meta5"
# [1] "files exist"
# [1] "df:"
#         rsid        var_id.x  pval.x        var_id.y      pval.y
# 1  rs1051614 1:154744807:C:G 0.98920 1:154744807:C:G 5.61967e-05
# 2 rs10796935 1:154891363:G:T 0.04777 1:154891363:G:T 4.14431e-27
# 3 rs10796936 1:154999514:T:A 0.61790 1:154999514:T:A 1.21236e-09
# 4 rs10796940 1:155202689:A:C 0.46790 1:155202689:A:C 2.00195e-04
# 5 rs10908432 1:154723546:A:C 0.29300 1:154723546:A:C 6.60066e-12
# 6 rs10908439 1:154750877:T:G 0.56870 1:154750877:T:G 3.64502e-06
# [1] 104
# [1] "checkingrs35749011 KCNN3 meta5"
# [1] "files exist"
# [1] "df:"
#         rsid        var_id.x  pval.x        var_id.y      pval.y
# 1  rs1051614 1:154744807:C:G 0.98920 1:154744807:C:G 5.61967e-05
# 2 rs10796935 1:154891363:G:T 0.04777 1:154891363:G:T 4.14431e-27
# 3 rs10796936 1:154999514:T:A 0.61790 1:154999514:T:A 1.21236e-09
# 4 rs10796940 1:155202689:A:C 0.46790 1:155202689:A:C 2.00195e-04
# 5 rs10908432 1:154723546:A:C 0.29300 1:154723546:A:C 6.60066e-12
# 6 rs10908439 1:154750877:T:G 0.56870 1:154750877:T:G 3.64502e-06
# [1] 105
# [1] "checkingrs76763715 KCNN3 meta5"
# [1] "files exist"
# [1] "df:"
#         rsid        var_id.x  pval.x        var_id.y      pval.y
# 1  rs1051614 1:154744807:C:G 0.98920 1:154744807:C:G 5.61967e-05
# 2 rs10796935 1:154891363:G:T 0.04777 1:154891363:G:T 4.14431e-27
# 3 rs10796936 1:154999514:T:A 0.61790 1:154999514:T:A 1.21236e-09
# 4 rs10796940 1:155202689:A:C 0.46790 1:155202689:A:C 2.00195e-04
# 5 rs10908432 1:154723546:A:C 0.29300 1:154723546:A:C 6.60066e-12
# 6 rs10908439 1:154750877:T:G 0.56870 1:154750877:T:G 3.64502e-06
# [1] 106
# [1] "checkingrs114138760 KHDC4 meta5"
# [1] "files exist"
# [1] 107
# [1] "checkingrs35749011 KHDC4 meta5"
# [1] "files exist"
# [1] 108
# [1] "checkingrs76763715 KHDC4 meta5"
# [1] "files exist"
# [1] 109
# [1] "checkingrs114138760 KRTCAP2 meta5"
# [1] "files exist"
# [1] 110
# [1] "checkingrs35749011 KRTCAP2 meta5"
# [1] "files exist"
# [1] 111
# [1] "checkingrs76763715 KRTCAP2 meta5"
# [1] "files exist"
# [1] 112
# [1] "checkingrs114138760 LAMTOR2 meta5"
# [1] "files exist"
# [1] "df:"
#          rsid        var_id.x pval.x        var_id.y      pval.y
# 1 rs143313487 1:155637899:C:T 0.2835 1:155637899:C:T 0.000163731
# 2 rs148794484 1:155533153:G:A 0.3331 1:155533153:G:A 0.000581426
# 3  rs34673835 1:156013676:C:T 0.4650 1:156013676:C:T 0.000263207
# 4  rs74543372 1:156016006:C:T 0.4209 1:156016006:C:T 0.000222378
# 5  rs79271479 1:155991578:A:G 0.4478 1:155991578:A:G 0.000135246
# 6  rs79918764 1:156015912:T:C 0.4352 1:156015912:T:C 0.000222234
# [1] 113
# [1] "checkingrs35749011 LAMTOR2 meta5"
# [1] "files exist"
# [1] "df:"
#          rsid        var_id.x pval.x        var_id.y      pval.y
# 1 rs143313487 1:155637899:C:T 0.2835 1:155637899:C:T 0.000163731
# 2 rs148794484 1:155533153:G:A 0.3331 1:155533153:G:A 0.000581426
# 3  rs34673835 1:156013676:C:T 0.4650 1:156013676:C:T 0.000263207
# 4  rs74543372 1:156016006:C:T 0.4209 1:156016006:C:T 0.000222378
# 5  rs79271479 1:155991578:A:G 0.4478 1:155991578:A:G 0.000135246
# 6  rs79918764 1:156015912:T:C 0.4352 1:156015912:T:C 0.000222234
# [1] 114
# [1] "checkingrs76763715 LAMTOR2 meta5"
# [1] "files exist"
# [1] "df:"
#          rsid        var_id.x pval.x        var_id.y      pval.y
# 1 rs143313487 1:155637899:C:T 0.2835 1:155637899:C:T 0.000163731
# 2 rs148794484 1:155533153:G:A 0.3331 1:155533153:G:A 0.000581426
# 3  rs34673835 1:156013676:C:T 0.4650 1:156013676:C:T 0.000263207
# 4  rs74543372 1:156016006:C:T 0.4209 1:156016006:C:T 0.000222378
# 5  rs79271479 1:155991578:A:G 0.4478 1:155991578:A:G 0.000135246
# 6  rs79918764 1:156015912:T:C 0.4352 1:156015912:T:C 0.000222234
# [1] 115
# [1] "checkingrs114138760 LENEP meta5"
# [1] "files exist"
# [1] "df:"
#          rsid        var_id.x pval.x        var_id.y      pval.y
# 1 rs184250479 1:154831288:C:T 0.2276 1:154831288:C:T 0.000464905
# [1] 116
# [1] "checkingrs35749011 LENEP meta5"
# [1] "files exist"
# [1] "df:"
#          rsid        var_id.x pval.x        var_id.y      pval.y
# 1 rs184250479 1:154831288:C:T 0.2276 1:154831288:C:T 0.000464905
# [1] 117
# [1] "checkingrs76763715 LENEP meta5"
# [1] "files exist"
# [1] "df:"
#          rsid        var_id.x pval.x        var_id.y      pval.y
# 1 rs184250479 1:154831288:C:T 0.2276 1:154831288:C:T 0.000464905
# [1] 118
# [1] "checkingrs114138760 LMNA meta5"
# [1] "files exist"
# [1] "df:"
#          rsid        var_id.x pval.x        var_id.y      pval.y
# 1 rs115136779 1:156429498:C:T 0.7143 1:156429498:C:T 0.000273498
# 2  rs12039893 1:155614815:A:C 0.3657 1:155614815:A:C 0.000627072
# 3  rs12047756 1:155624944:G:A 0.2889 1:155624944:G:A 0.000612015
# 4  rs12093350 1:155571609:A:G 0.2916 1:155571609:A:G 0.000645594
# 5 rs139356244 1:156428955:C:G 0.7294 1:156428955:C:G 0.000275513
# 6  rs34620961 1:155649827:G:C 0.3268 1:155649827:G:C 0.000471720
# [1] 119
# [1] "checkingrs35749011 LMNA meta5"
# [1] "files exist"
# [1] "df:"
#          rsid        var_id.x pval.x        var_id.y      pval.y
# 1 rs115136779 1:156429498:C:T 0.7143 1:156429498:C:T 0.000273498
# 2  rs12039893 1:155614815:A:C 0.3657 1:155614815:A:C 0.000627072
# 3  rs12047756 1:155624944:G:A 0.2889 1:155624944:G:A 0.000612015
# 4  rs12093350 1:155571609:A:G 0.2916 1:155571609:A:G 0.000645594
# 5 rs139356244 1:156428955:C:G 0.7294 1:156428955:C:G 0.000275513
# 6  rs34620961 1:155649827:G:C 0.3268 1:155649827:G:C 0.000471720
# [1] 120
# [1] "checkingrs76763715 LMNA meta5"
# [1] "files exist"
# [1] "df:"
#          rsid        var_id.x pval.x        var_id.y      pval.y
# 1 rs115136779 1:156429498:C:T 0.7143 1:156429498:C:T 0.000273498
# 2  rs12039893 1:155614815:A:C 0.3657 1:155614815:A:C 0.000627072
# 3  rs12047756 1:155624944:G:A 0.2889 1:155624944:G:A 0.000612015
# 4  rs12093350 1:155571609:A:G 0.2916 1:155571609:A:G 0.000645594
# 5 rs139356244 1:156428955:C:G 0.7294 1:156428955:C:G 0.000275513
# 6  rs34620961 1:155649827:G:C 0.3268 1:155649827:G:C 0.000471720
# [1] 121
# [1] "checkingrs114138760 LOC101928120 meta5"
# [1] "files exist"
# [1] 122
# [1] "checkingrs35749011 LOC101928120 meta5"
# [1] "files exist"
# [1] 123
# [1] "checkingrs76763715 LOC101928120 meta5"
# [1] "files exist"
# [1] 124
# [1] "checkingrs114138760 MEX3A meta5"
# [1] "files exist"
# [1] 125
# [1] "checkingrs35749011 MEX3A meta5"
# [1] "files exist"
# [1] 126
# [1] "checkingrs76763715 MEX3A meta5"
# [1] "files exist"
# [1] 127
# [1] "checkingrs114138760 MIR190B meta5"
# [1] "files exist"
# [1] 128
# [1] "checkingrs35749011 MIR190B meta5"
# [1] "files exist"
# [1] 129
# [1] "checkingrs76763715 MIR190B meta5"
# [1] "files exist"
# [1] 130
# [1] "checkingrs114138760 MIR4258 meta5"
# [1] "files exist"
# [1] 131
# [1] "checkingrs35749011 MIR4258 meta5"
# [1] "files exist"
# [1] 132
# [1] "checkingrs76763715 MIR4258 meta5"
# [1] "files exist"
# [1] 133
# [1] "checkingrs114138760 MIR555 meta5"
# [1] "files exist"
# [1] 134
# [1] "checkingrs35749011 MIR555 meta5"
# [1] "files exist"
# [1] 135
# [1] "checkingrs76763715 MIR555 meta5"
# [1] "files exist"
# [1] 136
# [1] "checkingrs114138760 MIR5698 meta5"
# [1] "files exist"
# [1] 137
# [1] "checkingrs35749011 MIR5698 meta5"
# [1] "files exist"
# [1] 138
# [1] "checkingrs76763715 MIR5698 meta5"
# [1] "files exist"
# [1] 139
# [1] "checkingrs114138760 MIR6737 meta5"
# [1] "files exist"
# [1] 140
# [1] "checkingrs35749011 MIR6737 meta5"
# [1] "files exist"
# [1] 141
# [1] "checkingrs76763715 MIR6737 meta5"
# [1] "files exist"
# [1] 142
# [1] "checkingrs114138760 MIR6738 meta5"
# [1] "files exist"
# [1] 143
# [1] "checkingrs35749011 MIR6738 meta5"
# [1] "files exist"
# [1] 144
# [1] "checkingrs76763715 MIR6738 meta5"
# [1] "files exist"
# [1] 145
# [1] "checkingrs114138760 MIR92B meta5"
# [1] "files exist"
# [1] "df:"
#          rsid        var_id.x pval.x        var_id.y      pval.y
# 1 rs143313487 1:155637899:C:T 0.2835 1:155637899:C:T 0.000152892
# 2 rs148794484 1:155533153:G:A 0.3331 1:155533153:G:A 0.000520986
# 3  rs79271479 1:155991578:A:G 0.4478 1:155991578:A:G 0.000191486
# [1] 146
# [1] "checkingrs35749011 MIR92B meta5"
# [1] "files exist"
# [1] "df:"
#          rsid        var_id.x pval.x        var_id.y      pval.y
# 1 rs143313487 1:155637899:C:T 0.2835 1:155637899:C:T 0.000152892
# 2 rs148794484 1:155533153:G:A 0.3331 1:155533153:G:A 0.000520986
# 3  rs79271479 1:155991578:A:G 0.4478 1:155991578:A:G 0.000191486
# [1] 147
# [1] "checkingrs76763715 MIR92B meta5"
# [1] "files exist"
# [1] "df:"
#          rsid        var_id.x pval.x        var_id.y      pval.y
# 1 rs143313487 1:155637899:C:T 0.2835 1:155637899:C:T 0.000152892
# 2 rs148794484 1:155533153:G:A 0.3331 1:155533153:G:A 0.000520986
# 3  rs79271479 1:155991578:A:G 0.4478 1:155991578:A:G 0.000191486
# [1] 148
# [1] "checkingrs114138760 MSTO1 meta5"
# [1] "files exist"
# [1] "df:"
#          rsid        var_id.x pval.x        var_id.y      pval.y
# 1 rs189117408 1:155557893:G:T  0.262 1:155557893:G:T 0.000760546
# [1] 149
# [1] "checkingrs35749011 MSTO1 meta5"
# [1] "files exist"
# [1] "df:"
#          rsid        var_id.x pval.x        var_id.y      pval.y
# 1 rs189117408 1:155557893:G:T  0.262 1:155557893:G:T 0.000760546
# [1] 150
# [1] "checkingrs76763715 MSTO1 meta5"
# [1] "files exist"
# [1] "df:"
#          rsid        var_id.x pval.x        var_id.y      pval.y
# 1 rs189117408 1:155557893:G:T  0.262 1:155557893:G:T 0.000760546
# [1] 151
# [1] "checkingrs114138760 MSTO2P meta5"
# [1] "files exist"
# [1] "df:"
#         rsid        var_id.x  pval.x        var_id.y      pval.y
# 1 rs10796954 1:155794478:T:C 0.08331 1:155794478:T:C 6.28568e-04
# 2 rs10908471 1:155542942:A:G 0.45380 1:155542942:A:G 3.72157e-04
# 3 rs10908472 1:155544256:T:C 0.48000 1:155544256:T:C 3.67738e-04
# 4 rs10908483 1:155866834:C:T 0.02825 1:155866834:C:T 6.57751e-05
# 5 rs10908486 1:155978544:C:G 0.14470 1:155978544:C:G 6.30186e-04
# 6 rs11264383 1:155545346:C:T 0.45060 1:155545346:C:T 3.65983e-04
# [1] 152
# [1] "checkingrs35749011 MSTO2P meta5"
# [1] "files exist"
# [1] "df:"
#         rsid        var_id.x  pval.x        var_id.y      pval.y
# 1 rs10796954 1:155794478:T:C 0.08331 1:155794478:T:C 6.28568e-04
# 2 rs10908471 1:155542942:A:G 0.45380 1:155542942:A:G 3.72157e-04
# 3 rs10908472 1:155544256:T:C 0.48000 1:155544256:T:C 3.67738e-04
# 4 rs10908483 1:155866834:C:T 0.02825 1:155866834:C:T 6.57751e-05
# 5 rs10908486 1:155978544:C:G 0.14470 1:155978544:C:G 6.30186e-04
# 6 rs11264383 1:155545346:C:T 0.45060 1:155545346:C:T 3.65983e-04
# [1] 153
# [1] "checkingrs76763715 MSTO2P meta5"
# [1] "files exist"
# [1] "df:"
#         rsid        var_id.x  pval.x        var_id.y      pval.y
# 1 rs10796954 1:155794478:T:C 0.08331 1:155794478:T:C 6.28568e-04
# 2 rs10908471 1:155542942:A:G 0.45380 1:155542942:A:G 3.72157e-04
# 3 rs10908472 1:155544256:T:C 0.48000 1:155544256:T:C 3.67738e-04
# 4 rs10908483 1:155866834:C:T 0.02825 1:155866834:C:T 6.57751e-05
# 5 rs10908486 1:155978544:C:G 0.14470 1:155978544:C:G 6.30186e-04
# 6 rs11264383 1:155545346:C:T 0.45060 1:155545346:C:T 3.65983e-04
# [1] 154
# [1] "checkingrs114138760 MTX1 meta5"
# [1] "files exist"
# [1] "df:"
#         rsid        var_id.x   pval.x        var_id.y      pval.y
# 1   rs675661 1:156087206:A:G 0.003305 1:156087206:A:G 0.000491131
# 2 rs78261031 1:156112470:G:A 0.041250 1:156112470:G:A 0.000766605
# [1] 155
# [1] "checkingrs35749011 MTX1 meta5"
# [1] "files exist"
# [1] "df:"
#         rsid        var_id.x   pval.x        var_id.y      pval.y
# 1   rs675661 1:156087206:A:G 0.003305 1:156087206:A:G 0.000491131
# 2 rs78261031 1:156112470:G:A 0.041250 1:156112470:G:A 0.000766605
# [1] 156
# [1] "checkingrs76763715 MTX1 meta5"
# [1] "files exist"
# [1] "df:"
#         rsid        var_id.x   pval.x        var_id.y      pval.y
# 1   rs675661 1:156087206:A:G 0.003305 1:156087206:A:G 0.000491131
# 2 rs78261031 1:156112470:G:A 0.041250 1:156112470:G:A 0.000766605
# [1] 157
# ...
# [1] 2846
# [1] "checkingrs11683001 IL1RL2 meta5"
# [1] "files exist"
# [1] "df:"
#         rsid        var_id.x  pval.x        var_id.y      pval.y
# 1  rs1007027 2:102731596:A:C 0.60350 2:102731596:A:C 5.61701e-06
# 2 rs10153578 2:102764609:A:G 0.83710 2:102764609:A:G 7.50437e-07
# 3  rs1019296 2:102721117:T:C 0.53830 2:102721117:T:C 5.02456e-06
# 4 rs10198135 2:102674631:G:A 0.69960 2:102674631:G:A 1.52566e-07
# 5 rs10490203 2:103059237:T:G 0.07217 2:103059237:T:G 1.65718e-04
# 6 rs11123912 2:102816536:G:A 0.29880 2:102816536:G:A 7.29694e-04
# [1] 2847
# [1] "checkingrs11683001 LINC01127 meta5"
# [1] "files exist"
# [1] 2848
# [1] "checkingrs11683001 LOC101927142 meta5"
# [1] "files exist"
# [1] 2849
# [1] "checkingrs11683001 MAP4K4 meta5"
# [1] "files exist"
# [1] "df:"
#         rsid        var_id.x    pval.x        var_id.y      pval.y
# 1  rs1009656 2:102431447:T:C 5.046e-01 2:102431447:T:C 3.60883e-14
# 2 rs10177289 2:102334446:T:C 5.067e-01 2:102334446:T:C 2.16123e-13
# 3 rs10182135 2:102553694:G:A 8.139e-01 2:102553694:G:A 4.68651e-06
# 4 rs10432622 2:102331171:A:G 5.337e-01 2:102331171:A:G 6.93596e-14
# 5 rs10489971 2:102527827:C:T 1.987e-12 2:102527827:C:T 4.25811e-05
# 6 rs10865047 2:102429516:A:G 5.379e-01 2:102429516:A:G 4.60060e-14
# [1] 2850
# [1] "checkingrs11683001 MFSD9 meta5"
# [1] "files exist"
# [1] "df:"
#         rsid        var_id.x pval.x        var_id.y      pval.y
# 1 rs12467776 2:103342904:G:T 0.7972 2:103342904:G:T 2.38224e-04
# 2 rs12990378 2:103323614:C:T 0.5930 2:103323614:C:T 4.22009e-04
# 3 rs12990389 2:103323641:C:G 0.6129 2:103323641:C:G 4.99788e-04
# 4  rs2540291 2:103385020:A:C 0.6591 2:103385020:A:C 7.09896e-04
# 5  rs2540292 2:103381750:A:G 0.6661 2:103381750:A:G 6.40203e-04
# 6  rs2540293 2:103381513:G:A 0.6579 2:103381513:G:A 6.35305e-05
# [1] 2851
# [1] "checkingrs11683001 MIR4772 meta5"
# [1] "files exist"
# [1] 2852
# [1] "checkingrs11683001 MIR5696 meta5"
# [1] "files exist"
# [1] 2853
# [1] "checkingrs11683001 NPAS2 meta5"
# [1] "files exist"
# [1] "df:"
#          rsid        var_id.x pval.x        var_id.y    pval.y
# 1 rs143286209 2:102031860:C:T 0.0956 2:102031860:C:T 0.0001545
# [1] 2854
# [1] "checkingrs11683001 RFX8 meta5"
# [1] "files exist"
# [1] "df:"
#         rsid        var_id.x pval.x        var_id.y      pval.y
# 1 rs10172545 2:102084183:G:C 0.1923 2:102084183:G:C 1.80123e-06
# 2 rs10180163 2:102063673:C:G 0.9631 2:102063673:C:G 1.01558e-05
# 3 rs10188564 2:102101064:C:A 0.3011 2:102101064:C:A 9.44917e-10
# 4 rs10191662 2:102062700:T:C 0.9434 2:102062700:T:C 7.66476e-06
# 5 rs10195061 2:102093974:T:G 0.4828 2:102093974:T:G 5.76957e-04
# 6 rs10865042 2:102056267:T:C 0.9035 2:102056267:T:C 3.28206e-05
# [1] 2855
# [1] "checkingrs11683001 RNF149 meta5"
# [1] "files exist"
# [1] "df:"
#         rsid        var_id.x pval.x        var_id.y      pval.y
# 1 rs10179266 2:102224583:T:C 0.7014 2:102224583:T:C 1.24757e-04
# 2 rs10184144 2:102104978:C:T 0.4039 2:102104978:C:T 3.93150e-04
# 3 rs10186000 2:101917082:C:T 0.5674 2:101917082:C:T 2.50832e-63
# 4 rs10193042 2:102229207:A:G 0.8973 2:102229207:A:G 4.31238e-05
# 5 rs10195061 2:102093974:T:G 0.4828 2:102093974:T:G 4.09801e-04
# 6 rs10195468 2:102229168:T:C 0.8310 2:102229168:T:C 4.30406e-05
# [1] 2856
# [1] "checkingrs11683001 RPL31 meta5"
# [1] "files exist"
# [1] "df:"
#         rsid        var_id.x pval.x        var_id.y      pval.y
# 1 rs12712088 2:101610592:G:C 0.5252 2:101610592:G:C 0.000617558
# 2  rs2310026 2:101603571:A:G 0.4422 2:101603571:A:G 0.000705501
# [1] 2857
# [1] "checkingrs11683001 SLC9A2 meta5"
# [1] "files exist"
# [1] "df:"
#         rsid        var_id.x  pval.x        var_id.y      pval.y
# 1 rs10173337 2:103258390:C:G 0.13790 2:103258390:C:G 1.57185e-05
# 2 rs10178118 2:103255519:T:C 0.82990 2:103255519:T:C 3.84141e-09
# 3 rs10186929 2:103182687:T:A 0.26720 2:103182687:T:A 5.42123e-04
# 4 rs10209131 2:103209596:C:T 0.15960 2:103209596:C:T 9.10371e-06
# 5 rs11123942 2:103266497:G:A 0.13100 2:103266497:G:A 6.57621e-08
# 6 rs11123943 2:103266644:C:T 0.07187 2:103266644:C:T 5.42413e-06
# [1] 2858
# [1] "checkingrs11683001 SLC9A4 meta5"
# [1] "files exist"
# [1] 2859
# [1] "checkingrs11683001 SNORD89 meta5"
# [1] "files exist"
# [1] "df:"
#         rsid        var_id.x pval.x        var_id.y      pval.y
# 1 rs78132130 2:102234360:G:A 0.7141 2:102234360:G:A 0.000380879
# [1] 2860
# [1] "checkingrs11683001 TBC1D8 meta5"
# [1] "files exist"
# [1] "df:"
#          rsid        var_id.x  pval.x        var_id.y      pval.y
# 1  rs10084339 2:101714723:A:G 0.82890 2:101714723:A:G 6.60883e-05
# 2 rs112493491 2:101675573:G:A 0.04150 2:101675573:G:A 1.71486e-07
# 3  rs11675221 2:101670937:C:T 0.04959 2:101670937:C:T 2.26116e-07
# 4  rs11675224 2:101670955:C:T 0.05583 2:101670955:C:T 2.25950e-07
# 5  rs11686916 2:101683179:C:T 0.09263 2:101683179:C:T 6.80597e-04
# 6   rs1192775 2:101794490:A:G 0.20140 2:101794490:A:G 1.44857e-04
# [1] 2861
# [1] "checkingrs11683001 TBC1D8-AS1 meta5"
# [1] "files exist"
# [1] 2862
# [1] "checkingrs11683001 TMEM182 meta5"
# [1] "files exist"
# [1] 2863
# [1] "checkingrs61863020 ADRA2A prog1"
# [1] "files exist"
# [1] "df:"
#         rsid         var_id.x  pval.x         var_id.y      pval.y
# 1 rs11195482 10:112998351:G:C 0.51520 10:112998351:G:C 3.18812e-04
# 2 rs11195483 10:112998370:C:T 0.51520 10:112998370:C:T 3.28529e-04
# 3 rs11592192 10:113116814:G:A 0.05429 10:113116814:G:A 6.49078e-04
# 4 rs12571767 10:113003262:C:T 0.50220 10:113003262:C:T 1.65174e-04
# 5  rs1360866 10:112967078:T:A 0.08485 10:112967078:T:A 7.31461e-07
# 6  rs4317914 10:112995886:G:A 0.51710 10:112995886:G:A 3.12027e-04
# [1] 2864
# [1] "checkingrs61863020 BBIP1 prog1"
# [1] "files exist"
# [1] "df:"
#         rsid         var_id.x pval.x         var_id.y      pval.y
# 1 rs11195367 10:112647116:A:G 0.9817 10:112647116:A:G 0.000245520
# 2 rs11195378 10:112689652:G:A 0.8579 10:112689652:G:A 0.000146387
# 3 rs11195386 10:112710798:A:G 0.7879 10:112710798:A:G 0.000453351
# 4 rs11195389 10:112715020:G:C 0.8579 10:112715020:G:C 0.000135797
# 5 rs11195392 10:112730678:T:A 0.8579 10:112730678:T:A 0.000136546
# 6 rs11195393 10:112740991:C:T 0.8579 10:112740991:C:T 0.000184116
# [1] 2865
# [1] "checkingrs61863020 DUSP5 prog1"
# [1] "files exist"
# [1] "df:"
#         rsid         var_id.x pval.x         var_id.y      pval.y
# 1 rs17126877 10:111672786:C:T 0.6953 10:111672786:C:T 0.000446979
# 2 rs17126931 10:111754633:T:C 0.8577 10:111754633:T:C 0.000486179
# 3 rs55683820 10:111665376:G:A 0.6953 10:111665376:G:A 0.000727896
# 4  rs7073969 10:111753798:C:G 0.9356 10:111753798:C:G 0.000466495
# 5 rs72828241 10:111744704:T:A 0.9993 10:111744704:T:A 0.000480422
# 6 rs72828242 10:111745121:T:C 0.9993 10:111745121:T:C 0.000474422
# [1] 2866
# [1] "checkingrs61863020 GPAM prog1"
# [1] "files exist"
# [1] "df:"
#         rsid         var_id.x pval.x         var_id.y      pval.y
# 1 rs10509956 10:113994152:T:C 0.7715 10:113994152:T:C 3.84546e-07
# 2 rs11195844 10:113979530:T:C 0.9843 10:113979530:T:C 4.32262e-07
# 3 rs11195847 10:113991862:T:C 0.9686 10:113991862:T:C 3.01927e-04
# 4 rs11195849 10:113996495:A:C 0.7715 10:113996495:A:C 6.84026e-07
# 5 rs11195857 10:114022566:G:A 0.7477 10:114022566:G:A 8.25182e-08
# 6 rs11195863 10:114034861:C:T 0.7715 10:114034861:C:T 1.57082e-11
# [1] 2867
# [1] "checkingrs61863020 HEAT2 prog1"
# [1] "files exist"
# [1] 2868
# [1] "checkingrs61863020 MIR4680 prog1"
# [1] "files exist"
# [1] 2869
# [1] "checkingrs61863020 MIR548E prog1"
# [1] "files exist"
# [1] 2870
# [1] "checkingrs61863020 MXI1 prog1"
# [1] "files exist"
# [1] "df:"
#         rsid         var_id.x pval.x         var_id.y      pval.y
# 1 rs10509912 10:112029405:T:A 0.6185 10:112029405:T:A 2.22601e-04
# 2 rs10509915 10:112088178:C:T 0.8445 10:112088178:C:T 4.80975e-42
# 3 rs10787228 10:112084976:T:C 0.6981 10:112084976:T:C 8.11782e-44
# 4 rs10884939 10:111981987:G:A 0.5273 10:111981987:G:A 1.24554e-46
# 5 rs10884948 10:112082903:G:A 0.6981 10:112082903:G:A 3.05709e-44
# 6 rs10884950 10:112092769:A:G 0.7253 10:112092769:A:G 2.70393e-43
# [1] 2871
# [1] "checkingrs61863020 PDCD4 prog1"
# [1] "files exist"
# [1] "df:"
#          rsid         var_id.x pval.x         var_id.y      pval.y
# 1  rs10885036 10:112505039:C:T 0.1322 10:112505039:C:T 5.05828e-04
# 2  rs10885037 10:112507307:G:T 0.1197 10:112507307:G:T 3.43084e-04
# 3   rs1113796 10:112506322:C:T 0.1305 10:112506322:C:T 5.08232e-04
# 4  rs11195539 10:113118382:T:A 0.4743 10:113118382:T:A 2.77859e-05
# 5  rs11195650 10:113378908:T:A 0.7937 10:113378908:T:A 6.21221e-04
# 6 rs117513632 10:112664314:C:G 0.1312 10:112664314:C:G 3.13542e-04
# [1] 2872
# [1] "checkingrs61863020 PDCD4-AS1 prog1"
# [1] "files exist"
# [1] "df:"
#         rsid         var_id.x pval.x         var_id.y      pval.y
# 1 rs10787410 10:113567331:G:C 0.4908 10:113567331:G:C 0.000608553
# 2 rs10885281 10:113605371:C:T 0.4727 10:113605371:C:T 0.000829528
# 3 rs11195731 10:113568367:T:G 0.6082 10:113568367:T:G 0.000538439
# 4 rs11195743 10:113603722:C:T 0.8416 10:113603722:C:T 0.000649606
# 5 rs12246370 10:113603793:T:C 0.9029 10:113603793:T:C 0.000608430
# 6  rs1819621 10:113572534:A:G 0.5992 10:113572534:A:G 0.000715480
# [1] 2873
# [1] "checkingrs61863020 RBM20 prog1"
# [1] "files exist"
# [1] "df:"
#         rsid         var_id.x pval.x         var_id.y      pval.y
# 1 rs11195238 10:112388857:C:T 0.8150 10:112388857:C:T 0.000697816
# 2 rs11195240 10:112388929:C:T 0.8475 10:112388929:C:T 0.000718648
# 3 rs12772433 10:112388183:T:C 0.7624 10:112388183:T:C 0.000455413
# 4 rs60946503 10:112398982:T:C 0.3256 10:112398982:T:C 0.000684625
# 5  rs7083124 10:112397991:C:G 0.2807 10:112397991:C:G 0.000533340
# 6 rs72641325 10:112403810:C:A 0.3994 10:112403810:C:A 0.000386369
# [1] 2874
# [1] "checkingrs61863020 RPL13AP6 prog1"
# [1] "files exist"
# [1] 2875
# [1] "checkingrs61863020 SHOC2 prog1"
# [1] "files exist"
# [1] 2876
# [1] "checkingrs61863020 SMC3 prog1"
# [1] "files exist"
# [1] 2877
# [1] "checkingrs61863020 SMNDC1 prog1"
# [1] "files exist"
# [1] 2878
# [1] "checkingrs382940 ABCA1 prog2"
# [1] "files exist"
# [1] "df:"
#         rsid        var_id.x pval.x        var_id.y      pval.y
# 1 rs10820756 9:107776314:A:G 0.2773 9:107776314:A:G 7.35337e-04
# 2 rs11496645 9:107774136:T:C 0.2770 9:107774136:T:C 7.86164e-04
# 3 rs11790326 9:107643810:T:C 0.7654 9:107643810:T:C 9.31464e-07
# 4  rs2099544 9:107660780:A:T 0.8479 9:107660780:A:T 7.33137e-04
# 5  rs2244278 9:107661129:C:A 0.7151 9:107661129:C:A 4.33391e-09
# 6  rs2740488 9:107661742:A:C 0.9705 9:107661742:A:C 6.76060e-06
# [1] 2879
# [1] "checkingrs382940 FKTN prog2"
# [1] "files exist"
# [1] "df:"
#         rsid        var_id.x  pval.x        var_id.y      pval.y
# 1  rs1018847 9:108335214:C:T 0.06662 9:108335214:C:T 6.44336e-09
# 2  rs1018848 9:108335215:G:A 0.43360 9:108335215:G:A 2.83514e-08
# 3  rs1018849 9:108335229:A:G 0.44220 9:108335229:A:G 3.03369e-08
# 4 rs10491808 9:108314287:T:C 0.08023 9:108314287:T:C 4.12143e-10
# 5 rs10820805 9:108221001:A:G 0.37000 9:108221001:A:G 5.03925e-09
# 6 rs10820806 9:108236804:A:G 0.43970 9:108236804:A:G 9.49788e-10
# [1] 2880
# [1] "checkingrs382940 FSD1L prog2"
# [1] "files exist"
# [1] "df:"
#         rsid        var_id.x pval.x        var_id.y      pval.y
# 1  rs1018849 9:108335229:A:G 0.4422 9:108335229:A:G 0.000268774
# 2 rs10820805 9:108221001:A:G 0.3700 9:108221001:A:G 0.000416636
# 3 rs10820806 9:108236804:A:G 0.4397 9:108236804:A:G 0.000388101
# 4 rs10820807 9:108250178:A:T 0.4390 9:108250178:A:T 0.000402738
# 5 rs10820808 9:108257028:A:G 0.4658 9:108257028:A:G 0.000131967
# 6 rs10991664 9:108230709:C:T 0.4393 9:108230709:C:T 0.000383476
# [1] 2881
# [1] "checkingrs382940 NIPSNAP3A prog2"
# [1] "files exist"
# [1] "df:"
#         rsid        var_id.x pval.x        var_id.y      pval.y
# 1 rs10116587 9:107438685:G:A 0.2493 9:107438685:G:A 6.93394e-47
# 2 rs10117760 9:107370114:G:T 0.6962 9:107370114:G:T 1.53734e-15
# 3 rs10118395 9:107321120:A:G 0.9335 9:107321120:A:G 7.11263e-12
# 4 rs10118764 9:107473687:T:C 0.3901 9:107473687:T:C 3.92073e-46
# 5 rs10122516 9:107377683:T:C 0.7030 9:107377683:T:C 1.51043e-15
# 6 rs10122519 9:107121825:G:A 0.8170 9:107121825:G:A 7.73127e-06
# [1] 2882
# [1] "checkingrs382940 NIPSNAP3B prog2"
# [1] "files exist"
# [1] 2883
# [1] "checkingrs382940 OR13C2 prog2"
# [1] "files exist"
# [1] 2884
# [1] "checkingrs382940 OR13C3 prog2"
# [1] "files exist"
# [1] "df:"
#         rsid        var_id.x pval.x        var_id.y      pval.y
# 1 rs10761063 9:107399341:A:G 0.2553 9:107399341:A:G 0.000592478
# 2 rs10761064 9:107400167:G:A 0.2283 9:107400167:G:A 0.000286835
# 3 rs10761067 9:107414571:A:C 0.2341 9:107414571:A:C 0.000320454
# 4 rs10761068 9:107418661:C:T 0.2427 9:107418661:C:T 0.000281958
# 5 rs10761069 9:107420932:G:T 0.2410 9:107420932:G:T 0.000497295
# 6 rs10820695 9:107402258:A:T 0.2289 9:107402258:A:T 0.000183525
# [1] 2885
# [1] "checkingrs382940 OR13C4 prog2"
# [1] "files exist"
# [1] "df:"
#         rsid        var_id.x pval.x        var_id.y      pval.y
# 1 rs10116587 9:107438685:G:A 0.2493 9:107438685:G:A 4.84895e-04
# 2 rs10156474 9:107367008:T:C 0.3945 9:107367008:T:C 2.63303e-04
# 3 rs10733733 9:107358376:C:G 0.3587 9:107358376:C:G 8.46287e-05
# 4 rs10733734 9:107387383:G:A 0.3236 9:107387383:G:A 3.12833e-05
# 5 rs10739893 9:107297371:C:A 0.9880 9:107297371:C:A 3.74986e-04
# 6 rs10739898 9:107369564:T:C 0.3636 9:107369564:T:C 9.68509e-05
# [1] 2886
# [1] "checkingrs382940 OR13C5 prog2"
# [1] "files exist"
# [1] 2887
# [1] "checkingrs382940 OR13C8 prog2"
# [1] "files exist"
# [1] "df:"
#          rsid        var_id.x  pval.x        var_id.y      pval.y
# 1 rs112228874 9:106857028:A:G 0.09668 9:106857028:A:G 0.000109935
# 2 rs112881018 9:106860057:A:G 0.09937 9:106860057:A:G 0.000268267
# [1] 2888
# [1] "checkingrs382940 OR13C9 prog2"
# [1] "files exist"
# [1] "df:"
#         rsid        var_id.x pval.x        var_id.y      pval.y
# 1 rs10156474 9:107367008:T:C 0.3945 9:107367008:T:C 7.69789e-05
# 2 rs10739899 9:107369612:C:G 0.4283 9:107369612:C:G 7.14428e-05
# 3 rs10761042 9:107344619:T:C 0.3965 9:107344619:T:C 7.70794e-05
# 4 rs10761044 9:107344927:A:G 0.3961 9:107344927:A:G 6.46655e-04
# 5 rs10761052 9:107375343:T:A 0.3899 9:107375343:T:A 2.27162e-05
# 6 rs10820671 9:107345349:C:T 0.3970 9:107345349:C:T 7.69544e-05
# [1] 2889
# [1] "checkingrs382940 OR13D1 prog2"
# [1] "files exist"
# [1] "df:"
#          rsid        var_id.x pval.x        var_id.y      pval.y
# 1  rs10991445 9:107749439:G:A 0.6314 9:107749439:G:A 0.000767150
# 2 rs146685885 9:107779933:C:T 0.2204 9:107779933:C:T 0.000247411
# 3   rs4743789 9:107776619:G:C 0.6099 9:107776619:G:C 0.000231809
# 4  rs62566524 9:107785164:G:A 0.1847 9:107785164:G:A 0.000186513
# 5  rs62566525 9:107785208:C:T 0.1854 9:107785208:C:T 0.000185677
# 6   rs7029441 9:107750757:G:A 0.6288 9:107750757:G:A 0.000773807
# [1] 2890
# [1] "checkingrs382940 OR13F1 prog2"
# [1] "files exist"
# [1] "df:"
#         rsid        var_id.x pval.x        var_id.y      pval.y
# 1 rs34868874 9:107965516:C:A 0.9398 9:107965516:C:A 0.000777723
# [1] 2891
# [1] "checkingrs382940 RALGAPA1P1 prog2"
# [1] "files exist"
# [1] "df:"
#         rsid        var_id.x pval.x        var_id.y      pval.y
# 1  rs1018848 9:108335215:G:A 0.4336 9:108335215:G:A 2.51226e-04
# 2  rs1018849 9:108335229:A:G 0.4422 9:108335229:A:G 1.69360e-05
# 3 rs10820805 9:108221001:A:G 0.3700 9:108221001:A:G 3.01362e-04
# 4 rs10820806 9:108236804:A:G 0.4397 9:108236804:A:G 2.55270e-04
# 5 rs10820807 9:108250178:A:T 0.4390 9:108250178:A:T 2.29430e-04
# 6 rs10820808 9:108257028:A:G 0.4658 9:108257028:A:G 4.19901e-05
# [1] 2892
# [1] "checkingrs382940 SLC44A1 prog2"
# [1] "files exist"
# [1] "df:"
#         rsid        var_id.x pval.x        var_id.y      pval.y
# 1 rs75767319 9:108553831:G:A 0.9014 9:108553831:G:A 0.000297442
# [1] 2893
# [1] "checkingrs382940 TAL2 prog2"
# [1] "files exist"
# [1] "df:"
#          rsid        var_id.x pval.x        var_id.y      pval.y
# 1 rs113647163 9:107655596:G:A 0.6994 9:107655596:G:A 6.23388e-05
# 2  rs57989482 9:107631071:C:T 0.5830 9:107631071:C:T 3.34018e-04
# [1] 2894
# [1] "checkingrs382940 TMEM38B prog2"
# [1] "files exist"
# [1] "df:"
#         rsid        var_id.x   pval.x        var_id.y      pval.y
# 1 rs10114831 9:108492735:C:T 0.098500 9:108492735:C:T 7.84219e-05
# 2 rs10117549 9:108584463:A:G 0.010320 9:108584463:A:G 2.23613e-04
# 3 rs10118718 9:109438975:G:A 0.030620 9:109438975:G:A 1.87971e-04
# 4 rs10120482 9:109430570:C:T 0.031700 9:109430570:C:T 2.52717e-04
# 5 rs10121208 9:108605606:G:A 0.004243 9:108605606:G:A 1.57864e-04
# 6 rs10217508 9:108557750:A:G 0.064280 9:108557750:A:G 1.65174e-04

# %%
dim(plots_with_risk_snp)
head(plots_with_risk_snp)

write.csv(plots_with_risk_snp,file="$PATH1/qtl/psychencode/eqtl_plots_with_risk_snp.csv",row.names=F,col.names=F)
# Out:
#   File "<ipython-input-1-a86cd515ba44>", line 4
#     write.csv(plots_with_risk_snp,file="$PATH1/qtl/psychencode/eqtl_plots_with_risk_snp.csv",row.names=F,col.names=F)
#                                                                                             ^
# SyntaxError: keyword can't be an expression

# %%
dim(plots_with_no_data)
head(plots_with_no_data)

write.csv(plots_with_no_data,file="$PATH1/qtl/psychencode/eqtl_plots_with_no_data.csv",row.names=F,col.names=F)
# Out:
#   File "<ipython-input-2-c79c6cfcad48>", line 4
#     write.csv(plots_with_no_data,file="$PATH1/qtl/psychencode/eqtl_plots_with_no_data.csv",row.names=F,col.names=F)
#                                                                                           ^
# SyntaxError: keyword can't be an expression

# %%
dim(plots_to_check)
head(plots_to_check)

write.csv(plots_to_check,file="$PATH1/qtl/psychencode/eqtl_plots_to_check.csv",row.names=F,col.names=F)
# Out:
#   File "<ipython-input-3-9bd7226199b4>", line 4
#     write.csv(plots_to_check,file="$PATH1/qtl/psychencode/eqtl_plots_to_check.csv",row.names=F,col.names=F)
#                                                                                   ^
# SyntaxError: keyword can't be an expression

# %% [markdown]
# ## (3) Obtain Proxy SNPS Per Locus
#
# use LDlinkR to generate a list of snps with a LD R2 > 0.7 for each risk variant
#
# run this in terminal. Queries must be made sequentially for LDlinkR to work (so don't bother changing the script to run in parallel)

# %%
print("Rscript getRiskSNPProxies.R")
# Out:
# [1] "Rscript getRiskSNPProxies.R"

# %% [markdown]
# ## (4) Check Plots for Proxy SNPs
#
# go through all the plots we know need checking and see if they have a proxy.
#
# write plots with a good proxy snp to a file. and then combine that file with the list of plots that already have the risk snp to create a final plot list file

# %%
proxy_dir <- "$PATH1/qtl/proxy_snps"

# %%
plots_to_check <- fread("$PATH1/qtl/psychencode/eqtl_plots_to_check.csv")
plots_with_proxy_snp <- data.frame()
plots_with_no_proxy_snp <- data.frame()

# %%
print(dim(plots_to_check))
# Out:
# [1] 1693   10

# %%
for (rownum in 1:nrow(plots_to_check))
{
    row <- plots_to_check[rownum,]

  
    chr <- row$CHR
    snp <- row$SNP
    gene <- row$Gene
    feature <- row$feature
    gwas <- row$gwas

    print(paste0("checking", snp, " " , gene, " ", gwas))


    if(gwas == "meta5")
    {
      tsv_dir <- paste0(eqtl_tsv_dir,"/meta5")
      gwas_fn = paste0(tsv_dir, '/', gene,'_gwas.tsv')
      qtl_fn = paste0(tsv_dir, '/', gene,'_eqtl.tsv')
    }
    if(gwas == "prog1")
    {
      tsv_dir <- paste0(eqtl_tsv_dir,"/prog1")
      gwas_fn = paste0(tsv_dir, '/', gene,'_gwas.tsv')
      qtl_fn = paste0(tsv_dir, '/', gene,'_eqtl.tsv')
    }
    if(gwas == "prog2")
    {
      tsv_dir <- paste0(eqtl_tsv_dir,"/prog2")
      gwas_fn = paste0(tsv_dir, '/', gene,'_gwas.tsv')
      qtl_fn = paste0(tsv_dir, '/', gene,'_eqtl.tsv')
    }
    

    g = read.table(gwas_fn, header = T)
    e = read.table(qtl_fn, header = T)

    #merge them by rsid
    df = merge(g, e, by = 'rsid')
    
    #load the proxy snps
    proxies <- fread(paste0(proxy_dir,"/",row$SNP,"_proxies.csv"))
    
    #if we even have any proxy snps for the risk variant
    if(nrow(proxies)>0)
    {
        #merge the proxy snp df with the data df
        merged <- merge(df, proxies, by.x = "rsid", by.y = "RS_Number")

        if(nrow(merged) > 0)
        {
            best_ld_snp <- merged[which.max(merged$R2),]
            row$'forced_lead_variant' <- best_ld_snp$rsid
            row$'forced_lead_variant_r2' <- best_ld_snp$R2
            row$'reason' <- "plot has a good proxy snp"
            plots_with_proxy_snp <- rbind(plots_with_proxy_snp,row)
            
        }
        else
        {
            row$'reason' <- "no good proxy snp exists in the data we want to plot"
            plots_with_no_proxy_snp <- rbind(plots_with_no_proxy_snp, row)
        }
    }
    else
    {
        row$'reason' <- "there was no proxy snp for the risk variant"
        plots_with_no_proxy_snp <- rbind(plots_with_no_proxy_snp, row)
    }
    
    
    
    
}
# Out:
# [1] "checkingrs114138760 ADAM15 meta5"
# [1] "checkingrs35749011 ADAM15 meta5"
# [1] "checkingrs76763715 ADAM15 meta5"
# [1] "checkingrs114138760 ADAR meta5"
# [1] "checkingrs35749011 ADAR meta5"
# [1] "checkingrs76763715 ADAR meta5"
# [1] "checkingrs114138760 AQP10 meta5"
# [1] "checkingrs35749011 AQP10 meta5"
# [1] "checkingrs76763715 AQP10 meta5"
# [1] "checkingrs114138760 ARHGEF2 meta5"
# [1] "checkingrs35749011 ARHGEF2 meta5"
# [1] "checkingrs76763715 ARHGEF2 meta5"
# [1] "checkingrs114138760 ASH1L-AS1 meta5"
# [1] "checkingrs35749011 ASH1L-AS1 meta5"
# [1] "checkingrs76763715 ASH1L-AS1 meta5"
# [1] "checkingrs114138760 ATP8B2 meta5"
# [1] "checkingrs35749011 ATP8B2 meta5"
# [1] "checkingrs76763715 ATP8B2 meta5"
# [1] "checkingrs114138760 C1orf189 meta5"
# [1] "checkingrs35749011 C1orf189 meta5"
# [1] "checkingrs76763715 C1orf189 meta5"
# [1] "checkingrs114138760 C1orf43 meta5"
# [1] "checkingrs35749011 C1orf43 meta5"
# [1] "checkingrs76763715 C1orf43 meta5"
# [1] "checkingrs114138760 CHRNB2 meta5"
# [1] "checkingrs35749011 CHRNB2 meta5"
# [1] "checkingrs76763715 CHRNB2 meta5"
# [1] "checkingrs114138760 CRTC2 meta5"
# [1] "checkingrs35749011 CRTC2 meta5"
# [1] "checkingrs76763715 CRTC2 meta5"
# [1] "checkingrs114138760 DAP3 meta5"
# [1] "checkingrs35749011 DAP3 meta5"
# [1] "checkingrs76763715 DAP3 meta5"
# [1] "checkingrs114138760 DCST1 meta5"
# [1] "checkingrs35749011 DCST1 meta5"
# [1] "checkingrs76763715 DCST1 meta5"
# [1] "checkingrs114138760 DCST2 meta5"
# [1] "checkingrs35749011 DCST2 meta5"
# [1] "checkingrs76763715 DCST2 meta5"
# [1] "checkingrs114138760 DENND4B meta5"
# [1] "checkingrs35749011 DENND4B meta5"
# [1] "checkingrs76763715 DENND4B meta5"
# [1] "checkingrs114138760 DPM3 meta5"
# [1] "checkingrs35749011 DPM3 meta5"
# [1] "checkingrs76763715 DPM3 meta5"
# [1] "checkingrs114138760 EFNA1 meta5"
# [1] "checkingrs35749011 EFNA1 meta5"
# [1] "checkingrs76763715 EFNA1 meta5"
# [1] "checkingrs114138760 EFNA3 meta5"
# [1] "checkingrs35749011 EFNA3 meta5"
# [1] "checkingrs76763715 EFNA3 meta5"
# [1] "checkingrs114138760 EFNA4 meta5"
# [1] "checkingrs35749011 EFNA4 meta5"
# [1] "checkingrs76763715 EFNA4 meta5"
# [1] "checkingrs114138760 FAM189B meta5"
# [1] "checkingrs35749011 FAM189B meta5"
# [1] "checkingrs76763715 FAM189B meta5"
# [1] "checkingrs114138760 FDPS meta5"
# [1] "checkingrs35749011 FDPS meta5"
# [1] "checkingrs76763715 FDPS meta5"
# [1] "checkingrs114138760 FLAD1 meta5"
# [1] "checkingrs35749011 FLAD1 meta5"
# [1] "checkingrs76763715 FLAD1 meta5"
# [1] "checkingrs114138760 GBA meta5"
# [1] "checkingrs35749011 GBA meta5"
# [1] "checkingrs76763715 GBA meta5"
# [1] "checkingrs114138760 GBAP1 meta5"
# [1] "checkingrs35749011 GBAP1 meta5"
# [1] "checkingrs76763715 GBAP1 meta5"
# [1] "checkingrs114138760 HAX1 meta5"
# [1] "checkingrs35749011 HAX1 meta5"
# [1] "checkingrs76763715 HAX1 meta5"
# [1] "checkingrs114138760 HCN3 meta5"
# [1] "checkingrs35749011 HCN3 meta5"
# [1] "checkingrs76763715 HCN3 meta5"
# [1] "checkingrs114138760 JTB meta5"
# [1] "checkingrs35749011 JTB meta5"
# [1] "checkingrs76763715 JTB meta5"
# [1] "checkingrs114138760 KCNN3 meta5"
# [1] "checkingrs35749011 KCNN3 meta5"
# [1] "checkingrs76763715 KCNN3 meta5"
# [1] "checkingrs114138760 LAMTOR2 meta5"
# [1] "checkingrs35749011 LAMTOR2 meta5"
# [1] "checkingrs76763715 LAMTOR2 meta5"
# [1] "checkingrs114138760 LENEP meta5"
# [1] "checkingrs35749011 LENEP meta5"
# [1] "checkingrs76763715 LENEP meta5"
# [1] "checkingrs114138760 LMNA meta5"
# [1] "checkingrs35749011 LMNA meta5"
# [1] "checkingrs76763715 LMNA meta5"
# [1] "checkingrs114138760 MIR92B meta5"
# [1] "checkingrs35749011 MIR92B meta5"
# [1] "checkingrs76763715 MIR92B meta5"
# [1] "checkingrs114138760 MSTO1 meta5"
# [1] "checkingrs35749011 MSTO1 meta5"
# [1] "checkingrs76763715 MSTO1 meta5"
# [1] "checkingrs114138760 MSTO2P meta5"
# [1] "checkingrs35749011 MSTO2P meta5"
# [1] "checkingrs76763715 MSTO2P meta5"
# [1] "checkingrs114138760 MTX1 meta5"
# [1] "checkingrs35749011 MTX1 meta5"
# [1] "checkingrs76763715 MTX1 meta5"
# [1] "checkingrs114138760 MUC1 meta5"
# [1] "checkingrs35749011 MUC1 meta5"
# [1] "checkingrs76763715 MUC1 meta5"
# [1] "checkingrs114138760 NUP210L meta5"
# [1] "checkingrs35749011 NUP210L meta5"
# [1] "checkingrs76763715 NUP210L meta5"
# [1] "checkingrs114138760 PBXIP1 meta5"
# [1] "checkingrs35749011 PBXIP1 meta5"
# [1] "checkingrs76763715 PBXIP1 meta5"
# [1] "checkingrs114138760 PMF1 meta5"
# [1] "checkingrs35749011 PMF1 meta5"
# [1] "checkingrs76763715 PMF1 meta5"
# [1] "checkingrs114138760 PMF1-BGLAP meta5"
# [1] "checkingrs35749011 PMF1-BGLAP meta5"
# [1] "checkingrs76763715 PMF1-BGLAP meta5"
# [1] "checkingrs114138760 PMVK meta5"
# [1] "checkingrs35749011 PMVK meta5"
# [1] "checkingrs76763715 PMVK meta5"
# [1] "checkingrs114138760 PYGO2 meta5"
# [1] "checkingrs35749011 PYGO2 meta5"
# [1] "checkingrs76763715 PYGO2 meta5"
# [1] "checkingrs114138760 RAB13 meta5"
# [1] "checkingrs35749011 RAB13 meta5"
# [1] "checkingrs76763715 RAB13 meta5"
# [1] "checkingrs114138760 RAB25 meta5"
# [1] "checkingrs35749011 RAB25 meta5"
# [1] "checkingrs76763715 RAB25 meta5"
# [1] "checkingrs114138760 RIT1 meta5"
# [1] "checkingrs35749011 RIT1 meta5"
# [1] "checkingrs76763715 RIT1 meta5"
# [1] "checkingrs114138760 RPS27 meta5"
# [1] "checkingrs35749011 RPS27 meta5"
# [1] "checkingrs76763715 RPS27 meta5"
# [1] "checkingrs114138760 RUSC1 meta5"
# [1] "checkingrs35749011 RUSC1 meta5"
# [1] "checkingrs76763715 RUSC1 meta5"
# [1] "checkingrs114138760 RUSC1-AS1 meta5"
# [1] "checkingrs35749011 RUSC1-AS1 meta5"
# [1] "checkingrs76763715 RUSC1-AS1 meta5"
# [1] "checkingrs114138760 SCAMP3 meta5"
# [1] "checkingrs35749011 SCAMP3 meta5"
# [1] "checkingrs76763715 SCAMP3 meta5"
# [1] "checkingrs114138760 SLC25A44 meta5"
# [1] "checkingrs35749011 SLC25A44 meta5"
# [1] "checkingrs76763715 SLC25A44 meta5"
# [1] "checkingrs114138760 SLC50A1 meta5"
# [1] "checkingrs35749011 SLC50A1 meta5"
# [1] "checkingrs76763715 SLC50A1 meta5"
# [1] "checkingrs114138760 SNORA80E meta5"
# [1] "checkingrs35749011 SNORA80E meta5"
# [1] "checkingrs76763715 SNORA80E meta5"
# [1] "checkingrs114138760 SYT11 meta5"
# [1] "checkingrs35749011 SYT11 meta5"
# [1] "checkingrs76763715 SYT11 meta5"
# [1] "checkingrs114138760 THBS3 meta5"
# [1] "checkingrs35749011 THBS3 meta5"
# [1] "checkingrs76763715 THBS3 meta5"
# [1] "checkingrs114138760 TPM3 meta5"
# [1] "checkingrs35749011 TPM3 meta5"
# [1] "checkingrs76763715 TPM3 meta5"
# [1] "checkingrs114138760 UBAP2L meta5"
# [1] "checkingrs35749011 UBAP2L meta5"
# [1] "checkingrs76763715 UBAP2L meta5"
# [1] "checkingrs114138760 UBE2Q1-AS1 meta5"
# [1] "checkingrs35749011 UBE2Q1-AS1 meta5"
# [1] "checkingrs76763715 UBE2Q1-AS1 meta5"
# [1] "checkingrs114138760 UBQLN4 meta5"
# [1] "checkingrs35749011 UBQLN4 meta5"
# [1] "checkingrs76763715 UBQLN4 meta5"
# [1] "checkingrs114138760 YY1AP1 meta5"
# [1] "checkingrs35749011 YY1AP1 meta5"
# [1] "checkingrs76763715 YY1AP1 meta5"
# [1] "checkingrs114138760 ZBTB7B meta5"
# [1] "checkingrs35749011 ZBTB7B meta5"
# [1] "checkingrs76763715 ZBTB7B meta5"
# [1] "checkingrs57891859 CCNT2 meta5"
# [1] "checkingrs57891859 CCNT2-AS1 meta5"
# [1] "checkingrs57891859 MGAT5 meta5"
# [1] "checkingrs57891859 R3HDM1 meta5"
# [1] "checkingrs57891859 RAB3GAP1 meta5"
# [1] "checkingrs57891859 TMEM163 meta5"
# [1] "checkingrs1474055 ABCB11 meta5"
# [1] "checkingrs1474055 B3GALT1 meta5"
# [1] "checkingrs1474055 CERS6 meta5"
# [1] "checkingrs1474055 CERS6-AS1 meta5"
# [1] "checkingrs1474055 DHRS9 meta5"
# [1] "checkingrs1474055 G6PC2 meta5"
# [1] "checkingrs1474055 LRP2 meta5"
# [1] "checkingrs1474055 NOSTRIN meta5"
# [1] "checkingrs1474055 SPC25 meta5"
# [1] "checkingrs1474055 XIRP2 meta5"
# [1] "checkingrs73038319 KCNH8 meta5"
# [1] "checkingrs73038319 SATB1-AS1 meta5"
# [1] "checkingrs73038319 TBC1D5 meta5"
# [1] "checkingrs6808178 AZI2 meta5"
# [1] "checkingrs6808178 CMC1 meta5"
# [1] "checkingrs6808178 EOMES meta5"
# [1] "checkingrs6808178 RBMS3 meta5"
# [1] "checkingrs6808178 RBMS3-AS3 meta5"
# [1] "checkingrs6808178 ZCWPW2 meta5"
# [1] "checkingrs12497850 AMT meta5"
# [1] "checkingrs12497850 ARIH2 meta5"
# [1] "checkingrs12497850 ATRIP meta5"
# [1] "checkingrs12497850 BSN meta5"
# [1] "checkingrs12497850 C3orf62 meta5"
# [1] "checkingrs12497850 CCDC36 meta5"
# [1] "checkingrs12497850 CCDC71 meta5"
# [1] "checkingrs12497850 CDC25A meta5"
# [1] "checkingrs12497850 COL7A1 meta5"
# [1] "checkingrs12497850 DALRD3 meta5"
# [1] "checkingrs12497850 DHX30 meta5"
# [1] "checkingrs12497850 FBXW12 meta5"
# [1] "checkingrs12497850 FCF1P2 meta5"
# [1] "checkingrs12497850 GPX1 meta5"
# [1] "checkingrs12497850 IP6K2 meta5"
# [1] "checkingrs12497850 KLHDC8B meta5"
# [1] "checkingrs12497850 LAMB2 meta5"
# [1] "checkingrs12497850 MAP4 meta5"
# [1] "checkingrs12497850 MST1 meta5"
# [1] "checkingrs12497850 NCKIPSD meta5"
# [1] "checkingrs12497850 NDUFAF3 meta5"
# [1] "checkingrs12497850 NICN1 meta5"
# [1] "checkingrs12497850 NME6 meta5"
# [1] "checkingrs12497850 P4HTM meta5"
# [1] "checkingrs12497850 PFKFB4 meta5"
# [1] "checkingrs12497850 PLXNB1 meta5"
# [1] "checkingrs12497850 PRKAR2A meta5"
# [1] "checkingrs12497850 QARS meta5"
# [1] "checkingrs12497850 QRICH1 meta5"
# [1] "checkingrs12497850 RHOA meta5"
# [1] "checkingrs12497850 RNF123 meta5"
# [1] "checkingrs12497850 SHISA5 meta5"
# [1] "checkingrs12497850 SLC25A20 meta5"
# [1] "checkingrs12497850 SMARCC1 meta5"
# [1] "checkingrs12497850 TCTA meta5"
# [1] "checkingrs12497850 TMA7 meta5"
# [1] "checkingrs12497850 TREX1 meta5"
# [1] "checkingrs12497850 UCN2 meta5"
# [1] "checkingrs12497850 USP4 meta5"
# [1] "checkingrs12497850 WDR6 meta5"
# [1] "checkingrs12497850 ZNF589 meta5"
# [1] "checkingrs55961674 CASR meta5"
# [1] "checkingrs55961674 CCDC58 meta5"
# [1] "checkingrs55961674 CD86 meta5"
# [1] "checkingrs55961674 DTX3L meta5"
# [1] "checkingrs55961674 EAF2 meta5"
# [1] "checkingrs55961674 FAM162A meta5"
# [1] "checkingrs55961674 FBXO40 meta5"
# [1] "checkingrs55961674 GOLGB1 meta5"
# [1] "checkingrs55961674 HCLS1 meta5"
# [1] "checkingrs55961674 HSPBAP1 meta5"
# [1] "checkingrs55961674 ILDR1 meta5"
# [1] "checkingrs55961674 IQCB1 meta5"
# [1] "checkingrs55961674 KPNA1 meta5"
# [1] "checkingrs55961674 PARP14 meta5"
# [1] "checkingrs55961674 PARP15 meta5"
# [1] "checkingrs55961674 PARP9 meta5"
# [1] "checkingrs55961674 SEC22A meta5"
# [1] "checkingrs55961674 SEMA5B meta5"
# [1] "checkingrs55961674 SLC15A2 meta5"
# [1] "checkingrs11707416 AADACL2 meta5"
# [1] "checkingrs11707416 AADACL2-AS1 meta5"
# [1] "checkingrs11707416 AADACP1 meta5"
# [1] "checkingrs11707416 CLRN1 meta5"
# [1] "checkingrs11707416 EIF2A meta5"
# [1] "checkingrs11707416 ERICH6 meta5"
# [1] "checkingrs11707416 ERICH6-AS1 meta5"
# [1] "checkingrs11707416 GPR87 meta5"
# [1] "checkingrs11707416 IGSF10 meta5"
# [1] "checkingrs11707416 MBNL1 meta5"
# [1] "checkingrs11707416 MBNL1-AS1 meta5"
# [1] "checkingrs11707416 MED12L meta5"
# [1] "checkingrs11707416 P2RY13 meta5"
# [1] "checkingrs11707416 SERP1 meta5"
# [1] "checkingrs11707416 SIAH2 meta5"
# [1] "checkingrs11707416 TMEM14EP meta5"
# [1] "checkingrs11707416 TSC22D2 meta5"
# [1] "checkingrs1450522 B3GALNT1 meta5"
# [1] "checkingrs1450522 IFT80 meta5"
# [1] "checkingrs1450522 KPNA4 meta5"
# [1] "checkingrs1450522 NMD3 meta5"
# [1] "checkingrs1450522 OTOL1 meta5"
# [1] "checkingrs1450522 PPM1L meta5"
# [1] "checkingrs1450522 SCARNA7 meta5"
# [1] "checkingrs1450522 SPTSSB meta5"
# [1] "checkingrs1450522 TRIM59 meta5"
# [1] "checkingrs10513789 ABCC5 meta5"
# [1] "checkingrs10513789 ABCC5-AS1 meta5"
# [1] "checkingrs10513789 ATP11B meta5"
# [1] "checkingrs10513789 HTR3D meta5"
# [1] "checkingrs10513789 KLHL24 meta5"
# [1] "checkingrs10513789 KLHL6 meta5"
# [1] "checkingrs10513789 KLHL6-AS1 meta5"
# [1] "checkingrs10513789 LINC00888 meta5"
# [1] "checkingrs10513789 MAP6D1 meta5"
# [1] "checkingrs10513789 MCCC1 meta5"
# [1] "checkingrs10513789 MCF2L2 meta5"
# [1] "checkingrs10513789 PARL meta5"
# [1] "checkingrs10513789 YEATS2 meta5"
# [1] "checkingrs10513789 YEATS2-AS1 meta5"
# [1] "checkingrs34311866 ABCA11P meta5"
# [1] "checkingrs873786 ABCA11P meta5"
# [1] "checkingrs34311866 CPLX1 meta5"
# [1] "checkingrs873786 CPLX1 meta5"
# [1] "checkingrs34311866 CRIPAK meta5"
# [1] "checkingrs873786 CRIPAK meta5"
# [1] "checkingrs34311866 DGKQ meta5"
# [1] "checkingrs873786 DGKQ meta5"
# [1] "checkingrs34311866 FAM53A meta5"
# [1] "checkingrs873786 FAM53A meta5"
# [1] "checkingrs34311866 FGFR3 meta5"
# [1] "checkingrs873786 FGFR3 meta5"
# [1] "checkingrs34311866 FGFRL1 meta5"
# [1] "checkingrs873786 FGFRL1 meta5"
# [1] "checkingrs34311866 GAK meta5"
# [1] "checkingrs873786 GAK meta5"
# [1] "checkingrs34311866 LETM1 meta5"
# [1] "checkingrs873786 LETM1 meta5"
# [1] "checkingrs34311866 MAEA meta5"
# [1] "checkingrs873786 MAEA meta5"
# [1] "checkingrs34311866 MYL5 meta5"
# [1] "checkingrs873786 MYL5 meta5"
# [1] "checkingrs34311866 PCGF3 meta5"
# [1] "checkingrs873786 PCGF3 meta5"
# [1] "checkingrs34311866 PDE6B meta5"
# [1] "checkingrs873786 PDE6B meta5"
# [1] "checkingrs34311866 PIGG meta5"
# [1] "checkingrs873786 PIGG meta5"
# [1] "checkingrs34311866 RNF212 meta5"
# [1] "checkingrs873786 RNF212 meta5"
# [1] "checkingrs34311866 SLBP meta5"
# [1] "checkingrs873786 SLBP meta5"
# [1] "checkingrs34311866 SLC26A1 meta5"
# [1] "checkingrs873786 SLC26A1 meta5"
# [1] "checkingrs34311866 SPON2 meta5"
# [1] "checkingrs873786 SPON2 meta5"
# [1] "checkingrs34311866 TACC3 meta5"
# [1] "checkingrs873786 TACC3 meta5"
# [1] "checkingrs34311866 TMED11P meta5"
# [1] "checkingrs873786 TMED11P meta5"
# [1] "checkingrs34311866 TMEM129 meta5"
# [1] "checkingrs873786 TMEM129 meta5"
# [1] "checkingrs34311866 TMEM175 meta5"
# [1] "checkingrs873786 TMEM175 meta5"
# [1] "checkingrs34311866 UVSSA meta5"
# [1] "checkingrs873786 UVSSA meta5"
# [1] "checkingrs34311866 ZNF141 meta5"
# [1] "checkingrs873786 ZNF141 meta5"
# [1] "checkingrs34311866 ZNF718 meta5"
# [1] "checkingrs873786 ZNF718 meta5"
# [1] "checkingrs34311866 ZNF721 meta5"
# [1] "checkingrs873786 ZNF721 meta5"
# [1] "checkingrs34311866 ZNF732 meta5"
# [1] "checkingrs873786 ZNF732 meta5"
# [1] "checkingrs34311866 ZNF876P meta5"
# [1] "checkingrs873786 ZNF876P meta5"
# [1] "checkingrs6658353 ARHGAP30 meta5"
# [1] "checkingrs6658353 ATF6 meta5"
# [1] "checkingrs6658353 B4GALT3 meta5"
# [1] "checkingrs6658353 C1orf226 meta5"
# [1] "checkingrs6658353 CD244 meta5"
# [1] "checkingrs6658353 CD48 meta5"
# [1] "checkingrs6658353 CD84 meta5"
# [1] "checkingrs6658353 CFAP126 meta5"
# [1] "checkingrs6658353 DEDD meta5"
# [1] "checkingrs6658353 DUSP12 meta5"
# [1] "checkingrs6658353 F11R meta5"
# [1] "checkingrs6658353 FCER1G meta5"
# [1] "checkingrs6658353 FCGR2A meta5"
# [1] "checkingrs6658353 FCGR2B meta5"
# [1] "checkingrs6658353 FCGR2C meta5"
# [1] "checkingrs6658353 FCGR3A meta5"
# [1] "checkingrs6658353 FCRLA meta5"
# [1] "checkingrs6658353 FCRLB meta5"
# [1] "checkingrs6658353 HSPA7 meta5"
# [1] "checkingrs6658353 ITLN1 meta5"
# [1] "checkingrs6658353 ITLN2 meta5"
# [1] "checkingrs6658353 KLHDC9 meta5"
# [1] "checkingrs6658353 LY9 meta5"
# [1] "checkingrs6658353 MPZ meta5"
# [1] "checkingrs6658353 NDUFS2 meta5"
# [1] "checkingrs6658353 NECTIN4 meta5"
# [1] "checkingrs6658353 NIT1 meta5"
# [1] "checkingrs6658353 NR1I3 meta5"
# [1] "checkingrs6658353 OLFML2B meta5"
# [1] "checkingrs6658353 PCP4L1 meta5"
# [1] "checkingrs6658353 PFDN2 meta5"
# [1] "checkingrs6658353 PPOX meta5"
# [1] "checkingrs6658353 RPL31P11 meta5"
# [1] "checkingrs6658353 SDHC meta5"
# [1] "checkingrs6658353 SH2D1B meta5"
# [1] "checkingrs6658353 SLAMF1 meta5"
# [1] "checkingrs6658353 SLAMF7 meta5"
# [1] "checkingrs6658353 TOMM40L meta5"
# [1] "checkingrs6658353 TSTD1 meta5"
# [1] "checkingrs6658353 UFC1 meta5"
# [1] "checkingrs6658353 UHMK1 meta5"
# [1] "checkingrs6658353 USF1 meta5"
# [1] "checkingrs4698412 BST1 meta5"
# [1] "checkingrs4698412 C1QTNF7 meta5"
# [1] "checkingrs4698412 CC2D2A meta5"
# [1] "checkingrs4698412 CD38 meta5"
# [1] "checkingrs4698412 CPEB2 meta5"
# [1] "checkingrs4698412 FAM200B meta5"
# [1] "checkingrs4698412 FBXL5 meta5"
# [1] "checkingrs4698412 FGFBP1 meta5"
# [1] "checkingrs4698412 LDB2 meta5"
# [1] "checkingrs4698412 LINC00504 meta5"
# [1] "checkingrs4698412 PROM1 meta5"
# [1] "checkingrs4698412 TAPT1 meta5"
# [1] "checkingrs4698412 TAPT1-AS1 meta5"
# [1] "checkingrs34025766 DCAF16 meta5"
# [1] "checkingrs34025766 FAM184B meta5"
# [1] "checkingrs34025766 LAP3 meta5"
# [1] "checkingrs34025766 LCORL meta5"
# [1] "checkingrs34025766 MED28 meta5"
# [1] "checkingrs34025766 QDPR meta5"
# [1] "checkingrs4101061 ART3 meta5"
# [1] "checkingrs6825004 ART3 meta5"
# [1] "checkingrs6854006 ART3 meta5"
# [1] "checkingrs6825004 CCDC158 meta5"
# [1] "checkingrs4101061 CCNG2 meta5"
# [1] "checkingrs6825004 CCNG2 meta5"
# [1] "checkingrs6854006 CCNG2 meta5"
# [1] "checkingrs4101061 CCNI meta5"
# [1] "checkingrs6825004 CCNI meta5"
# [1] "checkingrs6854006 CCNI meta5"
# [1] "checkingrs4101061 CDKL2 meta5"
# [1] "checkingrs6825004 CDKL2 meta5"
# [1] "checkingrs6854006 CDKL2 meta5"
# [1] "checkingrs4101061 CXCL11 meta5"
# [1] "checkingrs6825004 CXCL11 meta5"
# [1] "checkingrs6854006 CXCL11 meta5"
# [1] "checkingrs4101061 CXCL9 meta5"
# [1] "checkingrs6825004 CXCL9 meta5"
# [1] "checkingrs6854006 CXCL9 meta5"
# [1] "checkingrs4101061 FAM47E meta5"
# [1] "checkingrs6825004 FAM47E meta5"
# [1] "checkingrs6854006 FAM47E meta5"
# [1] "checkingrs4101061 FAM47E-STBD1 meta5"
# [1] "checkingrs6825004 FAM47E-STBD1 meta5"
# [1] "checkingrs6854006 FAM47E-STBD1 meta5"
# [1] "checkingrs4101061 G3BP2 meta5"
# [1] "checkingrs6825004 G3BP2 meta5"
# [1] "checkingrs6854006 G3BP2 meta5"
# [1] "checkingrs4101061 NAAA meta5"
# [1] "checkingrs6825004 NAAA meta5"
# [1] "checkingrs6854006 NAAA meta5"
# [1] "checkingrs4101061 NUP54 meta5"
# [1] "checkingrs6825004 NUP54 meta5"
# [1] "checkingrs6854006 NUP54 meta5"
# [1] "checkingrs4101061 PPEF2 meta5"
# [1] "checkingrs6825004 PPEF2 meta5"
# [1] "checkingrs6854006 PPEF2 meta5"
# [1] "checkingrs4101061 RCHY1 meta5"
# [1] "checkingrs6825004 RCHY1 meta5"
# [1] "checkingrs6854006 RCHY1 meta5"
# [1] "checkingrs4101061 SCARB2 meta5"
# [1] "checkingrs6825004 SCARB2 meta5"
# [1] "checkingrs4101061 SDAD1 meta5"
# [1] "checkingrs6825004 SDAD1 meta5"
# [1] "checkingrs6854006 SDAD1 meta5"
# [1] "checkingrs4101061 SOWAHB meta5"
# [1] "checkingrs6825004 SOWAHB meta5"
# [1] "checkingrs6854006 SOWAHB meta5"
# [1] "checkingrs4101061 STBD1 meta5"
# [1] "checkingrs6825004 STBD1 meta5"
# [1] "checkingrs6854006 STBD1 meta5"
# [1] "checkingrs4101061 THAP6 meta5"
# [1] "checkingrs6825004 THAP6 meta5"
# [1] "checkingrs6854006 THAP6 meta5"
# [1] "checkingrs4101061 USO1 meta5"
# [1] "checkingrs6825004 USO1 meta5"
# [1] "checkingrs6854006 USO1 meta5"
# [1] "checkingrs356182 CCSER1 meta5"
# [1] "checkingrs5019538 CCSER1 meta5"
# [1] "checkingrs356182 FAM13A meta5"
# [1] "checkingrs5019538 FAM13A meta5"
# [1] "checkingrs356182 FAM13A-AS1 meta5"
# [1] "checkingrs5019538 FAM13A-AS1 meta5"
# [1] "checkingrs356182 GPRIN3 meta5"
# [1] "checkingrs5019538 GPRIN3 meta5"
# [1] "checkingrs356182 HERC3 meta5"
# [1] "checkingrs5019538 HERC3 meta5"
# [1] "checkingrs356182 MMRN1 meta5"
# [1] "checkingrs5019538 MMRN1 meta5"
# [1] "checkingrs356182 SNCA-AS1 meta5"
# [1] "checkingrs356182 TIGD2 meta5"
# [1] "checkingrs5019538 TIGD2 meta5"
# [1] "checkingrs13117519 ANK2 meta5"
# [1] "checkingrs13117519 ARSJ meta5"
# [1] "checkingrs13117519 CAMK2D meta5"
# [1] "checkingrs13117519 LARP7 meta5"
# [1] "checkingrs13117519 MIR302B meta5"
# [1] "checkingrs13117519 NEUROG2 meta5"
# [1] "checkingrs13117519 ZGRF1 meta5"
# [1] "checkingrs62333164 AADAT meta5"
# [1] "checkingrs62333164 CBR4 meta5"
# [1] "checkingrs62333164 CLCN3 meta5"
# [1] "checkingrs62333164 HPF1 meta5"
# [1] "checkingrs62333164 LINC01612 meta5"
# [1] "checkingrs62333164 MFAP3L meta5"
# [1] "checkingrs62333164 NEK1 meta5"
# [1] "checkingrs62333164 PALLD meta5"
# [1] "checkingrs62333164 SH3RF1 meta5"
# [1] "checkingrs1867598 C5orf64 meta5"
# [1] "checkingrs1867598 DEPDC1B meta5"
# [1] "checkingrs1867598 ELOVL7 meta5"
# [1] "checkingrs1867598 PART1 meta5"
# [1] "checkingrs1867598 PDE4D meta5"
# [1] "checkingrs1867598 SMIM15 meta5"
# [1] "checkingrs1867598 ZSWIM6 meta5"
# [1] "checkingrs26431 C5orf30 meta5"
# [1] "checkingrs26431 GIN1 meta5"
# [1] "checkingrs26431 LINC00491 meta5"
# [1] "checkingrs26431 LINC00492 meta5"
# [1] "checkingrs26431 NUDT12 meta5"
# [1] "checkingrs26431 PAM meta5"
# [1] "checkingrs26431 PPIP5K2 meta5"
# [1] "checkingrs26431 SLCO4C1 meta5"
# [1] "checkingrs11950533 C5orf15 meta5"
# [1] "checkingrs11950533 C5orf24 meta5"
# [1] "checkingrs11950533 C5orf66-AS1 meta5"
# [1] "checkingrs11950533 C5orf66-AS2 meta5"
# [1] "checkingrs11950533 CAMLG meta5"
# [1] "checkingrs11950533 CATSPER3 meta5"
# [1] "checkingrs11950533 CDKL3 meta5"
# [1] "checkingrs11950533 CDKN2AIPNL meta5"
# [1] "checkingrs11950533 CXCL14 meta5"
# [1] "checkingrs11950533 DDX46 meta5"
# [1] "checkingrs11950533 H2AFY meta5"
# [1] "checkingrs11950533 NEUROG1 meta5"
# [1] "checkingrs11950533 PCBD2 meta5"
# [1] "checkingrs11950533 PPP2CA meta5"
# [1] "checkingrs11950533 SEC24A meta5"
# [1] "checkingrs11950533 SLC25A48 meta5"
# [1] "checkingrs11950533 TCF7 meta5"
# [1] "checkingrs11950533 TXNDC15 meta5"
# [1] "checkingrs4140646 GPX5 meta5"
# [1] "checkingrs4140646 GUSBP2 meta5"
# [1] "checkingrs4140646 HIST1H2BJ meta5"
# [1] "checkingrs4140646 HIST1H2BK meta5"
# [1] "checkingrs4140646 HIST1H2BL meta5"
# [1] "checkingrs4140646 HIST1H2BN meta5"
# [1] "checkingrs4140646 LINC00240 meta5"
# [1] "checkingrs4140646 NKAPL meta5"
# [1] "checkingrs4140646 OR2B2 meta5"
# [1] "checkingrs4140646 PGBD1 meta5"
# [1] "checkingrs4140646 PRSS16 meta5"
# [1] "checkingrs4140646 TOB2P1 meta5"
# [1] "checkingrs4140646 VN1R10P meta5"
# [1] "checkingrs4140646 ZKSCAN4 meta5"
# [1] "checkingrs4140646 ZNF184 meta5"
# [1] "checkingrs4140646 ZNF204P meta5"
# [1] "checkingrs4140646 ZSCAN12P1 meta5"
# [1] "checkingrs4140646 ZSCAN16-AS1 meta5"
# [1] "checkingrs4140646 ZSCAN9 meta5"
# [1] "checkingrs11578699 C1orf105 meta5"
# [1] "checkingrs11578699 DNM3 meta5"
# [1] "checkingrs11578699 FASLG meta5"
# [1] "checkingrs11578699 FMO2 meta5"
# [1] "checkingrs11578699 FMO3 meta5"
# [1] "checkingrs11578699 FMO4 meta5"
# [1] "checkingrs11578699 FMO6P meta5"
# [1] "checkingrs11578699 PIGC meta5"
# [1] "checkingrs11578699 PRRC2C meta5"
# [1] "checkingrs11578699 SUCO meta5"
# [1] "checkingrs112485576 B3GALT4 meta5"
# [1] "checkingrs112485576 BAK1 meta5"
# [1] "checkingrs112485576 BRD2 meta5"
# [1] "checkingrs112485576 COL11A2 meta5"
# [1] "checkingrs112485576 CUTA meta5"
# [1] "checkingrs112485576 DAXX meta5"
# [1] "checkingrs112485576 GGNBP1 meta5"
# [1] "checkingrs112485576 HCG24 meta5"
# [1] "checkingrs112485576 HCG25 meta5"
# [1] "checkingrs112485576 HLA-DMA meta5"
# [1] "checkingrs112485576 HLA-DMB meta5"
# [1] "checkingrs112485576 HLA-DOA meta5"
# [1] "checkingrs112485576 HLA-DOB meta5"
# [1] "checkingrs112485576 HLA-DPA1 meta5"
# [1] "checkingrs112485576 HLA-DPB1 meta5"
# [1] "checkingrs112485576 HLA-DPB2 meta5"
# [1] "checkingrs112485576 HLA-DQB1 meta5"
# [1] "checkingrs112485576 HLA-DQB1-AS1 meta5"
# [1] "checkingrs112485576 HLA-DRB1 meta5"
# [1] "checkingrs112485576 HLA-DRB5 meta5"
# [1] "checkingrs112485576 HLA-DRB6 meta5"
# [1] "checkingrs112485576 HSD17B8 meta5"
# [1] "checkingrs112485576 LINC00336 meta5"
# [1] "checkingrs112485576 PSMB8 meta5"
# [1] "checkingrs112485576 RGL2 meta5"
# [1] "checkingrs112485576 RING1 meta5"
# [1] "checkingrs112485576 RPS18 meta5"
# [1] "checkingrs112485576 RXRB meta5"
# [1] "checkingrs112485576 SLC39A7 meta5"
# [1] "checkingrs112485576 SYNGAP1 meta5"
# [1] "checkingrs112485576 TAP2 meta5"
# [1] "checkingrs112485576 TAPBP meta5"
# [1] "checkingrs112485576 VPS52 meta5"
# [1] "checkingrs112485576 WDR46 meta5"
# [1] "checkingrs112485576 ZBTB22 meta5"
# [1] "checkingrs112485576 ZBTB9 meta5"
# [1] "checkingrs12528068 B3GAT2 meta5"
# [1] "checkingrs12528068 KCNQ5 meta5"
# [1] "checkingrs12528068 KCNQ5-IT1 meta5"
# [1] "checkingrs12528068 OGFRL1 meta5"
# [1] "checkingrs12528068 RIMS1 meta5"
# [1] "checkingrs12528068 SMAP1 meta5"
# [1] "checkingrs997368 FAM229B meta5"
# [1] "checkingrs997368 FYN meta5"
# [1] "checkingrs997368 GSTM2P1 meta5"
# [1] "checkingrs997368 GTF3C6 meta5"
# [1] "checkingrs997368 LAMA4 meta5"
# [1] "checkingrs997368 MFSD4B meta5"
# [1] "checkingrs997368 REV3L meta5"
# [1] "checkingrs997368 RFPL4B meta5"
# [1] "checkingrs997368 RPF2 meta5"
# [1] "checkingrs997368 SLC16A10 meta5"
# [1] "checkingrs997368 TRAF3IP2 meta5"
# [1] "checkingrs997368 TRAF3IP2-AS1 meta5"
# [1] "checkingrs997368 TUBE1 meta5"
# [1] "checkingrs75859381 ENPP1 meta5"
# [1] "checkingrs75859381 EYA4 meta5"
# [1] "checkingrs75859381 LINC00326 meta5"
# [1] "checkingrs75859381 LINC01013 meta5"
# [1] "checkingrs75859381 LINC01312 meta5"
# [1] "checkingrs75859381 MOXD1 meta5"
# [1] "checkingrs75859381 RPS12 meta5"
# [1] "checkingrs75859381 SNORA33 meta5"
# [1] "checkingrs75859381 STX7 meta5"
# [1] "checkingrs75859381 TAAR6 meta5"
# [1] "checkingrs75859381 TAAR8 meta5"
# [1] "checkingrs75859381 TAAR9 meta5"
# [1] "checkingrs75859381 TARID meta5"
# [1] "checkingrs75859381 VNN1 meta5"
# [1] "checkingrs75859381 VNN2 meta5"
# [1] "checkingrs75859381 VNN3 meta5"
# [1] "checkingrs199351 CCDC126 meta5"
# [1] "checkingrs199351 CLK2P1 meta5"
# [1] "checkingrs199351 FAM126A meta5"
# [1] "checkingrs199351 FAM221A meta5"
# [1] "checkingrs199351 GPNMB meta5"
# [1] "checkingrs199351 IGF2BP3 meta5"
# [1] "checkingrs199351 IL6 meta5"
# [1] "checkingrs199351 KLHL7 meta5"
# [1] "checkingrs199351 RAPGEF5 meta5"
# [1] "checkingrs199351 RPS2P32 meta5"
# [1] "checkingrs199351 STEAP1B meta5"
# [1] "checkingrs199351 STK31 meta5"
# [1] "checkingrs199351 TOMM7 meta5"
# [1] "checkingrs199351 TRA2A meta5"
# [1] "checkingrs76949143 ASL meta5"
# [1] "checkingrs76949143 CCT6P1 meta5"
# [1] "checkingrs76949143 GS1-124K5.11 meta5"
# [1] "checkingrs76949143 GS1-124K5.4 meta5"
# [1] "checkingrs76949143 GTF2IP23 meta5"
# [1] "checkingrs76949143 LINC00174 meta5"
# [1] "checkingrs76949143 PMS2P4 meta5"
# [1] "checkingrs76949143 SBDS meta5"
# [1] "checkingrs76949143 SNORA22 meta5"
# [1] "checkingrs76949143 TMEM248 meta5"
# [1] "checkingrs76949143 TYW1 meta5"
# [1] "checkingrs1293298 BLK meta5"
# [1] "checkingrs1293298 C8orf49 meta5"
# [1] "checkingrs1293298 CTSB meta5"
# [1] "checkingrs1293298 DEFB134 meta5"
# [1] "checkingrs1293298 DEFB135 meta5"
# [1] "checkingrs1293298 DEFB136 meta5"
# [1] "checkingrs1293298 FAM167A meta5"
# [1] "checkingrs1293298 FAM167A-AS1 meta5"
# [1] "checkingrs1293298 FAM66A meta5"
# [1] "checkingrs1293298 FAM66D meta5"
# [1] "checkingrs1293298 FAM86B1 meta5"
# [1] "checkingrs1293298 FAM86B2 meta5"
# [1] "checkingrs1293298 FAM90A25P meta5"
# [1] "checkingrs1293298 FAM90A2P meta5"
# [1] "checkingrs1293298 FDFT1 meta5"
# [1] "checkingrs1293298 LINC00681 meta5"
# [1] "checkingrs1293298 LONRF1 meta5"
# [1] "checkingrs1293298 MTMR9 meta5"
# [1] "checkingrs1293298 NEIL2 meta5"
# [1] "checkingrs1293298 SLC35G5 meta5"
# [1] "checkingrs1293298 TDH meta5"
# [1] "checkingrs1293298 USP17L2 meta5"
# [1] "checkingrs1293298 USP17L7 meta5"
# [1] "checkingrs1293298 XKR6 meta5"
# [1] "checkingrs620513 CNOT7 meta5"
# [1] "checkingrs620513 FGF20 meta5"
# [1] "checkingrs620513 MICU3 meta5"
# [1] "checkingrs620513 MSR1 meta5"
# [1] "checkingrs620513 MTMR7 meta5"
# [1] "checkingrs620513 MTUS1 meta5"
# [1] "checkingrs620513 PDGFRL meta5"
# [1] "checkingrs620513 SLC7A2 meta5"
# [1] "checkingrs620513 VPS37A meta5"
# [1] "checkingrs620513 ZDHHC2 meta5"
# [1] "checkingrs2280104 BIN3 meta5"
# [1] "checkingrs2280104 BMP1 meta5"
# [1] "checkingrs2280104 C8orf58 meta5"
# [1] "checkingrs2280104 CCAR2 meta5"
# [1] "checkingrs2280104 CHMP7 meta5"
# [1] "checkingrs2280104 DMTN meta5"
# [1] "checkingrs2280104 EGR3 meta5"
# [1] "checkingrs2280104 ENTPD4 meta5"
# [1] "checkingrs2280104 FGF17 meta5"
# [1] "checkingrs2280104 GFRA2 meta5"
# [1] "checkingrs2280104 HR meta5"
# [1] "checkingrs2280104 LGI3 meta5"
# [1] "checkingrs2280104 LOXL2 meta5"
# [1] "checkingrs2280104 NPM2 meta5"
# [1] "checkingrs2280104 PDLIM2 meta5"
# [1] "checkingrs2280104 PEBP4 meta5"
# [1] "checkingrs2280104 PIWIL2 meta5"
# [1] "checkingrs2280104 POLR3D meta5"
# [1] "checkingrs2280104 PPP3CC meta5"
# [1] "checkingrs2280104 R3HCC1 meta5"
# [1] "checkingrs2280104 REEP4 meta5"
# [1] "checkingrs2280104 RHOBTB2 meta5"
# [1] "checkingrs2280104 SFTPC meta5"
# [1] "checkingrs2280104 SLC25A37 meta5"
# [1] "checkingrs2280104 SORBS3 meta5"
# [1] "checkingrs2280104 TNFRSF10A meta5"
# [1] "checkingrs2280104 TNFRSF10B meta5"
# [1] "checkingrs2280104 TNFRSF10C meta5"
# [1] "checkingrs2280104 TNFRSF10D meta5"
# [1] "checkingrs2280104 XPO7 meta5"
# [1] "checkingrs11557080 AVPR1B meta5"
# [1] "checkingrs823118 AVPR1B meta5"
# [1] "checkingrs11557080 CDK18 meta5"
# [1] "checkingrs823118 CDK18 meta5"
# [1] "checkingrs11557080 CNTN2 meta5"
# [1] "checkingrs823118 CNTN2 meta5"
# [1] "checkingrs11557080 CTSE meta5"
# [1] "checkingrs823118 CTSE meta5"
# [1] "checkingrs11557080 DSTYK meta5"
# [1] "checkingrs823118 DSTYK meta5"
# [1] "checkingrs11557080 ELK4 meta5"
# [1] "checkingrs823118 ELK4 meta5"
# [1] "checkingrs11557080 FAM72A meta5"
# [1] "checkingrs823118 FAM72A meta5"
# [1] "checkingrs11557080 KLHDC8A meta5"
# [1] "checkingrs823118 KLHDC8A meta5"
# [1] "checkingrs11557080 LEMD1-AS1 meta5"
# [1] "checkingrs823118 LEMD1-AS1 meta5"
# [1] "checkingrs11557080 MFSD4A meta5"
# [1] "checkingrs823118 MFSD4A meta5"
# [1] "checkingrs11557080 NFASC meta5"
# [1] "checkingrs823118 NFASC meta5"
# [1] "checkingrs11557080 NUAK2 meta5"
# [1] "checkingrs823118 NUAK2 meta5"
# [1] "checkingrs11557080 PM20D1 meta5"
# [1] "checkingrs823118 PM20D1 meta5"
# [1] "checkingrs11557080 RAB29 meta5"
# [1] "checkingrs11557080 RBBP5 meta5"
# [1] "checkingrs823118 RBBP5 meta5"
# [1] "checkingrs11557080 SLC26A9 meta5"
# [1] "checkingrs823118 SLC26A9 meta5"
# [1] "checkingrs11557080 SLC41A1 meta5"
# [1] "checkingrs823118 SLC41A1 meta5"
# [1] "checkingrs11557080 SLC45A3 meta5"
# [1] "checkingrs823118 SLC45A3 meta5"
# [1] "checkingrs11557080 TMCC2 meta5"
# [1] "checkingrs823118 TMCC2 meta5"
# [1] "checkingrs11557080 TMEM81 meta5"
# [1] "checkingrs823118 TMEM81 meta5"
# [1] "checkingrs2086641 ADCY8 meta5"
# [1] "checkingrs2086641 ASAP1 meta5"
# [1] "checkingrs2086641 FAM49B meta5"
# [1] "checkingrs2086641 GSDMC meta5"
# [1] "checkingrs2086641 MIR5194 meta5"
# [1] "checkingrs10756907 ADAMTSL1 meta5"
# [1] "checkingrs13294100 ADAMTSL1 meta5"
# [1] "checkingrs10756907 BNC2 meta5"
# [1] "checkingrs13294100 BNC2 meta5"
# [1] "checkingrs10756907 CNTLN meta5"
# [1] "checkingrs13294100 CNTLN meta5"
# [1] "checkingrs13294100 SH3GL2 meta5"
# [1] "checkingrs6476434 ANKRD18B meta5"
# [1] "checkingrs6476434 AQP3 meta5"
# [1] "checkingrs6476434 AQP7 meta5"
# [1] "checkingrs6476434 ARID3C meta5"
# [1] "checkingrs6476434 B4GALT1 meta5"
# [1] "checkingrs6476434 B4GALT1-AS1 meta5"
# [1] "checkingrs6476434 BAG1 meta5"
# [1] "checkingrs6476434 C9orf131 meta5"
# [1] "checkingrs6476434 C9orf24 meta5"
# [1] "checkingrs6476434 CHMP5 meta5"
# [1] "checkingrs6476434 DNAI1 meta5"
# [1] "checkingrs6476434 DNAJB5 meta5"
# [1] "checkingrs6476434 ENHO meta5"
# [1] "checkingrs6476434 FAM205A meta5"
# [1] "checkingrs6476434 FAM205C meta5"
# [1] "checkingrs6476434 GALT meta5"
# [1] "checkingrs6476434 IL11RA meta5"
# [1] "checkingrs6476434 KIF24 meta5"
# [1] "checkingrs6476434 NFX1 meta5"
# [1] "checkingrs6476434 NOL6 meta5"
# [1] "checkingrs6476434 PHF24 meta5"
# [1] "checkingrs6476434 PTENP1 meta5"
# [1] "checkingrs6476434 RPP25L meta5"
# [1] "checkingrs6476434 SIGMAR1 meta5"
# [1] "checkingrs6476434 SMU1 meta5"
# [1] "checkingrs6476434 SPINK4 meta5"
# [1] "checkingrs6476434 UBAP1 meta5"
# [1] "checkingrs6476434 UBAP2 meta5"
# [1] "checkingrs6476434 UBE2R2 meta5"
# [1] "checkingrs896435 ACBD7 meta5"
# [1] "checkingrs896435 C1QL3 meta5"
# [1] "checkingrs896435 CDNF meta5"
# [1] "checkingrs896435 DCLRE1C meta5"
# [1] "checkingrs896435 DCLRE1CP1 meta5"
# [1] "checkingrs896435 FAM107B meta5"
# [1] "checkingrs896435 FAM171A1 meta5"
# [1] "checkingrs896435 HSPA14 meta5"
# [1] "checkingrs896435 ITGA8 meta5"
# [1] "checkingrs896435 MEIG1 meta5"
# [1] "checkingrs896435 NMT2 meta5"
# [1] "checkingrs896435 OLAH meta5"
# [1] "checkingrs896435 PTER meta5"
# [1] "checkingrs896435 RPP38 meta5"
# [1] "checkingrs896435 SUV39H2 meta5"
# [1] "checkingrs10748818 ACTR1A meta5"
# [1] "checkingrs10748818 ARL3 meta5"
# [1] "checkingrs10748818 AS3MT meta5"
# [1] "checkingrs10748818 BORCS7 meta5"
# [1] "checkingrs10748818 BORCS7-ASMT meta5"
# [1] "checkingrs10748818 BTRC meta5"
# [1] "checkingrs10748818 CNNM2 meta5"
# [1] "checkingrs10748818 CUEDC2 meta5"
# [1] "checkingrs10748818 CYP17A1 meta5"
# [1] "checkingrs10748818 DPCD meta5"
# [1] "checkingrs10748818 FBXW4 meta5"
# [1] "checkingrs10748818 FGF8 meta5"
# [1] "checkingrs10748818 GBF1 meta5"
# [1] "checkingrs10748818 HPS6 meta5"
# [1] "checkingrs10748818 KCNIP2-AS1 meta5"
# [1] "checkingrs10748818 MFSD13A meta5"
# [1] "checkingrs10748818 NPM3 meta5"
# [1] "checkingrs10748818 NT5C2 meta5"
# [1] "checkingrs10748818 POLL meta5"
# [1] "checkingrs10748818 PSD meta5"
# [1] "checkingrs10748818 RPARP-AS1 meta5"
# [1] "checkingrs10748818 SFXN2 meta5"
# [1] "checkingrs10748818 SUFU meta5"
# [1] "checkingrs10748818 TRIM8 meta5"
# [1] "checkingrs10748818 WBP1L meta5"
# [1] "checkingrs117896735 BAG3 meta5"
# [1] "checkingrs117896735 CACUL1 meta5"
# [1] "checkingrs72840788 CACUL1 meta5"
# [1] "checkingrs117896735 FAM45A meta5"
# [1] "checkingrs72840788 FAM45A meta5"
# [1] "checkingrs117896735 GRK5 meta5"
# [1] "checkingrs72840788 GRK5 meta5"
# [1] "checkingrs117896735 INPP5F meta5"
# [1] "checkingrs72840788 INPP5F meta5"
# [1] "checkingrs117896735 LINC01561 meta5"
# [1] "checkingrs72840788 LINC01561 meta5"
# [1] "checkingrs117896735 MCMBP meta5"
# [1] "checkingrs72840788 MCMBP meta5"
# [1] "checkingrs117896735 NANOS1 meta5"
# [1] "checkingrs72840788 NANOS1 meta5"
# [1] "checkingrs117896735 PLPP4 meta5"
# [1] "checkingrs72840788 PLPP4 meta5"
# [1] "checkingrs117896735 PRDX3 meta5"
# [1] "checkingrs72840788 PRDX3 meta5"
# [1] "checkingrs117896735 RGS10 meta5"
# [1] "checkingrs72840788 RGS10 meta5"
# [1] "checkingrs117896735 RPL21 meta5"
# [1] "checkingrs72840788 RPL21 meta5"
# [1] "checkingrs117896735 SEC23IP meta5"
# [1] "checkingrs72840788 SEC23IP meta5"
# [1] "checkingrs117896735 SFXN4 meta5"
# [1] "checkingrs72840788 SFXN4 meta5"
# [1] "checkingrs117896735 SNORA19 meta5"
# [1] "checkingrs72840788 SNORA19 meta5"
# [1] "checkingrs117896735 TIAL1 meta5"
# [1] "checkingrs72840788 TIAL1 meta5"
# [1] "checkingrs117896735 WDR11-AS1 meta5"
# [1] "checkingrs72840788 WDR11-AS1 meta5"
# [1] "checkingrs7938782 ADM meta5"
# [1] "checkingrs7938782 AMPD3 meta5"
# [1] "checkingrs7938782 CTR9 meta5"
# [1] "checkingrs7938782 EIF4G2 meta5"
# [1] "checkingrs7938782 GALNT18 meta5"
# [1] "checkingrs7938782 LYVE1 meta5"
# [1] "checkingrs7938782 MRVI1 meta5"
# [1] "checkingrs7938782 MRVI1-AS1 meta5"
# [1] "checkingrs7938782 MTRNR2L8 meta5"
# [1] "checkingrs7938782 RNF141 meta5"
# [1] "checkingrs7938782 SBF2 meta5"
# [1] "checkingrs7938782 SBF2-AS1 meta5"
# [1] "checkingrs7938782 SWAP70 meta5"
# [1] "checkingrs7938782 WEE1 meta5"
# [1] "checkingrs7938782 ZBED5 meta5"
# [1] "checkingrs7938782 ZBED5-AS1 meta5"
# [1] "checkingrs12283611 ANKRD42 meta5"
# [1] "checkingrs12283611 PCF11 meta5"
# [1] "checkingrs12283611 PCF11-AS1 meta5"
# [1] "checkingrs12283611 PRCP meta5"
# [1] "checkingrs12283611 RAB30 meta5"
# [1] "checkingrs12283611 SNORA70E meta5"
# [1] "checkingrs3802920 ACAD8 meta5"
# [1] "checkingrs3802920 B3GAT1 meta5"
# [1] "checkingrs3802920 GLB1L2 meta5"
# [1] "checkingrs3802920 GLB1L3 meta5"
# [1] "checkingrs3802920 IGSF9B meta5"
# [1] "checkingrs3802920 JAM3 meta5"
# [1] "checkingrs3802920 OPCML meta5"
# [1] "checkingrs3802920 THYN1 meta5"
# [1] "checkingrs3802920 VPS26B meta5"
# [1] "checkingrs34637584 ABCD2 meta5"
# [1] "checkingrs76904798 ABCD2 meta5"
# [1] "checkingrs34637584 C12orf40 meta5"
# [1] "checkingrs76904798 C12orf40 meta5"
# [1] "checkingrs34637584 KIF21A meta5"
# [1] "checkingrs76904798 KIF21A meta5"
# [1] "checkingrs34637584 LRRK2 meta5"
# [1] "checkingrs76904798 LRRK2 meta5"
# [1] "checkingrs34637584 MUC19 meta5"
# [1] "checkingrs76904798 MUC19 meta5"
# [1] "checkingrs34637584 PDZRN4 meta5"
# [1] "checkingrs76904798 PDZRN4 meta5"
# [1] "checkingrs34637584 SLC2A13 meta5"
# [1] "checkingrs76904798 SLC2A13 meta5"
# [1] "checkingrs4653767 ACBD3 meta5"
# [1] "checkingrs4653767 CDC42BPA meta5"
# [1] "checkingrs4653767 COQ8A meta5"
# [1] "checkingrs4653767 EPHX1 meta5"
# [1] "checkingrs4653767 H3F3A meta5"
# [1] "checkingrs4653767 H3F3AP4 meta5"
# [1] "checkingrs4653767 ITPKB meta5"
# [1] "checkingrs4653767 ITPKB-IT1 meta5"
# [1] "checkingrs4653767 LEFTY1 meta5"
# [1] "checkingrs4653767 LEFTY2 meta5"
# [1] "checkingrs4653767 MIXL1 meta5"
# [1] "checkingrs4653767 PARP1 meta5"
# [1] "checkingrs4653767 PSEN2 meta5"
# [1] "checkingrs4653767 SNAP47 meta5"
# [1] "checkingrs4653767 SRP9 meta5"
# [1] "checkingrs4653767 TMEM63A meta5"
# [1] "checkingrs4653767 ZNF678 meta5"
# [1] "checkingrs4653767 ZNF847P meta5"
# [1] "checkingrs7134559 ANO6 meta5"
# [1] "checkingrs7134559 DBX2 meta5"
# [1] "checkingrs7134559 PLEKHA8P1 meta5"
# [1] "checkingrs7134559 SLC38A1 meta5"
# [1] "checkingrs7134559 SLC38A2 meta5"
# [1] "checkingrs10847864 ABCB9 meta5"
# [1] "checkingrs10847864 ARL6IP4 meta5"
# [1] "checkingrs10847864 ATP6V0A2 meta5"
# [1] "checkingrs10847864 BCL7A meta5"
# [1] "checkingrs10847864 C12orf65 meta5"
# [1] "checkingrs10847864 CCDC62 meta5"
# [1] "checkingrs10847864 CDK2AP1 meta5"
# [1] "checkingrs10847864 CLIP1 meta5"
# [1] "checkingrs10847864 DDX55 meta5"
# [1] "checkingrs10847864 DENR meta5"
# [1] "checkingrs10847864 DIABLO meta5"
# [1] "checkingrs10847864 DNAH10 meta5"
# [1] "checkingrs10847864 EIF2B1 meta5"
# [1] "checkingrs10847864 GTF2H3 meta5"
# [1] "checkingrs10847864 HCAR3 meta5"
# [1] "checkingrs10847864 HIP1R meta5"
# [1] "checkingrs10847864 IL31 meta5"
# [1] "checkingrs10847864 KMT5A meta5"
# [1] "checkingrs10847864 KNTC1 meta5"
# [1] "checkingrs10847864 LRRC43 meta5"
# [1] "checkingrs10847864 MLXIP meta5"
# [1] "checkingrs10847864 MPHOSPH9 meta5"
# [1] "checkingrs10847864 OGFOD2 meta5"
# [1] "checkingrs10847864 PITPNM2 meta5"
# [1] "checkingrs10847864 PSMD9 meta5"
# [1] "checkingrs10847864 RILPL1 meta5"
# [1] "checkingrs10847864 RILPL2 meta5"
# [1] "checkingrs10847864 RSRC2 meta5"
# [1] "checkingrs10847864 SBNO1 meta5"
# [1] "checkingrs10847864 SNRNP35 meta5"
# [1] "checkingrs10847864 TCTN2 meta5"
# [1] "checkingrs10847864 VPS33A meta5"
# [1] "checkingrs10847864 VPS37B meta5"
# [1] "checkingrs10847864 WDR66 meta5"
# [1] "checkingrs11610045 ANKLE2 meta5"
# [1] "checkingrs11610045 CHFR meta5"
# [1] "checkingrs11610045 DDX51 meta5"
# [1] "checkingrs11610045 EP400 meta5"
# [1] "checkingrs11610045 FBRSL1 meta5"
# [1] "checkingrs11610045 GALNT9 meta5"
# [1] "checkingrs11610045 GOLGA3 meta5"
# [1] "checkingrs11610045 LRCOL1 meta5"
# [1] "checkingrs11610045 MMP17 meta5"
# [1] "checkingrs11610045 NOC4L meta5"
# [1] "checkingrs11610045 P2RX2 meta5"
# [1] "checkingrs11610045 POLE meta5"
# [1] "checkingrs11610045 PUS1 meta5"
# [1] "checkingrs11610045 PXMP2 meta5"
# [1] "checkingrs11610045 SFSWAP meta5"
# [1] "checkingrs11610045 ZNF140 meta5"
# [1] "checkingrs11610045 ZNF268 meta5"
# [1] "checkingrs11610045 ZNF605 meta5"
# [1] "checkingrs11610045 ZNF84 meta5"
# [1] "checkingrs11610045 ZNF891 meta5"
# [1] "checkingrs9568188 ARL11 meta5"
# [1] "checkingrs9568188 CAB39L meta5"
# [1] "checkingrs9568188 CDADC1 meta5"
# [1] "checkingrs9568188 CTAGE10P meta5"
# [1] "checkingrs9568188 CYSLTR2 meta5"
# [1] "checkingrs9568188 DLEU1 meta5"
# [1] "checkingrs9568188 DLEU2 meta5"
# [1] "checkingrs9568188 EBPL meta5"
# [1] "checkingrs9568188 FNDC3A meta5"
# [1] "checkingrs9568188 KCNRG meta5"
# [1] "checkingrs9568188 KPNA3 meta5"
# [1] "checkingrs9568188 LINC00462 meta5"
# [1] "checkingrs9568188 PHF11 meta5"
# [1] "checkingrs9568188 RB1 meta5"
# [1] "checkingrs9568188 RCBTB1 meta5"
# [1] "checkingrs9568188 RCBTB2 meta5"
# [1] "checkingrs9568188 SETDB2 meta5"
# [1] "checkingrs9568188 SPRYD7 meta5"
# [1] "checkingrs9568188 ST13P4 meta5"
# [1] "checkingrs9568188 TRIM13 meta5"
# [1] "checkingrs4771268 FARP1 meta5"
# [1] "checkingrs4771268 HS6ST3 meta5"
# [1] "checkingrs4771268 IPO5 meta5"
# [1] "checkingrs4771268 LINC00359 meta5"
# [1] "checkingrs4771268 MBNL2 meta5"
# [1] "checkingrs4771268 OXGR1 meta5"
# [1] "checkingrs4771268 RAP2A meta5"
# [1] "checkingrs4771268 RNF113B meta5"
# [1] "checkingrs12147950 CLEC14A meta5"
# [1] "checkingrs12147950 FOXA1 meta5"
# [1] "checkingrs12147950 LINC00517 meta5"
# [1] "checkingrs12147950 MIPOL1 meta5"
# [1] "checkingrs12147950 NKX2-1 meta5"
# [1] "checkingrs12147950 NKX2-1-AS1 meta5"
# [1] "checkingrs12147950 NKX2-8 meta5"
# [1] "checkingrs12147950 PAX9 meta5"
# [1] "checkingrs12147950 SLC25A21-AS1 meta5"
# [1] "checkingrs12147950 SSTR1 meta5"
# [1] "checkingrs12147950 TTC6 meta5"
# [1] "checkingrs11158026 ATG14 meta5"
# [1] "checkingrs11158026 BMP4 meta5"
# [1] "checkingrs11158026 CDKN3 meta5"
# [1] "checkingrs11158026 CNIH1 meta5"
# [1] "checkingrs11158026 FBXO34 meta5"
# [1] "checkingrs11158026 GCH1 meta5"
# [1] "checkingrs11158026 GMFB meta5"
# [1] "checkingrs11158026 KTN1 meta5"
# [1] "checkingrs11158026 KTN1-AS1 meta5"
# [1] "checkingrs11158026 LGALS3 meta5"
# [1] "checkingrs11158026 LINC00520 meta5"
# [1] "checkingrs11158026 MAPK1IP1L meta5"
# [1] "checkingrs11158026 RPL13AP3 meta5"
# [1] "checkingrs11158026 SAMD4A meta5"
# [1] "checkingrs11158026 SOCS4 meta5"
# [1] "checkingrs11158026 WDHD1 meta5"
# [1] "checkingrs3742785 ABCD4 meta5"
# [1] "checkingrs3742785 ACYP1 meta5"
# [1] "checkingrs3742785 ALDH6A1 meta5"
# [1] "checkingrs3742785 AREL1 meta5"
# [1] "checkingrs3742785 BBOF1 meta5"
# [1] "checkingrs3742785 COQ6 meta5"
# [1] "checkingrs3742785 DLST meta5"
# [1] "checkingrs3742785 EIF2B2 meta5"
# [1] "checkingrs3742785 ENTPD5 meta5"
# [1] "checkingrs3742785 FAM161B meta5"
# [1] "checkingrs3742785 FCF1 meta5"
# [1] "checkingrs3742785 FLVCR2 meta5"
# [1] "checkingrs3742785 ISCA2 meta5"
# [1] "checkingrs3742785 JDP2 meta5"
# [1] "checkingrs3742785 LIN52 meta5"
# [1] "checkingrs3742785 LINC01220 meta5"
# [1] "checkingrs3742785 LTBP2 meta5"
# [1] "checkingrs3742785 MLH3 meta5"
# [1] "checkingrs3742785 NPC2 meta5"
# [1] "checkingrs3742785 RPS6KL1 meta5"
# [1] "checkingrs3742785 SYNDIG1L meta5"
# [1] "checkingrs3742785 TMED10 meta5"
# [1] "checkingrs3742785 TTLL5 meta5"
# [1] "checkingrs3742785 VRTN meta5"
# [1] "checkingrs3742785 ZC2HC1C meta5"
# [1] "checkingrs979812 EML5 meta5"
# [1] "checkingrs979812 GALC meta5"
# [1] "checkingrs979812 GPR65 meta5"
# [1] "checkingrs979812 KCNK10 meta5"
# [1] "checkingrs979812 LINC01146 meta5"
# [1] "checkingrs979812 PTPN21 meta5"
# [1] "checkingrs979812 SPATA7 meta5"
# [1] "checkingrs979812 TTC8 meta5"
# [1] "checkingrs979812 ZC3H14 meta5"
# [1] "checkingrs2251086 C2CD4A meta5"
# [1] "checkingrs2251086 C2CD4B meta5"
# [1] "checkingrs2251086 GOLGA2P11 meta5"
# [1] "checkingrs2251086 MGC15885 meta5"
# [1] "checkingrs2251086 RORA meta5"
# [1] "checkingrs2251086 TLN2 meta5"
# [1] "checkingrs2251086 VPS13C meta5"
# [1] "checkingrs10797576 DISC1 meta5"
# [1] "checkingrs10797576 MAP10 meta5"
# [1] "checkingrs10797576 NTPCR meta5"
# [1] "checkingrs10797576 PCNX2 meta5"
# [1] "checkingrs10797576 SIPA1L2 meta5"
# [1] "checkingrs10797576 TSNAX meta5"
# [1] "checkingrs6497339 ABCC6P1 meta5"
# [1] "checkingrs6497339 ARL6IP1 meta5"
# [1] "checkingrs6497339 CCP110 meta5"
# [1] "checkingrs6497339 COQ7 meta5"
# [1] "checkingrs6497339 GDE1 meta5"
# [1] "checkingrs6497339 GPR139 meta5"
# [1] "checkingrs6497339 GPRC5B meta5"
# [1] "checkingrs6497339 IQCK meta5"
# [1] "checkingrs6497339 ITPRIPL2 meta5"
# [1] "checkingrs6497339 KNOP1 meta5"
# [1] "checkingrs6497339 MIR3179-1 meta5"
# [1] "checkingrs6497339 MIR3179-2 meta5"
# [1] "checkingrs6497339 MIR3180-1 meta5"
# [1] "checkingrs6497339 NOMO2 meta5"
# [1] "checkingrs6497339 NPIPA7 meta5"
# [1] "checkingrs6497339 NPIPA8 meta5"
# [1] "checkingrs6497339 SMG1 meta5"
# [1] "checkingrs6497339 TMC5 meta5"
# [1] "checkingrs6497339 TMC7 meta5"
# [1] "checkingrs2904880 ASPHD1 meta5"
# [1] "checkingrs2904880 ATP2A1 meta5"
# [1] "checkingrs2904880 ATP2A1-AS1 meta5"
# [1] "checkingrs2904880 BOLA2 meta5"
# [1] "checkingrs2904880 CD19 meta5"
# [1] "checkingrs2904880 CDIPT meta5"
# [1] "checkingrs2904880 CLN3 meta5"
# [1] "checkingrs2904880 EIF3C meta5"
# [1] "checkingrs2904880 EIF3CL meta5"
# [1] "checkingrs2904880 GSG1L meta5"
# [1] "checkingrs2904880 IL27 meta5"
# [1] "checkingrs2904880 KCTD13 meta5"
# [1] "checkingrs2904880 NFATC2IP meta5"
# [1] "checkingrs2904880 NPIPB11 meta5"
# [1] "checkingrs2904880 NPIPB6 meta5"
# [1] "checkingrs2904880 NPIPB8 meta5"
# [1] "checkingrs2904880 NPIPB9 meta5"
# [1] "checkingrs2904880 NUPR1 meta5"
# [1] "checkingrs2904880 QPRT meta5"
# [1] "checkingrs2904880 RABEP2 meta5"
# [1] "checkingrs2904880 RRN3P2 meta5"
# [1] "checkingrs2904880 SBK1 meta5"
# [1] "checkingrs2904880 SEZ6L2 meta5"
# [1] "checkingrs2904880 SH2B1 meta5"
# [1] "checkingrs2904880 SLX1A meta5"
# [1] "checkingrs2904880 SLX1A-SULT1A3 meta5"
# [1] "checkingrs2904880 SLX1B meta5"
# [1] "checkingrs2904880 SLX1B-SULT1A4 meta5"
# [1] "checkingrs2904880 SMG1P2 meta5"
# [1] "checkingrs2904880 SMG1P6 meta5"
# [1] "checkingrs2904880 SNX29P2 meta5"
# [1] "checkingrs2904880 SPN meta5"
# [1] "checkingrs2904880 SPNS1 meta5"
# [1] "checkingrs2904880 SULT1A1 meta5"
# [1] "checkingrs2904880 SULT1A2 meta5"
# [1] "checkingrs2904880 SULT1A3 meta5"
# [1] "checkingrs2904880 TUFM meta5"
# [1] "checkingrs2904880 XPO6 meta5"
# [1] "checkingrs11150601 ARMC5 meta5"
# [1] "checkingrs11150601 BCL7C meta5"
# [1] "checkingrs11150601 BOLA2 meta5"
# [1] "checkingrs11150601 C16orf92 meta5"
# [1] "checkingrs11150601 CCDC189 meta5"
# [1] "checkingrs11150601 DOC2A meta5"
# [1] "checkingrs11150601 FBXL19-AS1 meta5"
# [1] "checkingrs11150601 HSD3B7 meta5"
# [1] "checkingrs11150601 INO80E meta5"
# [1] "checkingrs11150601 ITGAD meta5"
# [1] "checkingrs11150601 ITGAM meta5"
# [1] "checkingrs11150601 ITGAX meta5"
# [1] "checkingrs11150601 KAT8 meta5"
# [1] "checkingrs11150601 MAPK3 meta5"
# [1] "checkingrs11150601 MIR762HG meta5"
# [1] "checkingrs11150601 MYLPF meta5"
# [1] "checkingrs11150601 ORAI3 meta5"
# [1] "checkingrs11150601 PHKG2 meta5"
# [1] "checkingrs11150601 PPP4C meta5"
# [1] "checkingrs11150601 PRSS36 meta5"
# [1] "checkingrs11150601 PRSS53 meta5"
# [1] "checkingrs11150601 PYDC1 meta5"
# [1] "checkingrs11150601 RNF40 meta5"
# [1] "checkingrs11150601 SLX1A meta5"
# [1] "checkingrs11150601 SLX1A-SULT1A3 meta5"
# [1] "checkingrs11150601 SLX1B meta5"
# [1] "checkingrs11150601 SLX1B-SULT1A4 meta5"
# [1] "checkingrs11150601 SMG1P5 meta5"
# [1] "checkingrs11150601 SNORA30 meta5"
# [1] "checkingrs11150601 STX4 meta5"
# [1] "checkingrs11150601 SULT1A3 meta5"
# [1] "checkingrs11150601 TAOK2 meta5"
# [1] "checkingrs11150601 TBX6 meta5"
# [1] "checkingrs11150601 TMEM219 meta5"
# [1] "checkingrs11150601 TRIM72 meta5"
# [1] "checkingrs11150601 VKORC1 meta5"
# [1] "checkingrs11150601 VN1R3 meta5"
# [1] "checkingrs11150601 YPEL3 meta5"
# [1] "checkingrs11150601 ZNF646 meta5"
# [1] "checkingrs11150601 ZNF668 meta5"
# [1] "checkingrs11150601 ZNF688 meta5"
# [1] "checkingrs11150601 ZNF689 meta5"
# [1] "checkingrs11150601 ZNF720 meta5"
# [1] "checkingrs11150601 ZNF747 meta5"
# [1] "checkingrs11150601 ZNF843 meta5"
# [1] "checkingrs6500328 ADCY7 meta5"
# [1] "checkingrs6500328 BRD7 meta5"
# [1] "checkingrs6500328 CNEP1R1 meta5"
# [1] "checkingrs6500328 CYLD meta5"
# [1] "checkingrs6500328 HEATR3 meta5"
# [1] "checkingrs6500328 NKD1 meta5"
# [1] "checkingrs6500328 NOD2 meta5"
# [1] "checkingrs6500328 ZNF423 meta5"
# [1] "checkingrs3104783 AKTIP meta5"
# [1] "checkingrs3104783 C16orf97 meta5"
# [1] "checkingrs3104783 CASC16 meta5"
# [1] "checkingrs3104783 CHD9 meta5"
# [1] "checkingrs3104783 LINC01571 meta5"
# [1] "checkingrs3104783 RBL2 meta5"
# [1] "checkingrs3104783 RPGRIP1L meta5"
# [1] "checkingrs3104783 TOX3 meta5"
# [1] "checkingrs10221156 AKTIP meta5"
# [1] "checkingrs10221156 C16orf97 meta5"
# [1] "checkingrs10221156 CASC16 meta5"
# [1] "checkingrs10221156 CHD9 meta5"
# [1] "checkingrs10221156 FTO meta5"
# [1] "checkingrs10221156 RPGRIP1L meta5"
# [1] "checkingrs10221156 TOX3 meta5"
# [1] "checkingrs12600861 ACADVL meta5"
# [1] "checkingrs12600861 ACAP1 meta5"
# [1] "checkingrs12600861 ALOX12 meta5"
# [1] "checkingrs12600861 ALOX12-AS1 meta5"
# [1] "checkingrs12600861 ALOX12B meta5"
# [1] "checkingrs12600861 ALOX12P2 meta5"
# [1] "checkingrs12600861 ALOX15B meta5"
# [1] "checkingrs12600861 ARHGEF15 meta5"
# [1] "checkingrs12600861 ASGR1 meta5"
# [1] "checkingrs12600861 ASGR2 meta5"
# [1] "checkingrs12600861 ATP1B2 meta5"
# [1] "checkingrs12600861 BCL6B meta5"
# [1] "checkingrs12600861 BORCS6 meta5"
# [1] "checkingrs12600861 C17orf100 meta5"
# [1] "checkingrs12600861 C17orf49 meta5"
# [1] "checkingrs12600861 CHD3 meta5"
# [1] "checkingrs12600861 CLDN7 meta5"
# [1] "checkingrs12600861 CLEC10A meta5"
# [1] "checkingrs12600861 CNTROB meta5"
# [1] "checkingrs12600861 CTC1 meta5"
# [1] "checkingrs12600861 CTDNEP1 meta5"
# [1] "checkingrs12600861 CYB5D1 meta5"
# [1] "checkingrs12600861 DLG4 meta5"
# [1] "checkingrs12600861 DNAH2 meta5"
# [1] "checkingrs12600861 DVL2 meta5"
# [1] "checkingrs12600861 EFNB3 meta5"
# [1] "checkingrs12600861 EIF4A1 meta5"
# [1] "checkingrs12600861 EIF5A meta5"
# [1] "checkingrs12600861 ELP5 meta5"
# [1] "checkingrs12600861 FBXO39 meta5"
# [1] "checkingrs12600861 FGF11 meta5"
# [1] "checkingrs12600861 GABARAP meta5"
# [1] "checkingrs12600861 GPS2 meta5"
# [1] "checkingrs12600861 GUCY2D meta5"
# [1] "checkingrs12600861 HES7 meta5"
# [1] "checkingrs12600861 KCNAB3 meta5"
# [1] "checkingrs12600861 KCTD11 meta5"
# [1] "checkingrs12600861 KDM6B meta5"
# [1] "checkingrs12600861 KIAA0753 meta5"
# [1] "checkingrs12600861 KRBA2 meta5"
# [1] "checkingrs12600861 LINC00324 meta5"
# [1] "checkingrs12600861 MED31 meta5"
# [1] "checkingrs12600861 NAA38 meta5"
# [1] "checkingrs12600861 PFAS meta5"
# [1] "checkingrs12600861 PHF23 meta5"
# [1] "checkingrs12600861 PITPNM3 meta5"
# [1] "checkingrs12600861 POLR2A meta5"
# [1] "checkingrs12600861 RANGRF meta5"
# [1] "checkingrs12600861 RNASEK meta5"
# [1] "checkingrs12600861 RNASEK-C17orf49 meta5"
# [1] "checkingrs12600861 SAT2 meta5"
# [1] "checkingrs12600861 SCARNA21 meta5"
# [1] "checkingrs12600861 SENP3 meta5"
# [1] "checkingrs12600861 SHBG meta5"
# [1] "checkingrs12600861 SLC13A5 meta5"
# [1] "checkingrs12600861 SLC16A11 meta5"
# [1] "checkingrs12600861 SLC16A13 meta5"
# [1] "checkingrs12600861 SLC25A35 meta5"
# [1] "checkingrs12600861 SLC2A4 meta5"
# [1] "checkingrs12600861 SNORA48 meta5"
# [1] "checkingrs12600861 SNORA67 meta5"
# [1] "checkingrs12600861 SNORD10 meta5"
# [1] "checkingrs12600861 SOX15 meta5"
# [1] "checkingrs12600861 SPEM1 meta5"
# [1] "checkingrs12600861 TEKT1 meta5"
# [1] "checkingrs12600861 TMEM102 meta5"
# [1] "checkingrs12600861 TMEM107 meta5"
# [1] "checkingrs12600861 TMEM256 meta5"
# [1] "checkingrs12600861 TMEM256-PLSCR3 meta5"
# [1] "checkingrs12600861 TMEM95 meta5"
# [1] "checkingrs12600861 TNFSF12 meta5"
# [1] "checkingrs12600861 TNFSF13 meta5"
# [1] "checkingrs12600861 TNK1 meta5"
# [1] "checkingrs12600861 TXNDC17 meta5"
# [1] "checkingrs12600861 VAMP2 meta5"
# [1] "checkingrs12600861 XAF1 meta5"
# [1] "checkingrs12600861 YBX2 meta5"
# [1] "checkingrs12951632 AARSD1 meta5"
# [1] "checkingrs12951632 ACLY meta5"
# [1] "checkingrs12951632 BRCA1 meta5"
# [1] "checkingrs12951632 CCR10 meta5"
# [1] "checkingrs12951632 CNTD1 meta5"
# [1] "checkingrs12951632 COASY meta5"
# [1] "checkingrs12951632 DHX58 meta5"
# [1] "checkingrs12951632 DNAJC7 meta5"
# [1] "checkingrs12951632 ETV4 meta5"
# [1] "checkingrs12951632 HAP1 meta5"
# [1] "checkingrs12951632 HSD17B1 meta5"
# [1] "checkingrs12951632 IFI35 meta5"
# [1] "checkingrs12951632 JUP meta5"
# [1] "checkingrs12951632 KAT2A meta5"
# [1] "checkingrs12951632 KLHL11 meta5"
# [1] "checkingrs12951632 KRT16 meta5"
# [1] "checkingrs12951632 KRT17 meta5"
# [1] "checkingrs12951632 KRT42P meta5"
# [1] "checkingrs12951632 LINC00671 meta5"
# [1] "checkingrs12951632 LINC00910 meta5"
# [1] "checkingrs12951632 MIR2117HG meta5"
# [1] "checkingrs12951632 MLX meta5"
# [1] "checkingrs12951632 NAGLU meta5"
# [1] "checkingrs12951632 NBR1 meta5"
# [1] "checkingrs12951632 NBR2 meta5"
# [1] "checkingrs12951632 NKIRAS2 meta5"
# [1] "checkingrs12951632 NT5C3B meta5"
# [1] "checkingrs12951632 PLEKHH3 meta5"
# [1] "checkingrs12951632 PSMC3IP meta5"
# [1] "checkingrs12951632 PTGES3L meta5"
# [1] "checkingrs12951632 PTGES3L-AARSD1 meta5"
# [1] "checkingrs12951632 RAB5C meta5"
# [1] "checkingrs12951632 RAMP2 meta5"
# [1] "checkingrs12951632 RAMP2-AS1 meta5"
# [1] "checkingrs12951632 RND2 meta5"
# [1] "checkingrs12951632 RPL27 meta5"
# [1] "checkingrs12951632 RUNDC1 meta5"
# [1] "checkingrs12951632 STAT5B meta5"
# [1] "checkingrs12951632 TTC25 meta5"
# [1] "checkingrs12951632 WNK4 meta5"
# [1] "checkingrs12951632 ZNF385C meta5"
# [1] "checkingrs2269906 ACBD4 meta5"
# [1] "checkingrs850738 ACBD4 meta5"
# [1] "checkingrs2269906 ADAM11 meta5"
# [1] "checkingrs850738 ADAM11 meta5"
# [1] "checkingrs2269906 ASB16 meta5"
# [1] "checkingrs850738 ASB16 meta5"
# [1] "checkingrs2269906 ASB16-AS1 meta5"
# [1] "checkingrs850738 ASB16-AS1 meta5"
# [1] "checkingrs2269906 C17orf53 meta5"
# [1] "checkingrs850738 C17orf53 meta5"
# [1] "checkingrs2269906 C1QL1 meta5"
# [1] "checkingrs850738 C1QL1 meta5"
# [1] "checkingrs2269906 CCDC103 meta5"
# [1] "checkingrs850738 CCDC103 meta5"
# [1] "checkingrs2269906 CCDC43 meta5"
# [1] "checkingrs850738 CCDC43 meta5"
# [1] "checkingrs2269906 CD300LG meta5"
# [1] "checkingrs850738 CD300LG meta5"
# [1] "checkingrs2269906 DBF4B meta5"
# [1] "checkingrs850738 DBF4B meta5"
# [1] "checkingrs2269906 DCAKD meta5"
# [1] "checkingrs850738 DCAKD meta5"
# [1] "checkingrs2269906 DUSP3 meta5"
# [1] "checkingrs850738 DUSP3 meta5"
# [1] "checkingrs2269906 ETV4 meta5"
# [1] "checkingrs850738 ETV4 meta5"
# [1] "checkingrs2269906 FAM187A meta5"
# [1] "checkingrs850738 FAM187A meta5"
# [1] "checkingrs2269906 FAM215A meta5"
# [1] "checkingrs850738 FAM215A meta5"
# [1] "checkingrs2269906 FZD2 meta5"
# [1] "checkingrs850738 FZD2 meta5"
# [1] "checkingrs2269906 G6PC3 meta5"
# [1] "checkingrs850738 G6PC3 meta5"
# [1] "checkingrs2269906 GFAP meta5"
# [1] "checkingrs850738 GFAP meta5"
# [1] "checkingrs2269906 GJC1 meta5"
# [1] "checkingrs850738 GJC1 meta5"
# [1] "checkingrs2269906 GPATCH8 meta5"
# [1] "checkingrs850738 GPATCH8 meta5"
# [1] "checkingrs2269906 GRN meta5"
# [1] "checkingrs2269906 HDAC5 meta5"
# [1] "checkingrs850738 HDAC5 meta5"
# [1] "checkingrs2269906 HEXIM1 meta5"
# [1] "checkingrs850738 HEXIM1 meta5"
# [1] "checkingrs2269906 HEXIM2 meta5"
# [1] "checkingrs850738 HEXIM2 meta5"
# [1] "checkingrs2269906 HIGD1B meta5"
# [1] "checkingrs850738 HIGD1B meta5"
# [1] "checkingrs2269906 LINC00910 meta5"
# [1] "checkingrs850738 LINC00910 meta5"
# [1] "checkingrs2269906 LSM12 meta5"
# [1] "checkingrs850738 LSM12 meta5"
# [1] "checkingrs2269906 MAP3K14-AS1 meta5"
# [1] "checkingrs850738 MAP3K14-AS1 meta5"
# [1] "checkingrs2269906 MEIOC meta5"
# [1] "checkingrs850738 MEIOC meta5"
# [1] "checkingrs2269906 MIR2117HG meta5"
# [1] "checkingrs850738 MIR2117HG meta5"
# [1] "checkingrs2269906 MPP2 meta5"
# [1] "checkingrs850738 MPP2 meta5"
# [1] "checkingrs2269906 MPP3 meta5"
# [1] "checkingrs850738 MPP3 meta5"
# [1] "checkingrs2269906 NAGS meta5"
# [1] "checkingrs850738 NAGS meta5"
# [1] "checkingrs2269906 NBR1 meta5"
# [1] "checkingrs850738 NBR1 meta5"
# [1] "checkingrs2269906 NBR2 meta5"
# [1] "checkingrs850738 NBR2 meta5"
# [1] "checkingrs2269906 PPY meta5"
# [1] "checkingrs850738 PPY meta5"
# [1] "checkingrs2269906 PYY meta5"
# [1] "checkingrs850738 PYY meta5"
# [1] "checkingrs2269906 RUNDC3A meta5"
# [1] "checkingrs850738 RUNDC3A meta5"
# [1] "checkingrs2269906 RUNDC3A-AS1 meta5"
# [1] "checkingrs850738 RUNDC3A-AS1 meta5"
# [1] "checkingrs2269906 SLC25A39 meta5"
# [1] "checkingrs850738 SLC25A39 meta5"
# [1] "checkingrs2269906 SOST meta5"
# [1] "checkingrs850738 SOST meta5"
# [1] "checkingrs2269906 TMEM101 meta5"
# [1] "checkingrs850738 TMEM101 meta5"
# [1] "checkingrs2269906 UBTF meta5"
# [1] "checkingrs850738 UBTF meta5"
# [1] "checkingrs117615688 ACBD4 meta5"
# [1] "checkingrs62053943 ACBD4 meta5"
# [1] "checkingrs117615688 ADAM11 meta5"
# [1] "checkingrs62053943 ADAM11 meta5"
# [1] "checkingrs117615688 ARL17A meta5"
# [1] "checkingrs62053943 ARL17A meta5"
# [1] "checkingrs117615688 ARL17B meta5"
# [1] "checkingrs62053943 ARL17B meta5"
# [1] "checkingrs117615688 C1QL1 meta5"
# [1] "checkingrs62053943 C1QL1 meta5"
# [1] "checkingrs117615688 CCDC103 meta5"
# [1] "checkingrs62053943 CCDC103 meta5"
# [1] "checkingrs117615688 CCDC43 meta5"
# [1] "checkingrs62053943 CCDC43 meta5"
# [1] "checkingrs117615688 CRHR1 meta5"
# [1] "checkingrs62053943 CRHR1 meta5"
# [1] "checkingrs117615688 DBF4B meta5"
# [1] "checkingrs62053943 DBF4B meta5"
# [1] "checkingrs117615688 DCAKD meta5"
# [1] "checkingrs62053943 DCAKD meta5"
# [1] "checkingrs117615688 FAM187A meta5"
# [1] "checkingrs62053943 FAM187A meta5"
# [1] "checkingrs117615688 GFAP meta5"
# [1] "checkingrs62053943 GFAP meta5"
# [1] "checkingrs117615688 GJC1 meta5"
# [1] "checkingrs62053943 GJC1 meta5"
# [1] "checkingrs117615688 HEXIM1 meta5"
# [1] "checkingrs62053943 HEXIM1 meta5"
# [1] "checkingrs117615688 HEXIM2 meta5"
# [1] "checkingrs62053943 HEXIM2 meta5"
# [1] "checkingrs117615688 HIGD1B meta5"
# [1] "checkingrs62053943 HIGD1B meta5"
# [1] "checkingrs117615688 KANSL1 meta5"
# [1] "checkingrs62053943 KANSL1 meta5"
# [1] "checkingrs117615688 KANSL1-AS1 meta5"
# [1] "checkingrs62053943 KANSL1-AS1 meta5"
# [1] "checkingrs117615688 LRRC37A meta5"
# [1] "checkingrs62053943 LRRC37A meta5"
# [1] "checkingrs117615688 LRRC37A2 meta5"
# [1] "checkingrs62053943 LRRC37A2 meta5"
# [1] "checkingrs117615688 LRRC37A4P meta5"
# [1] "checkingrs62053943 LRRC37A4P meta5"
# [1] "checkingrs117615688 MAP3K14-AS1 meta5"
# [1] "checkingrs62053943 MAP3K14-AS1 meta5"
# [1] "checkingrs117615688 MAPT meta5"
# [1] "checkingrs62053943 MAPT meta5"
# [1] "checkingrs117615688 MAPT-AS1 meta5"
# [1] "checkingrs62053943 MAPT-AS1 meta5"
# [1] "checkingrs117615688 MEIOC meta5"
# [1] "checkingrs62053943 MEIOC meta5"
# [1] "checkingrs117615688 NSF meta5"
# [1] "checkingrs62053943 NSF meta5"
# [1] "checkingrs117615688 NSFP1 meta5"
# [1] "checkingrs62053943 NSFP1 meta5"
# [1] "checkingrs117615688 PLEKHM1 meta5"
# [1] "checkingrs62053943 PLEKHM1 meta5"
# [1] "checkingrs117615688 SPPL2C meta5"
# [1] "checkingrs62053943 SPPL2C meta5"
# [1] "checkingrs117615688 STH meta5"
# [1] "checkingrs62053943 STH meta5"
# [1] "checkingrs76116224 GEN1 meta5"
# [1] "checkingrs76116224 KCNS3 meta5"
# [1] "checkingrs76116224 MSGN1 meta5"
# [1] "checkingrs76116224 NT5C1B meta5"
# [1] "checkingrs76116224 RAD51AP2 meta5"
# [1] "checkingrs76116224 RDH14 meta5"
# [1] "checkingrs76116224 SMC6 meta5"
# [1] "checkingrs76116224 VSNL1 meta5"
# [1] "checkingrs11658976 ARL17A meta5"
# [1] "checkingrs11658976 ARL17B meta5"
# [1] "checkingrs11658976 CRHR1 meta5"
# [1] "checkingrs11658976 EFCAB13 meta5"
# [1] "checkingrs11658976 GOSR2 meta5"
# [1] "checkingrs11658976 ITGB3 meta5"
# [1] "checkingrs11658976 KANSL1 meta5"
# [1] "checkingrs11658976 KANSL1-AS1 meta5"
# [1] "checkingrs11658976 KPNB1 meta5"
# [1] "checkingrs11658976 LRRC37A meta5"
# [1] "checkingrs11658976 LRRC37A2 meta5"
# [1] "checkingrs11658976 MAPT meta5"
# [1] "checkingrs11658976 MAPT-AS1 meta5"
# [1] "checkingrs11658976 MYL4 meta5"
# [1] "checkingrs11658976 NPEPPS meta5"
# [1] "checkingrs11658976 NSF meta5"
# [1] "checkingrs11658976 NSFP1 meta5"
# [1] "checkingrs11658976 RPRML meta5"
# [1] "checkingrs11658976 SPPL2C meta5"
# [1] "checkingrs11658976 STH meta5"
# [1] "checkingrs11658976 TBKBP1 meta5"
# [1] "checkingrs11658976 TBX21 meta5"
# [1] "checkingrs11658976 THCAT158 meta5"
# [1] "checkingrs11658976 WNT3 meta5"
# [1] "checkingrs61169879 BRIP1 meta5"
# [1] "checkingrs61169879 EFCAB3 meta5"
# [1] "checkingrs61169879 INTS2 meta5"
# [1] "checkingrs61169879 MARCH10 meta5"
# [1] "checkingrs61169879 METTL2A meta5"
# [1] "checkingrs61169879 MRC2 meta5"
# [1] "checkingrs61169879 NACA2 meta5"
# [1] "checkingrs61169879 TBX2-AS1 meta5"
# [1] "checkingrs61169879 TBX4 meta5"
# [1] "checkingrs61169879 TLK2 meta5"
# [1] "checkingrs666463 AFMID meta5"
# [1] "checkingrs666463 C17orf99 meta5"
# [1] "checkingrs666463 C1QTNF1 meta5"
# [1] "checkingrs666463 C1QTNF1-AS1 meta5"
# [1] "checkingrs666463 CANT1 meta5"
# [1] "checkingrs666463 CEP295NL meta5"
# [1] "checkingrs666463 CYTH1 meta5"
# [1] "checkingrs666463 DNAH17 meta5"
# [1] "checkingrs666463 DNAH17-AS1 meta5"
# [1] "checkingrs666463 ENGASE meta5"
# [1] "checkingrs666463 LGALS3BP meta5"
# [1] "checkingrs666463 RBFOX3 meta5"
# [1] "checkingrs666463 SOCS3 meta5"
# [1] "checkingrs666463 SYNGR2 meta5"
# [1] "checkingrs666463 TIMP2 meta5"
# [1] "checkingrs666463 TK1 meta5"
# [1] "checkingrs666463 TMC6 meta5"
# [1] "checkingrs666463 TMC8 meta5"
# [1] "checkingrs666463 TMEM235 meta5"
# [1] "checkingrs666463 TNRC6C meta5"
# [1] "checkingrs666463 TNRC6C-AS1 meta5"
# [1] "checkingrs666463 USP36 meta5"
# [1] "checkingrs1941685 CCDC178 meta5"
# [1] "checkingrs1941685 DTNA meta5"
# [1] "checkingrs1941685 KLHL14 meta5"
# [1] "checkingrs1941685 NOL4 meta5"
# [1] "checkingrs12456492 LINC00907 meta5"
# [1] "checkingrs12456492 RIT2 meta5"
# [1] "checkingrs12456492 SYT4 meta5"
# [1] "checkingrs8087969 CFAP53 meta5"
# [1] "checkingrs8087969 CXXC1 meta5"
# [1] "checkingrs8087969 ELAC1 meta5"
# [1] "checkingrs8087969 LINC01630 meta5"
# [1] "checkingrs8087969 MAPK4 meta5"
# [1] "checkingrs8087969 MBD1 meta5"
# [1] "checkingrs8087969 ME2 meta5"
# [1] "checkingrs8087969 MEX3C meta5"
# [1] "checkingrs8087969 MRO meta5"
# [1] "checkingrs8087969 MYO5B meta5"
# [1] "checkingrs8087969 SMAD4 meta5"
# [1] "checkingrs55818311 ABHD17A meta5"
# [1] "checkingrs55818311 ADAMTSL5 meta5"
# [1] "checkingrs55818311 AMH meta5"
# [1] "checkingrs55818311 AP3D1 meta5"
# [1] "checkingrs55818311 APC2 meta5"
# [1] "checkingrs55818311 BTBD2 meta5"
# [1] "checkingrs55818311 C19orf25 meta5"
# [1] "checkingrs55818311 CELF5 meta5"
# [1] "checkingrs55818311 CSNK1G2 meta5"
# [1] "checkingrs55818311 DAZAP1 meta5"
# [1] "checkingrs55818311 DIRAS1 meta5"
# [1] "checkingrs55818311 DOT1L meta5"
# [1] "checkingrs55818311 GADD45B meta5"
# [1] "checkingrs55818311 GNA11 meta5"
# [1] "checkingrs55818311 GNA15 meta5"
# [1] "checkingrs55818311 GNG7 meta5"
# [1] "checkingrs55818311 IZUMO4 meta5"
# [1] "checkingrs55818311 KLF16 meta5"
# [1] "checkingrs55818311 LINGO3 meta5"
# [1] "checkingrs55818311 MEX3D meta5"
# [1] "checkingrs55818311 MKNK2 meta5"
# [1] "checkingrs55818311 MOB3A meta5"
# [1] "checkingrs55818311 NCLN meta5"
# [1] "checkingrs55818311 NDUFS7 meta5"
# [1] "checkingrs55818311 OAZ1 meta5"
# [1] "checkingrs55818311 PCSK4 meta5"
# [1] "checkingrs55818311 PLEKHJ1 meta5"
# [1] "checkingrs55818311 PLK5 meta5"
# [1] "checkingrs55818311 RPS15 meta5"
# [1] "checkingrs55818311 S1PR4 meta5"
# [1] "checkingrs55818311 SCAMP4 meta5"
# [1] "checkingrs55818311 SF3A2 meta5"
# [1] "checkingrs55818311 SGTA meta5"
# [1] "checkingrs55818311 SLC39A3 meta5"
# [1] "checkingrs55818311 THOP1 meta5"
# [1] "checkingrs55818311 TLE2 meta5"
# [1] "checkingrs55818311 ZNF554 meta5"
# [1] "checkingrs55818311 ZNF555 meta5"
# [1] "checkingrs55818311 ZNF556 meta5"
# [1] "checkingrs55818311 ZNF57 meta5"
# [1] "checkingrs55818311 ZNF77 meta5"
# [1] "checkingrs77351827 BMP2 meta5"
# [1] "checkingrs77351827 CDS2 meta5"
# [1] "checkingrs77351827 CHGB meta5"
# [1] "checkingrs77351827 CRLS1 meta5"
# [1] "checkingrs77351827 FERMT1 meta5"
# [1] "checkingrs77351827 GPCPD1 meta5"
# [1] "checkingrs77351827 LINC00654 meta5"
# [1] "checkingrs77351827 LINC00658 meta5"
# [1] "checkingrs77351827 LRRN4 meta5"
# [1] "checkingrs77351827 MCM8 meta5"
# [1] "checkingrs77351827 PCNA meta5"
# [1] "checkingrs77351827 PROKR2 meta5"
# [1] "checkingrs77351827 TMEM230 meta5"
# [1] "checkingrs77351827 TRMT6 meta5"
# [1] "checkingrs2248244 CLDN14 meta5"
# [1] "checkingrs2248244 DYRK1A meta5"
# [1] "checkingrs2248244 ERG meta5"
# [1] "checkingrs2248244 HLCS meta5"
# [1] "checkingrs2248244 KCNJ6 meta5"
# [1] "checkingrs2248244 LINC01423 meta5"
# [1] "checkingrs2248244 PIGP meta5"
# [1] "checkingrs2248244 TTC3 meta5"
# [1] "checkingrs2248244 TTC3-AS1 meta5"
# [1] "checkingrs2042477 ANKRD20A8P meta5"
# [1] "checkingrs2042477 ANKRD36C meta5"
# [1] "checkingrs2042477 ASTL meta5"
# [1] "checkingrs2042477 CIAO1 meta5"
# [1] "checkingrs2042477 DUSP2 meta5"
# [1] "checkingrs2042477 FAHD2A meta5"
# [1] "checkingrs2042477 FAHD2CP meta5"
# [1] "checkingrs2042477 GPAT2 meta5"
# [1] "checkingrs2042477 ITPRIPL1 meta5"
# [1] "checkingrs2042477 MRPS5 meta5"
# [1] "checkingrs2042477 PROM2 meta5"
# [1] "checkingrs2042477 SNRNP200 meta5"
# [1] "checkingrs2042477 STARD7 meta5"
# [1] "checkingrs2042477 TEKT4 meta5"
# [1] "checkingrs2042477 TMEM127 meta5"
# [1] "checkingrs2042477 ZNF514 meta5"
# [1] "checkingrs11683001 CNOT11 meta5"
# [1] "checkingrs11683001 CREG2 meta5"
# [1] "checkingrs11683001 IL18R1 meta5"
# [1] "checkingrs11683001 IL1R1 meta5"
# [1] "checkingrs11683001 IL1RL1 meta5"
# [1] "checkingrs11683001 IL1RL2 meta5"
# [1] "checkingrs11683001 MAP4K4 meta5"
# [1] "checkingrs11683001 MFSD9 meta5"
# [1] "checkingrs11683001 NPAS2 meta5"
# [1] "checkingrs11683001 RFX8 meta5"
# [1] "checkingrs11683001 RNF149 meta5"
# [1] "checkingrs11683001 RPL31 meta5"
# [1] "checkingrs11683001 SLC9A2 meta5"
# [1] "checkingrs11683001 SNORD89 meta5"
# [1] "checkingrs11683001 TBC1D8 meta5"
# [1] "checkingrs61863020 ADRA2A prog1"
# [1] "checkingrs61863020 BBIP1 prog1"
# [1] "checkingrs61863020 DUSP5 prog1"
# [1] "checkingrs61863020 GPAM prog1"
# [1] "checkingrs61863020 MXI1 prog1"
# [1] "checkingrs61863020 PDCD4 prog1"
# [1] "checkingrs61863020 PDCD4-AS1 prog1"
# [1] "checkingrs61863020 RBM20 prog1"
# [1] "checkingrs382940 ABCA1 prog2"
# [1] "checkingrs382940 FKTN prog2"
# [1] "checkingrs382940 FSD1L prog2"
# [1] "checkingrs382940 NIPSNAP3A prog2"
# [1] "checkingrs382940 OR13C3 prog2"
# [1] "checkingrs382940 OR13C4 prog2"
# [1] "checkingrs382940 OR13C8 prog2"
# [1] "checkingrs382940 OR13C9 prog2"
# [1] "checkingrs382940 OR13D1 prog2"
# [1] "checkingrs382940 OR13F1 prog2"
# [1] "checkingrs382940 RALGAPA1P1 prog2"
# [1] "checkingrs382940 SLC44A1 prog2"
# [1] "checkingrs382940 TAL2 prog2"
# [1] "checkingrs382940 TMEM38B prog2"

# %%
dim(plots_with_proxy_snp)
head(plots_with_proxy_snp)

write.csv(plots_with_proxy_snp,file="$PATH1/qtl/psychencode/eqtl_plots_with_proxy_snp.csv",row.names=F,col.names=F)
# Out:
#   File "<ipython-input-4-bf1e393aabc5>", line 4
#     write.csv(plots_with_proxy_snp,file="$PATH1/qtl/psychencode/eqtl_plots_with_proxy_snp.csv",row.names=F,col.names=F)
#                                                                                               ^
# SyntaxError: keyword can't be an expression

# %%
dim(plots_with_no_proxy_snp)
head(plots_with_no_proxy_snp)

write.csv(plots_with_no_proxy_snp,file="$PATH1/qtl/psychencode/eqtl_plots_with_no_proxy_snp.csv",row.names=F,col.names=F)
# Out:
#   File "<ipython-input-5-dd25b2e57a30>", line 4
#     write.csv(plots_with_no_proxy_snp,file="$PATH1/qtl/psychencode/eqtl_plots_with_no_proxy_snp.csv",row.names=F,col.names=F)
#                                                                                                     ^
# SyntaxError: keyword can't be an expression

# %% [markdown]
# make the final plot list file

# %%
plots_with_risk_snp <- fread("$PATH1/qtl/psychencode/eqtl_plots_with_risk_snp.csv")
plots_with_risk_snp$'num_snps' <- NA

plots_to_plot <- rbind(plots_with_risk_snp, plots_with_proxy_snp)


write.csv(plots_to_plot,file="$PATH1/qtl/psychencode/eqtl_plots_to_plot.csv",row.names=F,col.names=F)
# Out:
#   File "<ipython-input-6-813f38dd4050>", line 2
#     plots_with_risk_snp$'num_snps' <- NA
#                        ^
# SyntaxError: invalid syntax

# %% [markdown]
# finally summary table for all the plots

# %%
plots_to_plot <- plots_to_plot[, -c('num_snps')]
plots_with_no_proxy_snp <- plots_with_no_proxy_snp[, -c('num_snps')]

final_summary <- rbind(plots_to_plot,plots_with_no_proxy_snp, plots_with_no_data)
dim(final_summary)
head(final_summary)
write.csv(final_summary,file="$PATH1/qtl/psychencode/eqtl_plots_final_overview.csv",row.names=F,col.names=F)
# Out:
#   File "<ipython-input-7-a9293f8124ec>", line 1
#     plots_to_plot <- plots_to_plot[, -c('num_snps')]
#                                    ^
# SyntaxError: invalid syntax
