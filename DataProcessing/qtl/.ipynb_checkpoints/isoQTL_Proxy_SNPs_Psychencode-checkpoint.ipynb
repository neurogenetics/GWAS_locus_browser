# %% [markdown]
# # Generate QTL Plot Lead SNP Information for Psychencode isoQTL Data
# - **Author(s)** - Frank Grenn
# - **Date Started** - March 2020
# - **Quick Description:** Create a list of all the qtl plots we want to generate and get proxy snps for each plot that doesn't have the risk snp available in the data
# - **Data:**

# %%
library(data.table)
library(dplyr)
# Out:
# Attaching package: 'dplyr'
#
#
# The following objects are masked from 'package:data.table':
#
#     between, first, last
#
#
# The following objects are masked from 'package:stats':
#
#     filter, lag
#
#
# The following objects are masked from 'package:base':
#
#     intersect, setdiff, setequal, union

# %%
#location of the plot data tsvs created previously
isoqtl_tsv_dir <- "$PATH1/qtl/psychencode/isoqtl_tsv"

# %%
gwas_folders <- list.files(isoqtl_tsv_dir)
gwas_folders
# Out:
# [1] "meta5" "prog1" "prog2"

# %% [markdown]
# ## (1) Create a Dataframe Containing Information for all the Plots
#
# we want a plot for each gene, each feature on each locus

# %%
#read the isoqtl_tsv directories and its contents to parse the filenames for gene and transcript info

file_df <- NULL
for (gwas in gwas_folders)
{
    gwas_files <- list.files(paste0(isoqtl_tsv_dir,"/",gwas))
    for(file in gwas_files)
    {
 
        row <- NULL
        if(grepl("gwas", file, fixed=TRUE))
        {

            split <- strsplit(file,split="_",fixed=T)

            row <- data.frame("gene"=split[[1]][1],"transcript"=split[[1]][2])

            file_df <- rbind(file_df, row)
        }
    }
}
print(dim(file_df))
print(head(file_df))
# Out:
# [1] 731   2
#     gene      transcript
# 1  ABCC5 ENST00000443497
# 2  ACAD8 ENST00000524502
# 3  ACAD8 ENST00000526026
# 4  ACAD8 ENST00000531338
# 5  ACAD8 ENST00000534240
# 6 ACADVL ENST00000322910

# %%
evidence <- fread("$PATH1/genes_by_locus.csv")
meta5_data <- fread("$PATH1/GWAS_loci_overview.csv")
meta5_data <- meta5_data %>% select("Locus Number", "SNP", "CHR")
prog_data <- fread("$PATH1/ProgressionLoci.csv")
prog_data <- prog_data %>% select("Locus Number", "RSID", "CHR")
colnames(prog_data) <- c("Locus Number", "SNP","CHR")

# %%
#combine all the rsids to one df
variant_data <- rbind(meta5_data, prog_data)
print(head(variant_data))
# Out:
#    Locus Number         SNP CHR
# 1:            1 rs114138760   1
# 2:            1  rs35749011   1
# 3:            1  rs76763715   1
# 4:            2   rs6658353   1
# 5:            3  rs11578699   1
# 6:            4    rs823118   1

# %%
#merge the evidence df with the variant df
#this is done to account for loci with multiple snps (ex: locus 1 has three risk variants, so we should try to create three plots for each gene on that locus)
plot_df <- merge(x=evidence, y=variant_data, by.x = "Locusnumber", by.y = "Locus Number", all.x = TRUE, allow.cartesian = TRUE)
print(head(plot_df))
# Out:
#    Locusnumber   Gene         SNP CHR
# 1:           1 ADAM15 rs114138760   1
# 2:           1 ADAM15  rs35749011   1
# 3:           1 ADAM15  rs76763715   1
# 4:           1   ADAR rs114138760   1
# 5:           1   ADAR  rs35749011   1
# 6:           1   ADAR  rs76763715   1

# %%
plot_df_transcript <- merge(x = file_df, y = plot_df, by.x = "gene", by.y = "Gene", all.x = TRUE, allow.cartesian = TRUE)
print(dim(plot_df_transcript))
print(head(plot_df_transcript))
print(tail(plot_df_transcript))
# Out:
# [1] 952   5
#     gene      transcript Locusnumber        SNP CHR
# 1  ABCC5 ENST00000443497          18 rs10513789   3
# 2  ACAD8 ENST00000524502          48  rs3802920  11
# 3  ACAD8 ENST00000526026          48  rs3802920  11
# 4  ACAD8 ENST00000531338          48  rs3802920  11
# 5  ACAD8 ENST00000534240          48  rs3802920  11
# 6 ACADVL ENST00000322910          66 rs12600861  17
#       gene      transcript Locusnumber        SNP CHR
# 947 ZNF721 ENST00000338977          19 rs34311866   4
# 948 ZNF721 ENST00000338977          19   rs873786   4
# 949  ZNF84 ENST00000441040          52 rs11610045  12
# 950  ZNF84 ENST00000536123          52 rs11610045  12
# 951  ZNF84 ENST00000542358          52 rs11610045  12
# 952  ZNF84 ENST00000543758          52 rs11610045  12

# %%
plot_df_transcript$'feature' <- 'isoqtl'

meta5_plots <- plot_df_transcript[which(plot_df_transcript$Locusnumber!="prog1" & plot_df_transcript$Locusnumber!="prog2"),]
meta5_plots$'gwas' <- 'meta5'

prog1_plots <- plot_df_transcript[which(plot_df_transcript$Locusnumber=="prog1"),]
prog1_plots$'gwas' <- 'prog1'

prog2_plots <- plot_df_transcript[which(plot_df_transcript$Locusnumber=="prog2"),]
prog2_plots$'gwas' <- 'prog2'

# %%
plot_df_transcript <- rbind(meta5_plots,prog1_plots,prog2_plots)
plot_df_transcript <- plot_df_transcript[with(plot_df_transcript, order(Locusnumber, gene, SNP)),]

#temp values for the manually assigned lead snp (because some/many likely won't have data for the actual lead snp in the 'SNP' col of this dataframe)
plot_df_transcript$'forced_lead_variant' <- "NA"
plot_df_transcript$'forced_lead_variant_r2' <- 0
plot_df_transcript$'reason' <- "NA"

# %%
dim(plot_df_transcript)
head(plot_df_transcript)
tail(plot_df_transcript)
# Out:
# [1] 952  10
#    gene transcript      Locusnumber SNP         CHR feature gwas
# 16 ADAR ENST00000368471 1           rs114138760 1   isoqtl  meta5
# 19 ADAR ENST00000463920 1           rs114138760 1   isoqtl  meta5
# 22 ADAR ENST00000529168 1           rs114138760 1   isoqtl  meta5
# 17 ADAR ENST00000368471 1           rs35749011  1   isoqtl  meta5
# 20 ADAR ENST00000463920 1           rs35749011  1   isoqtl  meta5
# 23 ADAR ENST00000529168 1           rs35749011  1   isoqtl  meta5
#    forced_lead_variant forced_lead_variant_r2 reason
# 16 NA                  0                      NA
# 19 NA                  0                      NA
# 22 NA                  0                      NA
# 17 NA                  0                      NA
# 20 NA                  0                      NA
# 23 NA                  0                      NA
#     gene      transcript      Locusnumber SNP        CHR feature gwas
# 754 SHOC2     ENST00000480155 prog1       rs61863020 10  isoqtl  prog1
# 572 NIPSNAP3A ENST00000374767 prog2       rs382940    9  isoqtl  prog2
# 573 NIPSNAP3A ENST00000471001 prog2       rs382940    9  isoqtl  prog2
# 760 SLC44A1   ENST00000374720 prog2       rs382940    9  isoqtl  prog2
# 761 SLC44A1   ENST00000374724 prog2       rs382940    9  isoqtl  prog2
# 762 SLC44A1   ENST00000436716 prog2       rs382940    9  isoqtl  prog2
#     forced_lead_variant forced_lead_variant_r2 reason
# 754 NA                  0                      NA
# 572 NA                  0                      NA
# 573 NA                  0                      NA
# 760 NA                  0                      NA
# 761 NA                  0                      NA
# 762 NA                  0                      NA

# %% [markdown]
# ## (2) Filter the plot_df
#
# `plots_with_risk_snp` will contain the plots that contain the risk snp in the data. So we should have no issue plotting these
# `plots_with_no_data` will contain plots that have no snps in their tsvs to plot. So we won't plot these
# `plots_to_check` will contain plots that don't have the risk snp but do have data. So we will need to find a proxy snp for these to determine if we can plot them or not

# %%
plots_with_risk_snp <- data.frame()
plots_with_no_data <- data.frame()
plots_to_check <- data.frame()

# %% [markdown]
# do the filtering

# %%
for (rownum in 1:nrow(plot_df_transcript))
{

  print(rownum)
  

  
  row <- plot_df_transcript[rownum,]
  
  chr <- row$CHR
  snp <- row$SNP
  gene <- row$gene
  transcript <- row$transcript
  feature <- row$feature
  gwas <- row$gwas

  print(paste0("checking", snp, " " , gene, " ", gwas))
    
      
  if(gwas == "meta5")
  {
      tsv_dir <- paste0(isoqtl_tsv_dir,"/meta5")

  }
  if(gwas == "prog1")
  {
      tsv_dir <- paste0(isoqtl_tsv_dir,"/prog1")

  }
  if(gwas == "prog2")
  {
      tsv_dir <- paste0(isoqtl_tsv_dir,"/prog2")

  }
  gwas_fn = paste0(tsv_dir, '/', gene, '_', transcript, '_gwas.tsv')
  qtl_fn = paste0(tsv_dir, '/', gene, '_', transcript,'_isoqtl.tsv')
  
  #check if the files actually exist
  if(file.exists(gwas_fn) && file.exists(qtl_fn))
  {
    print("files exist")
    #read the tsv files
    g = read.table(gwas_fn, header = T)
    e = read.table(qtl_fn, header = T)
    
    #if they both aren't empty 
    if(nrow(g)!=0 && nrow(e)!=0)
    {
      
      #merge them by rsid
      df = merge(g, e, by = 'rsid')
      print("df:")
      print(head(df))
      #check if the risk variant is already in the data. If so, then we are fine
      if(row$SNP %in% df$rsid)
      {
        print("we have the risk snp!!!")
        row$'forced_lead_variant' <- row$SNP
        row$'forced_lead_variant_r2' <- 1
        row$'reason' <- "has risk variant"
        plots_with_risk_snp<-rbind(plots_with_risk_snp,row)
        
      }
      #if we don't have the risk variant then put the row in the plot_to_check df to check later
      else
      {
        tmp <- row
        tmp$num_snps <- nrow(df)
        plots_to_check<-rbind(plots_to_check,tmp)
        
      }
      

      

    }
    #if they are empty then put in the no data df
    else
    {
      row$'reason' <- "no data for plot"
      plots_with_no_data<-rbind(plots_with_no_data,row)
    }
  }
  #if the files don't even exist then put in the no data df
  else
  {
      row$'reason' <- "no data for plot"
      plots_with_no_data<-rbind(plots_with_no_data,row)
  }
  plot_df_transcript[rownum,] <- row

}
# Out:
# [1] 1
# [1] "checkingrs114138760 ADAR meta5"
# [1] "files exist"
# [1] "df:"
#         rsid        var_id.x  pval.x        var_id.y      pval.y
# 1 rs11264228 1:154598437:A:G 0.02882 1:154598437:A:G 8.64327e-07
# 2 rs12117101 1:154578391:T:C 0.04316 1:154578391:T:C 3.18150e-07
# 3 rs12128435 1:154579634:C:G 0.04366 1:154579634:C:G 5.00353e-07
# 4 rs12141385 1:154565582:G:C 0.05439 1:154565582:G:C 1.32127e-07
# 5 rs34126801 1:154586012:C:T 0.03063 1:154586012:C:T 9.89123e-07
# 6 rs36121466 1:154589648:C:A 0.03225 1:154589648:C:A 1.08303e-06
# [1] 2
# [1] "checkingrs114138760 ADAR meta5"
# [1] "files exist"
# [1] "df:"
#         rsid        var_id.x  pval.x        var_id.y      pval.y
# 1 rs11264228 1:154598437:A:G 0.02882 1:154598437:A:G 1.09999e-09
# 2 rs11264229 1:154602588:C:A 0.02792 1:154602588:C:A 1.83146e-09
# 3 rs12117101 1:154578391:T:C 0.04316 1:154578391:T:C 8.10022e-10
# 4 rs12128435 1:154579634:C:G 0.04366 1:154579634:C:G 9.75936e-10
# 5 rs12139887 1:154573139:A:C 0.70840 1:154573139:A:C 2.34981e-07
# 6 rs12141385 1:154565582:G:C 0.05439 1:154565582:G:C 1.23162e-09
# [1] 3
# [1] "checkingrs114138760 ADAR meta5"
# [1] "files exist"
# [1] "df:"
#          rsid        var_id.x  pval.x        var_id.y      pval.y
# 1 rs112095222 1:154627851:C:T 0.02078 1:154627851:C:T 1.16736e-06
# 2 rs115800464 1:154569895:G:C 0.01024 1:154569895:G:C 6.05209e-08
# 3  rs12117101 1:154578391:T:C 0.04316 1:154578391:T:C 3.45154e-06
# 4  rs12128435 1:154579634:C:G 0.04366 1:154579634:C:G 3.88185e-06
# 5  rs34126801 1:154586012:C:T 0.03063 1:154586012:C:T 3.84773e-06
# 6  rs61300392 1:154575685:A:T 0.00926 1:154575685:A:T 3.92010e-07
# [1] 4
# [1] "checkingrs35749011 ADAR meta5"
# [1] "files exist"
# [1] "df:"
#         rsid        var_id.x  pval.x        var_id.y      pval.y
# 1 rs11264228 1:154598437:A:G 0.02882 1:154598437:A:G 8.64327e-07
# 2 rs12117101 1:154578391:T:C 0.04316 1:154578391:T:C 3.18150e-07
# 3 rs12128435 1:154579634:C:G 0.04366 1:154579634:C:G 5.00353e-07
# 4 rs12141385 1:154565582:G:C 0.05439 1:154565582:G:C 1.32127e-07
# 5 rs34126801 1:154586012:C:T 0.03063 1:154586012:C:T 9.89123e-07
# 6 rs36121466 1:154589648:C:A 0.03225 1:154589648:C:A 1.08303e-06
# [1] 5
# [1] "checkingrs35749011 ADAR meta5"
# [1] "files exist"
# [1] "df:"
#         rsid        var_id.x  pval.x        var_id.y      pval.y
# 1 rs11264228 1:154598437:A:G 0.02882 1:154598437:A:G 1.09999e-09
# 2 rs11264229 1:154602588:C:A 0.02792 1:154602588:C:A 1.83146e-09
# 3 rs12117101 1:154578391:T:C 0.04316 1:154578391:T:C 8.10022e-10
# 4 rs12128435 1:154579634:C:G 0.04366 1:154579634:C:G 9.75936e-10
# 5 rs12139887 1:154573139:A:C 0.70840 1:154573139:A:C 2.34981e-07
# 6 rs12141385 1:154565582:G:C 0.05439 1:154565582:G:C 1.23162e-09
# [1] 6
# [1] "checkingrs35749011 ADAR meta5"
# [1] "files exist"
# [1] "df:"
#          rsid        var_id.x  pval.x        var_id.y      pval.y
# 1 rs112095222 1:154627851:C:T 0.02078 1:154627851:C:T 1.16736e-06
# 2 rs115800464 1:154569895:G:C 0.01024 1:154569895:G:C 6.05209e-08
# 3  rs12117101 1:154578391:T:C 0.04316 1:154578391:T:C 3.45154e-06
# 4  rs12128435 1:154579634:C:G 0.04366 1:154579634:C:G 3.88185e-06
# 5  rs34126801 1:154586012:C:T 0.03063 1:154586012:C:T 3.84773e-06
# 6  rs61300392 1:154575685:A:T 0.00926 1:154575685:A:T 3.92010e-07
# [1] 7
# [1] "checkingrs76763715 ADAR meta5"
# [1] "files exist"
# [1] "df:"
#         rsid        var_id.x  pval.x        var_id.y      pval.y
# 1 rs11264228 1:154598437:A:G 0.02882 1:154598437:A:G 8.64327e-07
# 2 rs12117101 1:154578391:T:C 0.04316 1:154578391:T:C 3.18150e-07
# 3 rs12128435 1:154579634:C:G 0.04366 1:154579634:C:G 5.00353e-07
# 4 rs12141385 1:154565582:G:C 0.05439 1:154565582:G:C 1.32127e-07
# 5 rs34126801 1:154586012:C:T 0.03063 1:154586012:C:T 9.89123e-07
# 6 rs36121466 1:154589648:C:A 0.03225 1:154589648:C:A 1.08303e-06
# [1] 8
# [1] "checkingrs76763715 ADAR meta5"
# [1] "files exist"
# [1] "df:"
#         rsid        var_id.x  pval.x        var_id.y      pval.y
# 1 rs11264228 1:154598437:A:G 0.02882 1:154598437:A:G 1.09999e-09
# 2 rs11264229 1:154602588:C:A 0.02792 1:154602588:C:A 1.83146e-09
# 3 rs12117101 1:154578391:T:C 0.04316 1:154578391:T:C 8.10022e-10
# 4 rs12128435 1:154579634:C:G 0.04366 1:154579634:C:G 9.75936e-10
# 5 rs12139887 1:154573139:A:C 0.70840 1:154573139:A:C 2.34981e-07
# 6 rs12141385 1:154565582:G:C 0.05439 1:154565582:G:C 1.23162e-09
# [1] 9
# [1] "checkingrs76763715 ADAR meta5"
# [1] "files exist"
# [1] "df:"
#          rsid        var_id.x  pval.x        var_id.y      pval.y
# 1 rs112095222 1:154627851:C:T 0.02078 1:154627851:C:T 1.16736e-06
# 2 rs115800464 1:154569895:G:C 0.01024 1:154569895:G:C 6.05209e-08
# 3  rs12117101 1:154578391:T:C 0.04316 1:154578391:T:C 3.45154e-06
# 4  rs12128435 1:154579634:C:G 0.04366 1:154579634:C:G 3.88185e-06
# 5  rs34126801 1:154586012:C:T 0.03063 1:154586012:C:T 3.84773e-06
# 6  rs61300392 1:154575685:A:T 0.00926 1:154575685:A:T 3.92010e-07
# [1] 10
# [1] "checkingrs114138760 ARHGEF2 meta5"
# [1] "files exist"
# [1] "df:"
#          rsid        var_id.x pval.x        var_id.y      pval.y
# 1 rs148134069 1:155962510:C:T 0.8314 1:155962510:C:T 3.76735e-06
# [1] 11
# [1] "checkingrs35749011 ARHGEF2 meta5"
# [1] "files exist"
# [1] "df:"
#          rsid        var_id.x pval.x        var_id.y      pval.y
# 1 rs148134069 1:155962510:C:T 0.8314 1:155962510:C:T 3.76735e-06
# [1] 12
# [1] "checkingrs76763715 ARHGEF2 meta5"
# [1] "files exist"
# [1] "df:"
#          rsid        var_id.x pval.x        var_id.y      pval.y
# 1 rs148134069 1:155962510:C:T 0.8314 1:155962510:C:T 3.76735e-06
# [1] 13
# [1] "checkingrs114138760 C1orf43 meta5"
# [1] "files exist"
# [1] "df:"
#         rsid        var_id.x   pval.x        var_id.y      pval.y
# 1  rs1051370 1:154129265:A:G 0.030470 1:154129265:A:G 3.13262e-08
# 2 rs10796956 1:153795569:T:C 0.004640 1:153795569:T:C 1.96368e-06
# 3 rs10796968 1:153899330:A:C 0.007473 1:153899330:A:C 1.19916e-06
# 4 rs10796986 1:153987412:G:A 0.017580 1:153987412:G:A 5.80692e-08
# 5 rs10797067 1:154237638:G:T 0.133800 1:154237638:G:T 1.56489e-07
# 6 rs10908691 1:154062342:C:T 0.048000 1:154062342:C:T 9.36956e-09
# [1] 14
# [1] "checkingrs114138760 C1orf43 meta5"
# [1] "files exist"
# [1] "df:"
#         rsid        var_id.x pval.x        var_id.y      pval.y
# 1 rs11265353 1:154211215:C:A 0.8699 1:154211215:C:A 2.12518e-06
# [1] 15
# [1] "checkingrs114138760 C1orf43 meta5"
# [1] "files exist"
# [1] "df:"
#         rsid        var_id.x   pval.x        var_id.y      pval.y
# 1 rs10158820 1:154217763:C:T 0.027050 1:154217763:C:T 3.40380e-24
# 2  rs1051370 1:154129265:A:G 0.030470 1:154129265:A:G 1.90712e-19
# 3 rs10796956 1:153795569:T:C 0.004640 1:153795569:T:C 2.38164e-14
# 4 rs10796968 1:153899330:A:C 0.007473 1:153899330:A:C 1.04814e-14
# 5 rs10796986 1:153987412:G:A 0.017580 1:153987412:G:A 2.30494e-17
# 6 rs10797047 1:154149240:G:A 0.011420 1:154149240:G:A 3.11830e-16
# [1] 16
# [1] "checkingrs114138760 C1orf43 meta5"
# [1] "files exist"
# [1] "df:"
#         rsid        var_id.x  pval.x        var_id.y      pval.y
# 1 rs10158820 1:154217763:C:T 0.02705 1:154217763:C:T 9.60876e-09
# 2 rs10796986 1:153987412:G:A 0.01758 1:153987412:G:A 2.65424e-06
# 3 rs10797047 1:154149240:G:A 0.01142 1:154149240:G:A 3.84190e-06
# 4 rs10797058 1:154200704:T:C 0.76170 1:154200704:T:C 2.96316e-06
# 5 rs10908691 1:154062342:C:T 0.04800 1:154062342:C:T 2.83278e-06
# 6 rs11264734 1:153937746:T:C 0.01351 1:153937746:T:C 3.36818e-06
# [1] 17
# [1] "checkingrs35749011 C1orf43 meta5"
# [1] "files exist"
# [1] "df:"
#         rsid        var_id.x   pval.x        var_id.y      pval.y
# 1  rs1051370 1:154129265:A:G 0.030470 1:154129265:A:G 3.13262e-08
# 2 rs10796956 1:153795569:T:C 0.004640 1:153795569:T:C 1.96368e-06
# 3 rs10796968 1:153899330:A:C 0.007473 1:153899330:A:C 1.19916e-06
# 4 rs10796986 1:153987412:G:A 0.017580 1:153987412:G:A 5.80692e-08
# 5 rs10797067 1:154237638:G:T 0.133800 1:154237638:G:T 1.56489e-07
# 6 rs10908691 1:154062342:C:T 0.048000 1:154062342:C:T 9.36956e-09
# [1] 18
# [1] "checkingrs35749011 C1orf43 meta5"
# [1] "files exist"
# [1] "df:"
#         rsid        var_id.x pval.x        var_id.y      pval.y
# 1 rs11265353 1:154211215:C:A 0.8699 1:154211215:C:A 2.12518e-06
# [1] 19
# [1] "checkingrs35749011 C1orf43 meta5"
# [1] "files exist"
# [1] "df:"
#         rsid        var_id.x   pval.x        var_id.y      pval.y
# 1 rs10158820 1:154217763:C:T 0.027050 1:154217763:C:T 3.40380e-24
# 2  rs1051370 1:154129265:A:G 0.030470 1:154129265:A:G 1.90712e-19
# 3 rs10796956 1:153795569:T:C 0.004640 1:153795569:T:C 2.38164e-14
# 4 rs10796968 1:153899330:A:C 0.007473 1:153899330:A:C 1.04814e-14
# 5 rs10796986 1:153987412:G:A 0.017580 1:153987412:G:A 2.30494e-17
# 6 rs10797047 1:154149240:G:A 0.011420 1:154149240:G:A 3.11830e-16
# [1] 20
# [1] "checkingrs35749011 C1orf43 meta5"
# [1] "files exist"
# [1] "df:"
#         rsid        var_id.x  pval.x        var_id.y      pval.y
# 1 rs10158820 1:154217763:C:T 0.02705 1:154217763:C:T 9.60876e-09
# 2 rs10796986 1:153987412:G:A 0.01758 1:153987412:G:A 2.65424e-06
# 3 rs10797047 1:154149240:G:A 0.01142 1:154149240:G:A 3.84190e-06
# 4 rs10797058 1:154200704:T:C 0.76170 1:154200704:T:C 2.96316e-06
# 5 rs10908691 1:154062342:C:T 0.04800 1:154062342:C:T 2.83278e-06
# 6 rs11264734 1:153937746:T:C 0.01351 1:153937746:T:C 3.36818e-06
# [1] 21
# [1] "checkingrs76763715 C1orf43 meta5"
# [1] "files exist"
# [1] "df:"
#         rsid        var_id.x   pval.x        var_id.y      pval.y
# 1  rs1051370 1:154129265:A:G 0.030470 1:154129265:A:G 3.13262e-08
# 2 rs10796956 1:153795569:T:C 0.004640 1:153795569:T:C 1.96368e-06
# 3 rs10796968 1:153899330:A:C 0.007473 1:153899330:A:C 1.19916e-06
# 4 rs10796986 1:153987412:G:A 0.017580 1:153987412:G:A 5.80692e-08
# 5 rs10797067 1:154237638:G:T 0.133800 1:154237638:G:T 1.56489e-07
# 6 rs10908691 1:154062342:C:T 0.048000 1:154062342:C:T 9.36956e-09
# [1] 22
# [1] "checkingrs76763715 C1orf43 meta5"
# [1] "files exist"
# [1] "df:"
#         rsid        var_id.x pval.x        var_id.y      pval.y
# 1 rs11265353 1:154211215:C:A 0.8699 1:154211215:C:A 2.12518e-06
# [1] 23
# [1] "checkingrs76763715 C1orf43 meta5"
# [1] "files exist"
# [1] "df:"
#         rsid        var_id.x   pval.x        var_id.y      pval.y
# 1 rs10158820 1:154217763:C:T 0.027050 1:154217763:C:T 3.40380e-24
# 2  rs1051370 1:154129265:A:G 0.030470 1:154129265:A:G 1.90712e-19
# 3 rs10796956 1:153795569:T:C 0.004640 1:153795569:T:C 2.38164e-14
# 4 rs10796968 1:153899330:A:C 0.007473 1:153899330:A:C 1.04814e-14
# 5 rs10796986 1:153987412:G:A 0.017580 1:153987412:G:A 2.30494e-17
# 6 rs10797047 1:154149240:G:A 0.011420 1:154149240:G:A 3.11830e-16
# [1] 24
# [1] "checkingrs76763715 C1orf43 meta5"
# [1] "files exist"
# [1] "df:"
#         rsid        var_id.x  pval.x        var_id.y      pval.y
# 1 rs10158820 1:154217763:C:T 0.02705 1:154217763:C:T 9.60876e-09
# 2 rs10796986 1:153987412:G:A 0.01758 1:153987412:G:A 2.65424e-06
# 3 rs10797047 1:154149240:G:A 0.01142 1:154149240:G:A 3.84190e-06
# 4 rs10797058 1:154200704:T:C 0.76170 1:154200704:T:C 2.96316e-06
# 5 rs10908691 1:154062342:C:T 0.04800 1:154062342:C:T 2.83278e-06
# 6 rs11264734 1:153937746:T:C 0.01351 1:153937746:T:C 3.36818e-06
# [1] 25
# [1] "checkingrs114138760 DAP3 meta5"
# [1] "files exist"
# [1] "df:"
#         rsid        var_id.x  pval.x        var_id.y      pval.y
# 1 rs10796941 1:155284261:C:T 0.79020 1:155284261:C:T 4.53662e-08
# 2 rs10796944 1:155416328:G:A 0.22990 1:155416328:G:A 1.81724e-07
# 3 rs10796946 1:155429490:A:T 0.60480 1:155429490:A:T 1.64184e-08
# 4 rs10796947 1:155477053:A:G 0.61040 1:155477053:A:G 2.89907e-08
# 5 rs10796954 1:155794478:T:C 0.08331 1:155794478:T:C 1.62102e-08
# 6 rs10908461 1:155275727:C:T 0.81970 1:155275727:C:T 3.21537e-07
# [1] 26
# [1] "checkingrs114138760 DAP3 meta5"
# [1] "files exist"
# [1] "df:"
#          rsid        var_id.x pval.x        var_id.y      pval.y
# 1  rs10908479 1:155643403:C:T 0.2999 1:155643403:C:T 7.51881e-07
# 2  rs10908480 1:155699762:T:G 0.1466 1:155699762:T:G 5.37344e-07
# 3 rs111324936 1:155796306:G:A 0.9969 1:155796306:G:A 3.69478e-08
# 4 rs111461849 1:155760721:G:A 0.9907 1:155760721:G:A 2.96637e-08
# 5 rs111667027 1:155732270:G:A 0.9308 1:155732270:G:A 2.63979e-06
# 6 rs111738962 1:155818737:G:A 0.4806 1:155818737:G:A 3.35503e-08
# [1] 27
# [1] "checkingrs35749011 DAP3 meta5"
# [1] "files exist"
# [1] "df:"
#         rsid        var_id.x  pval.x        var_id.y      pval.y
# 1 rs10796941 1:155284261:C:T 0.79020 1:155284261:C:T 4.53662e-08
# 2 rs10796944 1:155416328:G:A 0.22990 1:155416328:G:A 1.81724e-07
# 3 rs10796946 1:155429490:A:T 0.60480 1:155429490:A:T 1.64184e-08
# 4 rs10796947 1:155477053:A:G 0.61040 1:155477053:A:G 2.89907e-08
# 5 rs10796954 1:155794478:T:C 0.08331 1:155794478:T:C 1.62102e-08
# 6 rs10908461 1:155275727:C:T 0.81970 1:155275727:C:T 3.21537e-07
# [1] 28
# [1] "checkingrs35749011 DAP3 meta5"
# [1] "files exist"
# [1] "df:"
#          rsid        var_id.x pval.x        var_id.y      pval.y
# 1  rs10908479 1:155643403:C:T 0.2999 1:155643403:C:T 7.51881e-07
# 2  rs10908480 1:155699762:T:G 0.1466 1:155699762:T:G 5.37344e-07
# 3 rs111324936 1:155796306:G:A 0.9969 1:155796306:G:A 3.69478e-08
# 4 rs111461849 1:155760721:G:A 0.9907 1:155760721:G:A 2.96637e-08
# 5 rs111667027 1:155732270:G:A 0.9308 1:155732270:G:A 2.63979e-06
# 6 rs111738962 1:155818737:G:A 0.4806 1:155818737:G:A 3.35503e-08
# [1] 29
# [1] "checkingrs76763715 DAP3 meta5"
# [1] "files exist"
# [1] "df:"
#         rsid        var_id.x  pval.x        var_id.y      pval.y
# 1 rs10796941 1:155284261:C:T 0.79020 1:155284261:C:T 4.53662e-08
# 2 rs10796944 1:155416328:G:A 0.22990 1:155416328:G:A 1.81724e-07
# 3 rs10796946 1:155429490:A:T 0.60480 1:155429490:A:T 1.64184e-08
# 4 rs10796947 1:155477053:A:G 0.61040 1:155477053:A:G 2.89907e-08
# 5 rs10796954 1:155794478:T:C 0.08331 1:155794478:T:C 1.62102e-08
# 6 rs10908461 1:155275727:C:T 0.81970 1:155275727:C:T 3.21537e-07
# [1] 30
# [1] "checkingrs76763715 DAP3 meta5"
# [1] "files exist"
# [1] "df:"
#          rsid        var_id.x pval.x        var_id.y      pval.y
# 1  rs10908479 1:155643403:C:T 0.2999 1:155643403:C:T 7.51881e-07
# 2  rs10908480 1:155699762:T:G 0.1466 1:155699762:T:G 5.37344e-07
# 3 rs111324936 1:155796306:G:A 0.9969 1:155796306:G:A 3.69478e-08
# 4 rs111461849 1:155760721:G:A 0.9907 1:155760721:G:A 2.96637e-08
# 5 rs111667027 1:155732270:G:A 0.9308 1:155732270:G:A 2.63979e-06
# 6 rs111738962 1:155818737:G:A 0.4806 1:155818737:G:A 3.35503e-08
# [1] 31
# [1] "checkingrs114138760 FDPS meta5"
# [1] "files exist"
# [1] "df:"
#         rsid        var_id.x pval.x        var_id.y      pval.y
# 1 rs10908462 1:155285854:T:C 0.8476 1:155285854:T:C 1.09282e-06
# 2 rs11264348 1:155229915:G:T 0.6206 1:155229915:G:T 4.02465e-07
# 3 rs11264357 1:155268958:C:T 0.7593 1:155268958:C:T 3.63810e-06
# 4 rs11264358 1:155280164:T:C 0.9280 1:155280164:T:C 2.35880e-06
# 5 rs12067675 1:155268120:T:C 0.9322 1:155268120:T:C 2.76920e-06
# 6 rs12563994 1:155244092:C:T 0.9839 1:155244092:C:T 3.66352e-06
# [1] 32
# [1] "checkingrs114138760 FDPS meta5"
# [1] "files exist"
# [1] "df:"
#         rsid        var_id.x pval.x        var_id.y      pval.y
# 1 rs10796941 1:155284261:C:T 0.7902 1:155284261:C:T 1.16901e-10
# 2 rs10796946 1:155429490:A:T 0.6048 1:155429490:A:T 5.45467e-08
# 3 rs10908461 1:155275727:C:T 0.8197 1:155275727:C:T 2.47852e-09
# 4 rs10908462 1:155285854:T:C 0.8476 1:155285854:T:C 1.08041e-06
# 5 rs10908467 1:155439062:T:C 0.6969 1:155439062:T:C 2.76571e-06
# 6 rs10908471 1:155542942:A:G 0.4538 1:155542942:A:G 8.70705e-08
# [1] 33
# [1] "checkingrs114138760 FDPS meta5"
# [1] "files exist"
# [1] "df:"
#         rsid        var_id.x  pval.x        var_id.y      pval.y
# 1 rs10796940 1:155202689:A:C 0.46790 1:155202689:A:C 6.91376e-09
# 2 rs10796941 1:155284261:C:T 0.79020 1:155284261:C:T 2.45664e-15
# 3 rs10796944 1:155416328:G:A 0.22990 1:155416328:G:A 9.48535e-10
# 4 rs10796946 1:155429490:A:T 0.60480 1:155429490:A:T 1.53794e-12
# 5 rs10796947 1:155477053:A:G 0.61040 1:155477053:A:G 2.68553e-07
# 6 rs10796954 1:155794478:T:C 0.08331 1:155794478:T:C 1.47333e-06
# [1] 34
# [1] "checkingrs114138760 FDPS meta5"
# [1] "files exist"
# [1] "df:"
#         rsid        var_id.x    pval.x        var_id.y      pval.y
# 1 rs10796938 1:155072055:C:A 3.829e-08 1:155072055:C:A 1.23266e-08
# 2 rs10796940 1:155202689:A:C 4.679e-01 1:155202689:A:C 7.94361e-16
# 3 rs10796941 1:155284261:C:T 7.902e-01 1:155284261:C:T 9.85859e-30
# 4 rs10796944 1:155416328:G:A 2.299e-01 1:155416328:G:A 1.12868e-17
# 5 rs10796946 1:155429490:A:T 6.048e-01 1:155429490:A:T 1.98088e-23
# 6 rs10796947 1:155477053:A:G 6.104e-01 1:155477053:A:G 8.11592e-13
# [1] 35
# [1] "checkingrs114138760 FDPS meta5"
# [1] "files exist"
# [1] "df:"
#         rsid        var_id.x    pval.x        var_id.y      pval.y
# 1 rs10796938 1:155072055:C:A 3.829e-08 1:155072055:C:A 6.35439e-08
# 2 rs10796939 1:155088795:C:T 1.737e-05 1:155088795:C:T 4.84660e-07
# 3 rs10796940 1:155202689:A:C 4.679e-01 1:155202689:A:C 2.08924e-18
# 4 rs10796941 1:155284261:C:T 7.902e-01 1:155284261:C:T 4.08410e-29
# 5 rs10796944 1:155416328:G:A 2.299e-01 1:155416328:G:A 8.10051e-17
# 6 rs10796946 1:155429490:A:T 6.048e-01 1:155429490:A:T 1.97730e-21
# [1] 36
# [1] "checkingrs114138760 FDPS meta5"
# [1] "files exist"
# [1] "df:"
#         rsid        var_id.x    pval.x        var_id.y      pval.y
# 1 rs10458626 1:155281689:G:A 1.355e-01 1:155281689:G:A 2.59493e-08
# 2 rs10796938 1:155072055:C:A 3.829e-08 1:155072055:C:A 2.31017e-13
# 3 rs10796939 1:155088795:C:T 1.737e-05 1:155088795:C:T 2.08964e-09
# 4 rs10796940 1:155202689:A:C 4.679e-01 1:155202689:A:C 1.96578e-36
# 5 rs10796941 1:155284261:C:T 7.902e-01 1:155284261:C:T 7.63855e-91
# 6 rs10796944 1:155416328:G:A 2.299e-01 1:155416328:G:A 8.59237e-52
# [1] 37
# [1] "checkingrs35749011 FDPS meta5"
# [1] "files exist"
# [1] "df:"
#         rsid        var_id.x pval.x        var_id.y      pval.y
# 1 rs10908462 1:155285854:T:C 0.8476 1:155285854:T:C 1.09282e-06
# 2 rs11264348 1:155229915:G:T 0.6206 1:155229915:G:T 4.02465e-07
# 3 rs11264357 1:155268958:C:T 0.7593 1:155268958:C:T 3.63810e-06
# 4 rs11264358 1:155280164:T:C 0.9280 1:155280164:T:C 2.35880e-06
# 5 rs12067675 1:155268120:T:C 0.9322 1:155268120:T:C 2.76920e-06
# 6 rs12563994 1:155244092:C:T 0.9839 1:155244092:C:T 3.66352e-06
# [1] 38
# [1] "checkingrs35749011 FDPS meta5"
# [1] "files exist"
# [1] "df:"
#         rsid        var_id.x pval.x        var_id.y      pval.y
# 1 rs10796941 1:155284261:C:T 0.7902 1:155284261:C:T 1.16901e-10
# 2 rs10796946 1:155429490:A:T 0.6048 1:155429490:A:T 5.45467e-08
# 3 rs10908461 1:155275727:C:T 0.8197 1:155275727:C:T 2.47852e-09
# 4 rs10908462 1:155285854:T:C 0.8476 1:155285854:T:C 1.08041e-06
# 5 rs10908467 1:155439062:T:C 0.6969 1:155439062:T:C 2.76571e-06
# 6 rs10908471 1:155542942:A:G 0.4538 1:155542942:A:G 8.70705e-08
# [1] 39
# [1] "checkingrs35749011 FDPS meta5"
# [1] "files exist"
# [1] "df:"
#         rsid        var_id.x  pval.x        var_id.y      pval.y
# 1 rs10796940 1:155202689:A:C 0.46790 1:155202689:A:C 6.91376e-09
# 2 rs10796941 1:155284261:C:T 0.79020 1:155284261:C:T 2.45664e-15
# 3 rs10796944 1:155416328:G:A 0.22990 1:155416328:G:A 9.48535e-10
# 4 rs10796946 1:155429490:A:T 0.60480 1:155429490:A:T 1.53794e-12
# 5 rs10796947 1:155477053:A:G 0.61040 1:155477053:A:G 2.68553e-07
# 6 rs10796954 1:155794478:T:C 0.08331 1:155794478:T:C 1.47333e-06
# [1] 40
# [1] "checkingrs35749011 FDPS meta5"
# [1] "files exist"
# [1] "df:"
#         rsid        var_id.x    pval.x        var_id.y      pval.y
# 1 rs10796938 1:155072055:C:A 3.829e-08 1:155072055:C:A 1.23266e-08
# 2 rs10796940 1:155202689:A:C 4.679e-01 1:155202689:A:C 7.94361e-16
# 3 rs10796941 1:155284261:C:T 7.902e-01 1:155284261:C:T 9.85859e-30
# 4 rs10796944 1:155416328:G:A 2.299e-01 1:155416328:G:A 1.12868e-17
# 5 rs10796946 1:155429490:A:T 6.048e-01 1:155429490:A:T 1.98088e-23
# 6 rs10796947 1:155477053:A:G 6.104e-01 1:155477053:A:G 8.11592e-13
# [1] 41
# [1] "checkingrs35749011 FDPS meta5"
# [1] "files exist"
# [1] "df:"
#         rsid        var_id.x    pval.x        var_id.y      pval.y
# 1 rs10796938 1:155072055:C:A 3.829e-08 1:155072055:C:A 6.35439e-08
# 2 rs10796939 1:155088795:C:T 1.737e-05 1:155088795:C:T 4.84660e-07
# 3 rs10796940 1:155202689:A:C 4.679e-01 1:155202689:A:C 2.08924e-18
# 4 rs10796941 1:155284261:C:T 7.902e-01 1:155284261:C:T 4.08410e-29
# 5 rs10796944 1:155416328:G:A 2.299e-01 1:155416328:G:A 8.10051e-17
# 6 rs10796946 1:155429490:A:T 6.048e-01 1:155429490:A:T 1.97730e-21
# [1] 42
# [1] "checkingrs35749011 FDPS meta5"
# [1] "files exist"
# [1] "df:"
#         rsid        var_id.x    pval.x        var_id.y      pval.y
# 1 rs10458626 1:155281689:G:A 1.355e-01 1:155281689:G:A 2.59493e-08
# 2 rs10796938 1:155072055:C:A 3.829e-08 1:155072055:C:A 2.31017e-13
# 3 rs10796939 1:155088795:C:T 1.737e-05 1:155088795:C:T 2.08964e-09
# 4 rs10796940 1:155202689:A:C 4.679e-01 1:155202689:A:C 1.96578e-36
# 5 rs10796941 1:155284261:C:T 7.902e-01 1:155284261:C:T 7.63855e-91
# 6 rs10796944 1:155416328:G:A 2.299e-01 1:155416328:G:A 8.59237e-52
# [1] 43
# [1] "checkingrs76763715 FDPS meta5"
# [1] "files exist"
# [1] "df:"
#         rsid        var_id.x pval.x        var_id.y      pval.y
# 1 rs10908462 1:155285854:T:C 0.8476 1:155285854:T:C 1.09282e-06
# 2 rs11264348 1:155229915:G:T 0.6206 1:155229915:G:T 4.02465e-07
# 3 rs11264357 1:155268958:C:T 0.7593 1:155268958:C:T 3.63810e-06
# 4 rs11264358 1:155280164:T:C 0.9280 1:155280164:T:C 2.35880e-06
# 5 rs12067675 1:155268120:T:C 0.9322 1:155268120:T:C 2.76920e-06
# 6 rs12563994 1:155244092:C:T 0.9839 1:155244092:C:T 3.66352e-06
# [1] 44
# [1] "checkingrs76763715 FDPS meta5"
# [1] "files exist"
# [1] "df:"
#         rsid        var_id.x pval.x        var_id.y      pval.y
# 1 rs10796941 1:155284261:C:T 0.7902 1:155284261:C:T 1.16901e-10
# 2 rs10796946 1:155429490:A:T 0.6048 1:155429490:A:T 5.45467e-08
# 3 rs10908461 1:155275727:C:T 0.8197 1:155275727:C:T 2.47852e-09
# 4 rs10908462 1:155285854:T:C 0.8476 1:155285854:T:C 1.08041e-06
# 5 rs10908467 1:155439062:T:C 0.6969 1:155439062:T:C 2.76571e-06
# 6 rs10908471 1:155542942:A:G 0.4538 1:155542942:A:G 8.70705e-08
# [1] 45
# [1] "checkingrs76763715 FDPS meta5"
# [1] "files exist"
# [1] "df:"
#         rsid        var_id.x  pval.x        var_id.y      pval.y
# 1 rs10796940 1:155202689:A:C 0.46790 1:155202689:A:C 6.91376e-09
# 2 rs10796941 1:155284261:C:T 0.79020 1:155284261:C:T 2.45664e-15
# 3 rs10796944 1:155416328:G:A 0.22990 1:155416328:G:A 9.48535e-10
# 4 rs10796946 1:155429490:A:T 0.60480 1:155429490:A:T 1.53794e-12
# 5 rs10796947 1:155477053:A:G 0.61040 1:155477053:A:G 2.68553e-07
# 6 rs10796954 1:155794478:T:C 0.08331 1:155794478:T:C 1.47333e-06
# [1] 46
# [1] "checkingrs76763715 FDPS meta5"
# [1] "files exist"
# [1] "df:"
#         rsid        var_id.x    pval.x        var_id.y      pval.y
# 1 rs10796938 1:155072055:C:A 3.829e-08 1:155072055:C:A 1.23266e-08
# 2 rs10796940 1:155202689:A:C 4.679e-01 1:155202689:A:C 7.94361e-16
# 3 rs10796941 1:155284261:C:T 7.902e-01 1:155284261:C:T 9.85859e-30
# 4 rs10796944 1:155416328:G:A 2.299e-01 1:155416328:G:A 1.12868e-17
# 5 rs10796946 1:155429490:A:T 6.048e-01 1:155429490:A:T 1.98088e-23
# 6 rs10796947 1:155477053:A:G 6.104e-01 1:155477053:A:G 8.11592e-13
# [1] 47
# [1] "checkingrs76763715 FDPS meta5"
# [1] "files exist"
# [1] "df:"
#         rsid        var_id.x    pval.x        var_id.y      pval.y
# 1 rs10796938 1:155072055:C:A 3.829e-08 1:155072055:C:A 6.35439e-08
# 2 rs10796939 1:155088795:C:T 1.737e-05 1:155088795:C:T 4.84660e-07
# 3 rs10796940 1:155202689:A:C 4.679e-01 1:155202689:A:C 2.08924e-18
# 4 rs10796941 1:155284261:C:T 7.902e-01 1:155284261:C:T 4.08410e-29
# 5 rs10796944 1:155416328:G:A 2.299e-01 1:155416328:G:A 8.10051e-17
# 6 rs10796946 1:155429490:A:T 6.048e-01 1:155429490:A:T 1.97730e-21
# [1] 48
# [1] "checkingrs76763715 FDPS meta5"
# [1] "files exist"
# [1] "df:"
#         rsid        var_id.x    pval.x        var_id.y      pval.y
# 1 rs10458626 1:155281689:G:A 1.355e-01 1:155281689:G:A 2.59493e-08
# 2 rs10796938 1:155072055:C:A 3.829e-08 1:155072055:C:A 2.31017e-13
# 3 rs10796939 1:155088795:C:T 1.737e-05 1:155088795:C:T 2.08964e-09
# 4 rs10796940 1:155202689:A:C 4.679e-01 1:155202689:A:C 1.96578e-36
# 5 rs10796941 1:155284261:C:T 7.902e-01 1:155284261:C:T 7.63855e-91
# 6 rs10796944 1:155416328:G:A 2.299e-01 1:155416328:G:A 8.59237e-52
# [1] 49
# [1] "checkingrs114138760 HAX1 meta5"
# [1] "files exist"
# [1] "df:"
#         rsid        var_id.x    pval.x        var_id.y      pval.y
# 1 rs11586902 1:154251428:T:C 0.0112100 1:154251428:T:C 2.95237e-07
# 2  rs1194593 1:154245512:A:G 0.0109500 1:154245512:A:G 3.24721e-07
# 3  rs1760802 1:154259275:C:G 0.0098550 1:154259275:C:G 2.03171e-07
# 4  rs1760803 1:154257894:A:T 0.0110800 1:154257894:A:T 2.13274e-07
# 5 rs28372838 1:154145532:C:G 0.0003801 1:154145532:C:G 1.34079e-06
# 6  rs4433384 1:154133316:T:C 0.0004133 1:154133316:T:C 2.71331e-06
# [1] 50
# [1] "checkingrs114138760 HAX1 meta5"
# [1] "files exist"
# [1] "df:"
#          rsid        var_id.x pval.x        var_id.y      pval.y
# 1 rs114268268 1:154758322:C:T 0.2277 1:154758322:C:T 3.88395e-06
# [1] 51
# [1] "checkingrs35749011 HAX1 meta5"
# [1] "files exist"
# [1] "df:"
#         rsid        var_id.x    pval.x        var_id.y      pval.y
# 1 rs11586902 1:154251428:T:C 0.0112100 1:154251428:T:C 2.95237e-07
# 2  rs1194593 1:154245512:A:G 0.0109500 1:154245512:A:G 3.24721e-07
# 3  rs1760802 1:154259275:C:G 0.0098550 1:154259275:C:G 2.03171e-07
# 4  rs1760803 1:154257894:A:T 0.0110800 1:154257894:A:T 2.13274e-07
# 5 rs28372838 1:154145532:C:G 0.0003801 1:154145532:C:G 1.34079e-06
# 6  rs4433384 1:154133316:T:C 0.0004133 1:154133316:T:C 2.71331e-06
# [1] 52
# [1] "checkingrs35749011 HAX1 meta5"
# [1] "files exist"
# [1] "df:"
#          rsid        var_id.x pval.x        var_id.y      pval.y
# 1 rs114268268 1:154758322:C:T 0.2277 1:154758322:C:T 3.88395e-06
# [1] 53
# [1] "checkingrs76763715 HAX1 meta5"
# [1] "files exist"
# [1] "df:"
#         rsid        var_id.x    pval.x        var_id.y      pval.y
# 1 rs11586902 1:154251428:T:C 0.0112100 1:154251428:T:C 2.95237e-07
# 2  rs1194593 1:154245512:A:G 0.0109500 1:154245512:A:G 3.24721e-07
# 3  rs1760802 1:154259275:C:G 0.0098550 1:154259275:C:G 2.03171e-07
# 4  rs1760803 1:154257894:A:T 0.0110800 1:154257894:A:T 2.13274e-07
# 5 rs28372838 1:154145532:C:G 0.0003801 1:154145532:C:G 1.34079e-06
# 6  rs4433384 1:154133316:T:C 0.0004133 1:154133316:T:C 2.71331e-06
# [1] 54
# [1] "checkingrs76763715 HAX1 meta5"
# [1] "files exist"
# [1] "df:"
#          rsid        var_id.x pval.x        var_id.y      pval.y
# 1 rs114268268 1:154758322:C:T 0.2277 1:154758322:C:T 3.88395e-06
# [1] 55
# [1] "checkingrs114138760 RPS27 meta5"
# [1] "files exist"
# [1] 56
# [1] "checkingrs35749011 RPS27 meta5"
# [1] "files exist"
# [1] 57
# [1] "checkingrs76763715 RPS27 meta5"
# [1] "files exist"
# [1] 58
# [1] "checkingrs114138760 TPM3 meta5"
# [1] "files exist"
# [1] "df:"
#          rsid        var_id.x pval.x        var_id.y      pval.y
# 1 rs114779784 1:154239549:G:C 0.4185 1:154239549:G:C 2.86883e-06
# [1] 59
# [1] "checkingrs114138760 TPM3 meta5"
# [1] "files exist"
# [1] "df:"
#         rsid        var_id.x    pval.x        var_id.y      pval.y
# 1 rs10797058 1:154200704:T:C 0.7617000 1:154200704:T:C 1.88518e-07
# 2 rs10908739 1:154160655:T:C 0.8807000 1:154160655:T:C 2.71776e-09
# 3 rs11802893 1:154163526:G:C 0.0003301 1:154163526:G:C 1.01454e-08
# 4  rs1194582 1:154215973:A:G 0.7382000 1:154215973:A:G 1.83574e-07
# 5  rs1194600 1:154236009:G:C 0.7254000 1:154236009:G:C 1.16147e-07
# 6  rs1194602 1:154231943:T:C 0.7106000 1:154231943:T:C 1.92520e-08
# [1] 60
# [1] "checkingrs114138760 TPM3 meta5"
# [1] "files exist"
# [1] "df:"
#         rsid        var_id.x  pval.x        var_id.y      pval.y
# 1  rs1051370 1:154129265:A:G 0.03047 1:154129265:A:G 1.89221e-08
# 2 rs10796986 1:153987412:G:A 0.01758 1:153987412:G:A 1.98269e-06
# 3 rs10797047 1:154149240:G:A 0.01142 1:154149240:G:A 1.45116e-12
# 4 rs10797058 1:154200704:T:C 0.76170 1:154200704:T:C 4.46590e-10
# 5 rs10908525 1:153882544:A:C 0.19150 1:153882544:A:C 1.07560e-08
# 6 rs10908526 1:153883169:C:T 0.19670 1:153883169:C:T 6.00296e-08
# [1] 61
# [1] "checkingrs114138760 TPM3 meta5"
# [1] "files exist"
# [1] "df:"
#         rsid        var_id.x    pval.x        var_id.y      pval.y
# 1 rs10797058 1:154200704:T:C 0.7617000 1:154200704:T:C 5.82453e-09
# 2 rs10908739 1:154160655:T:C 0.8807000 1:154160655:T:C 3.76487e-08
# 3 rs11584755 1:154252208:G:A 0.0570600 1:154252208:G:A 2.04966e-06
# 4 rs11586916 1:154251514:T:C 0.0628400 1:154251514:T:C 2.59882e-06
# 5 rs11802893 1:154163526:G:C 0.0003301 1:154163526:G:C 2.37568e-11
# 6  rs1194582 1:154215973:A:G 0.7382000 1:154215973:A:G 5.87246e-09
# [1] 62
# [1] "checkingrs114138760 TPM3 meta5"
# [1] "files exist"
# [1] "df:"
#        rsid        var_id.x pval.x        var_id.y      pval.y
# 1 rs2494667 1:154109153:G:A 0.7131 1:154109153:G:A 8.97916e-07
# 2 rs2494670 1:154101057:T:C 0.6320 1:154101057:T:C 3.76468e-07
# 3 rs2494671 1:154100779:C:T 0.6354 1:154100779:C:T 4.39902e-07
# 4 rs2500220 1:154095016:C:T 0.6441 1:154095016:C:T 5.54867e-07
# 5 rs3001362 1:154115165:G:A 0.6431 1:154115165:G:A 2.36249e-07
# 6 rs3001363 1:154125067:C:T 0.5704 1:154125067:C:T 1.17851e-07
# [1] 63
# [1] "checkingrs114138760 TPM3 meta5"
# [1] "files exist"
# [1] 64
# [1] "checkingrs114138760 TPM3 meta5"
# [1] "files exist"
# [1] "df:"
#          rsid        var_id.x pval.x        var_id.y      pval.y
# 1 rs138981684 1:154961803:C:G 0.8999 1:154961803:C:G 1.13536e-06
# 2 rs146564277 1:155024095:G:A 0.7061 1:155024095:G:A 8.31916e-08
# [1] 65
# [1] "checkingrs35749011 TPM3 meta5"
# [1] "files exist"
# [1] "df:"
#          rsid        var_id.x pval.x        var_id.y      pval.y
# 1 rs114779784 1:154239549:G:C 0.4185 1:154239549:G:C 2.86883e-06
# [1] 66
# [1] "checkingrs35749011 TPM3 meta5"
# [1] "files exist"
# [1] "df:"
#         rsid        var_id.x    pval.x        var_id.y      pval.y
# 1 rs10797058 1:154200704:T:C 0.7617000 1:154200704:T:C 1.88518e-07
# 2 rs10908739 1:154160655:T:C 0.8807000 1:154160655:T:C 2.71776e-09
# 3 rs11802893 1:154163526:G:C 0.0003301 1:154163526:G:C 1.01454e-08
# 4  rs1194582 1:154215973:A:G 0.7382000 1:154215973:A:G 1.83574e-07
# 5  rs1194600 1:154236009:G:C 0.7254000 1:154236009:G:C 1.16147e-07
# 6  rs1194602 1:154231943:T:C 0.7106000 1:154231943:T:C 1.92520e-08
# [1] 67
# [1] "checkingrs35749011 TPM3 meta5"
# [1] "files exist"
# [1] "df:"
#         rsid        var_id.x  pval.x        var_id.y      pval.y
# 1  rs1051370 1:154129265:A:G 0.03047 1:154129265:A:G 1.89221e-08
# 2 rs10796986 1:153987412:G:A 0.01758 1:153987412:G:A 1.98269e-06
# 3 rs10797047 1:154149240:G:A 0.01142 1:154149240:G:A 1.45116e-12
# 4 rs10797058 1:154200704:T:C 0.76170 1:154200704:T:C 4.46590e-10
# 5 rs10908525 1:153882544:A:C 0.19150 1:153882544:A:C 1.07560e-08
# 6 rs10908526 1:153883169:C:T 0.19670 1:153883169:C:T 6.00296e-08
# [1] 68
# [1] "checkingrs35749011 TPM3 meta5"
# [1] "files exist"
# [1] "df:"
#         rsid        var_id.x    pval.x        var_id.y      pval.y
# 1 rs10797058 1:154200704:T:C 0.7617000 1:154200704:T:C 5.82453e-09
# 2 rs10908739 1:154160655:T:C 0.8807000 1:154160655:T:C 3.76487e-08
# 3 rs11584755 1:154252208:G:A 0.0570600 1:154252208:G:A 2.04966e-06
# 4 rs11586916 1:154251514:T:C 0.0628400 1:154251514:T:C 2.59882e-06
# 5 rs11802893 1:154163526:G:C 0.0003301 1:154163526:G:C 2.37568e-11
# 6  rs1194582 1:154215973:A:G 0.7382000 1:154215973:A:G 5.87246e-09
# [1] 69
# [1] "checkingrs35749011 TPM3 meta5"
# [1] "files exist"
# [1] "df:"
#        rsid        var_id.x pval.x        var_id.y      pval.y
# 1 rs2494667 1:154109153:G:A 0.7131 1:154109153:G:A 8.97916e-07
# 2 rs2494670 1:154101057:T:C 0.6320 1:154101057:T:C 3.76468e-07
# 3 rs2494671 1:154100779:C:T 0.6354 1:154100779:C:T 4.39902e-07
# 4 rs2500220 1:154095016:C:T 0.6441 1:154095016:C:T 5.54867e-07
# 5 rs3001362 1:154115165:G:A 0.6431 1:154115165:G:A 2.36249e-07
# 6 rs3001363 1:154125067:C:T 0.5704 1:154125067:C:T 1.17851e-07
# [1] 70
# [1] "checkingrs35749011 TPM3 meta5"
# [1] "files exist"
# [1] 71
# [1] "checkingrs35749011 TPM3 meta5"
# [1] "files exist"
# [1] "df:"
#          rsid        var_id.x pval.x        var_id.y      pval.y
# 1 rs138981684 1:154961803:C:G 0.8999 1:154961803:C:G 1.13536e-06
# 2 rs146564277 1:155024095:G:A 0.7061 1:155024095:G:A 8.31916e-08
# [1] 72
# [1] "checkingrs76763715 TPM3 meta5"
# [1] "files exist"
# [1] "df:"
#          rsid        var_id.x pval.x        var_id.y      pval.y
# 1 rs114779784 1:154239549:G:C 0.4185 1:154239549:G:C 2.86883e-06
# [1] 73
# [1] "checkingrs76763715 TPM3 meta5"
# [1] "files exist"
# [1] "df:"
#         rsid        var_id.x    pval.x        var_id.y      pval.y
# 1 rs10797058 1:154200704:T:C 0.7617000 1:154200704:T:C 1.88518e-07
# 2 rs10908739 1:154160655:T:C 0.8807000 1:154160655:T:C 2.71776e-09
# 3 rs11802893 1:154163526:G:C 0.0003301 1:154163526:G:C 1.01454e-08
# 4  rs1194582 1:154215973:A:G 0.7382000 1:154215973:A:G 1.83574e-07
# 5  rs1194600 1:154236009:G:C 0.7254000 1:154236009:G:C 1.16147e-07
# 6  rs1194602 1:154231943:T:C 0.7106000 1:154231943:T:C 1.92520e-08
# [1] 74
# [1] "checkingrs76763715 TPM3 meta5"
# [1] "files exist"
# [1] "df:"
#         rsid        var_id.x  pval.x        var_id.y      pval.y
# 1  rs1051370 1:154129265:A:G 0.03047 1:154129265:A:G 1.89221e-08
# 2 rs10796986 1:153987412:G:A 0.01758 1:153987412:G:A 1.98269e-06
# 3 rs10797047 1:154149240:G:A 0.01142 1:154149240:G:A 1.45116e-12
# 4 rs10797058 1:154200704:T:C 0.76170 1:154200704:T:C 4.46590e-10
# 5 rs10908525 1:153882544:A:C 0.19150 1:153882544:A:C 1.07560e-08
# 6 rs10908526 1:153883169:C:T 0.19670 1:153883169:C:T 6.00296e-08
# [1] 75
# [1] "checkingrs76763715 TPM3 meta5"
# [1] "files exist"
# [1] "df:"
#         rsid        var_id.x    pval.x        var_id.y      pval.y
# 1 rs10797058 1:154200704:T:C 0.7617000 1:154200704:T:C 5.82453e-09
# 2 rs10908739 1:154160655:T:C 0.8807000 1:154160655:T:C 3.76487e-08
# 3 rs11584755 1:154252208:G:A 0.0570600 1:154252208:G:A 2.04966e-06
# 4 rs11586916 1:154251514:T:C 0.0628400 1:154251514:T:C 2.59882e-06
# 5 rs11802893 1:154163526:G:C 0.0003301 1:154163526:G:C 2.37568e-11
# 6  rs1194582 1:154215973:A:G 0.7382000 1:154215973:A:G 5.87246e-09
# [1] 76
# [1] "checkingrs76763715 TPM3 meta5"
# [1] "files exist"
# [1] "df:"
#        rsid        var_id.x pval.x        var_id.y      pval.y
# 1 rs2494667 1:154109153:G:A 0.7131 1:154109153:G:A 8.97916e-07
# 2 rs2494670 1:154101057:T:C 0.6320 1:154101057:T:C 3.76468e-07
# 3 rs2494671 1:154100779:C:T 0.6354 1:154100779:C:T 4.39902e-07
# 4 rs2500220 1:154095016:C:T 0.6441 1:154095016:C:T 5.54867e-07
# 5 rs3001362 1:154115165:G:A 0.6431 1:154115165:G:A 2.36249e-07
# 6 rs3001363 1:154125067:C:T 0.5704 1:154125067:C:T 1.17851e-07
# [1] 77
# [1] "checkingrs76763715 TPM3 meta5"
# [1] "files exist"
# [1] 78
# [1] "checkingrs76763715 TPM3 meta5"
# [1] "files exist"
# [1] "df:"
#          rsid        var_id.x pval.x        var_id.y      pval.y
# 1 rs138981684 1:154961803:C:G 0.8999 1:154961803:C:G 1.13536e-06
# 2 rs146564277 1:155024095:G:A 0.7061 1:155024095:G:A 8.31916e-08
# [1] 79
# [1] "checkingrs114138760 YY1AP1 meta5"
# [1] "files exist"
# [1] "df:"
#         rsid        var_id.x  pval.x        var_id.y      pval.y
# 1 rs10796941 1:155284261:C:T 0.79020 1:155284261:C:T 1.27033e-08
# 2 rs10796944 1:155416328:G:A 0.22990 1:155416328:G:A 5.92719e-07
# 3 rs10796946 1:155429490:A:T 0.60480 1:155429490:A:T 2.71933e-09
# 4 rs10796954 1:155794478:T:C 0.08331 1:155794478:T:C 6.30798e-07
# 5 rs10908461 1:155275727:C:T 0.81970 1:155275727:C:T 1.29834e-07
# 6 rs10908471 1:155542942:A:G 0.45380 1:155542942:A:G 5.40231e-09
# [1] 80
# [1] "checkingrs114138760 YY1AP1 meta5"
# [1] "files exist"
# [1] "df:"
#         rsid        var_id.x  pval.x        var_id.y      pval.y
# 1 rs10796940 1:155202689:A:C 0.46790 1:155202689:A:C 1.11271e-15
# 2 rs10796941 1:155284261:C:T 0.79020 1:155284261:C:T 1.86207e-31
# 3 rs10796944 1:155416328:G:A 0.22990 1:155416328:G:A 6.03969e-32
# 4 rs10796946 1:155429490:A:T 0.60480 1:155429490:A:T 7.05523e-40
# 5 rs10796947 1:155477053:A:G 0.61040 1:155477053:A:G 1.42908e-19
# 6 rs10796954 1:155794478:T:C 0.08331 1:155794478:T:C 1.20979e-29
# [1] 81
# [1] "checkingrs114138760 YY1AP1 meta5"
# [1] "files exist"
# [1] "df:"
#         rsid        var_id.x pval.x        var_id.y      pval.y
# 1 rs10796944 1:155416328:G:A 0.2299 1:155416328:G:A 1.21054e-06
# 2 rs11264358 1:155280164:T:C 0.9280 1:155280164:T:C 3.69057e-06
# 3 rs12037824 1:155415181:G:A 0.4043 1:155415181:G:A 1.95740e-06
# 4 rs12049455 1:155320492:T:A 0.8824 1:155320492:T:A 2.72386e-06
# 5 rs56675301 1:155364327:T:C 0.6279 1:155364327:T:C 3.19759e-06
# [1] 82
# [1] "checkingrs114138760 YY1AP1 meta5"
# [1] "files exist"
# [1] "df:"
#         rsid        var_id.x  pval.x        var_id.y      pval.y
# 1 rs10796940 1:155202689:A:C 0.46790 1:155202689:A:C 1.70179e-09
# 2 rs10796941 1:155284261:C:T 0.79020 1:155284261:C:T 2.63758e-18
# 3 rs10796944 1:155416328:G:A 0.22990 1:155416328:G:A 5.50349e-19
# 4 rs10796946 1:155429490:A:T 0.60480 1:155429490:A:T 5.58441e-23
# 5 rs10796947 1:155477053:A:G 0.61040 1:155477053:A:G 1.10269e-08
# 6 rs10796954 1:155794478:T:C 0.08331 1:155794478:T:C 1.03082e-17
# [1] 83
# [1] "checkingrs114138760 YY1AP1 meta5"
# [1] "files exist"
# [1] "df:"
#         rsid        var_id.x    pval.x        var_id.y      pval.y
# 1 rs10458626 1:155281689:G:A 1.355e-01 1:155281689:G:A 1.69641e-08
# 2 rs10796938 1:155072055:C:A 3.829e-08 1:155072055:C:A 1.32430e-06
# 3 rs10796940 1:155202689:A:C 4.679e-01 1:155202689:A:C 2.88215e-24
# 4 rs10796941 1:155284261:C:T 7.902e-01 1:155284261:C:T 1.26991e-54
# 5 rs10796944 1:155416328:G:A 2.299e-01 1:155416328:G:A 2.22338e-48
# 6 rs10796946 1:155429490:A:T 6.048e-01 1:155429490:A:T 8.94514e-62
# [1] 84
# [1] "checkingrs114138760 YY1AP1 meta5"
# [1] "files exist"
# [1] "df:"
#         rsid        var_id.x    pval.x        var_id.y      pval.y
# 1 rs10458626 1:155281689:G:A 1.355e-01 1:155281689:G:A 2.00871e-09
# 2 rs10796938 1:155072055:C:A 3.829e-08 1:155072055:C:A 2.06658e-10
# 3 rs10796940 1:155202689:A:C 4.679e-01 1:155202689:A:C 1.17005e-15
# 4 rs10796941 1:155284261:C:T 7.902e-01 1:155284261:C:T 1.43011e-32
# 5 rs10796944 1:155416328:G:A 2.299e-01 1:155416328:G:A 1.68806e-24
# 6 rs10796946 1:155429490:A:T 6.048e-01 1:155429490:A:T 2.00379e-29
# [1] 85
# [1] "checkingrs114138760 YY1AP1 meta5"
# [1] "files exist"
# [1] "df:"
#         rsid        var_id.x  pval.x        var_id.y      pval.y
# 1 rs10796940 1:155202689:A:C 0.46790 1:155202689:A:C 1.57149e-06
# 2 rs10796941 1:155284261:C:T 0.79020 1:155284261:C:T 7.75933e-15
# 3 rs10796944 1:155416328:G:A 0.22990 1:155416328:G:A 1.77686e-10
# 4 rs10796946 1:155429490:A:T 0.60480 1:155429490:A:T 1.27694e-15
# 5 rs10796954 1:155794478:T:C 0.08331 1:155794478:T:C 3.88594e-16
# 6 rs10908459 1:155214066:C:T 0.52390 1:155214066:C:T 4.36612e-07
# [1] 86
# [1] "checkingrs114138760 YY1AP1 meta5"
# [1] "files exist"
# [1] "df:"
#         rsid        var_id.x  pval.x        var_id.y      pval.y
# 1 rs10796940 1:155202689:A:C 0.46790 1:155202689:A:C 6.34202e-11
# 2 rs10796941 1:155284261:C:T 0.79020 1:155284261:C:T 2.45667e-21
# 3 rs10796944 1:155416328:G:A 0.22990 1:155416328:G:A 2.80637e-21
# 4 rs10796946 1:155429490:A:T 0.60480 1:155429490:A:T 5.10932e-26
# 5 rs10796947 1:155477053:A:G 0.61040 1:155477053:A:G 4.87543e-15
# 6 rs10796954 1:155794478:T:C 0.08331 1:155794478:T:C 2.65276e-22
# [1] 87
# [1] "checkingrs114138760 YY1AP1 meta5"
# [1] "files exist"
# [1] "df:"
#         rsid        var_id.x  pval.x        var_id.y      pval.y
# 1 rs10796941 1:155284261:C:T 0.79020 1:155284261:C:T 4.88730e-07
# 2 rs10796944 1:155416328:G:A 0.22990 1:155416328:G:A 6.60158e-09
# 3 rs10796946 1:155429490:A:T 0.60480 1:155429490:A:T 2.63158e-11
# 4 rs10796947 1:155477053:A:G 0.61040 1:155477053:A:G 1.40952e-06
# 5 rs10796954 1:155794478:T:C 0.08331 1:155794478:T:C 3.80969e-08
# 6 rs10908461 1:155275727:C:T 0.81970 1:155275727:C:T 3.67320e-06
# [1] 88
# [1] "checkingrs114138760 YY1AP1 meta5"
# [1] "files exist"
# [1] "df:"
#         rsid        var_id.x  pval.x        var_id.y      pval.y
# 1 rs10796941 1:155284261:C:T 0.79020 1:155284261:C:T 3.16672e-07
# 2 rs10796944 1:155416328:G:A 0.22990 1:155416328:G:A 1.04220e-08
# 3 rs10796946 1:155429490:A:T 0.60480 1:155429490:A:T 1.69058e-10
# 4 rs10796947 1:155477053:A:G 0.61040 1:155477053:A:G 7.18339e-07
# 5 rs10796954 1:155794478:T:C 0.08331 1:155794478:T:C 4.29363e-11
# 6 rs10908467 1:155439062:T:C 0.69690 1:155439062:T:C 1.65560e-07
# [1] 89
# [1] "checkingrs114138760 YY1AP1 meta5"
# [1] "files exist"
# [1] "df:"
#         rsid        var_id.x  pval.x        var_id.y      pval.y
# 1 rs10796940 1:155202689:A:C 0.46790 1:155202689:A:C 2.51208e-09
# 2 rs10796941 1:155284261:C:T 0.79020 1:155284261:C:T 5.51659e-12
# 3 rs10796944 1:155416328:G:A 0.22990 1:155416328:G:A 6.18493e-09
# 4 rs10796946 1:155429490:A:T 0.60480 1:155429490:A:T 5.68604e-12
# 5 rs10796947 1:155477053:A:G 0.61040 1:155477053:A:G 1.02471e-06
# 6 rs10796954 1:155794478:T:C 0.08331 1:155794478:T:C 2.82339e-08
# [1] 90
# [1] "checkingrs35749011 YY1AP1 meta5"
# [1] "files exist"
# [1] "df:"
#         rsid        var_id.x  pval.x        var_id.y      pval.y
# 1 rs10796941 1:155284261:C:T 0.79020 1:155284261:C:T 1.27033e-08
# 2 rs10796944 1:155416328:G:A 0.22990 1:155416328:G:A 5.92719e-07
# 3 rs10796946 1:155429490:A:T 0.60480 1:155429490:A:T 2.71933e-09
# 4 rs10796954 1:155794478:T:C 0.08331 1:155794478:T:C 6.30798e-07
# 5 rs10908461 1:155275727:C:T 0.81970 1:155275727:C:T 1.29834e-07
# 6 rs10908471 1:155542942:A:G 0.45380 1:155542942:A:G 5.40231e-09
# [1] 91
# [1] "checkingrs35749011 YY1AP1 meta5"
# [1] "files exist"
# [1] "df:"
#         rsid        var_id.x  pval.x        var_id.y      pval.y
# 1 rs10796940 1:155202689:A:C 0.46790 1:155202689:A:C 1.11271e-15
# 2 rs10796941 1:155284261:C:T 0.79020 1:155284261:C:T 1.86207e-31
# 3 rs10796944 1:155416328:G:A 0.22990 1:155416328:G:A 6.03969e-32
# 4 rs10796946 1:155429490:A:T 0.60480 1:155429490:A:T 7.05523e-40
# 5 rs10796947 1:155477053:A:G 0.61040 1:155477053:A:G 1.42908e-19
# 6 rs10796954 1:155794478:T:C 0.08331 1:155794478:T:C 1.20979e-29
# [1] 92
# [1] "checkingrs35749011 YY1AP1 meta5"
# [1] "files exist"
# [1] "df:"
#         rsid        var_id.x pval.x        var_id.y      pval.y
# 1 rs10796944 1:155416328:G:A 0.2299 1:155416328:G:A 1.21054e-06
# 2 rs11264358 1:155280164:T:C 0.9280 1:155280164:T:C 3.69057e-06
# 3 rs12037824 1:155415181:G:A 0.4043 1:155415181:G:A 1.95740e-06
# 4 rs12049455 1:155320492:T:A 0.8824 1:155320492:T:A 2.72386e-06
# 5 rs56675301 1:155364327:T:C 0.6279 1:155364327:T:C 3.19759e-06
# [1] 93
# [1] "checkingrs35749011 YY1AP1 meta5"
# [1] "files exist"
# [1] "df:"
#         rsid        var_id.x  pval.x        var_id.y      pval.y
# 1 rs10796940 1:155202689:A:C 0.46790 1:155202689:A:C 1.70179e-09
# 2 rs10796941 1:155284261:C:T 0.79020 1:155284261:C:T 2.63758e-18
# 3 rs10796944 1:155416328:G:A 0.22990 1:155416328:G:A 5.50349e-19
# 4 rs10796946 1:155429490:A:T 0.60480 1:155429490:A:T 5.58441e-23
# 5 rs10796947 1:155477053:A:G 0.61040 1:155477053:A:G 1.10269e-08
# 6 rs10796954 1:155794478:T:C 0.08331 1:155794478:T:C 1.03082e-17
# [1] 94
# [1] "checkingrs35749011 YY1AP1 meta5"
# [1] "files exist"
# [1] "df:"
#         rsid        var_id.x    pval.x        var_id.y      pval.y
# 1 rs10458626 1:155281689:G:A 1.355e-01 1:155281689:G:A 1.69641e-08
# 2 rs10796938 1:155072055:C:A 3.829e-08 1:155072055:C:A 1.32430e-06
# 3 rs10796940 1:155202689:A:C 4.679e-01 1:155202689:A:C 2.88215e-24
# 4 rs10796941 1:155284261:C:T 7.902e-01 1:155284261:C:T 1.26991e-54
# 5 rs10796944 1:155416328:G:A 2.299e-01 1:155416328:G:A 2.22338e-48
# 6 rs10796946 1:155429490:A:T 6.048e-01 1:155429490:A:T 8.94514e-62
# [1] 95
# [1] "checkingrs35749011 YY1AP1 meta5"
# [1] "files exist"
# [1] "df:"
#         rsid        var_id.x    pval.x        var_id.y      pval.y
# 1 rs10458626 1:155281689:G:A 1.355e-01 1:155281689:G:A 2.00871e-09
# 2 rs10796938 1:155072055:C:A 3.829e-08 1:155072055:C:A 2.06658e-10
# 3 rs10796940 1:155202689:A:C 4.679e-01 1:155202689:A:C 1.17005e-15
# 4 rs10796941 1:155284261:C:T 7.902e-01 1:155284261:C:T 1.43011e-32
# 5 rs10796944 1:155416328:G:A 2.299e-01 1:155416328:G:A 1.68806e-24
# 6 rs10796946 1:155429490:A:T 6.048e-01 1:155429490:A:T 2.00379e-29
# [1] 96
# [1] "checkingrs35749011 YY1AP1 meta5"
# [1] "files exist"
# [1] "df:"
#         rsid        var_id.x  pval.x        var_id.y      pval.y
# 1 rs10796940 1:155202689:A:C 0.46790 1:155202689:A:C 1.57149e-06
# 2 rs10796941 1:155284261:C:T 0.79020 1:155284261:C:T 7.75933e-15
# 3 rs10796944 1:155416328:G:A 0.22990 1:155416328:G:A 1.77686e-10
# 4 rs10796946 1:155429490:A:T 0.60480 1:155429490:A:T 1.27694e-15
# 5 rs10796954 1:155794478:T:C 0.08331 1:155794478:T:C 3.88594e-16
# 6 rs10908459 1:155214066:C:T 0.52390 1:155214066:C:T 4.36612e-07
# [1] 97
# [1] "checkingrs35749011 YY1AP1 meta5"
# [1] "files exist"
# [1] "df:"
#         rsid        var_id.x  pval.x        var_id.y      pval.y
# 1 rs10796940 1:155202689:A:C 0.46790 1:155202689:A:C 6.34202e-11
# 2 rs10796941 1:155284261:C:T 0.79020 1:155284261:C:T 2.45667e-21
# 3 rs10796944 1:155416328:G:A 0.22990 1:155416328:G:A 2.80637e-21
# 4 rs10796946 1:155429490:A:T 0.60480 1:155429490:A:T 5.10932e-26
# 5 rs10796947 1:155477053:A:G 0.61040 1:155477053:A:G 4.87543e-15
# 6 rs10796954 1:155794478:T:C 0.08331 1:155794478:T:C 2.65276e-22
# [1] 98
# [1] "checkingrs35749011 YY1AP1 meta5"
# [1] "files exist"
# [1] "df:"
#         rsid        var_id.x  pval.x        var_id.y      pval.y
# 1 rs10796941 1:155284261:C:T 0.79020 1:155284261:C:T 4.88730e-07
# 2 rs10796944 1:155416328:G:A 0.22990 1:155416328:G:A 6.60158e-09
# 3 rs10796946 1:155429490:A:T 0.60480 1:155429490:A:T 2.63158e-11
# 4 rs10796947 1:155477053:A:G 0.61040 1:155477053:A:G 1.40952e-06
# 5 rs10796954 1:155794478:T:C 0.08331 1:155794478:T:C 3.80969e-08
# 6 rs10908461 1:155275727:C:T 0.81970 1:155275727:C:T 3.67320e-06
# [1] 99
# [1] "checkingrs35749011 YY1AP1 meta5"
# [1] "files exist"
# [1] "df:"
#         rsid        var_id.x  pval.x        var_id.y      pval.y
# 1 rs10796941 1:155284261:C:T 0.79020 1:155284261:C:T 3.16672e-07
# 2 rs10796944 1:155416328:G:A 0.22990 1:155416328:G:A 1.04220e-08
# 3 rs10796946 1:155429490:A:T 0.60480 1:155429490:A:T 1.69058e-10
# 4 rs10796947 1:155477053:A:G 0.61040 1:155477053:A:G 7.18339e-07
# 5 rs10796954 1:155794478:T:C 0.08331 1:155794478:T:C 4.29363e-11
# 6 rs10908467 1:155439062:T:C 0.69690 1:155439062:T:C 1.65560e-07
# [1] 100
# [1] "checkingrs35749011 YY1AP1 meta5"
# [1] "files exist"
# [1] "df:"
#         rsid        var_id.x  pval.x        var_id.y      pval.y
# 1 rs10796940 1:155202689:A:C 0.46790 1:155202689:A:C 2.51208e-09
# 2 rs10796941 1:155284261:C:T 0.79020 1:155284261:C:T 5.51659e-12
# 3 rs10796944 1:155416328:G:A 0.22990 1:155416328:G:A 6.18493e-09
# 4 rs10796946 1:155429490:A:T 0.60480 1:155429490:A:T 5.68604e-12
# 5 rs10796947 1:155477053:A:G 0.61040 1:155477053:A:G 1.02471e-06
# 6 rs10796954 1:155794478:T:C 0.08331 1:155794478:T:C 2.82339e-08
# [1] 101
# [1] "checkingrs76763715 YY1AP1 meta5"
# [1] "files exist"
# [1] "df:"
#         rsid        var_id.x  pval.x        var_id.y      pval.y
# 1 rs10796941 1:155284261:C:T 0.79020 1:155284261:C:T 1.27033e-08
# 2 rs10796944 1:155416328:G:A 0.22990 1:155416328:G:A 5.92719e-07
# 3 rs10796946 1:155429490:A:T 0.60480 1:155429490:A:T 2.71933e-09
# 4 rs10796954 1:155794478:T:C 0.08331 1:155794478:T:C 6.30798e-07
# 5 rs10908461 1:155275727:C:T 0.81970 1:155275727:C:T 1.29834e-07
# 6 rs10908471 1:155542942:A:G 0.45380 1:155542942:A:G 5.40231e-09
# [1] 102
# [1] "checkingrs76763715 YY1AP1 meta5"
# [1] "files exist"
# [1] "df:"
#         rsid        var_id.x  pval.x        var_id.y      pval.y
# 1 rs10796940 1:155202689:A:C 0.46790 1:155202689:A:C 1.11271e-15
# 2 rs10796941 1:155284261:C:T 0.79020 1:155284261:C:T 1.86207e-31
# 3 rs10796944 1:155416328:G:A 0.22990 1:155416328:G:A 6.03969e-32
# 4 rs10796946 1:155429490:A:T 0.60480 1:155429490:A:T 7.05523e-40
# 5 rs10796947 1:155477053:A:G 0.61040 1:155477053:A:G 1.42908e-19
# 6 rs10796954 1:155794478:T:C 0.08331 1:155794478:T:C 1.20979e-29
# [1] 103
# [1] "checkingrs76763715 YY1AP1 meta5"
# [1] "files exist"
# [1] "df:"
#         rsid        var_id.x pval.x        var_id.y      pval.y
# 1 rs10796944 1:155416328:G:A 0.2299 1:155416328:G:A 1.21054e-06
# 2 rs11264358 1:155280164:T:C 0.9280 1:155280164:T:C 3.69057e-06
# 3 rs12037824 1:155415181:G:A 0.4043 1:155415181:G:A 1.95740e-06
# 4 rs12049455 1:155320492:T:A 0.8824 1:155320492:T:A 2.72386e-06
# 5 rs56675301 1:155364327:T:C 0.6279 1:155364327:T:C 3.19759e-06
# [1] 104
# [1] "checkingrs76763715 YY1AP1 meta5"
# [1] "files exist"
# [1] "df:"
#         rsid        var_id.x  pval.x        var_id.y      pval.y
# 1 rs10796940 1:155202689:A:C 0.46790 1:155202689:A:C 1.70179e-09
# 2 rs10796941 1:155284261:C:T 0.79020 1:155284261:C:T 2.63758e-18
# 3 rs10796944 1:155416328:G:A 0.22990 1:155416328:G:A 5.50349e-19
# 4 rs10796946 1:155429490:A:T 0.60480 1:155429490:A:T 5.58441e-23
# 5 rs10796947 1:155477053:A:G 0.61040 1:155477053:A:G 1.10269e-08
# 6 rs10796954 1:155794478:T:C 0.08331 1:155794478:T:C 1.03082e-17
# [1] 105
# [1] "checkingrs76763715 YY1AP1 meta5"
# [1] "files exist"
# [1] "df:"
#         rsid        var_id.x    pval.x        var_id.y      pval.y
# 1 rs10458626 1:155281689:G:A 1.355e-01 1:155281689:G:A 1.69641e-08
# 2 rs10796938 1:155072055:C:A 3.829e-08 1:155072055:C:A 1.32430e-06
# 3 rs10796940 1:155202689:A:C 4.679e-01 1:155202689:A:C 2.88215e-24
# 4 rs10796941 1:155284261:C:T 7.902e-01 1:155284261:C:T 1.26991e-54
# 5 rs10796944 1:155416328:G:A 2.299e-01 1:155416328:G:A 2.22338e-48
# 6 rs10796946 1:155429490:A:T 6.048e-01 1:155429490:A:T 8.94514e-62
# [1] 106
# ...
# 3 rs114803818 21:38443348:A:C 0.027050 21:38443348:A:C 2.57802e-08
# 4 rs116511474 21:38438946:A:G 0.039560 21:38438946:A:G 3.87342e-08
# 5  rs13052203 21:38704741:G:T 0.001919 21:38704741:G:T 6.69510e-07
# 6 rs143286815 21:38436591:G:A 0.030330 21:38436591:G:A 2.05194e-08
# [1] 916
# [1] "checkingrs2248244 TTC3 meta5"
# [1] "files exist"
# [1] "df:"
#         rsid        var_id.x  pval.x        var_id.y      pval.y
# 1 rs10154032 21:38453459:T:C 0.14910 21:38453459:T:C 1.75882e-16
# 2 rs10154036 21:38453510:T:C 0.15380 21:38453510:T:C 1.74585e-16
# 3 rs10154113 21:38497490:C:G 0.06008 21:38497490:C:G 5.59093e-17
# 4  rs1015551 21:38449510:G:A 0.17080 21:38449510:G:A 1.66416e-16
# 5  rs1053808 21:38525356:T:C 0.42530 21:38525356:T:C 1.70174e-12
# 6  rs1115639 21:38509353:A:G 0.25650 21:38509353:A:G 1.01011e-07
# [1] 917
# [1] "checkingrs2248244 TTC3 meta5"
# [1] "files exist"
# [1] "df:"
#         rsid        var_id.x  pval.x        var_id.y      pval.y
# 1 rs10154032 21:38453459:T:C 0.14910 21:38453459:T:C 3.15517e-09
# 2 rs10154036 21:38453510:T:C 0.15380 21:38453510:T:C 3.19521e-09
# 3 rs10154113 21:38497490:C:G 0.06008 21:38497490:C:G 8.62452e-11
# 4  rs1015551 21:38449510:G:A 0.17080 21:38449510:G:A 2.76164e-09
# 5  rs1053808 21:38525356:T:C 0.42530 21:38525356:T:C 1.25079e-09
# 6  rs1133001 21:38512956:A:G 0.08726 21:38512956:A:G 3.43992e-11
# [1] 918
# [1] "checkingrs2248244 TTC3 meta5"
# [1] "files exist"
# [1] "df:"
#          rsid        var_id.x pval.x        var_id.y      pval.y
# 1 rs117848276 21:38405126:C:T 0.4311 21:38405126:C:T 3.12165e-06
# [1] 919
# [1] "checkingrs2248244 TTC3 meta5"
# [1] "files exist"
# [1] "df:"
#          rsid        var_id.x pval.x        var_id.y      pval.y
# 1 rs117217082 21:37787099:C:T 0.3891 21:37787099:C:T 1.10868e-08
# [1] 920
# [1] "checkingrs2248244 TTC3 meta5"
# [1] "files exist"
# [1] "df:"
#         rsid        var_id.x  pval.x        var_id.y      pval.y
# 1 rs10154032 21:38453459:T:C 0.14910 21:38453459:T:C 1.99757e-08
# 2 rs10154036 21:38453510:T:C 0.15380 21:38453510:T:C 2.01122e-08
# 3 rs10154113 21:38497490:C:G 0.06008 21:38497490:C:G 5.37720e-08
# 4  rs1015551 21:38449510:G:A 0.17080 21:38449510:G:A 1.76329e-08
# 5  rs1053808 21:38525356:T:C 0.42530 21:38525356:T:C 5.64899e-08
# 6  rs1115639 21:38509353:A:G 0.25650 21:38509353:A:G 3.65528e-06
# [1] 921
# [1] "checkingrs2248244 TTC3 meta5"
# [1] "files exist"
# [1] "df:"
#         rsid        var_id.x pval.x        var_id.y      pval.y
# 1  rs1115639 21:38509353:A:G 0.2565 21:38509353:A:G 3.49364e-10
# 2 rs11701575 21:38446054:T:C 0.3604 21:38446054:T:C 5.63546e-09
# 3 rs12185849 21:38498585:G:C 0.2154 21:38498585:G:C 1.94490e-08
# 4  rs1235345 21:38432325:A:G 0.3731 21:38432325:A:G 3.46167e-06
# 5  rs1344046 21:38517140:A:G 0.2661 21:38517140:A:G 3.50577e-10
# 6  rs1344047 21:38517021:G:A 0.2969 21:38517021:G:A 9.16018e-09
# [1] 922
# [1] "checkingrs2248244 TTC3 meta5"
# [1] "files exist"
# [1] "df:"
#         rsid        var_id.x  pval.x        var_id.y      pval.y
# 1  rs1009923 21:38643970:A:G 0.50090 21:38643970:A:G 1.77743e-07
# 2 rs10154032 21:38453459:T:C 0.14910 21:38453459:T:C 1.10884e-23
# 3 rs10154036 21:38453510:T:C 0.15380 21:38453510:T:C 1.12954e-23
# 4 rs10154113 21:38497490:C:G 0.06008 21:38497490:C:G 1.95136e-21
# 5  rs1015551 21:38449510:G:A 0.17080 21:38449510:G:A 1.67593e-23
# 6  rs1053808 21:38525356:T:C 0.42530 21:38525356:T:C 7.81226e-14
# [1] 923
# [1] "checkingrs2248244 TTC3 meta5"
# [1] "files exist"
# [1] "df:"
#         rsid        var_id.x  pval.x        var_id.y      pval.y
# 1  rs1009923 21:38643970:A:G 0.50090 21:38643970:A:G 1.71329e-11
# 2 rs10154032 21:38453459:T:C 0.14910 21:38453459:T:C 6.06157e-65
# 3 rs10154036 21:38453510:T:C 0.15380 21:38453510:T:C 6.06003e-65
# 4 rs10154113 21:38497490:C:G 0.06008 21:38497490:C:G 1.84795e-60
# 5  rs1015551 21:38449510:G:A 0.17080 21:38449510:G:A 5.24277e-65
# 6  rs1053808 21:38525356:T:C 0.42530 21:38525356:T:C 4.44592e-47
# [1] 924
# [1] "checkingrs2248244 TTC3 meta5"
# [1] "files exist"
# [1] "df:"
#         rsid        var_id.x pval.x        var_id.y      pval.y
# 1  rs2096497 21:38652778:T:A 0.1238 21:38652778:T:A 3.92317e-07
# 2  rs3787798 21:38630561:C:A 0.3570 21:38630561:C:A 2.10383e-06
# 3 rs74805926 21:38619709:A:T 0.3331 21:38619709:A:T 2.01038e-06
# 4 rs77288947 21:38578728:T:C 0.8034 21:38578728:T:C 1.01486e-06
# 5 rs77440607 21:38452200:A:G 0.4278 21:38452200:A:G 1.46932e-06
# 6 rs78517475 21:38629488:G:A 0.3747 21:38629488:G:A 2.13889e-06
# [1] 925
# [1] "checkingrs2248244 TTC3 meta5"
# [1] "files exist"
# [1] "df:"
#         rsid        var_id.x  pval.x        var_id.y      pval.y
# 1 rs10154032 21:38453459:T:C 0.14910 21:38453459:T:C 6.59848e-12
# 2 rs10154036 21:38453510:T:C 0.15380 21:38453510:T:C 6.54561e-12
# 3 rs10154113 21:38497490:C:G 0.06008 21:38497490:C:G 1.87541e-10
# 4  rs1015551 21:38449510:G:A 0.17080 21:38449510:G:A 6.70449e-12
# 5  rs1053808 21:38525356:T:C 0.42530 21:38525356:T:C 4.61772e-09
# 6  rs1115639 21:38509353:A:G 0.25650 21:38509353:A:G 2.10326e-07
# [1] 926
# [1] "checkingrs2248244 TTC3 meta5"
# [1] "files exist"
# [1] "df:"
#         rsid        var_id.x  pval.x        var_id.y      pval.y
# 1 rs10154032 21:38453459:T:C 0.14910 21:38453459:T:C 1.72713e-20
# 2 rs10154036 21:38453510:T:C 0.15380 21:38453510:T:C 1.69187e-20
# 3 rs10154113 21:38497490:C:G 0.06008 21:38497490:C:G 1.35188e-19
# 4  rs1015551 21:38449510:G:A 0.17080 21:38449510:G:A 2.49162e-20
# 5  rs1053808 21:38525356:T:C 0.42530 21:38525356:T:C 3.22403e-15
# 6  rs1115639 21:38509353:A:G 0.25650 21:38509353:A:G 1.56994e-24
# [1] 927
# [1] "checkingrs2042477 CIAO1 meta5"
# [1] "files exist"
# [1] "df:"
#         rsid       var_id.x pval.x       var_id.y      pval.y
# 1  rs2276649 2:96971409:A:G 0.9900 2:96971409:A:G 2.35152e-06
# 2  rs3731930 2:96966661:G:C 0.5257 2:96966661:G:C 7.60530e-08
# 3  rs4907231 2:96969543:G:A 0.9020 2:96969543:G:A 1.25943e-06
# 4  rs4907307 2:96925269:T:A 0.6426 2:96925269:T:A 1.65694e-06
# 5  rs4907308 2:96927965:C:T 0.6920 2:96927965:C:T 6.57025e-07
# 6 rs56800261 2:96942273:A:C 0.4729 2:96942273:A:C 4.84500e-08
# [1] 928
# [1] "checkingrs2042477 MRPS5 meta5"
# [1] "files exist"
# [1] "df:"
#         rsid       var_id.x    pval.x       var_id.y      pval.y
# 1 rs10179234 2:95597163:A:G 0.0017870 2:95597163:A:G 5.35385e-08
# 2 rs10210891 2:95580865:T:G 0.0466200 2:95580865:T:G 5.79932e-08
# 3 rs11164116 2:95585292:C:G 0.0010650 2:95585292:C:G 7.82121e-08
# 4 rs11686534 2:95901265:A:G 0.0002881 2:95901265:A:G 2.53067e-10
# 5  rs1316873 2:95698646:C:G 0.6521000 2:95698646:C:G 3.63219e-06
# 6 rs13386035 2:95451642:T:C 0.2907000 2:95451642:T:C 1.09106e-06
# [1] 929
# [1] "checkingrs2042477 STARD7 meta5"
# [1] "files exist"
# [1] "df:"
#          rsid       var_id.x  pval.x       var_id.y      pval.y
# 1 rs111397326 2:96374796:C:T 0.02767 2:96374796:C:T 3.29078e-08
# 2 rs114495648 2:96746794:C:T 0.17650 2:96746794:C:T 7.03913e-08
# 3 rs115967585 2:96837527:G:A 0.28400 2:96837527:G:A 2.05722e-07
# 4 rs150964531 2:96624165:T:C 0.37810 2:96624165:T:C 2.95346e-07
# 5   rs3915894 2:96433984:G:A 0.44100 2:96433984:G:A 2.37614e-07
# 6   rs4062960 2:96472449:C:T 0.41630 2:96472449:C:T 2.53658e-07
# [1] 930
# [1] "checkingrs11683001 MAP4K4 meta5"
# [1] "files exist"
# [1] "df:"
#         rsid        var_id.x    pval.x        var_id.y      pval.y
# 1  rs1009656 2:102431447:T:C 5.046e-01 2:102431447:T:C 3.75085e-08
# 2 rs10177289 2:102334446:T:C 5.067e-01 2:102334446:T:C 5.97504e-08
# 3 rs10432622 2:102331171:A:G 5.337e-01 2:102331171:A:G 1.17576e-07
# 4 rs10865047 2:102429516:A:G 5.379e-01 2:102429516:A:G 2.42059e-08
# 5 rs11678405 2:102513306:T:C 2.504e-06 2:102513306:T:C 3.11100e-06
# 6 rs11680078 2:102425602:A:G 5.665e-01 2:102425602:A:G 3.22388e-08
# [1] 931
# [1] "checkingrs11683001 MAP4K4 meta5"
# [1] "files exist"
# [1] "df:"
#         rsid        var_id.x    pval.x        var_id.y      pval.y
# 1  rs1009656 2:102431447:T:C 5.046e-01 2:102431447:T:C 3.99377e-08
# 2 rs10177289 2:102334446:T:C 5.067e-01 2:102334446:T:C 1.11736e-07
# 3 rs10432622 2:102331171:A:G 5.337e-01 2:102331171:A:G 1.88739e-07
# 4 rs10432624 2:102331772:C:T 4.486e-12 2:102331772:C:T 2.62309e-11
# 5 rs10865047 2:102429516:A:G 5.379e-01 2:102429516:A:G 3.14254e-08
# 6 rs11674324 2:102425601:C:G 5.533e-08 2:102425601:C:G 4.91022e-12
# [1] 932
# [1] "checkingrs11683001 MAP4K4 meta5"
# [1] "files exist"
# [1] "df:"
#        rsid        var_id.x pval.x        var_id.y      pval.y
# 1 rs6704799 2:101695147:T:C 0.7131 2:101695147:T:C 1.34439e-06
# [1] 933
# [1] "checkingrs11683001 RNF149 meta5"
# [1] "files exist"
# [1] "df:"
#         rsid        var_id.x pval.x        var_id.y      pval.y
# 1 rs10186000 2:101917082:C:T 0.5674 2:101917082:C:T 4.13425e-15
# 2 rs10496353 2:101917459:T:C 0.5794 2:101917459:T:C 2.03752e-15
# 3 rs11123868 2:101925026:T:C 0.1982 2:101925026:T:C 2.89604e-07
# 4 rs11687939 2:101872630:G:A 0.4992 2:101872630:G:A 3.04290e-06
# 5 rs11903744 2:101887533:G:A 0.5141 2:101887533:G:A 2.15360e-06
# 6  rs1192799 2:101843276:G:A 0.7184 2:101843276:G:A 8.09485e-11
# [1] 934
# [1] "checkingrs11683001 RNF149 meta5"
# [1] "files exist"
# [1] "df:"
#          rsid        var_id.x pval.x        var_id.y      pval.y
# 1  rs10186000 2:101917082:C:T 0.5674 2:101917082:C:T 4.94446e-16
# 2  rs10496353 2:101917459:T:C 0.5794 2:101917459:T:C 3.29301e-16
# 3  rs11123868 2:101925026:T:C 0.1982 2:101925026:T:C 3.10572e-08
# 4 rs113293102 2:102153722:C:T 0.5526 2:102153722:C:T 1.55678e-06
# 5   rs1192809 2:101894820:A:G 0.1134 2:101894820:A:G 1.98591e-06
# 6  rs12468262 2:101988553:T:C 0.3727 2:101988553:T:C 1.68989e-09
# [1] 935
# [1] "checkingrs11683001 RNF149 meta5"
# [1] "files exist"
# [1] "df:"
#         rsid        var_id.x pval.x        var_id.y      pval.y
# 1 rs10186000 2:101917082:C:T 0.5674 2:101917082:C:T 3.34139e-78
# 2 rs10496353 2:101917459:T:C 0.5794 2:101917459:T:C 1.31686e-79
# 3 rs11123868 2:101925026:T:C 0.1982 2:101925026:T:C 5.54257e-38
# 4 rs11123870 2:101954867:C:G 0.8961 2:101954867:C:G 1.39920e-13
# 5 rs11123871 2:101960506:C:T 0.3226 2:101960506:C:T 1.65162e-06
# 6 rs11123873 2:101969701:C:T 0.3455 2:101969701:C:T 3.63828e-10
# [1] 936
# [1] "checkingrs11683001 RNF149 meta5"
# [1] "files exist"
# [1] "df:"
#         rsid        var_id.x pval.x        var_id.y      pval.y
# 1 rs12991475 2:101867189:A:G 0.4449 2:101867189:A:G 1.07038e-08
# [1] 937
# [1] "checkingrs11683001 RPL31 meta5"
# [1] "files exist"
# [1] "df:"
#         rsid        var_id.x  pval.x        var_id.y      pval.y
# 1 rs10084339 2:101714723:A:G 0.82890 2:101714723:A:G 1.93337e-41
# 2 rs10171847 2:101631888:C:G 0.28790 2:101631888:C:G 3.01653e-35
# 3 rs10174369 2:101632115:C:T 0.95170 2:101632115:C:T 8.02856e-12
# 4 rs10179426 2:101649269:C:T 0.70280 2:101649269:C:T 7.11568e-09
# 5 rs10182072 2:101685620:C:T 0.09682 2:101685620:C:T 3.06082e-12
# 6 rs10189697 2:101617493:C:G 0.92960 2:101617493:C:G 4.67246e-09
# [1] 938
# [1] "checkingrs11683001 RPL31 meta5"
# [1] "files exist"
# [1] "df:"
#         rsid        var_id.x  pval.x        var_id.y      pval.y
# 1 rs10171847 2:101631888:C:G 0.28790 2:101631888:C:G 4.83650e-11
# 2 rs10174369 2:101632115:C:T 0.95170 2:101632115:C:T 2.20023e-08
# 3 rs10179426 2:101649269:C:T 0.70280 2:101649269:C:T 7.86380e-08
# 4 rs10189697 2:101617493:C:G 0.92960 2:101617493:C:G 7.93502e-09
# 5 rs10201416 2:101617245:A:G 0.85060 2:101617245:A:G 3.82100e-09
# 6  rs1053095 2:101612584:T:A 0.02919 2:101612584:T:A 5.83370e-11
# [1] 939
# [1] "checkingrs61863020 BBIP1 prog1"
# [1] "files exist"
# [1] "df:"
#          rsid         var_id.x pval.x         var_id.y      pval.y
# 1 rs141417375 10:112661005:C:T 0.8572 10:112661005:C:T 4.32410e-08
# 2 rs567541240 10:112619527:A:G 0.5568 10:112619527:A:G 5.40598e-07
# [1] 940
# [1] "checkingrs61863020 BBIP1 prog1"
# [1] "files exist"
# [1] 941
# [1] "checkingrs61863020 MXI1 prog1"
# [1] "files exist"
# [1] "df:"
#         rsid         var_id.x pval.x         var_id.y      pval.y
# 1 rs11812839 10:111989675:G:A 0.8262 10:111989675:G:A 1.20120e-06
# 2 rs12256505 10:112036882:G:C 0.7258 10:112036882:G:C 3.24824e-06
# 3 rs12256823 10:111977189:G:C 0.9741 10:111977189:G:C 1.90066e-06
# 4 rs12260786 10:112032145:A:C 0.8300 10:112032145:A:C 1.90608e-06
# 5 rs12263999 10:112036646:T:G 0.7258 10:112036646:T:G 3.14311e-06
# 6 rs12264946 10:111981118:C:T 0.9993 10:111981118:C:T 1.92323e-06
# [1] 942
# [1] "checkingrs61863020 MXI1 prog1"
# [1] "files exist"
# [1] "df:"
#        rsid         var_id.x pval.x         var_id.y      pval.y
# 1 rs1418362 10:112003642:T:A 0.8888 10:112003642:T:A 1.41482e-06
# 2 rs1954282 10:112041889:T:C 0.8117 10:112041889:T:C 2.61539e-06
# 3 rs4918493 10:112070993:G:A 0.9047 10:112070993:G:A 3.74657e-06
# [1] 943
# [1] "checkingrs61863020 MXI1 prog1"
# [1] "files exist"
# [1] "df:"
#         rsid         var_id.x pval.x         var_id.y      pval.y
# 1 rs10509915 10:112088178:C:T 0.8445 10:112088178:C:T 1.00274e-10
# 2 rs10787228 10:112084976:T:C 0.6981 10:112084976:T:C 4.20304e-11
# 3 rs10884939 10:111981987:G:A 0.5273 10:111981987:G:A 4.62025e-13
# 4 rs10884948 10:112082903:G:A 0.6981 10:112082903:G:A 3.76459e-11
# 5 rs10884950 10:112092769:A:G 0.7253 10:112092769:A:G 5.04888e-11
# 6 rs10884952 10:112096173:C:T 0.6981 10:112096173:C:T 2.65686e-11
# [1] 944
# [1] "checkingrs61863020 MXI1 prog1"
# [1] "files exist"
# [1] 945
# [1] "checkingrs61863020 MXI1 prog1"
# [1] "files exist"
# [1] "df:"
#          rsid         var_id.x pval.x         var_id.y      pval.y
# 1 rs188652128 10:111614778:G:A 0.6011 10:111614778:G:A 3.35827e-06
# [1] 946
# [1] "checkingrs61863020 MXI1 prog1"
# [1] "files exist"
# [1] "df:"
#         rsid         var_id.x pval.x         var_id.y      pval.y
# 1 rs10509915 10:112088178:C:T 0.8445 10:112088178:C:T 1.28966e-07
# 2 rs10787228 10:112084976:T:C 0.6981 10:112084976:T:C 9.84156e-08
# 3 rs10884939 10:111981987:G:A 0.5273 10:111981987:G:A 8.57666e-10
# 4 rs10884948 10:112082903:G:A 0.6981 10:112082903:G:A 5.36621e-08
# 5 rs10884950 10:112092769:A:G 0.7253 10:112092769:A:G 7.05307e-08
# 6 rs10884952 10:112096173:C:T 0.6981 10:112096173:C:T 8.42040e-08
# [1] 947
# [1] "checkingrs61863020 SHOC2 prog1"
# [1] "files exist"
# [1] "df:"
#         rsid         var_id.x  pval.x         var_id.y      pval.y
# 1 rs79938072 10:112668737:G:C 0.05199 10:112668737:G:C 3.07946e-06
# [1] 948
# [1] "checkingrs382940 NIPSNAP3A prog2"
# [1] "files exist"
# [1] "df:"
#         rsid        var_id.x pval.x        var_id.y      pval.y
# 1 rs10761063 9:107399341:A:G 0.2553 9:107399341:A:G 2.24912e-06
# 2 rs10761064 9:107400167:G:A 0.2283 9:107400167:G:A 3.71381e-07
# 3 rs10761067 9:107414571:A:C 0.2341 9:107414571:A:C 2.89385e-07
# 4 rs10761068 9:107418661:C:T 0.2427 9:107418661:C:T 3.25008e-07
# 5 rs10761069 9:107420932:G:T 0.2410 9:107420932:G:T 4.31825e-07
# 6 rs10820695 9:107402258:A:T 0.2289 9:107402258:A:T 1.97553e-07
# [1] 949
# [1] "checkingrs382940 NIPSNAP3A prog2"
# [1] "files exist"
# [1] "df:"
#         rsid        var_id.x pval.x        var_id.y      pval.y
# 1 rs10761064 9:107400167:G:A 0.2283 9:107400167:G:A 8.64901e-07
# 2 rs10761067 9:107414571:A:C 0.2341 9:107414571:A:C 6.53537e-07
# 3 rs10761068 9:107418661:C:T 0.2427 9:107418661:C:T 7.48851e-07
# 4 rs10761069 9:107420932:G:T 0.2410 9:107420932:G:T 1.01187e-06
# 5 rs10820695 9:107402258:A:T 0.2289 9:107402258:A:T 4.99018e-07
# 6 rs10820698 9:107405264:A:G 0.2325 9:107405264:A:G 7.04157e-07
# [1] 950
# [1] "checkingrs382940 SLC44A1 prog2"
# [1] "files exist"
# [1] "df:"
#         rsid        var_id.x   pval.x        var_id.y      pval.y
# 1 rs10114041 9:108080002:C:T 0.006575 9:108080002:C:T 3.52558e-10
# 2 rs10115833 9:108100060:G:T 0.364000 9:108100060:G:T 4.17950e-16
# 3 rs10116656 9:108137525:C:T 0.288200 9:108137525:C:T 6.07216e-19
# 4 rs10123494 9:108121697:T:C 0.248600 9:108121697:T:C 7.67195e-11
# 5 rs10820800 9:108094558:A:G 0.065090 9:108094558:A:G 5.60657e-09
# 6 rs10991624 9:108088575:T:C 0.073750 9:108088575:T:C 3.66298e-09
# [1] 951
# [1] "checkingrs382940 SLC44A1 prog2"
# [1] "files exist"
# [1] "df:"
#         rsid        var_id.x   pval.x        var_id.y      pval.y
# 1 rs10114041 9:108080002:C:T 0.006575 9:108080002:C:T 8.20642e-08
# 2 rs10115833 9:108100060:G:T 0.364000 9:108100060:G:T 6.70495e-15
# 3 rs10116656 9:108137525:C:T 0.288200 9:108137525:C:T 1.05798e-20
# 4 rs10123494 9:108121697:T:C 0.248600 9:108121697:T:C 6.09163e-10
# 5 rs10820800 9:108094558:A:G 0.065090 9:108094558:A:G 3.69019e-07
# 6 rs10991624 9:108088575:T:C 0.073750 9:108088575:T:C 1.62752e-07
# [1] 952
# [1] "checkingrs382940 SLC44A1 prog2"
# [1] "files exist"

# %%
dim(plots_with_risk_snp)
head(plots_with_risk_snp)

write.csv(plots_with_risk_snp,file="$PATH1/qtl/psychencode/isoqtl_plots_with_risk_snp.csv",row.names=F,col.names=F)
# Out:
#   File "<ipython-input-1-a1fd8b778055>", line 4
#     write.csv(plots_with_risk_snp,file="$PATH1/qtl/psychencode/isoqtl_plots_with_risk_snp.csv",row.names=F,col.names=F)
#                                                                                               ^
# SyntaxError: keyword can't be an expression

# %%
dim(plots_with_no_data)
head(plots_with_no_data)

write.csv(plots_with_no_data,file="$PATH1/qtl/psychencode/isoqtl_plots_with_no_data.csv",row.names=F,col.names=F)
# Out:
#   File "<ipython-input-2-b0c93fd9b597>", line 4
#     write.csv(plots_with_no_data,file="$PATH1/qtl/psychencode/isoqtl_plots_with_no_data.csv",row.names=F,col.names=F)
#                                                                                             ^
# SyntaxError: keyword can't be an expression

# %%
dim(plots_to_check)
head(plots_to_check)

write.csv(plots_to_check,file="$PATH1/qtl/psychencode/isoqtl_plots_to_check.csv",row.names=F,col.names=F)
# Out:
#   File "<ipython-input-3-5257dadc66e4>", line 4
#     write.csv(plots_to_check,file="$PATH1/qtl/psychencode/isoqtl_plots_to_check.csv",row.names=F,col.names=F)
#                                                                                     ^
# SyntaxError: keyword can't be an expression

# %% [markdown]
# ## (3) Obtain Proxy SNPS Per Locus
#
# use LDlinkR to generate a list of snps with a LD R2 > 0.7 for each risk variant
#
# run this in terminal. Queries must be made sequentially for LDlinkR to work (so don't bother changing the script to run in parallel)

# %%
print("Rscript getRiskSNPProxies.R")
# Out:
# [1] "Rscript getRiskSNPProxies.R"

# %% [markdown]
# ## (4) Check Plots for Proxy SNPs
#
# go through all the plots we know need checking and see if they have a proxy.
#
# write plots with a good proxy snp to a file. and then combine that file with the list of plots that already have the risk snp to create a final plot list file

# %%
proxy_dir <- "$PATH1/qtl/proxy_snps"

# %%
plots_to_check <- fread("$PATH1/qtl/psychencode/isoqtl_plots_to_check.csv")
plots_with_proxy_snp <- data.frame()
plots_with_no_proxy_snp <- data.frame()

# %%
print(dim(plots_to_check))
# Out:
# [1] 878  11

# %%
for (rownum in 1:nrow(plots_to_check))
{
    row <- plots_to_check[rownum,]

  
  chr <- row$CHR
  snp <- row$SNP
  gene <- row$gene
  transcript <- row$transcript
  feature <- row$feature
  gwas <- row$gwas

  print(paste0("checking", snp, " " , gene, " ", gwas))
    
      
  if(gwas == "meta5")
  {
      tsv_dir <- paste0(isoqtl_tsv_dir,"/meta5")

  }
  if(gwas == "prog1")
  {
      tsv_dir <- paste0(isoqtl_tsv_dir,"/prog1")

  }
  if(gwas == "prog2")
  {
      tsv_dir <- paste0(isoqtl_tsv_dir,"/prog2")

  }
  gwas_fn = paste0(tsv_dir, '/', gene, '_', transcript, '_gwas.tsv')
  qtl_fn = paste0(tsv_dir, '/', gene, '_', transcript,'_isoqtl.tsv')
    

    g = read.table(gwas_fn, header = T)
    e = read.table(qtl_fn, header = T)

    #merge them by rsid
    df = merge(g, e, by = 'rsid')
    
    #load the proxy snps
    proxies <- fread(paste0(proxy_dir,"/",row$SNP,"_proxies.csv"))
    
    #if we even have any proxy snps for the risk variant
    if(nrow(proxies)>0)
    {
        #merge the proxy snp df with the data df
        merged <- merge(df, proxies, by.x = "rsid", by.y = "RS_Number")

        if(nrow(merged) > 0)
        {
            best_ld_snp <- merged[which.max(merged$R2),]
            row$'forced_lead_variant' <- best_ld_snp$rsid
            row$'forced_lead_variant_r2' <- best_ld_snp$R2
            row$'reason' <- "plot has a good proxy snp"
            plots_with_proxy_snp <- rbind(plots_with_proxy_snp,row)
            
        }
        else
        {
            row$'reason' <- "no good proxy snp exists in the data we want to plot"
            plots_with_no_proxy_snp <- rbind(plots_with_no_proxy_snp, row)
        }
    }
    else
    {
        row$'reason' <- "there was no proxy snp for the risk variant"
        plots_with_no_proxy_snp <- rbind(plots_with_no_proxy_snp, row)
    }
    
    
    
    
}
# Out:
# [1] "checkingrs114138760 ADAR meta5"
# [1] "checkingrs114138760 ADAR meta5"
# [1] "checkingrs114138760 ADAR meta5"
# [1] "checkingrs35749011 ADAR meta5"
# [1] "checkingrs35749011 ADAR meta5"
# [1] "checkingrs35749011 ADAR meta5"
# [1] "checkingrs76763715 ADAR meta5"
# [1] "checkingrs76763715 ADAR meta5"
# [1] "checkingrs76763715 ADAR meta5"
# [1] "checkingrs114138760 ARHGEF2 meta5"
# [1] "checkingrs35749011 ARHGEF2 meta5"
# [1] "checkingrs76763715 ARHGEF2 meta5"
# [1] "checkingrs114138760 C1orf43 meta5"
# [1] "checkingrs114138760 C1orf43 meta5"
# [1] "checkingrs114138760 C1orf43 meta5"
# [1] "checkingrs114138760 C1orf43 meta5"
# [1] "checkingrs35749011 C1orf43 meta5"
# [1] "checkingrs35749011 C1orf43 meta5"
# [1] "checkingrs35749011 C1orf43 meta5"
# [1] "checkingrs35749011 C1orf43 meta5"
# [1] "checkingrs76763715 C1orf43 meta5"
# [1] "checkingrs76763715 C1orf43 meta5"
# [1] "checkingrs76763715 C1orf43 meta5"
# [1] "checkingrs76763715 C1orf43 meta5"
# [1] "checkingrs114138760 DAP3 meta5"
# [1] "checkingrs114138760 DAP3 meta5"
# [1] "checkingrs35749011 DAP3 meta5"
# [1] "checkingrs35749011 DAP3 meta5"
# [1] "checkingrs76763715 DAP3 meta5"
# [1] "checkingrs76763715 DAP3 meta5"
# [1] "checkingrs114138760 FDPS meta5"
# [1] "checkingrs114138760 FDPS meta5"
# [1] "checkingrs114138760 FDPS meta5"
# [1] "checkingrs114138760 FDPS meta5"
# [1] "checkingrs114138760 FDPS meta5"
# [1] "checkingrs114138760 FDPS meta5"
# [1] "checkingrs35749011 FDPS meta5"
# [1] "checkingrs35749011 FDPS meta5"
# [1] "checkingrs35749011 FDPS meta5"
# [1] "checkingrs35749011 FDPS meta5"
# [1] "checkingrs35749011 FDPS meta5"
# [1] "checkingrs35749011 FDPS meta5"
# [1] "checkingrs76763715 FDPS meta5"
# [1] "checkingrs76763715 FDPS meta5"
# [1] "checkingrs76763715 FDPS meta5"
# [1] "checkingrs76763715 FDPS meta5"
# [1] "checkingrs76763715 FDPS meta5"
# [1] "checkingrs76763715 FDPS meta5"
# [1] "checkingrs114138760 HAX1 meta5"
# [1] "checkingrs114138760 HAX1 meta5"
# [1] "checkingrs35749011 HAX1 meta5"
# [1] "checkingrs35749011 HAX1 meta5"
# [1] "checkingrs76763715 HAX1 meta5"
# [1] "checkingrs76763715 HAX1 meta5"
# [1] "checkingrs114138760 TPM3 meta5"
# [1] "checkingrs114138760 TPM3 meta5"
# [1] "checkingrs114138760 TPM3 meta5"
# [1] "checkingrs114138760 TPM3 meta5"
# [1] "checkingrs114138760 TPM3 meta5"
# [1] "checkingrs114138760 TPM3 meta5"
# [1] "checkingrs35749011 TPM3 meta5"
# [1] "checkingrs35749011 TPM3 meta5"
# [1] "checkingrs35749011 TPM3 meta5"
# [1] "checkingrs35749011 TPM3 meta5"
# [1] "checkingrs35749011 TPM3 meta5"
# [1] "checkingrs35749011 TPM3 meta5"
# [1] "checkingrs76763715 TPM3 meta5"
# [1] "checkingrs76763715 TPM3 meta5"
# [1] "checkingrs76763715 TPM3 meta5"
# [1] "checkingrs76763715 TPM3 meta5"
# [1] "checkingrs76763715 TPM3 meta5"
# [1] "checkingrs76763715 TPM3 meta5"
# [1] "checkingrs114138760 YY1AP1 meta5"
# [1] "checkingrs114138760 YY1AP1 meta5"
# [1] "checkingrs114138760 YY1AP1 meta5"
# [1] "checkingrs114138760 YY1AP1 meta5"
# [1] "checkingrs114138760 YY1AP1 meta5"
# [1] "checkingrs114138760 YY1AP1 meta5"
# [1] "checkingrs114138760 YY1AP1 meta5"
# [1] "checkingrs114138760 YY1AP1 meta5"
# [1] "checkingrs114138760 YY1AP1 meta5"
# [1] "checkingrs114138760 YY1AP1 meta5"
# [1] "checkingrs114138760 YY1AP1 meta5"
# [1] "checkingrs35749011 YY1AP1 meta5"
# [1] "checkingrs35749011 YY1AP1 meta5"
# [1] "checkingrs35749011 YY1AP1 meta5"
# [1] "checkingrs35749011 YY1AP1 meta5"
# [1] "checkingrs35749011 YY1AP1 meta5"
# [1] "checkingrs35749011 YY1AP1 meta5"
# [1] "checkingrs35749011 YY1AP1 meta5"
# [1] "checkingrs35749011 YY1AP1 meta5"
# [1] "checkingrs35749011 YY1AP1 meta5"
# [1] "checkingrs35749011 YY1AP1 meta5"
# [1] "checkingrs35749011 YY1AP1 meta5"
# [1] "checkingrs76763715 YY1AP1 meta5"
# [1] "checkingrs76763715 YY1AP1 meta5"
# [1] "checkingrs76763715 YY1AP1 meta5"
# [1] "checkingrs76763715 YY1AP1 meta5"
# [1] "checkingrs76763715 YY1AP1 meta5"
# [1] "checkingrs76763715 YY1AP1 meta5"
# [1] "checkingrs76763715 YY1AP1 meta5"
# [1] "checkingrs76763715 YY1AP1 meta5"
# [1] "checkingrs76763715 YY1AP1 meta5"
# [1] "checkingrs76763715 YY1AP1 meta5"
# [1] "checkingrs76763715 YY1AP1 meta5"
# [1] "checkingrs57891859 CCNT2 meta5"
# [1] "checkingrs57891859 CCNT2 meta5"
# [1] "checkingrs57891859 R3HDM1 meta5"
# [1] "checkingrs73038319 SATB1 meta5"
# [1] "checkingrs73038319 SATB1 meta5"
# [1] "checkingrs73038319 TBC1D5 meta5"
# [1] "checkingrs73038319 TBC1D5 meta5"
# [1] "checkingrs73038319 TBC1D5 meta5"
# [1] "checkingrs73038319 TBC1D5 meta5"
# [1] "checkingrs73038319 TBC1D5 meta5"
# [1] "checkingrs73038319 TBC1D5 meta5"
# [1] "checkingrs73038319 TBC1D5 meta5"
# [1] "checkingrs73038319 TBC1D5 meta5"
# [1] "checkingrs73038319 TBC1D5 meta5"
# [1] "checkingrs73038319 TBC1D5 meta5"
# [1] "checkingrs73038319 TBC1D5 meta5"
# [1] "checkingrs6808178 AZI2 meta5"
# [1] "checkingrs12497850 ARIH2 meta5"
# [1] "checkingrs12497850 ARIH2 meta5"
# [1] "checkingrs12497850 ARIH2 meta5"
# [1] "checkingrs12497850 DHX30 meta5"
# [1] "checkingrs12497850 DHX30 meta5"
# [1] "checkingrs12497850 IP6K2 meta5"
# [1] "checkingrs12497850 IP6K2 meta5"
# [1] "checkingrs12497850 IP6K2 meta5"
# [1] "checkingrs12497850 IP6K2 meta5"
# [1] "checkingrs12497850 IP6K2 meta5"
# [1] "checkingrs12497850 MAP4 meta5"
# [1] "checkingrs12497850 MAP4 meta5"
# [1] "checkingrs12497850 MAP4 meta5"
# [1] "checkingrs12497850 MAP4 meta5"
# [1] "checkingrs12497850 P4HTM meta5"
# [1] "checkingrs12497850 P4HTM meta5"
# [1] "checkingrs12497850 P4HTM meta5"
# [1] "checkingrs12497850 P4HTM meta5"
# [1] "checkingrs12497850 P4HTM meta5"
# [1] "checkingrs12497850 PLXNB1 meta5"
# [1] "checkingrs12497850 QARS meta5"
# [1] "checkingrs12497850 QRICH1 meta5"
# [1] "checkingrs12497850 QRICH1 meta5"
# [1] "checkingrs12497850 QRICH1 meta5"
# [1] "checkingrs12497850 UQCRC1 meta5"
# [1] "checkingrs55961674 FAM162A meta5"
# [1] "checkingrs55961674 FAM162A meta5"
# [1] "checkingrs55961674 FAM162A meta5"
# [1] "checkingrs55961674 KPNA1 meta5"
# [1] "checkingrs55961674 KPNA1 meta5"
# [1] "checkingrs55961674 KPNA1 meta5"
# [1] "checkingrs55961674 KPNA1 meta5"
# [1] "checkingrs55961674 KPNA1 meta5"
# [1] "checkingrs11707416 EIF2A meta5"
# [1] "checkingrs11707416 EIF2A meta5"
# [1] "checkingrs11707416 EIF2A meta5"
# [1] "checkingrs11707416 EIF2A meta5"
# [1] "checkingrs11707416 MBNL1 meta5"
# [1] "checkingrs11707416 SERP1 meta5"
# [1] "checkingrs11707416 SERP1 meta5"
# [1] "checkingrs11707416 SERP1 meta5"
# [1] "checkingrs11707416 SERP1 meta5"
# [1] "checkingrs11707416 SERP1 meta5"
# [1] "checkingrs11707416 SERP1 meta5"
# [1] "checkingrs11707416 SERP1 meta5"
# [1] "checkingrs1450522 IFT80 meta5"
# [1] "checkingrs1450522 IFT80 meta5"
# [1] "checkingrs1450522 NMD3 meta5"
# [1] "checkingrs1450522 NMD3 meta5"
# [1] "checkingrs10513789 MCCC1 meta5"
# [1] "checkingrs10513789 MCCC1 meta5"
# [1] "checkingrs10513789 MCCC1 meta5"
# [1] "checkingrs10513789 PARL meta5"
# [1] "checkingrs34311866 GAK meta5"
# [1] "checkingrs34311866 GAK meta5"
# [1] "checkingrs34311866 GAK meta5"
# [1] "checkingrs873786 GAK meta5"
# [1] "checkingrs873786 GAK meta5"
# [1] "checkingrs873786 GAK meta5"
# [1] "checkingrs34311866 MAEA meta5"
# [1] "checkingrs34311866 MAEA meta5"
# [1] "checkingrs34311866 MAEA meta5"
# [1] "checkingrs873786 MAEA meta5"
# [1] "checkingrs873786 MAEA meta5"
# [1] "checkingrs873786 MAEA meta5"
# [1] "checkingrs34311866 PCGF3 meta5"
# [1] "checkingrs34311866 PCGF3 meta5"
# [1] "checkingrs34311866 PCGF3 meta5"
# [1] "checkingrs34311866 PCGF3 meta5"
# [1] "checkingrs873786 PCGF3 meta5"
# [1] "checkingrs873786 PCGF3 meta5"
# [1] "checkingrs873786 PCGF3 meta5"
# [1] "checkingrs873786 PCGF3 meta5"
# [1] "checkingrs34311866 ZNF721 meta5"
# [1] "checkingrs873786 ZNF721 meta5"
# [1] "checkingrs6658353 DUSP12 meta5"
# [1] "checkingrs6658353 NDUFS2 meta5"
# [1] "checkingrs6658353 NDUFS2 meta5"
# [1] "checkingrs6658353 NDUFS2 meta5"
# [1] "checkingrs6658353 NDUFS2 meta5"
# [1] "checkingrs6658353 NDUFS2 meta5"
# [1] "checkingrs6658353 SDHC meta5"
# [1] "checkingrs6658353 UHMK1 meta5"
# [1] "checkingrs6658353 USF1 meta5"
# [1] "checkingrs4698412 FAM200B meta5"
# [1] "checkingrs4698412 FAM200B meta5"
# [1] "checkingrs4698412 FAM200B meta5"
# [1] "checkingrs4698412 FAM200B meta5"
# [1] "checkingrs4698412 FAM200B meta5"
# [1] "checkingrs4698412 FAM200B meta5"
# [1] "checkingrs4698412 FAM200B meta5"
# [1] "checkingrs4698412 FAM200B meta5"
# [1] "checkingrs4698412 FAM200B meta5"
# [1] "checkingrs4698412 FAM200B meta5"
# [1] "checkingrs4698412 FBXL5 meta5"
# [1] "checkingrs4698412 FBXL5 meta5"
# [1] "checkingrs4698412 LDB2 meta5"
# [1] "checkingrs4698412 TAPT1 meta5"
# [1] "checkingrs4698412 TAPT1 meta5"
# [1] "checkingrs4698412 TAPT1 meta5"
# [1] "checkingrs4698412 TAPT1 meta5"
# [1] "checkingrs4698412 TAPT1 meta5"
# [1] "checkingrs34025766 LAP3 meta5"
# [1] "checkingrs34025766 QDPR meta5"
# [1] "checkingrs34025766 QDPR meta5"
# [1] "checkingrs34025766 QDPR meta5"
# [1] "checkingrs34025766 QDPR meta5"
# [1] "checkingrs34025766 QDPR meta5"
# [1] "checkingrs4101061 G3BP2 meta5"
# [1] "checkingrs4101061 G3BP2 meta5"
# [1] "checkingrs4101061 G3BP2 meta5"
# [1] "checkingrs4101061 G3BP2 meta5"
# [1] "checkingrs6825004 G3BP2 meta5"
# [1] "checkingrs6825004 G3BP2 meta5"
# [1] "checkingrs6825004 G3BP2 meta5"
# [1] "checkingrs6825004 G3BP2 meta5"
# [1] "checkingrs6854006 G3BP2 meta5"
# [1] "checkingrs6854006 G3BP2 meta5"
# [1] "checkingrs6854006 G3BP2 meta5"
# [1] "checkingrs6854006 G3BP2 meta5"
# [1] "checkingrs4101061 RCHY1 meta5"
# [1] "checkingrs4101061 RCHY1 meta5"
# [1] "checkingrs4101061 RCHY1 meta5"
# [1] "checkingrs4101061 RCHY1 meta5"
# [1] "checkingrs4101061 RCHY1 meta5"
# [1] "checkingrs4101061 RCHY1 meta5"
# [1] "checkingrs6825004 RCHY1 meta5"
# [1] "checkingrs6825004 RCHY1 meta5"
# [1] "checkingrs6825004 RCHY1 meta5"
# [1] "checkingrs6825004 RCHY1 meta5"
# [1] "checkingrs6825004 RCHY1 meta5"
# [1] "checkingrs6825004 RCHY1 meta5"
# [1] "checkingrs6854006 RCHY1 meta5"
# [1] "checkingrs6854006 RCHY1 meta5"
# [1] "checkingrs6854006 RCHY1 meta5"
# [1] "checkingrs6854006 RCHY1 meta5"
# [1] "checkingrs6854006 RCHY1 meta5"
# [1] "checkingrs6854006 RCHY1 meta5"
# [1] "checkingrs4101061 USO1 meta5"
# [1] "checkingrs6825004 USO1 meta5"
# [1] "checkingrs6854006 USO1 meta5"
# [1] "checkingrs356182 HERC3 meta5"
# [1] "checkingrs356182 HERC3 meta5"
# [1] "checkingrs356182 HERC3 meta5"
# [1] "checkingrs356182 HERC3 meta5"
# [1] "checkingrs356182 HERC3 meta5"
# [1] "checkingrs5019538 HERC3 meta5"
# [1] "checkingrs5019538 HERC3 meta5"
# [1] "checkingrs5019538 HERC3 meta5"
# [1] "checkingrs5019538 HERC3 meta5"
# [1] "checkingrs5019538 HERC3 meta5"
# [1] "checkingrs356182 SNCA meta5"
# [1] "checkingrs356182 SNCA meta5"
# [1] "checkingrs356182 SNCA meta5"
# [1] "checkingrs356182 SNCA meta5"
# [1] "checkingrs356182 SNCA meta5"
# [1] "checkingrs356182 SNCA meta5"
# [1] "checkingrs356182 SNCA meta5"
# [1] "checkingrs356182 SNCA meta5"
# [1] "checkingrs356182 SNCA meta5"
# [1] "checkingrs5019538 SNCA meta5"
# [1] "checkingrs5019538 SNCA meta5"
# [1] "checkingrs5019538 SNCA meta5"
# [1] "checkingrs13117519 ANK2 meta5"
# [1] "checkingrs13117519 CAMK2D meta5"
# [1] "checkingrs13117519 CAMK2D meta5"
# [1] "checkingrs13117519 CAMK2D meta5"
# [1] "checkingrs13117519 LARP7 meta5"
# [1] "checkingrs13117519 LARP7 meta5"
# [1] "checkingrs13117519 LARP7 meta5"
# [1] "checkingrs13117519 LARP7 meta5"
# [1] "checkingrs13117519 LARP7 meta5"
# [1] "checkingrs62333164 CLCN3 meta5"
# [1] "checkingrs62333164 CLCN3 meta5"
# [1] "checkingrs1867598 NDUFAF2 meta5"
# [1] "checkingrs26431 PAM meta5"
# [1] "checkingrs26431 PAM meta5"
# [1] "checkingrs26431 PAM meta5"
# [1] "checkingrs26431 PAM meta5"
# [1] "checkingrs26431 PAM meta5"
# [1] "checkingrs26431 PAM meta5"
# [1] "checkingrs11950533 CAMLG meta5"
# [1] "checkingrs11950533 CAMLG meta5"
# [1] "checkingrs11950533 PPP2CA meta5"
# [1] "checkingrs11950533 SAR1B meta5"
# [1] "checkingrs11950533 SKP1 meta5"
# [1] "checkingrs11950533 SKP1 meta5"
# [1] "checkingrs11950533 SKP1 meta5"
# [1] "checkingrs11950533 TXNDC15 meta5"
# [1] "checkingrs11950533 TXNDC15 meta5"
# [1] "checkingrs11950533 TXNDC15 meta5"
# [1] "checkingrs11950533 TXNDC15 meta5"
# [1] "checkingrs11950533 TXNDC15 meta5"
# [1] "checkingrs11950533 TXNDC15 meta5"
# [1] "checkingrs11950533 TXNDC15 meta5"
# [1] "checkingrs11950533 UBE2B meta5"
# [1] "checkingrs11950533 VDAC1 meta5"
# [1] "checkingrs11950533 VDAC1 meta5"
# [1] "checkingrs11578699 DNM3 meta5"
# [1] "checkingrs11578699 DNM3 meta5"
# [1] "checkingrs11578699 PRRC2C meta5"
# [1] "checkingrs11578699 PRRC2C meta5"
# [1] "checkingrs112485576 BRD2 meta5"
# [1] "checkingrs112485576 CUTA meta5"
# [1] "checkingrs112485576 CUTA meta5"
# [1] "checkingrs112485576 CUTA meta5"
# [1] "checkingrs112485576 CUTA meta5"
# [1] "checkingrs112485576 RPS18 meta5"
# [1] "checkingrs12528068 RIMS1 meta5"
# [1] "checkingrs12528068 RIMS1 meta5"
# [1] "checkingrs12528068 SMAP1 meta5"
# [1] "checkingrs12528068 SMAP1 meta5"
# [1] "checkingrs12528068 SMAP1 meta5"
# [1] "checkingrs997368 FAM229B meta5"
# [1] "checkingrs997368 FAM229B meta5"
# [1] "checkingrs997368 FYN meta5"
# [1] "checkingrs997368 FYN meta5"
# [1] "checkingrs997368 FYN meta5"
# [1] "checkingrs997368 TUBE1 meta5"
# [1] "checkingrs997368 TUBE1 meta5"
# [1] "checkingrs75859381 STX7 meta5"
# [1] "checkingrs199351 KLHL7 meta5"
# [1] "checkingrs199351 KLHL7 meta5"
# [1] "checkingrs199351 KLHL7 meta5"
# [1] "checkingrs199351 RAPGEF5 meta5"
# [1] "checkingrs199351 RAPGEF5 meta5"
# [1] "checkingrs199351 TOMM7 meta5"
# [1] "checkingrs199351 TOMM7 meta5"
# [1] "checkingrs199351 TRA2A meta5"
# [1] "checkingrs76949143 CRCP meta5"
# [1] "checkingrs1293298 CTSB meta5"
# [1] "checkingrs1293298 CTSB meta5"
# [1] "checkingrs1293298 CTSB meta5"
# [1] "checkingrs1293298 CTSB meta5"
# [1] "checkingrs1293298 CTSB meta5"
# [1] "checkingrs1293298 CTSB meta5"
# [1] "checkingrs1293298 CTSB meta5"
# [1] "checkingrs1293298 CTSB meta5"
# [1] "checkingrs1293298 CTSB meta5"
# [1] "checkingrs1293298 CTSB meta5"
# [1] "checkingrs1293298 CTSB meta5"
# [1] "checkingrs1293298 CTSB meta5"
# [1] "checkingrs1293298 CTSB meta5"
# [1] "checkingrs1293298 CTSB meta5"
# [1] "checkingrs1293298 FDFT1 meta5"
# [1] "checkingrs1293298 FDFT1 meta5"
# [1] "checkingrs620513 CNOT7 meta5"
# [1] "checkingrs620513 CNOT7 meta5"
# [1] "checkingrs620513 CNOT7 meta5"
# [1] "checkingrs620513 CNOT7 meta5"
# [1] "checkingrs620513 MICU3 meta5"
# [1] "checkingrs620513 MICU3 meta5"
# [1] "checkingrs620513 MTUS1 meta5"
# [1] "checkingrs620513 MTUS1 meta5"
# [1] "checkingrs620513 MTUS1 meta5"
# [1] "checkingrs620513 MTUS1 meta5"
# [1] "checkingrs620513 MTUS1 meta5"
# [1] "checkingrs620513 MTUS1 meta5"
# [1] "checkingrs620513 MTUS1 meta5"
# [1] "checkingrs620513 MTUS1 meta5"
# [1] "checkingrs620513 MTUS1 meta5"
# [1] "checkingrs620513 MTUS1 meta5"
# [1] "checkingrs620513 VPS37A meta5"
# [1] "checkingrs620513 VPS37A meta5"
# [1] "checkingrs620513 VPS37A meta5"
# [1] "checkingrs2280104 DMTN meta5"
# [1] "checkingrs2280104 DMTN meta5"
# [1] "checkingrs2280104 DMTN meta5"
# [1] "checkingrs2280104 DMTN meta5"
# [1] "checkingrs2280104 DMTN meta5"
# [1] "checkingrs2280104 DMTN meta5"
# [1] "checkingrs2280104 NPM2 meta5"
# [1] "checkingrs2280104 NPM2 meta5"
# [1] "checkingrs2280104 PHYHIP meta5"
# [1] "checkingrs2280104 PHYHIP meta5"
# [1] "checkingrs2280104 PHYHIP meta5"
# [1] "checkingrs2280104 R3HCC1 meta5"
# [1] "checkingrs11557080 MFSD4A meta5"
# [1] "checkingrs11557080 MFSD4A meta5"
# [1] "checkingrs823118 MFSD4A meta5"
# [1] "checkingrs823118 MFSD4A meta5"
# [1] "checkingrs11557080 NFASC meta5"
# [1] "checkingrs11557080 NFASC meta5"
# [1] "checkingrs11557080 NFASC meta5"
# [1] "checkingrs11557080 NFASC meta5"
# [1] "checkingrs11557080 NFASC meta5"
# [1] "checkingrs823118 NFASC meta5"
# [1] "checkingrs823118 NFASC meta5"
# [1] "checkingrs823118 NFASC meta5"
# [1] "checkingrs823118 NFASC meta5"
# [1] "checkingrs823118 NFASC meta5"
# [1] "checkingrs11557080 SRGAP2 meta5"
# [1] "checkingrs823118 SRGAP2 meta5"
# [1] "checkingrs2086641 ASAP1 meta5"
# [1] "checkingrs2086641 ASAP1 meta5"
# [1] "checkingrs2086641 ASAP1 meta5"
# [1] "checkingrs2086641 FAM49B meta5"
# [1] "checkingrs2086641 FAM49B meta5"
# [1] "checkingrs2086641 FAM49B meta5"
# [1] "checkingrs6476434 BAG1 meta5"
# [1] "checkingrs6476434 FAM219A meta5"
# [1] "checkingrs6476434 NFX1 meta5"
# [1] "checkingrs6476434 SMU1 meta5"
# [1] "checkingrs896435 HSPA14 meta5"
# [1] "checkingrs896435 HSPA14 meta5"
# [1] "checkingrs10748818 ACTR1A meta5"
# [1] "checkingrs10748818 ACTR1A meta5"
# [1] "checkingrs10748818 ACTR1A meta5"
# [1] "checkingrs10748818 ACTR1A meta5"
# [1] "checkingrs10748818 CUEDC2 meta5"
# [1] "checkingrs10748818 NOLC1 meta5"
# [1] "checkingrs10748818 NT5C2 meta5"
# [1] "checkingrs10748818 NT5C2 meta5"
# [1] "checkingrs117896735 FAM45A meta5"
# [1] "checkingrs117896735 FAM45A meta5"
# [1] "checkingrs117896735 FAM45A meta5"
# [1] "checkingrs117896735 FAM45A meta5"
# [1] "checkingrs117896735 FAM45A meta5"
# [1] "checkingrs72840788 FAM45A meta5"
# [1] "checkingrs72840788 FAM45A meta5"
# [1] "checkingrs72840788 FAM45A meta5"
# [1] "checkingrs72840788 FAM45A meta5"
# [1] "checkingrs72840788 FAM45A meta5"
# [1] "checkingrs117896735 INPP5F meta5"
# [1] "checkingrs117896735 INPP5F meta5"
# [1] "checkingrs117896735 INPP5F meta5"
# [1] "checkingrs72840788 INPP5F meta5"
# [1] "checkingrs117896735 RPL21 meta5"
# [1] "checkingrs117896735 RPL21 meta5"
# [1] "checkingrs117896735 RPL21 meta5"
# [1] "checkingrs117896735 RPL21 meta5"
# [1] "checkingrs117896735 RPL21 meta5"
# [1] "checkingrs72840788 RPL21 meta5"
# [1] "checkingrs72840788 RPL21 meta5"
# [1] "checkingrs72840788 RPL21 meta5"
# [1] "checkingrs72840788 RPL21 meta5"
# [1] "checkingrs72840788 RPL21 meta5"
# [1] "checkingrs117896735 TIAL1 meta5"
# [1] "checkingrs72840788 TIAL1 meta5"
# [1] "checkingrs7938782 EIF4G2 meta5"
# [1] "checkingrs7938782 EIF4G2 meta5"
# [1] "checkingrs7938782 EIF4G2 meta5"
# [1] "checkingrs7938782 EIF4G2 meta5"
# [1] "checkingrs7938782 EIF4G2 meta5"
# [1] "checkingrs7938782 EIF4G2 meta5"
# [1] "checkingrs7938782 EIF4G2 meta5"
# [1] "checkingrs7938782 RNF141 meta5"
# [1] "checkingrs7938782 RNF141 meta5"
# [1] "checkingrs7938782 RNF141 meta5"
# [1] "checkingrs7938782 RNF141 meta5"
# [1] "checkingrs7938782 ZBED5 meta5"
# [1] "checkingrs7938782 ZBED5 meta5"
# [1] "checkingrs12283611 CCDC90B meta5"
# [1] "checkingrs12283611 CCDC90B meta5"
# [1] "checkingrs12283611 CCDC90B meta5"
# [1] "checkingrs12283611 CCDC90B meta5"
# [1] "checkingrs12283611 CCDC90B meta5"
# [1] "checkingrs12283611 CCDC90B meta5"
# [1] "checkingrs12283611 CCDC90B meta5"
# [1] "checkingrs12283611 DLG2 meta5"
# [1] "checkingrs12283611 PRCP meta5"
# [1] "checkingrs12283611 PRCP meta5"
# [1] "checkingrs12283611 PRCP meta5"
# [1] "checkingrs12283611 PRCP meta5"
# [1] "checkingrs12283611 PRCP meta5"
# [1] "checkingrs3802920 ACAD8 meta5"
# [1] "checkingrs3802920 ACAD8 meta5"
# [1] "checkingrs3802920 B3GAT1 meta5"
# [1] "checkingrs3802920 B3GAT1 meta5"
# [1] "checkingrs3802920 B3GAT1 meta5"
# [1] "checkingrs3802920 JAM3 meta5"
# [1] "checkingrs3802920 JAM3 meta5"
# [1] "checkingrs3802920 THYN1 meta5"
# [1] "checkingrs3802920 THYN1 meta5"
# [1] "checkingrs34637584 CNTN1 meta5"
# [1] "checkingrs34637584 CNTN1 meta5"
# [1] "checkingrs76904798 CNTN1 meta5"
# [1] "checkingrs76904798 CNTN1 meta5"
# [1] "checkingrs4653767 CDC42BPA meta5"
# [1] "checkingrs4653767 CDC42BPA meta5"
# [1] "checkingrs4653767 CDC42BPA meta5"
# [1] "checkingrs4653767 CDC42BPA meta5"
# [1] "checkingrs4653767 CDC42BPA meta5"
# [1] "checkingrs4653767 CDC42BPA meta5"
# [1] "checkingrs4653767 H3F3A meta5"
# [1] "checkingrs4653767 H3F3A meta5"
# [1] "checkingrs4653767 H3F3A meta5"
# [1] "checkingrs4653767 PARP1 meta5"
# [1] "checkingrs4653767 PARP1 meta5"
# [1] "checkingrs4653767 SNAP47 meta5"
# [1] "checkingrs4653767 SNAP47 meta5"
# [1] "checkingrs4653767 SNAP47 meta5"
# [1] "checkingrs4653767 SNAP47 meta5"
# [1] "checkingrs4653767 SNAP47 meta5"
# [1] "checkingrs4653767 SNAP47 meta5"
# [1] "checkingrs4653767 SRP9 meta5"
# [1] "checkingrs4653767 SRP9 meta5"
# [1] "checkingrs7134559 SLC38A2 meta5"
# [1] "checkingrs10847864 ARL6IP4 meta5"
# [1] "checkingrs10847864 ARL6IP4 meta5"
# [1] "checkingrs10847864 ARL6IP4 meta5"
# [1] "checkingrs10847864 ARL6IP4 meta5"
# [1] "checkingrs10847864 ARL6IP4 meta5"
# [1] "checkingrs10847864 ARL6IP4 meta5"
# [1] "checkingrs10847864 ARL6IP4 meta5"
# [1] "checkingrs10847864 CDK2AP1 meta5"
# [1] "checkingrs10847864 CLIP1 meta5"
# [1] "checkingrs10847864 DIABLO meta5"
# [1] "checkingrs10847864 DIABLO meta5"
# [1] "checkingrs10847864 RSRC2 meta5"
# [1] "checkingrs10847864 RSRC2 meta5"
# [1] "checkingrs10847864 RSRC2 meta5"
# [1] "checkingrs10847864 RSRC2 meta5"
# [1] "checkingrs10847864 RSRC2 meta5"
# [1] "checkingrs10847864 RSRC2 meta5"
# [1] "checkingrs10847864 RSRC2 meta5"
# [1] "checkingrs10847864 RSRC2 meta5"
# [1] "checkingrs10847864 RSRC2 meta5"
# [1] "checkingrs11610045 ANKLE2 meta5"
# [1] "checkingrs11610045 ANKLE2 meta5"
# [1] "checkingrs11610045 ANKLE2 meta5"
# [1] "checkingrs11610045 ANKLE2 meta5"
# [1] "checkingrs11610045 ANKLE2 meta5"
# [1] "checkingrs11610045 ANKLE2 meta5"
# [1] "checkingrs11610045 ZNF84 meta5"
# [1] "checkingrs11610045 ZNF84 meta5"
# [1] "checkingrs11610045 ZNF84 meta5"
# [1] "checkingrs11610045 ZNF84 meta5"
# [1] "checkingrs9568188 CAB39L meta5"
# [1] "checkingrs9568188 CAB39L meta5"
# [1] "checkingrs9568188 CAB39L meta5"
# [1] "checkingrs9568188 CAB39L meta5"
# [1] "checkingrs9568188 CAB39L meta5"
# [1] "checkingrs4771268 FARP1 meta5"
# [1] "checkingrs4771268 FARP1 meta5"
# [1] "checkingrs4771268 FARP1 meta5"
# [1] "checkingrs4771268 FARP1 meta5"
# [1] "checkingrs4771268 FARP1 meta5"
# [1] "checkingrs4771268 FARP1 meta5"
# [1] "checkingrs4771268 FARP1 meta5"
# [1] "checkingrs4771268 FARP1 meta5"
# [1] "checkingrs4771268 IPO5 meta5"
# [1] "checkingrs4771268 IPO5 meta5"
# [1] "checkingrs4771268 IPO5 meta5"
# [1] "checkingrs4771268 IPO5 meta5"
# [1] "checkingrs4771268 IPO5 meta5"
# [1] "checkingrs4771268 IPO5 meta5"
# [1] "checkingrs11158026 CNIH1 meta5"
# [1] "checkingrs11158026 CNIH1 meta5"
# [1] "checkingrs11158026 CNIH1 meta5"
# [1] "checkingrs11158026 KTN1 meta5"
# [1] "checkingrs11158026 KTN1 meta5"
# [1] "checkingrs11158026 KTN1 meta5"
# [1] "checkingrs11158026 KTN1 meta5"
# [1] "checkingrs3742785 ALDH6A1 meta5"
# [1] "checkingrs3742785 ALDH6A1 meta5"
# [1] "checkingrs3742785 ALDH6A1 meta5"
# [1] "checkingrs3742785 DLST meta5"
# [1] "checkingrs3742785 TMED10 meta5"
# [1] "checkingrs3742785 TMED10 meta5"
# [1] "checkingrs3742785 ZNF410 meta5"
# [1] "checkingrs3742785 ZNF410 meta5"
# [1] "checkingrs3742785 ZNF410 meta5"
# [1] "checkingrs3742785 ZNF410 meta5"
# [1] "checkingrs3742785 ZNF410 meta5"
# [1] "checkingrs2251086 VPS13C meta5"
# [1] "checkingrs2251086 VPS13C meta5"
# [1] "checkingrs10797576 NTPCR meta5"
# [1] "checkingrs10797576 NTPCR meta5"
# [1] "checkingrs10797576 NTPCR meta5"
# [1] "checkingrs10797576 NTPCR meta5"
# [1] "checkingrs10797576 NTPCR meta5"
# [1] "checkingrs10797576 NTPCR meta5"
# [1] "checkingrs10797576 NTPCR meta5"
# [1] "checkingrs10797576 PCNX2 meta5"
# [1] "checkingrs6497339 ARL6IP1 meta5"
# [1] "checkingrs6497339 CCP110 meta5"
# [1] "checkingrs6497339 CCP110 meta5"
# [1] "checkingrs6497339 GDE1 meta5"
# [1] "checkingrs6497339 GDE1 meta5"
# [1] "checkingrs6497339 GPRC5B meta5"
# [1] "checkingrs6497339 RPS15A meta5"
# [1] "checkingrs6497339 RPS15A meta5"
# [1] "checkingrs2904880 EIF3C meta5"
# [1] "checkingrs2904880 EIF3C meta5"
# [1] "checkingrs2904880 EIF3C meta5"
# [1] "checkingrs2904880 TUFM meta5"
# [1] "checkingrs2904880 TUFM meta5"
# [1] "checkingrs2904880 XPO6 meta5"
# [1] "checkingrs11150601 KAT8 meta5"
# [1] "checkingrs11150601 KAT8 meta5"
# [1] "checkingrs11150601 TMEM219 meta5"
# [1] "checkingrs11150601 TMEM219 meta5"
# [1] "checkingrs11150601 YPEL3 meta5"
# [1] "checkingrs11150601 YPEL3 meta5"
# [1] "checkingrs11150601 YPEL3 meta5"
# [1] "checkingrs6500328 BRD7 meta5"
# [1] "checkingrs6500328 BRD7 meta5"
# [1] "checkingrs6500328 BRD7 meta5"
# [1] "checkingrs3104783 AKTIP meta5"
# [1] "checkingrs3104783 AKTIP meta5"
# [1] "checkingrs3104783 AKTIP meta5"
# [1] "checkingrs3104783 RBL2 meta5"
# [1] "checkingrs3104783 RBL2 meta5"
# [1] "checkingrs3104783 RBL2 meta5"
# [1] "checkingrs3104783 RBL2 meta5"
# [1] "checkingrs3104783 RBL2 meta5"
# [1] "checkingrs3104783 RBL2 meta5"
# [1] "checkingrs10221156 AKTIP meta5"
# [1] "checkingrs10221156 AKTIP meta5"
# [1] "checkingrs10221156 AKTIP meta5"
# [1] "checkingrs10221156 FTO meta5"
# [1] "checkingrs10221156 FTO meta5"
# [1] "checkingrs10221156 FTO meta5"
# [1] "checkingrs10221156 RBL2 meta5"
# [1] "checkingrs10221156 RBL2 meta5"
# [1] "checkingrs10221156 RBL2 meta5"
# [1] "checkingrs10221156 RBL2 meta5"
# [1] "checkingrs10221156 RBL2 meta5"
# [1] "checkingrs10221156 RBL2 meta5"
# [1] "checkingrs12600861 ACADVL meta5"
# [1] "checkingrs12600861 ACADVL meta5"
# [1] "checkingrs12600861 ACADVL meta5"
# [1] "checkingrs12600861 ACADVL meta5"
# [1] "checkingrs12600861 ACADVL meta5"
# [1] "checkingrs12600861 CTDNEP1 meta5"
# [1] "checkingrs12600861 CTDNEP1 meta5"
# [1] "checkingrs12600861 CTDNEP1 meta5"
# [1] "checkingrs12600861 CTDNEP1 meta5"
# [1] "checkingrs12600861 EIF4A1 meta5"
# [1] "checkingrs12600861 EIF4A1 meta5"
# [1] "checkingrs12600861 EIF4A1 meta5"
# [1] "checkingrs12600861 GPS2 meta5"
# [1] "checkingrs12600861 MPDU1 meta5"
# [1] "checkingrs12600861 MPDU1 meta5"
# [1] "checkingrs12600861 NAA38 meta5"
# [1] "checkingrs12600861 NAA38 meta5"
# [1] "checkingrs12600861 NDEL1 meta5"
# [1] "checkingrs12600861 NDEL1 meta5"
# [1] "checkingrs12600861 RPL26 meta5"
# [1] "checkingrs12600861 RPL26 meta5"
# [1] "checkingrs12600861 SAT2 meta5"
# [1] "checkingrs12600861 SAT2 meta5"
# [1] "checkingrs12600861 SAT2 meta5"
# [1] "checkingrs12600861 SAT2 meta5"
# [1] "checkingrs12600861 SAT2 meta5"
# [1] "checkingrs12600861 SAT2 meta5"
# [1] "checkingrs12600861 SAT2 meta5"
# [1] "checkingrs12600861 SAT2 meta5"
# [1] "checkingrs12600861 SAT2 meta5"
# [1] "checkingrs12600861 SAT2 meta5"
# [1] "checkingrs12600861 SAT2 meta5"
# [1] "checkingrs12600861 VAMP2 meta5"
# [1] "checkingrs12951632 ACLY meta5"
# [1] "checkingrs12951632 ATP6V0A1 meta5"
# [1] "checkingrs12951632 ATP6V0A1 meta5"
# [1] "checkingrs12951632 ATP6V0A1 meta5"
# [1] "checkingrs12951632 BECN1 meta5"
# [1] "checkingrs12951632 CNP meta5"
# [1] "checkingrs12951632 DNAJC7 meta5"
# [1] "checkingrs12951632 DNAJC7 meta5"
# [1] "checkingrs12951632 EIF1 meta5"
# [1] "checkingrs12951632 EIF1 meta5"
# [1] "checkingrs12951632 EIF1 meta5"
# [1] "checkingrs12951632 EZH1 meta5"
# [1] "checkingrs12951632 EZH1 meta5"
# [1] "checkingrs12951632 EZH1 meta5"
# [1] "checkingrs12951632 EZH1 meta5"
# [1] "checkingrs12951632 NBR1 meta5"
# [1] "checkingrs12951632 NT5C3B meta5"
# [1] "checkingrs12951632 NT5C3B meta5"
# [1] "checkingrs12951632 NT5C3B meta5"
# [1] "checkingrs12951632 RAB5C meta5"
# [1] "checkingrs2269906 EFTUD2 meta5"
# [1] "checkingrs850738 EFTUD2 meta5"
# [1] "checkingrs2269906 GFAP meta5"
# [1] "checkingrs2269906 GFAP meta5"
# [1] "checkingrs2269906 GFAP meta5"
# [1] "checkingrs850738 GFAP meta5"
# [1] "checkingrs850738 GFAP meta5"
# [1] "checkingrs850738 GFAP meta5"
# [1] "checkingrs2269906 NBR1 meta5"
# [1] "checkingrs850738 NBR1 meta5"
# [1] "checkingrs2269906 RUNDC3A meta5"
# [1] "checkingrs2269906 RUNDC3A meta5"
# [1] "checkingrs2269906 RUNDC3A meta5"
# [1] "checkingrs850738 RUNDC3A meta5"
# [1] "checkingrs850738 RUNDC3A meta5"
# [1] "checkingrs850738 RUNDC3A meta5"
# [1] "checkingrs2269906 UBTF meta5"
# [1] "checkingrs2269906 UBTF meta5"
# [1] "checkingrs850738 UBTF meta5"
# [1] "checkingrs850738 UBTF meta5"
# [1] "checkingrs117615688 EFTUD2 meta5"
# [1] "checkingrs62053943 EFTUD2 meta5"
# [1] "checkingrs117615688 GFAP meta5"
# [1] "checkingrs117615688 GFAP meta5"
# [1] "checkingrs117615688 GFAP meta5"
# [1] "checkingrs62053943 GFAP meta5"
# [1] "checkingrs62053943 GFAP meta5"
# [1] "checkingrs62053943 GFAP meta5"
# [1] "checkingrs117615688 KANSL1 meta5"
# [1] "checkingrs117615688 KANSL1 meta5"
# [1] "checkingrs117615688 KANSL1 meta5"
# [1] "checkingrs117615688 KANSL1 meta5"
# [1] "checkingrs117615688 KANSL1 meta5"
# [1] "checkingrs117615688 KANSL1 meta5"
# [1] "checkingrs117615688 KANSL1 meta5"
# [1] "checkingrs117615688 KANSL1 meta5"
# [1] "checkingrs117615688 KANSL1 meta5"
# [1] "checkingrs62053943 KANSL1 meta5"
# [1] "checkingrs62053943 KANSL1 meta5"
# [1] "checkingrs62053943 KANSL1 meta5"
# [1] "checkingrs62053943 KANSL1 meta5"
# [1] "checkingrs62053943 KANSL1 meta5"
# [1] "checkingrs62053943 KANSL1 meta5"
# [1] "checkingrs62053943 KANSL1 meta5"
# [1] "checkingrs62053943 KANSL1 meta5"
# [1] "checkingrs62053943 KANSL1 meta5"
# [1] "checkingrs117615688 MAPT meta5"
# [1] "checkingrs117615688 MAPT meta5"
# [1] "checkingrs117615688 MAPT meta5"
# [1] "checkingrs117615688 MAPT meta5"
# [1] "checkingrs117615688 MAPT meta5"
# [1] "checkingrs117615688 MAPT meta5"
# [1] "checkingrs117615688 MAPT meta5"
# [1] "checkingrs117615688 MAPT meta5"
# [1] "checkingrs117615688 MAPT meta5"
# [1] "checkingrs117615688 MAPT meta5"
# [1] "checkingrs62053943 MAPT meta5"
# [1] "checkingrs62053943 MAPT meta5"
# [1] "checkingrs62053943 MAPT meta5"
# [1] "checkingrs62053943 MAPT meta5"
# [1] "checkingrs62053943 MAPT meta5"
# [1] "checkingrs62053943 MAPT meta5"
# [1] "checkingrs62053943 MAPT meta5"
# [1] "checkingrs62053943 MAPT meta5"
# [1] "checkingrs62053943 MAPT meta5"
# [1] "checkingrs62053943 MAPT meta5"
# [1] "checkingrs117615688 NSF meta5"
# [1] "checkingrs62053943 NSF meta5"
# [1] "checkingrs76116224 VSNL1 meta5"
# [1] "checkingrs76116224 VSNL1 meta5"
# [1] "checkingrs76116224 VSNL1 meta5"
# [1] "checkingrs11658976 CDC27 meta5"
# [1] "checkingrs11658976 CDC27 meta5"
# [1] "checkingrs11658976 CDC27 meta5"
# [1] "checkingrs11658976 GOSR2 meta5"
# [1] "checkingrs11658976 GOSR2 meta5"
# [1] "checkingrs11658976 GOSR2 meta5"
# [1] "checkingrs11658976 GOSR2 meta5"
# [1] "checkingrs11658976 GOSR2 meta5"
# [1] "checkingrs11658976 KANSL1 meta5"
# [1] "checkingrs11658976 KANSL1 meta5"
# [1] "checkingrs11658976 KANSL1 meta5"
# [1] "checkingrs11658976 KANSL1 meta5"
# [1] "checkingrs11658976 KANSL1 meta5"
# [1] "checkingrs11658976 KANSL1 meta5"
# [1] "checkingrs11658976 KANSL1 meta5"
# [1] "checkingrs11658976 KANSL1 meta5"
# [1] "checkingrs11658976 KANSL1 meta5"
# [1] "checkingrs11658976 KPNB1 meta5"
# [1] "checkingrs11658976 KPNB1 meta5"
# [1] "checkingrs11658976 KPNB1 meta5"
# [1] "checkingrs11658976 KPNB1 meta5"
# [1] "checkingrs11658976 MAPT meta5"
# [1] "checkingrs11658976 MAPT meta5"
# [1] "checkingrs11658976 MAPT meta5"
# [1] "checkingrs11658976 MAPT meta5"
# [1] "checkingrs11658976 MAPT meta5"
# [1] "checkingrs11658976 MAPT meta5"
# [1] "checkingrs11658976 MAPT meta5"
# [1] "checkingrs11658976 MAPT meta5"
# [1] "checkingrs11658976 MAPT meta5"
# [1] "checkingrs11658976 MAPT meta5"
# [1] "checkingrs11658976 NPEPPS meta5"
# [1] "checkingrs11658976 NPEPPS meta5"
# [1] "checkingrs11658976 NPEPPS meta5"
# [1] "checkingrs11658976 NPEPPS meta5"
# [1] "checkingrs11658976 NPEPPS meta5"
# [1] "checkingrs11658976 NSF meta5"
# [1] "checkingrs61169879 BCAS3 meta5"
# [1] "checkingrs61169879 BCAS3 meta5"
# [1] "checkingrs666463 AFMID meta5"
# [1] "checkingrs666463 AFMID meta5"
# [1] "checkingrs666463 CYTH1 meta5"
# [1] "checkingrs666463 CYTH1 meta5"
# [1] "checkingrs666463 TIMP2 meta5"
# [1] "checkingrs1941685 DTNA meta5"
# [1] "checkingrs1941685 DTNA meta5"
# [1] "checkingrs1941685 DTNA meta5"
# [1] "checkingrs1941685 DTNA meta5"
# [1] "checkingrs1941685 DTNA meta5"
# [1] "checkingrs1941685 DTNA meta5"
# [1] "checkingrs1941685 DTNA meta5"
# [1] "checkingrs1941685 DTNA meta5"
# [1] "checkingrs1941685 DTNA meta5"
# [1] "checkingrs1941685 DTNA meta5"
# [1] "checkingrs1941685 DTNA meta5"
# [1] "checkingrs1941685 DTNA meta5"
# [1] "checkingrs1941685 DTNA meta5"
# [1] "checkingrs1941685 DTNA meta5"
# [1] "checkingrs1941685 DTNA meta5"
# [1] "checkingrs1941685 DTNA meta5"
# [1] "checkingrs8087969 MBD1 meta5"
# [1] "checkingrs8087969 ME2 meta5"
# [1] "checkingrs8087969 ME2 meta5"
# [1] "checkingrs8087969 SMAD4 meta5"
# [1] "checkingrs55818311 AP3D1 meta5"
# [1] "checkingrs55818311 AP3D1 meta5"
# [1] "checkingrs55818311 OAZ1 meta5"
# [1] "checkingrs55818311 THOP1 meta5"
# [1] "checkingrs77351827 CDS2 meta5"
# [1] "checkingrs77351827 CDS2 meta5"
# [1] "checkingrs77351827 TMEM230 meta5"
# [1] "checkingrs77351827 TMEM230 meta5"
# [1] "checkingrs77351827 TMEM230 meta5"
# [1] "checkingrs2248244 TTC3 meta5"
# [1] "checkingrs2248244 TTC3 meta5"
# [1] "checkingrs2248244 TTC3 meta5"
# [1] "checkingrs2248244 TTC3 meta5"
# [1] "checkingrs2248244 TTC3 meta5"
# [1] "checkingrs2248244 TTC3 meta5"
# [1] "checkingrs2248244 TTC3 meta5"
# [1] "checkingrs2248244 TTC3 meta5"
# [1] "checkingrs2248244 TTC3 meta5"
# [1] "checkingrs2248244 TTC3 meta5"
# [1] "checkingrs2248244 TTC3 meta5"
# [1] "checkingrs2248244 TTC3 meta5"
# [1] "checkingrs2248244 TTC3 meta5"
# [1] "checkingrs2248244 TTC3 meta5"
# [1] "checkingrs2248244 TTC3 meta5"
# [1] "checkingrs2248244 TTC3 meta5"
# [1] "checkingrs2042477 CIAO1 meta5"
# [1] "checkingrs2042477 MRPS5 meta5"
# [1] "checkingrs2042477 STARD7 meta5"
# [1] "checkingrs11683001 MAP4K4 meta5"
# [1] "checkingrs11683001 MAP4K4 meta5"
# [1] "checkingrs11683001 MAP4K4 meta5"
# [1] "checkingrs11683001 RNF149 meta5"
# [1] "checkingrs11683001 RNF149 meta5"
# [1] "checkingrs11683001 RNF149 meta5"
# [1] "checkingrs11683001 RNF149 meta5"
# [1] "checkingrs11683001 RPL31 meta5"
# [1] "checkingrs11683001 RPL31 meta5"
# [1] "checkingrs61863020 BBIP1 prog1"
# [1] "checkingrs61863020 MXI1 prog1"
# [1] "checkingrs61863020 MXI1 prog1"
# [1] "checkingrs61863020 MXI1 prog1"
# [1] "checkingrs61863020 MXI1 prog1"
# [1] "checkingrs61863020 MXI1 prog1"
# [1] "checkingrs61863020 SHOC2 prog1"
# [1] "checkingrs382940 NIPSNAP3A prog2"
# [1] "checkingrs382940 NIPSNAP3A prog2"
# [1] "checkingrs382940 SLC44A1 prog2"
# [1] "checkingrs382940 SLC44A1 prog2"

# %%
dim(plots_with_proxy_snp)
head(plots_with_proxy_snp)

write.csv(plots_with_proxy_snp,file="$PATH1/qtl/psychencode/isoqtl_plots_with_proxy_snp.csv",row.names=F,col.names=F)
# Out:
#   File "<ipython-input-4-7903972fbf95>", line 4
#     write.csv(plots_with_proxy_snp,file="$PATH1/qtl/psychencode/isoqtl_plots_with_proxy_snp.csv",row.names=F,col.names=F)
#                                                                                                 ^
# SyntaxError: keyword can't be an expression

# %%
dim(plots_with_no_proxy_snp)
head(plots_with_no_proxy_snp)

write.csv(plots_with_no_proxy_snp,file="$PATH1/qtl/psychencode/isoqtl_plots_with_no_proxy_snp.csv",row.names=F,col.names=F)
# Out:
#   File "<ipython-input-5-856c209aa6e5>", line 4
#     write.csv(plots_with_no_proxy_snp,file="$PATH1/qtl/psychencode/isoqtl_plots_with_no_proxy_snp.csv",row.names=F,col.names=F)
#                                                                                                       ^
# SyntaxError: keyword can't be an expression

# %% [markdown]
# make the final plot list file

# %%
plots_with_risk_snp <- fread("$PATH1/qtl/psychencode/isoqtl_plots_with_risk_snp.csv")
plots_with_risk_snp$'num_snps' <- NA

plots_to_plot <- rbind(plots_with_risk_snp, plots_with_proxy_snp)


write.csv(plots_to_plot,file="$PATH1/qtl/psychencode/isoqtl_plots_to_plot.csv",row.names=F,col.names=F)
# Out:
#   File "<ipython-input-7-3258b8dc225e>", line 2
#     plots_with_risk_snp$'num_snps' <- NA
#                        ^
# SyntaxError: invalid syntax

# %% [markdown]
# finally summary table for all the plots

# %%
plots_to_plot <- plots_to_plot[, -c('num_snps')]
plots_with_no_proxy_snp <- plots_with_no_proxy_snp[, -c('num_snps')]

final_summary <- rbind(plots_to_plot,plots_with_no_proxy_snp, plots_with_no_data)
dim(final_summary)
head(final_summary)
write.csv(final_summary,file="$PATH1/qtl/psychencode/isoqtl_plots_final_overview.csv",row.names=F,col.names=F)
# Out:
#   File "<ipython-input-8-d9b18e444230>", line 1
#     plots_to_plot <- plots_to_plot[, -c('num_snps')]
#                                    ^
# SyntaxError: invalid syntax
